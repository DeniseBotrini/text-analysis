# %% [markdown]
# # Most frequent words

# %%
#Import libraries
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter
import string
import nltk
import spacy

# %%
#!python -m spacy download it_core_news_sm #ITALIAN POS TAGGING

# %%
#Import the dataset
df = pd.read_csv("transcriptions.csv") #transcriptions
df1=pd.read_csv("all_commercials_classified_filtered.csv") # Nice_categories

# %%
#Join the two datasets
df_total=pd.concat([df.set_index('commercial_id'),df1.set_index('commercial_id')], axis=1, join='inner') #Join on commercial_id
#Keep only the transcription with log_prob >=-0.5
df_total=df_total.loc[df_total['log_prob']>=-0.5]

#Remove all the Nan values of nice_class, they are marked by -1
df_total=df_total.loc[df_total['nice_class']>-1]

#Select only the columns of interest: transcriptions (of the descriptions) and nice_class
df_total.drop('title', axis=1, inplace=True)
df_total.drop('log_prob', axis=1, inplace=True)

# %%
#Remove the punctuation from the transcriptions
def remove_punctuation(text):
    if pd.isna(text):
        return text
    punctuationfree="".join([i for i in str(text) if i not in string.punctuation])
    return punctuationfree

df_total['transcription'] = df_total['transcription'].apply(remove_punctuation)

# %%
nlp = spacy.load("it_core_news_sm")
def lemmatize(testo):
    doc = nlp(testo)
    lemmi = [token.lemma_ for token in doc]
    return " ".join(lemmi)
df_total['transcription']=df_total['transcription'].apply(lemmatize)

# %%
#Apply the lower method to strings

df_total['transcription'] = df_total['transcription'].apply(lambda s: s.lower() if type(s) == str else s)

#Remove the stopwords
stopwords = stopwords.words('italian')
stopwords_plus=['cè', 'così', 'oh', 'eh', 'sì', 'to', 'po', 'già', 'mai', 'no', 'ce', 'ah', 'allora', 'me', 'doro']
for element in stopwords_plus:
    stopwords.append(element)
df_total['transcription'] = df_total['transcription'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stopwords)]))

# %%
#Grouping all by nice_class and lustrum
dictionary = {}
for i, g in df_total.groupby(['nice_class', 'lustrum']):
    if i not in dictionary:
        dictionary[i] = g['transcription'].tolist()  
    else:
        dictionary[i].extend(g['transcription'].tolist())

# %%
#Transform the value lists into strings

for key, value in dictionary.items():
    dictionary[key] = ' '.join(value)
    
dictionary[28.0, '1980_1984'] #example
# Out:
# 'ehi moto chicco acceleratore raglio specchietto classo cambio perfetto lg corda ora senza bisogno motore brillantina essere pallina parente allina brillantina comodino pallina nome essere brillantina brillantina rimbalzina coloratissimo brillantissimo essere pallina divertitevi brillantina rimbalzina pallina super rimbalzare ogni altro pallina brillantina rimbalzina adesiva personalizzante essere unesclusivo linea g occhio grande grande capello biondi biondi essere candy candy candy candy candy candy candy candy essere fare quattro essere candy candy saltaragno nuovo gioco emozionante attenzione ragno essere cattivo potere salvare animaletto catturare ragno toccare ragnatela voglio provare anchio paurare adesso provo attenzione aiuto emozionante divertente saltaragno nuovo gioco editore giochi bravo bravo tanto bravo prere formelli brillo novello inuntro listantire cogli luntro piatti ora brillare sennuore bravo essere qua essere grande qualità bento core coltello cagliote gamia laszello lecetto cromato metallo essere bello vedere brillare sennuore bravo essere qua essere grande qualità bravo bravo limone bravo bravo bravo paglietta saponare brillare limone pium bavare giù dappertutto cerano fantasmine inseguivare essere videogioco super certo essere atari cambiare cassetta cambiare gioco colpire davvero attaccare tv punto fare voglia giocare mettare avere chiudere videogioco atari essere facile volere difficile fare fantastico sperare comprino atari magari prova atari niente divertire wow atari attento chiudere cancello scappare gallina caccentare essere venere multare gallina attraversare solo frisso eroe essere playmobil super stunt moto harbert moto bribido rombono motore iniziare competizione velocità incredibile salta volare acrobato potere sistemare pilota super stunt moto volere gareggere gomito gomito rivale funziona senza batteria super stunt moto essere vero acrobata potere fare langelo sfondare muro restare sempre equilibrio super stunt moto essere altro fantastico giocattolo harbert linea sport grazie visione vieni vieni vicino vienare qui bambola bello camilla camilla piccolo nehi te vieni vienare mondo viaggare domani camilla viaggare te bambola passaporto mammino cullame eccomi bambino racconterò storia mimmino piettere disparare bosco incantato corrivo locchilare nellorecchio mimmino cippare sussurro fiore mare solo mimmino due tre essere felice re volere tanto bene mimmino ascoltare sussurrare parolina dolce smettare piangere lunga lungo gioco casa barbie splendida grande arricchita ambiente raffinato accogliere barbie amico eccolo arrivare allegro simpatico barbie ora cucina affrettare preparare pranzo benvenuto amico venire accogliere salotto aperitivo finalmente sala pranzo dopo piscina casa barbie mondo diversimento ciochi baby cioco mattel finalmente oso gelati gelati essere gelatario deserto camello piacere molto gelato eroe essere playmobil possenti ricco tecnologia forgiare componente apeniristico ecco dinosauro robot trasformer nascita mito creati computer perfetto trasformazione invincibile robot quattro esemplare diverso bello appassionante prestigioso dinosauro robot trasformer lultimo generazione serie trasformer linea gig mattel presentare masters dominatore delluniverso castello tessio grigio essere intratto lha strato resisti venetaro brucare uomo uccello vissme aspetta tila spalla vale dire zodac aiuto dire potere vincere meno bene vincere mattel gioco avventuroso delluniverso oggi avere fare buono pesta ehi andare esplorare lisola scentrare volere fare lhanno sbagliare larca noe eroe essere playmobil ragazzi guardato caccia formaggio harbert abilità topino portare tano maggiore numero dade formaggio vincere essere abile nuovo pepo cosa avere diverso pepo essere diverso guardare bene metto chiotto vedere cosa avvenire cosa avvenire vieno pepo sfidare grande affare tane braccio volere abbracciare poi eeeeh poi pepo essere feludo fare mezzo vero fare predo presto nuovo pepo muovere ritagliare  ...

# %%
#Tokenization and PoS tagging

# %%
nlp = spacy.load("it_core_news_sm")

def pos_tag_italian(text):
    # Tokenize and POS tag the text using SpaCy
    doc = nlp(text)
    # Create a list of tuples with tokens and their corresponding POS tags
    pos_tags = [(token.text, token.pos_) for token in doc]
    return pos_tags

# %%
spots_words = dict()
for key in dictionary:
    spots_words[key] = pos_tag_italian(dictionary[key])
    
spots_words[28.0, '1980_1984'] #example
# Out:
# [('ehi', 'PROPN'),
#  ('moto', 'PROPN'),
#  ('chicco', 'ADJ'),
#  ('acceleratore', 'NOUN'),
#  ('raglio', 'ADJ'),
#  ('specchietto', 'VERB'),
#  ('classo', 'ADJ'),
#  ('cambio', 'NOUN'),
#  ('perfetto', 'ADJ'),
#  ('lg', 'PROPN'),
#  ('corda', 'VERB'),
#  ('ora', 'ADV'),
#  ('senza', 'ADP'),
#  ('bisogno', 'NOUN'),
#  ('motore', 'NOUN'),
#  ('brillantina', 'ADJ'),
#  ('essere', 'AUX'),
#  ('pallina', 'VERB'),
#  ('parente', 'PROPN'),
#  ('allina', 'ADJ'),
#  ('brillantina', 'PROPN'),
#  ('comodino', 'PROPN'),
#  ('pallina', 'PROPN'),
#  ('nome', 'NOUN'),
#  ('essere', 'AUX'),
#  ('brillantina', 'PROPN'),
#  ('brillantina', 'PROPN'),
#  ('rimbalzina', 'NOUN'),
#  ('coloratissimo', 'ADJ'),
#  ('brillantissimo', 'VERB'),
#  ('essere', 'AUX'),
#  ('pallina', 'VERB'),
#  ('divertitevi', 'NOUN'),
#  ('brillantina', 'ADJ'),
#  ('rimbalzina', 'NOUN'),
#  ('pallina', 'VERB'),
#  ('super', 'ADJ'),
#  ('rimbalzare', 'VERB'),
#  ('ogni', 'DET'),
#  ('altro', 'ADJ'),
#  ('pallina', 'NOUN'),
#  ('brillantina', 'ADJ'),
#  ('rimbalzina', 'NOUN'),
#  ('adesiva', 'ADJ'),
#  ('personalizzante', 'ADV'),
#  ('essere', 'AUX'),
#  ('unesclusivo', 'ADJ'),
#  ('linea', 'NOUN'),
#  ('g', 'CCONJ'),
#  ('occhio', 'NOUN'),
#  ('grande', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('capello', 'NOUN'),
#  ('biondi', 'NOUN'),
#  ('biondi', 'PROPN'),
#  ('essere', 'AUX'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('essere', 'AUX'),
#  ('fare', 'VERB'),
#  ('quattro', 'NUM'),
#  ('essere', 'AUX'),
#  ('candy', 'PROPN'),
#  ('candy', 'PROPN'),
#  ('saltaragno', 'NOUN'),
#  ('nuovo', 'ADJ'),
#  ('gioco', 'NOUN'),
#  ('emozionante', 'ADJ'),
#  ('attenzione', 'NOUN'),
#  ('ragno', 'ADJ'),
#  ('essere', 'AUX'),
#  ('cattivo', 'ADJ'),
#  ('potere', 'NOUN'),
#  ('salvare', 'VERB'),
#  ('animaletto', 'AUX'),
#  ('catturare', 'VERB'),
#  ('ragno', 'ADJ'),
#  ('toccare', 'VERB'),
#  ('ragnatela', 'NOUN'),
#  ('voglio', 'AUX'),
#  ('provare', 'VERB'),
#  ('anchio', 'NOUN'),
#  ('paurare', 'VERB'),
#  ('adesso', 'ADV'),
#  ('provo', 'ADJ'),
#  ('attenzione', 'NOUN'),
#  ('aiuto', 'NOUN'),
#  ('emozionante', 'ADV'),
#  ('divertente', 'ADJ'),
#  ('saltaragno', 'NOUN'),
#  ('nuovo', 'ADJ'),
#  ('gioco', 'NOUN'),
#  ('editore', 'NOUN'),
#  ('giochi', 'NOUN'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'VERB'),
#  ('tanto', 'ADV'),
#  ('bravo', 'ADJ'),
#  ('prere', 'VERB'),
#  ('formelli', 'NOUN'),
#  ('brillo', 'ADJ'),
#  ('novello', 'ADP'),
#  ('inuntro', 'ADJ'),
#  ('listantire', 'VERB'),
#  ('cogli', 'DET'),
#  ('luntro', 'NOUN'),
#  ('piatti', 'ADJ'),
#  ('ora', 'ADV'),
#  ('brillare', 'VERB'),
#  ('sennuore', 'NOUN'),
#  ('bravo', 'ADJ'),
#  ('essere', 'AUX'),
#  ('qua', 'ADV'),
#  ('essere', 'AUX'),
#  ('grande', 'ADJ'),
#  ('qualità', 'NOUN'),
#  ('bento', 'NOUN'),
#  ('core', 'ADJ'),
#  ('coltello', 'PROPN'),
#  ('cagliote', 'NOUN'),
#  ('gamia', 'NOUN'),
#  ('laszello', 'NOUN'),
#  ('lecetto', 'ADJ'),
#  ('cromato', 'ADJ'),
#  ('metallo', 'ADJ'),
#  ('essere', 'AUX'),
#  ('bello', 'ADJ'),
#  ('vedere', 'VERB'),
#  ('brillare', 'VERB'),
#  ('sennuore', 'NOUN'),
#  ('bravo', 'ADJ'),
#  ('essere', 'AUX'),
#  ('qua', 'ADV'),
#  ('essere', 'AUX'),
#  ('grande', 'ADJ'),
#  ('qualità', 'NOUN'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('limone', 'NOUN'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('paglietta', 'NOUN'),
#  ('saponare', 'VERB'),
#  ('brillare', 'VERB'),
#  ('limone', 'NOUN'),
#  ('pium', 'PROPN'),
#  ('bavare', 'VERB'),
#  ('giù', 'ADV'),
#  ('dappertutto', 'ADV'),
#  ('cerano', 'VERB'),
#  ('fantasmine', 'ADV'),
#  ('inseguivare', 'VERB'),
#  ('essere', 'AUX'),
#  ('videogioco', 'VERB'),
#  ('super', 'ADJ'),
#  ('certo', 'ADV'),
#  ('essere', 'AUX'),
#  ('atari', 'ADV'),
#  ('cambiare', 'VERB'),
#  ('cassetta', 'NOUN'),
#  ('cambiare', 'VERB'),
#  ('gioco', 'NOUN'),
#  ('colpire', 'VERB'),
#  ('davvero', 'ADV'),
#  ('attaccare', 'VERB'),
#  ('tv', 'NOUN'),
#  ('punto', 'NOUN'),
#  ('fare', 'VERB'),
#  ('voglia', 'AUX'),
#  ('giocare', 'VERB'),
#  ('mettare', 'VERB'),
#  ('avere', 'VERB'),
#  ('chiudere', 'VERB'),
#  ('videogioco', 'ADJ'),
#  ('atari', 'NOUN'),
#  ('essere', 'AUX'),
#  ('facile', 'ADJ'),
#  ('volere', 'VERB'),
#  ('difficile', 'ADJ'),
#  ('fare', 'VERB'),
#  ('fantastico', 'ADJ'),
#  ('sperare', 'VERB'),
#  ('comprino', 'VERB'),
#  ('atari', 'ADV'),
#  ('magari', 'ADV'),
#  ('prova', 'VERB'),
#  ('atari', 'ADV'),
#  ('niente', 'PRON'),
#  ('divertire', 'VERB'),
#  ('wow', 'NOUN'),
#  ('atari', 'ADJ'),
#  ('attento', 'ADJ'),
#  ('chiudere', 'VERB'),
#  ('cancello', 'NOUN'),
#  ('scappare', 'ADJ'),
#  ('gallina', 'PROPN'),
#  ('caccentare', 'VERB'),
#  ('essere', 'AUX'),
#  ('venere', 'VERB'),
#  ('multare', 'VERB'),
#  ('gallina', 'ADJ'),
#  ('attraversare', 'VERB'),
#  ('solo', 'ADV'),
#  ('frisso', 'ADJ'),
#  ('eroe', 'NOUN'),
#  ('essere', 'AUX'),
#  ('playmobil', 'VERB'),
#  ('super', 'ADJ'),
#  ('stunt', 'NOUN'),
#  ('moto', 'PROPN'),
#  ('harbert', 'PROPN'),
#  ('moto', 'PROPN'),
#  ('bribido', 'ADJ'),
#  ('rombono', 'VERB'),
#  ('motore', 'NOUN'),
#  ('iniziare', 'VERB'),
#  ('competizione', 'NOUN'),
#  ('velocità', 'NOUN'),
#  ('incredibile', 'ADJ'),
#  ('salta', 'AUX'),
#  ('volare', 'VERB'),
#  ('acrobato', 'VERB'),
#  ('potere', 'NOUN'),
#  ('sistemare', 'VERB'),
#  ('pilota', 'NOUN'),
#  ('super', 'ADJ'),
#  ('stunt', 'NOUN'),
#  ('moto', 'ADJ'),
#  ('volere', 'VERB'),
#  ('gareggere', 'VERB'),
#  ('gomito', 'ADJ'),
#  ('gomito', 'NOUN'),
#  ('rivale', 'ADJ'),
#  ('funziona', 'VERB'),
#  ('senza', 'ADP'),
#  ('batteria', 'NOUN'),
#  ('super', 'ADJ'),
#  ('stunt', 'NOUN'),
#  ('moto', 'ADJ'),
#  ('essere', 'AUX'),
#  ('vero', 'ADJ'),
#  ('acrobata', 'VERB'),
#  ('potere', 'NOUN'),
#  ('fare', 'VERB'),
#  ('langelo', 'ADJ'),
#  ('sfondare', 'VERB'),
#  ('muro', 'NOUN'),
#  ('restare', 'VERB'),
#  ('sempre', 'ADV'),
#  ('equilibrio', 'NOUN'),
#  ('super', 'ADJ'),
#  ('stunt', 'NOUN'),
#  ('moto', 'ADJ'),
#  ('essere', 'AUX'),
#  ('altro', 'ADJ'),
#  ('fantastico', 'ADJ'),
#  ('giocattolo', 'ADJ'),
#  ('harbert', 'NOUN'),
#  ('linea', 'NOUN'),
#  ('sport', 'NOUN'),
#  ('grazie', 'NOUN'),
#  ('visione', 'NOUN'),
#  ('vieni', 'PROPN'),
#  ('vieni', 'VERB'),
#  ('vicino', 'ADV'),
#  ('vienare', 'VERB'),
#  ('qui', 'ADV'),
#  ('bambola', 'NOUN'),
#  ('bello', 'ADJ'),
#  ('camilla', 'ADP'),
#  ('camilla', 'NOUN'),
#  ('piccolo', 'ADJ'),
#  ('nehi', 'PROPN'),
#  ('te', 'PRON'),
#  ('vieni', 'AUX'),
#  ('vienare', 'VERB'),
#  ('mondo', 'NOUN'),
#  ('viaggare', 'VERB'),
#  ('domani', 'ADV'),
#  ('camilla', 'NOUN'),
#  ('viaggare', 'VERB'),
#  ('te', 'PRON'),
#  ('bambola', 'VERB'),
#  ('passaporto', 'ADJ'),
#  ('mammino', 'NOUN'),
#  ('cullame', 'NOUN'),
#  ('eccomi', 'PROPN'),
#  ('bambino', 'NOUN'),
#  ('racconterò', 'VERB'),
#  ('storia', 'NOUN'),
#  ('mimmino', 'VERB'),
#  ('piettere', 'VERB'),
#  ('disparare', 'VERB'),
#  ('bosco', 'PROPN'),
#  ('incantato', 'NOUN'),
#  ('corrivo', 'ADJ'),
#  ('locchilare', 'VERB'),
#  ('nellorecchio', 'NOUN'),
#  ('mimmino', 'NOUN'),
#  ('cippare', 'VERB'),
#  ('sussurro', 'ADJ'),
#  ('fiore', 'ADJ'),
#  ('mare', 'NOUN'),
#  ('solo', 'ADV'),
#  ('mimmino', 'VERB'),
#  ('due', 'NUM'),
#  ('tre', 'NUM'),
#  ('essere', 'AUX'),
#  ('felice', 'ADJ'),
#  ('re', 'NOUN'),
#  ('volere', 'VERB'),
#  ('tanto', 'ADV'),
#  ('bene', 'ADV'),
#  ('mimmino', 'NOUN'),
#  ('ascoltare', 'VERB'),
#  ('sussurrare', 'VERB'),
#  ('parolina', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('smettare', 'VERB'),
#  ('piangere', 'VERB'),
#  ('lunga', 'ADJ'),
#  ('lungo', 'ADJ'),
#  ('gioco', 'NOUN'),
#  ('casa', 'NOUN'),
#  ('barbie', 'X'),
#  ('splendida', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('arricchita', 'VERB'),
#  ('ambiente', 'NOUN'),
#  ('raffinato', 'ADJ'),
#  ('accogliere', 'VERB'),
#  ('barbie', 'ADJ'),
#  ('amico', 'NOUN'),
#  ('eccolo', 'ADV'),
#  ('arrivare', 'VERB'),
#  ('allegro', 'ADJ'),
#  ('simpatico', 'ADJ'),
#  ('barbie', 'PROPN'),
#  ('ora', 'ADV'),
#  ('cucina', 'VERB'),
#  ('affrettare', 'VERB'),
#  ('preparare', 'VERB'),
#  ('pranzo', 'NOUN'),
#  ('benvenuto', 'ADJ'),
#  ('amico', 'ADJ'),
#  ('venire', 'VERB'),
#  ('accogliere', 'VERB'),
#  ('salotto', 'NOUN'),
#  ('aperitivo', 'ADJ'),
#  ('finalmente', 'ADV'),
#  ('sala', 'VERB'),
#  ('pranzo', 'ADV'),
#  ('dopo', 'ADP'),
#  ('piscina', 'NOUN'),
#  ('casa', 'VERB'),
#  ('barbie', 'X'),
#  ('mondo', 'PROPN'),
#  ('diversimento', 'VERB'),
#  ('ciochi', 'NOUN'),
#  ('baby', 'NOUN'),
#  ('cioco', 'NOUN'),
#  ('mattel', 'NOUN'),
#  ('finalmente', 'ADV'),
#  ('oso', 'ADJ'),
#  ('gelati', 'NOUN'),
#  ('gelati', 'ADJ'),
#  ('essere', 'AUX'),
#  ('gelatario', 'ADJ'),
#  ('deserto', 'ADJ'),
#  ('camello', 'VERB'),
#  ('piacere', 'NOUN'),
#  ('molto', 'ADV'),
#  ('gelato', 'ADJ'),
#  ('eroe', 'NOUN'),
#  ('essere', 'AUX'),
#  ('playmobil', 'PRON'),
#  ('possenti', 'ADJ'),
#  ('ricco', 'ADJ'),
#  ('tecnologia', 'NOUN'),
#  ('forgiare', 'VERB'),
#  ('componente', 'ADV'),
#  ('apeniristico', 'ADJ'),
#  ('ecco', 'ADV'),
#  ('dinosauro', 'ADJ'),
#  ('robot', 'NOUN'),
#  ('trasformer', 'VERB'),
#  ('nascita', 'NOUN'),
#  ('mito', 'ADJ'),
#  ('creati', 'VERB'),
#  ('computer', 'NOUN'),
#  ('perfetto', 'ADJ'),
#  ('trasformazione', 'NOUN'),
#  ('invincibile', 'ADJ'),
#  ('robot', 'NOUN'),
#  ('quattro', 'NUM'),
#  ('esemplare', 'VERB'),
#  ('diverso', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('appassionante', 'ADJ'),
#  ('prestigioso', 'ADJ'),
#  ('dinosauro', 'ADJ'),
#  ('robot', 'NOUN'),
#  ('trasformer', 'VERB'),
#  ('lultimo', 'ADJ'),
#  ('generazione', 'NOUN'),
#  ('serie', 'NOUN'),
#  ('trasformer', 'VERB'),
#  ('linea', 'NOUN'),
#  ('gig', 'ADP'),
#  ('mattel', 'NOUN'),
#  ('presentare', 'VERB'),
#  ('masters', 'NOUN'),
#  ('dominatore', 'NOUN'),
#  ('delluniverso', 'ADJ'),
#  ('castello', 'NOUN'),
#  ('tessio', 'NOUN'),
#  ('grigio', 'ADJ'),
#  ('essere', 'AUX'),
#  ('intratto', 'VERB'),
#  ('lha', 'DET'),
#  ('strato', 'NOUN'),
#  ('resisti', 'VERB'),
#  ('venetaro', 'ADJ'),
#  ('brucare', 'VERB'),
#  ('uomo', 'NOUN'),
#  ('uccello', 'NOUN'),
#  ('vissme', 'ADJ'),
#  ('aspetta', 'VERB'),
#  ('tila', 'NUM'),
#  ('spalla', 'NOUN'),
#  ('vale', 'AUX'),
#  ('dire', 'VERB'),
#  ('zodac', 'ADJ'),
#  ('aiuto', 'NOUN'),
#  ('dire', 'VERB'),
#  ('potere', 'NOUN'),
#  ('vincere', 'VERB'),
#  ('meno', 'ADV'),
#  ('bene', 'ADV'),
#  ('vincere', 'VERB'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('avventuroso', 'ADJ'),
#  ('delluniverso', 'VERB'),
#  ('oggi', 'ADV'),
#  ('avere', 'VERB'),
#  ('fare', 'VERB'),
#  ('buono', 'VERB'),
#  ('pesta', 'NOUN'),
#  ('ehi', 'PROPN'),
#  ('andare', 'VERB'),
#  ('esplorare', 'VERB'),
#  ('lisola', 'NOUN'),
#  ('scentrare', 'VERB'),
#  ('volere', 'VERB'),
#  ('fare', 'VERB'),
#  ('lhanno', 'NOUN'),
#  ('sbagliare', 'VERB'),
#  ('larca', 'NOUN'),
#  ('noe', 'ADV'),
#  ('eroe', 'NOUN'),
#  ('essere', 'AUX'),
#  ('playmobil', 'DET'),
#  ('ragazzi', 'NOUN'),
#  ('guardato', 'ADJ'),
#  ('caccia', 'VERB'),
#  ('formaggio', 'NOUN'),
#  ('harbert', 'PROPN'),
#  ('abilità', 'NOUN'),
#  ('topino', 'ADJ'),
#  ('portare', 'VERB'),
#  ('tano', 'NOUN'),
#  ('maggiore', 'ADJ'),
#  ('numero', 'NOUN'),
#  ('dade', 'VERB'),
#  ('formaggio', 'NOUN'),
#  ('vincere', 'VERB'),
#  ('essere', 'AUX'),
#  ('abile', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('pepo', 'VERB'),
#  ('cosa', 'NOUN'),
#  ('avere', 'VERB'),
#  ('diverso', 'ADJ'),
#  ('pepo', 'AUX'),
#  ('essere', 'AUX'),
#  ('diverso', 'ADJ'),
#  ('guardare', 'VERB'),
#  ('bene', 'ADV'),
#  ('metto', 'VERB'),
#  ('chiotto', 'ADJ'),
#  ('vedere', 'VERB'),
#  ('cosa', 'NOUN'),
#  ('avvenire', 'VERB'),
#  ('cosa', 'NOUN'),
#  ('avvenire', 'VERB'),
#  ('vieno', 'ADV'),
#  ('pepo', 'VERB'),
#  ('sfidare', 'VERB'),
#  ('grande', 'ADJ'),
#  ('affare', 'NOUN'),
#  ('tane', 'ADJ'),
#  ('braccio', 'NOUN'),
#  ('volere', 'VERB'),
#  ('abbracciare', 'VERB'),
#  ('poi', 'ADV'),
#  ('eeeeh', 'ADV'),
#  ('poi', 'ADV'),
#  ('pepo', 'AUX'),
#  ('essere', 'AUX'),
#  ('feludo', 'ADJ'),
#  ('fare', 'VERB'),
#  ('mezzo', 'NOUN'),
#  ('vero', 'ADJ'),
#  ('fare', 'VERB'),
#  ('predo', 'VERB'),
#  ('presto', 'ADV'),
#  ('nuovo', 'ADJ'),
#  ('pepo', 'AUX'),
#  ('muovere', 'VERB'),
#  ('ritagliare', 'VERB'),
#  ('succhiotto', 'ADV'),
#  ('piange', 'VERB'),
#  ('lha', 'PRON'),
#  ('portare', 'VERB'),
#  ('lì', 'ADV'),
#  ('gig', 'ADP'),
#  ('vedere', 'VERB'),
#  ('fare', 'VERB'),
#  ('rana', 'NOUN'),
#  ('senti', 'VERB'),
#  ('rana', 'ADJ'),
#  ('crac', 'NOUN'),
#  ('crac', 'NOUN'),
#  ('crac', 'NOUN'),
#  ('crac', 'NOUN'),
#  ('gallo', 'NOUN'),
#  ('dovè', 'ADJ'),
#  ('ecco', 'ADV'),
#  ('gallo', 'NOUN'),
#  ('fa', 'VERB'),
#  ('bastare', 'VERB'),
#  ('dammelo', 'SCONJ'),
#  ('essere', 'AUX'),
#  ('essere', 'AUX'),
#  ('dammela', 'VERB'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADV'),
#  ('mattel', 'PROPN'),
#  ('bambino', 'NOUN'),
#  ('giocare', 'VERB'),
#  ('imparare', 'VERB'),
#  ('subito', 'ADV'),
#  ('voce', 'NOUN'),
#  ('animale', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('sentire', 'VERB'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('sentire', 'VERB'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('sentire', 'VERB'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('sentire', 'VERB'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('mattel', 'PROPN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('dolce', 'ADJ'),
#  ('ragazzi', 'NOUN'),
#  ('guardato', 'VERB'),
#  ('squalo', 'NOUN'),
#  ('mangerelli', 'ADJ'),
#  ('harbert', 'AUX'),
#  ('continuo', 'VERB'),
#  ('suspense', 'VERB'),
#  ('intrepide', 'ADJ'),
#  ('cacciatore', 'PROPN'),
#  ('tesore', 'ADV'),
#  ('attento', 'ADJ'),
#  ('muovere', 'VERB'),
#  ('niente', 'PRON'),
#  ('paura', 'NOUN'),
#  ('pesca', 'VERB'),
#  ('continuare', 'VERB'),
#  ('attenta', 'DET'),
#  ('essere', 'AUX'),
#  ('catturare', 'VERB'),
#  ('squalo', 'NOUN'),
#  ('mangerelli', 'ADJ'),
#  ('harbert', 'AUX'),
#  ('essere', 'AUX'),
#  ('gioco', 'VERB'),
#  ('mozzafiato', 'ADJ'),
#  ('sapevo', 'VERB'),
#  ('barbie', 'VERB'),
#  ('piacere', 'NOUN'),
#  ('tanto', 'ADV'),
#  ('andare', 'VERB'),
#  ('moto', 'PROPN'),
#  ('avere', 'AUX'),
#  ('meraviglioso', 'ADJ'),
#  ('motorino', 'NOUN'),
#  ('rosa', 'ADJ'),
#  ('shockingre', 'PROPN'),
#  ('mette', 'VERB'),
#  ('casco', 'NOUN'),
#  ('fila', 'NOUN'),
#  ('libro', 'NOUN'),
#  ('portapacco', 'ADJ'),
#  ('barbie', 'ADJ'),
#  ('essere', 'AUX'),
#  ('libero', 'ADJ'),
#  ('andare', 'VERB'),
#  ('volere', 'VERB'),
#  ('gas', 'NOUN'),
#  ('barbie', 'X'),
#  ('bello', 'ADJ'),
#  ('essere', 'AUX'),
#  ('splendido', 'ADJ'),
#  ('trucco', 'NOUN'),
#  ('allultima', 'ADJ'),
#  ('moda', 'NOUN'),
#  ('lombretto', 'ADV'),
#  ('occhio', 'NOUN'),
#  ('colore', 'NOUN'),
#  ('guance', 'VERB'),
#  ('ornamento', 'NOUN'),
#  ('capello', 'ADJ'),
#  ('trovare', 'VERB'),
#  ('confezione', 'NOUN'),
#  ('barbie', 'ADJ'),
#  ('bellissima', 'ADJ'),
#  ('barbie', 'NOUN'),
#  ('essere', 'AUX'),
#  ('sempre', 'ADV'),
#  ('bello', 'ADJ'),
#  ('vieni', 'PROPN'),
#  ('vieni', 'VERB'),
#  ('vicino', 'ADV'),
#  ('vieni', 'VERB'),
#  ('qui', 'ADV'),
#  ('bambola', 'ADV'),
#  ('bello', 'ADJ'),
#  ('camilla', 'VERB'),
#  ('ora', 'NOUN'),
#  ('camilla', 'ADP'),
#  ('piccolina', 'NOUN'),
#  ('te', 'PRON'),
#  ('vieni', 'AUX'),
#  ('vienare', 'VERB'),
#  ('mondo', 'NOUN'),
#  ('viaggare', 'VERB'),
#  ('domani', 'ADV'),
#  ('camilla', 'NOUN'),
#  ('viaggare', 'VERB'),
#  ('te', 'PRON'),
#  ('essere', 'AUX'),
#  ('bambola', 'ADV'),
#  ('passaporto', 'ADJ'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('cut', 'VERB'),
#  ('play', 'X'),
#  ('pallone', 'NOUN'),
#  ('giovane', 'ADJ'),
#  ('campione', 'NOUN'),
#  ('unesclusivo', 'ADJ'),
#  ('mondo', 'NOUN'),
#  ('barbie', 'VERB'),
#  ('nuovo', 'ADJ'),
#  ('bagno', 'NOUN'),
#  ('termale', 'ADJ'),
#  ('mille', 'NUM'),
#  ('bollicine', 'NOUN'),
#  ('essere', 'AUX'),
#  ('fantastico', 'ADJ'),
#  ('bolla', 'NOUN'),
#  ('continuare', 'VERB'),
#  ('riprodure', 'NOUN'),
#  ('barbie', 'VERB'),
#  ('essere', 'AUX'),
#  ('entusiasta', 'ADJ'),
#  ('dopo', 'ADP'),
#  ('bagno', 'NOUN'),
#  ('termale', 'ADJ'),
#  ('eccola', 'NOUN'),
#  ('allistitere', 'VERB'),
#  ('bellezza', 'NOUN'),
#  ('unaccurata', 'VERB'),
#  ('mettere', 'VERB'),
#  ('piega', 'VERB'),
#  ('shampoo', 'NOUN'),
#  ('spumeggiante', 'ADJ'),
#  ('mere', 'NOUN'),
#  ('allultimo', 'ADJ'),
#  ('moda', 'NOUN'),
#  ('barbie', 'ADJ'),
#  ('essere', 'AUX'),
#  ('splendido', 'ADJ'),
#  ('ore', 'NOUN'),
#  ('meraviglioso', 'ADJ'),
#  ('bagno', 'NOUN'),
#  ('termale', 'ADJ'),
#  ('barbie', 'VERB'),
#  ('listitere', 'NOUN'),
#  ('bellezza', 'PROPN')]

# %%
#Print the top 10 words of every nice class and lustrum

vocabularies = dict()
for key in dictionary:
    vocabularies[key] = set(spots_words[key])

frequencies = dict()
for key in dictionary:
    frequencies[key] = Counter(spots_words[key])

top = 10
previous_key = None

for key in sorted(dictionary):
    if key != previous_key and previous_key is not None:
        print()
    previous_key = key
    words_top = sorted(frequencies[key].items(), key=lambda x: x[1], reverse=True)[:10]
    for word, frequency in words_top:
        print(key, word, frequency, sep='\t')
# Out:
# (1.0, '1980_1984')	('essere', 'AUX')	3
# (1.0, '1980_1984')	('chimeral', 'PROPN')	2
# (1.0, '1980_1984')	('oggi', 'ADV')	1
# (1.0, '1980_1984')	('sabato', 'NOUN')	1
# (1.0, '1980_1984')	('finalmente', 'ADV')	1
# (1.0, '1980_1984')	('giorno', 'NOUN')	1
# (1.0, '1980_1984')	('substral', 'ADJ')	1
# (1.0, '1980_1984')	('wow', 'PROPN')	1
# (1.0, '1980_1984')	('substral', 'PROPN')	1
# (1.0, '1980_1984')	('cuore', 'ADJ')	1
#
# (1.0, '1985_1989')	('essere', 'AUX')	2
# (1.0, '1985_1989')	('fare', 'VERB')	2
# (1.0, '1985_1989')	('bostik', 'NOUN')	2
# (1.0, '1985_1989')	('primavera', 'NOUN')	2
# (1.0, '1985_1989')	('vien', 'AUX')	2
# (1.0, '1985_1989')	('danzare', 'VERB')	2
# (1.0, '1985_1989')	('buongiorno', 'ADJ')	1
# (1.0, '1985_1989')	('chiodo', 'VERB')	1
# (1.0, '1985_1989')	('piegare', 'VERB')	1
# (1.0, '1985_1989')	('spezzare', 'VERB')	1
#
# (2.0, '1980_1984')	('essere', 'AUX')	2
# (2.0, '1980_1984')	('25000', 'NUM')	2
# (2.0, '1980_1984')	('tanto', 'ADV')	2
# (2.0, '1980_1984')	('casacolor', 'NOUN')	2
# (2.0, '1980_1984')	('stanza', 'NOUN')	2
# (2.0, '1980_1984')	('colore', 'NOUN')	2
# (2.0, '1980_1984')	('casacolor', 'VERB')	2
# (2.0, '1980_1984')	('prova', 'NOUN')	1
# (2.0, '1980_1984')	('pratico', 'ADJ')	1
# (2.0, '1980_1984')	('dimostrare', 'VERB')	1
#
# (3.0, '1980_1984')	('essere', 'AUX')	157
# (3.0, '1980_1984')	('sintony', 'PROPN')	68
# (3.0, '1980_1984')	('nuovo', 'ADJ')	51
# (3.0, '1980_1984')	('fare', 'VERB')	34
# (3.0, '1980_1984')	('shampoo', 'NOUN')	34
# (3.0, '1980_1984')	('avere', 'VERB')	31
# (3.0, '1980_1984')	('lavare', 'VERB')	27
# (3.0, '1980_1984')	('potere', 'NOUN')	25
# (3.0, '1980_1984')	('pelle', 'NOUN')	24
# (3.0, '1980_1984')	('dare', 'VERB')	23
#
# (3.0, '1985_1989')	('essere', 'AUX')	507
# (3.0, '1985_1989')	('nuovo', 'ADJ')	237
# (3.0, '1985_1989')	('avere', 'VERB')	116
# (3.0, '1985_1989')	('oggi', 'ADV')	98
# (3.0, '1985_1989')	('fare', 'VERB')	95
# (3.0, '1985_1989')	('potere', 'NOUN')	94
# (3.0, '1985_1989')	('pulito', 'VERB')	80
# (3.0, '1985_1989')	('pelle', 'NOUN')	73
# (3.0, '1985_1989')	('senza', 'ADP')	71
# (3.0, '1985_1989')	('giorno', 'NOUN')	70
#
# (3.0, '1990_1994')	('essere', 'AUX')	420
# (3.0, '1990_1994')	('nuovo', 'ADJ')	249
# (3.0, '1990_1994')	('avere', 'VERB')	106
# (3.0, '1990_1994')	('fare', 'VERB')	101
# (3.0, '1990_1994')	('shampoo', 'NOUN')	95
# (3.0, '1990_1994')	('oggi', 'ADV')	93
# (3.0, '1990_1994')	('pelle', 'NOUN')	81
# (3.0, '1990_1994')	('detersivo', 'ADJ')	71
# (3.0, '1990_1994')	('bianco', 'ADJ')	71
# (3.0, '1990_1994')	('ogni', 'DET')	69
#
# (3.0, '1995_1999')	('essere', 'AUX')	112
# (3.0, '1995_1999')	('nuovo', 'ADJ')	54
# (3.0, '1995_1999')	('avere', 'VERB')	28
# (3.0, '1995_1999')	('pelle', 'NOUN')	27
# (3.0, '1995_1999')	('bianco', 'ADJ')	25
# (3.0, '1995_1999')	('forza', 'NOUN')	21
# (3.0, '1995_1999')	('pulito', 'VERB')	20
# (3.0, '1995_1999')	('oggi', 'ADV')	19
# (3.0, '1995_1999')	('gel', 'NOUN')	19
# (3.0, '1995_1999')	('giorno', 'NOUN')	19
#
# (3.0, '2000_2004')	('essere', 'AUX')	126
# (3.0, '2000_2004')	('nuovo', 'ADJ')	108
# (3.0, '2000_2004')	('pelle', 'NOUN')	51
# (3.0, '2000_2004')	('colore', 'NOUN')	42
# (3.0, '2000_2004')	('bianco', 'ADJ')	39
# (3.0, '2000_2004')	('avere', 'VERB')	32
# (3.0, '2000_2004')	('fare', 'VERB')	29
# (3.0, '2000_2004')	('oggi', 'ADV')	29
# (3.0, '2000_2004')	('capello', 'ADP')	27
# (3.0, '2000_2004')	('avere', 'AUX')	24
#
# (3.0, '2005_2009')	('essere', 'AUX')	131
# (3.0, '2005_2009')	('nuovo', 'ADJ')	98
# (3.0, '2005_2009')	('avere', 'VERB')	45
# (3.0, '2005_2009')	('pelle', 'NOUN')	40
# (3.0, '2005_2009')	('fare', 'VERB')	35
# (3.0, '2005_2009')	('bianco', 'ADJ')	35
# (3.0, '2005_2009')	('potere', 'NOUN')	32
# (3.0, '2005_2009')	('pulire', 'VERB')	28
# (3.0, '2005_2009')	('solo', 'ADV')	26
# (3.0, '2005_2009')	('ogni', 'DET')	22
#
# (3.0, '2010_2014')	('essere', 'AUX')	51
# (3.0, '2010_2014')	('nuovo', 'ADJ')	42
# (3.0, '2010_2014')	('potere', 'NOUN')	12
# (3.0, '2010_2014')	('fare', 'VERB')	12
# (3.0, '2010_2014')	('borotalco', 'NOUN')	11
# (3.0, '2010_2014')	('capello', 'ADP')	10
# (3.0, '2010_2014')	('pantene', 'ADJ')	10
# (3.0, '2010_2014')	('solo', 'ADV')	10
# (3.0, '2010_2014')	('garnier', 'PROPN')	9
# (3.0, '2010_2014')	('lisci', 'VERB')	9
#
# (3.0, '2015_2019')	('essere', 'AUX')	36
# (3.0, '2015_2019')	('nuovo', 'ADJ')	20
# (3.0, '2015_2019')	('potere', 'NOUN')	12
# (3.0, '2015_2019')	('quando', 'SCONJ')	11
# (3.0, '2015_2019')	('pelle', 'NOUN')	11
# (3.0, '2015_2019')	('macchia', 'NOUN')	11
# (3.0, '2015_2019')	('ogni', 'DET')	10
# (3.0, '2015_2019')	('capello', 'ADP')	9
# (3.0, '2015_2019')	('dolce', 'ADJ')	9
# (3.0, '2015_2019')	('capelli', 'NOUN')	9
#
# (3.0, '2020_2024')	('essere', 'AUX')	63
# (3.0, '2020_2024')	('nuovo', 'ADJ')	28
# (3.0, '2020_2024')	('sporco', 'ADJ')	21
# (3.0, '2020_2024')	('ogni', 'DET')	17
# (3.0, '2020_2024')	('pulire', 'VERB')	16
# (3.0, '2020_2024')	('potere', 'NOUN')	14
# (3.0, '2020_2024')	('pelle', 'NOUN')	13
# (3.0, '2020_2024')	('fare', 'VERB')	13
# (3.0, '2020_2024')	('avere', 'VERB')	10
# (3.0, '2020_2024')	('sempre', 'ADV')	10
#
# (4.0, '1980_1984')	('chevron', 'PROPN')	3
# (4.0, '1980_1984')	('ogni', 'DET')	2
# (4.0, '1980_1984')	('nome', 'NOUN')	1
# (4.0, '1980_1984')	('strada', 'NOUN')	1
# (4.0, '1980_1984')	('stagione', 'NOUN')	1
# (4.0, '1980_1984')	('vai', 'VERB')	1
# (4.0, '1980_1984')	('sempre', 'ADV')	1
# (4.0, '1980_1984')	('bene', 'ADV')	1
# (4.0, '1980_1984')	('quando', 'SCONJ')	1
# (4.0, '1980_1984')	('scegliere', 'VERB')	1
#
# (4.0, '1985_1989')	('metano', 'VERB')	26
# (4.0, '1985_1989')	('essere', 'AUX')	24
# (4.0, '1985_1989')	('dare', 'VERB')	13
# (4.0, '1985_1989')	('mano', 'NOUN')	11
# (4.0, '1985_1989')	('pulito', 'VERB')	10
# (4.0, '1985_1989')	('bello', 'ADJ')	10
# (4.0, '1985_1989')	('azzurro', 'ADJ')	9
# (4.0, '1985_1989')	('riscaldamento', 'NOUN')	8
# (4.0, '1985_1989')	('vincere', 'VERB')	7
# (4.0, '1985_1989')	('potere', 'NOUN')	7
#
# (4.0, '1990_1994')	('essere', 'AUX')	26
# (4.0, '1990_1994')	('fare', 'VERB')	18
# (4.0, '1990_1994')	('vincere', 'VERB')	9
# (4.0, '1990_1994')	('dollaro', 'NOUN')	9
# (4.0, '1990_1994')	('allip', 'ADV')	7
# (4.0, '1990_1994')	('gas', 'NOUN')	7
# (4.0, '1990_1994')	('dario', 'ADJ')	7
# (4.0, '1990_1994')	('caldo', 'ADJ')	6
# (4.0, '1990_1994')	('metano', 'VERB')	6
# (4.0, '1990_1994')	('avere', 'VERB')	6
#
# (4.0, '1995_1999')	('piano', 'ADV')	8
# (4.0, '1995_1999')	('esso', 'PRON')	7
# (4.0, '1995_1999')	('essere', 'AUX')	6
# (4.0, '1995_1999')	('q8', 'PROPN')	6
# (4.0, '1995_1999')	('benzina', 'NOUN')	4
# (4.0, '1995_1999')	('grande', 'ADJ')	4
# (4.0, '1995_1999')	('nuovo', 'ADJ')	4
# (4.0, '1995_1999')	('regalo', 'ADJ')	3
# (4.0, '1995_1999')	('paraflu', 'VERB')	3
# (4.0, '1995_1999')	('agip', 'ADJ')	3
#
# (4.0, '2000_2004')	('unopera', 'ADJ')	41
# (4.0, '2000_2004')	('essere', 'AUX')	5
# (4.0, '2000_2004')	('promozione', 'NOUN')	5
# (4.0, '2000_2004')	('esso', 'PRON')	4
# (4.0, '2000_2004')	('fare', 'VERB')	3
# (4.0, '2000_2004')	('te', 'PRON')	3
# (4.0, '2000_2004')	('grande', 'ADJ')	3
# (4.0, '2000_2004')	('nuovo', 'ADJ')	3
# (4.0, '2000_2004')	('omitel', 'PROPN')	2
# (4.0, '2000_2004')	('ericsson', 'PROPN')	2
#
# (4.0, '2005_2009')	('essere', 'AUX')	11
# (4.0, '2005_2009')	('motore', 'NOUN')	6
# (4.0, '2005_2009')	('grande', 'ADJ')	5
# (4.0, '2005_2009')	('sempre', 'ADV')	5
# (4.0, '2005_2009')	('diesel', 'VERB')	5
# (4.0, '2005_2009')	('strada', 'NOUN')	4
# (4.0, '2005_2009')	('api', 'NOUN')	4
# (4.0, '2005_2009')	('ogni', 'DET')	4
# (4.0, '2005_2009')	('dare', 'VERB')	3
# (4.0, '2005_2009')	('avere', 'AUX')	3
#
# (5.0, '1980_1984')	('essere', 'AUX')	56
# (5.0, '1980_1984')	('fare', 'VERB')	25
# (5.0, '1980_1984')	('avere', 'VERB')	19
# (5.0, '1980_1984')	('potere', 'NOUN')	14
# (5.0, '1980_1984')	('quando', 'SCONJ')	14
# (5.0, '1980_1984')	('poi', 'ADV')	13
# (5.0, '1980_1984')	('leggere', 'VERB')	12
# (5.0, '1980_1984')	('attentamente', 'ADV')	11
# (5.0, '1980_1984')	('linea', 'ADJ')	11
# (5.0, '1980_1984')	('troppo', 'ADV')	11
#
# (5.0, '1985_1989')	('essere', 'AUX')	173
# (5.0, '1985_1989')	('usare', 'VERB')	45
# (5.0, '1985_1989')	('lines', 'NOUN')	40
# (5.0, '1985_1989')	('potere', 'NOUN')	39
# (5.0, '1985_1989')	('medicinale', 'ADJ')	37
# (5.0, '1985_1989')	('avere', 'VERB')	37
# (5.0, '1985_1989')	('male', 'ADV')	34
# (5.0, '1985_1989')	('cautela', 'NOUN')	30
# (5.0, '1985_1989')	('fare', 'VERB')	30
# (5.0, '1985_1989')	('nuovo', 'ADJ')	29
#
# (5.0, '1990_1994')	('essere', 'AUX')	113
# (5.0, '1990_1994')	('avere', 'VERB')	55
# (5.0, '1990_1994')	('potere', 'NOUN')	28
# (5.0, '1990_1994')	('lines', 'NOUN')	26
# (5.0, '1990_1994')	('nuovo', 'ADJ')	26
# (5.0, '1990_1994')	('male', 'ADV')	26
# (5.0, '1990_1994')	('plasmon', 'ADJ')	22
# (5.0, '1990_1994')	('quando', 'SCONJ')	21
# (5.0, '1990_1994')	('oggi', 'ADV')	21
# (5.0, '1990_1994')	('qui', 'ADV')	21
#
# (5.0, '1995_1999')	('essere', 'AUX')	54
# (5.0, '1995_1999')	('avere', 'VERB')	20
# (5.0, '1995_1999')	('medicinale', 'ADJ')	16
# (5.0, '1995_1999')	('foglio', 'NOUN')	13
# (5.0, '1995_1999')	('potere', 'NOUN')	12
# (5.0, '1995_1999')	('male', 'ADV')	12
# (5.0, '1995_1999')	('tosse', 'NOUN')	12
# (5.0, '1995_1999')	('attentamente', 'ADV')	11
# (5.0, '1995_1999')	('illustrativo', 'ADJ')	11
# (5.0, '1995_1999')	('solo', 'ADV')	9
#
# (5.0, '2000_2004')	('essere', 'AUX')	76
# (5.0, '2000_2004')	('medicinale', 'ADJ')	29
# (5.0, '2000_2004')	('illustrativo', 'ADJ')	25
# (5.0, '2000_2004')	('potere', 'NOUN')	24
# (5.0, '2000_2004')	('foglio', 'NOUN')	22
# (5.0, '2000_2004')	('avere', 'VERB')	22
# (5.0, '2000_2004')	('nuovo', 'ADJ')	21
# (5.0, '2000_2004')	('dolore', 'NOUN')	15
# (5.0, '2000_2004')	('attentamente', 'ADV')	13
# (5.0, '2000_2004')	('momendol', 'VERB')	13
#
# (5.0, '2005_2009')	('essere', 'AUX')	112
# (5.0, '2005_2009')	('avere', 'VERB')	48
# (5.0, '2005_2009')	('medicinale', 'ADJ')	37
# (5.0, '2005_2009')	('potere', 'NOUN')	33
# (5.0, '2005_2009')	('foglio', 'NOUN')	27
# (5.0, '2005_2009')	('quando', 'SCONJ')	24
# (5.0, '2005_2009')	('oggi', 'ADV')	23
# (5.0, '2005_2009')	('nuovo', 'ADJ')	23
# (5.0, '2005_2009')	('attentamente', 'ADV')	22
# (5.0, '2005_2009')	('dolore', 'NOUN')	21
#
# (5.0, '2010_2014')	('essere', 'AUX')	272
# (5.0, '2010_2014')	('potere', 'NOUN')	41
# (5.0, '2010_2014')	('male', 'ADV')	29
# (5.0, '2010_2014')	('avere', 'VERB')	26
# (5.0, '2010_2014')	('provare', 'VERB')	24
# (5.0, '2010_2014')	('medicinale', 'ADJ')	22
# (5.0, '2010_2014')	('effetto', 'NOUN')	17
# (5.0, '2010_2014')	('dolore', 'NOUN')	16
# (5.0, '2010_2014')	('base', 'NOUN')	15
# (5.0, '2010_2014')	('grave', 'ADJ')	15
#
# (5.0, '2015_2019')	('essere', 'AUX')	61
# (5.0, '2015_2019')	('potere', 'NOUN')	49
# (5.0, '2015_2019')	('avere', 'VERB')	28
# (5.0, '2015_2019')	('male', 'ADV')	28
# (5.0, '2015_2019')	('provare', 'VERB')	20
# (5.0, '2015_2019')	('dolore', 'NOUN')	19
# (5.0, '2015_2019')	('quando', 'SCONJ')	16
# (5.0, '2015_2019')	('effetto', 'NOUN')	14
# (5.0, '2015_2019')	('sintomo', 'NOUN')	13
# (5.0, '2015_2019')	('fare', 'VERB')	11
#
# (5.0, '2020_2024')	('essere', 'AUX')	51
# (5.0, '2020_2024')	('potere', 'NOUN')	37
# (5.0, '2020_2024')	('male', 'ADV')	21
# (5.0, '2020_2024')	('quando', 'SCONJ')	19
# (5.0, '2020_2024')	('provare', 'VERB')	17
# (5.0, '2020_2024')	('avere', 'VERB')	16
# (5.0, '2020_2024')	('dolore', 'NOUN')	13
# (5.0, '2020_2024')	('gola', 'NOUN')	11
# (5.0, '2020_2024')	('puoi', 'AUX')	10
# (5.0, '2020_2024')	('lines', 'NOUN')	10
#
# (6.0, '1980_1984')	('mamoli', 'ADJ')	3
# (6.0, '1980_1984')	('essere', 'AUX')	3
# (6.0, '1980_1984')	('bagno', 'NOUN')	3
# (6.0, '1980_1984')	('fare', 'VERB')	3
# (6.0, '1980_1984')	('frattini', 'ADJ')	2
# (6.0, '1980_1984')	('lha', 'PROPN')	2
# (6.0, '1980_1984')	('ceramix', 'VERB')	2
# (6.0, '1980_1984')	('dare', 'VERB')	2
# (6.0, '1980_1984')	('là', 'ADV')	2
# (6.0, '1980_1984')	('chiudo', 'ADJ')	2
#
# (6.0, '1985_1989')	('entrare', 'VERB')	4
# (6.0, '1985_1989')	('onduline', 'NOUN')	3
# (6.0, '1985_1989')	('fare', 'VERB')	2
# (6.0, '1985_1989')	('brio', 'ADJ')	2
# (6.0, '1985_1989')	('sottocoppo', 'ADV')	2
# (6.0, '1985_1989')	('standard', 'NOUN')	2
# (6.0, '1985_1989')	('miscelatori', 'ADJ')	1
# (6.0, '1985_1989')	('paini', 'NOUN')	1
# (6.0, '1985_1989')	('piloti', 'ADJ')	1
# (6.0, '1985_1989')	('dacqua', 'ADJ')	1
#
# (6.0, '2005_2009')	('grazie', 'ADP')	3
# (6.0, '2005_2009')	('raccolta', 'NOUN')	3
# (6.0, '2005_2009')	('lattina', 'NOUN')	2
# (6.0, '2005_2009')	('potere', 'NOUN')	2
# (6.0, '2005_2009')	('differenziare', 'VERB')	2
# (6.0, '2005_2009')	('principio', 'NOUN')	1
# (6.0, '2005_2009')	('essere', 'AUX')	1
# (6.0, '2005_2009')	('forse', 'ADV')	1
# (6.0, '2005_2009')	('scatoletta', 'ADJ')	1
# (6.0, '2005_2009')	('vaschetta', 'VERB')	1
#
# (6.0, '2020_2024')	('essere', 'AUX')	5
# (6.0, '2020_2024')	('finestra', 'VERB')	4
# (6.0, '2020_2024')	('oknoplast', 'ADJ')	3
# (6.0, '2020_2024')	('bella', 'ADJ')	2
# (6.0, '2020_2024')	('ascoltare', 'VERB')	1
# (6.0, '2020_2024')	('pecchio', 'NOUN')	1
# (6.0, '2020_2024')	('letro', 'NOUN')	1
# (6.0, '2020_2024')	('marco', 'X')	1
# (6.0, '2020_2024')	('guardare', 'VERB')	1
# (6.0, '2020_2024')	('rendere', 'VERB')	1
#
# (7.0, '1980_1984')	('caffè', 'NOUN')	10
# (7.0, '1980_1984')	('100', 'NUM')	6
# (7.0, '1980_1984')	('grado', 'NOUN')	6
# (7.0, '1980_1984')	('fare', 'VERB')	5
# (7.0, '1980_1984')	('oggi', 'ADV')	5
# (7.0, '1980_1984')	('simac', 'ADJ')	5
# (7.0, '1980_1984')	('vapore', 'NOUN')	4
# (7.0, '1980_1984')	('essere', 'AUX')	3
# (7.0, '1980_1984')	('lavorare', 'VERB')	3
# (7.0, '1980_1984')	('sporco', 'ADJ')	3
#
# (7.0, '1985_1989')	('essere', 'AUX')	21
# (7.0, '1985_1989')	('braun', 'PROPN')	9
# (7.0, '1985_1989')	('nuovo', 'ADJ')	7
# (7.0, '1985_1989')	('ok', 'ADP')	7
# (7.0, '1985_1989')	('vapore', 'NOUN')	6
# (7.0, '1985_1989')	('fare', 'VERB')	6
# (7.0, '1985_1989')	('cucina', 'NOUN')	6
# (7.0, '1985_1989')	('100', 'NUM')	5
# (7.0, '1985_1989')	('grado', 'NOUN')	5
# (7.0, '1985_1989')	('caffè', 'NOUN')	5
#
# (7.0, '1990_1994')	('fare', 'VERB')	11
# (7.0, '1990_1994')	('essere', 'AUX')	11
# (7.0, '1990_1994')	('casa', 'NOUN')	9
# (7.0, '1990_1994')	('minipimer', 'VERB')	7
# (7.0, '1990_1994')	('caffè', 'NOUN')	7
# (7.0, '1990_1994')	('prendere', 'VERB')	7
# (7.0, '1990_1994')	('volere', 'VERB')	6
# (7.0, '1990_1994')	('vaporetto', 'ADJ')	6
# (7.0, '1990_1994')	('nuovo', 'ADJ')	6
# (7.0, '1990_1994')	('solo', 'ADV')	5
#
# (7.0, '1995_1999')	('cisco', 'ADJ')	6
# (7.0, '1995_1999')	('asciugare', 'VERB')	5
# (7.0, '1995_1999')	('tasciugo', 'PROPN')	4
# (7.0, '1995_1999')	('lumidità', 'NOUN')	4
# (7.0, '1995_1999')	('essere', 'AUX')	4
# (7.0, '1995_1999')	('senza', 'ADP')	4
# (7.0, '1995_1999')	('cosa', 'NOUN')	3
# (7.0, '1995_1999')	('deumidificatore', 'ADJ')	3
# (7.0, '1995_1999')	('casa', 'NOUN')	3
# (7.0, '1995_1999')	('poi', 'ADV')	3
#
# (7.0, '2000_2004')	('nuovo', 'ADJ')	3
# (7.0, '2000_2004')	('sistema', 'NOUN')	3
# (7.0, '2000_2004')	('bosch', 'PROPN')	3
# (7.0, '2000_2004')	('microfilter', 'NOUN')	2
# (7.0, '2000_2004')	('asciugare', 'VERB')	2
# (7.0, '2000_2004')	('canal', 'ADJ')	2
# (7.0, '2000_2004')	('due', 'NUM')	1
# (7.0, '2000_2004')	('uomo', 'NOUN')	1
# (7.0, '2000_2004')	('stesso', 'ADJ')	1
# (7.0, '2000_2004')	('idea', 'NOUN')	1
#
# (7.0, '2005_2009')	('essere', 'AUX')	7
# (7.0, '2005_2009')	('ehi', 'PROPN')	4
# (7.0, '2005_2009')	('nuovo', 'ADJ')	3
# (7.0, '2005_2009')	('fare', 'VERB')	3
# (7.0, '2005_2009')	('avere', 'VERB')	2
# (7.0, '2005_2009')	('vorwerk', 'NOUN')	2
# (7.0, '2005_2009')	('blackdecker', 'NOUN')	2
# (7.0, '2005_2009')	('lecoaspira', 'NOUN')	2
# (7.0, '2005_2009')	('generazione', 'NOUN')	1
# (7.0, '2005_2009')	('hoover', 'PROPN')	1
#
# (7.0, '2020_2024')	('explore', 'NOUN')	2
# (7.0, '2020_2024')	('chicco', 'ADJ')	2
# (7.0, '2020_2024')	('delonghi', 'NOUN')	2
# (7.0, '2020_2024')	('perfetto', 'ADJ')	2
# (7.0, '2020_2024')	('scoprire', 'VERB')	1
# (7.0, '2020_2024')	('eletta', 'VERB')	1
# (7.0, '2020_2024')	('nuovo', 'ADJ')	1
# (7.0, '2020_2024')	('macchina', 'NOUN')	1
# (7.0, '2020_2024')	('caffè', 'NOUN')	1
# (7.0, '2020_2024')	('fare', 'VERB')	1
#
# (8.0, '1980_1984')	('perfetto', 'ADJ')	5
# (8.0, '1980_1984')	('bravo', 'ADJ')	5
# (8.0, '1980_1984')	('lamarasoio', 'NOUN')	3
# (8.0, '1980_1984')	('bello', 'ADJ')	3
# (8.0, '1980_1984')	('qualità', 'NOUN')	2
# (8.0, '1980_1984')	('radere', 'VERB')	2
# (8.0, '1980_1984')	('bic', 'ADJ')	2
# (8.0, '1980_1984')	('bic', 'NOUN')	2
# (8.0, '1980_1984')	('rg', 'ADP')	2
# (8.0, '1980_1984')	('gillette', 'ADJ')	2
#
# (8.0, '1985_1989')	('rasatura', 'NOUN')	19
# (8.0, '1985_1989')	('rasoio', 'NOUN')	11
# (8.0, '1985_1989')	('nuovo', 'ADJ')	10
# (8.0, '1985_1989')	('philips', 'NOUN')	10
# (8.0, '1985_1989')	('massimo', 'ADJ')	10
# (8.0, '1985_1989')	('elettronico', 'ADJ')	9
# (8.0, '1985_1989')	('ricaricabile', 'ADJ')	9
# (8.0, '1985_1989')	('gillette', 'ADJ')	9
# (8.0, '1985_1989')	('contour', 'NOUN')	9
# (8.0, '1985_1989')	('plus', 'NOUN')	9
#
# (8.0, '1990_1994')	('essere', 'AUX')	25
# (8.0, '1990_1994')	('nuovo', 'ADJ')	21
# (8.0, '1990_1994')	('rasoio', 'NOUN')	17
# (8.0, '1990_1994')	('rasatura', 'NOUN')	16
# (8.0, '1990_1994')	('sempre', 'ADV')	15
# (8.0, '1990_1994')	('uomo', 'NOUN')	14
# (8.0, '1990_1994')	('radere', 'VERB')	12
# (8.0, '1990_1994')	('braun', 'PROPN')	10
# (8.0, '1990_1994')	('fondo', 'NOUN')	10
# (8.0, '1990_1994')	('sistema', 'NOUN')	9
#
# (8.0, '1995_1999')	('sensorexcel', 'ADJ')	4
# (8.0, '1995_1999')	('senti', 'VERB')	3
# (8.0, '1995_1999')	('meglio', 'ADV')	3
# (8.0, '1995_1999')	('gillette', 'VERB')	2
# (8.0, '1995_1999')	('pour', 'ADP')	2
# (8.0, '1995_1999')	('elle', 'PROPN')	2
# (8.0, '1995_1999')	('pelle', 'NOUN')	2
# (8.0, '1995_1999')	('morbidare', 'VERB')	1
# (8.0, '1995_1999')	('sensazione', 'NOUN')	1
# (8.0, '1995_1999')	('seta', 'ADJ')	1
#
# (8.0, '2000_2004')	('facile', 'ADJ')	6
# (8.0, '2000_2004')	('nuovo', 'ADJ')	4
# (8.0, '2000_2004')	('essere', 'AUX')	4
# (8.0, '2000_2004')	('rasatura', 'NOUN')	4
# (8.0, '2000_2004')	('pelo', 'NOUN')	3
# (8.0, '2000_2004')	('fondo', 'NOUN')	3
# (8.0, '2000_2004')	('sistema', 'NOUN')	3
# (8.0, '2000_2004')	('fondo', 'PROPN')	3
# (8.0, '2000_2004')	('tre', 'NUM')	3
# (8.0, '2000_2004')	('3', 'NUM')	3
#
# (8.0, '2005_2009')	('nuovo', 'ADJ')	6
# (8.0, '2005_2009')	('das', 'NOUN')	5
# (8.0, '2005_2009')	('3', 'NUM')	4
# (8.0, '2005_2009')	('gillette', 'VERB')	4
# (8.0, '2005_2009')	('avere', 'VERB')	4
# (8.0, '2005_2009')	('gillette', 'ADJ')	4
# (8.0, '2005_2009')	('essere', 'AUX')	4
# (8.0, '2005_2009')	('es', 'NOUN')	4
# (8.0, '2005_2009')	('tre', 'NUM')	3
# (8.0, '2005_2009')	('lame', 'NOUN')	3
#
# (8.0, '2010_2014')	('nuovo', 'ADJ')	2
# (8.0, '2010_2014')	('curva', 'ADJ')	2
# (8.0, '2010_2014')	('viso', 'VERB')	2
# (8.0, '2010_2014')	('scoprire', 'VERB')	1
# (8.0, '2010_2014')	('piacere', 'NOUN')	1
# (8.0, '2010_2014')	('depilazione', 'NOUN')	1
# (8.0, '2010_2014')	('passa', 'VERB')	1
# (8.0, '2010_2014')	('luce', 'NOUN')	1
# (8.0, '2010_2014')	('pulsata', 'NOUN')	1
# (8.0, '2010_2014')	('centro', 'NOUN')	1
#
# (8.0, '2015_2019')	('pronto', 'ADJ')	4
# (8.0, '2015_2019')	('essere', 'AUX')	3
# (8.0, '2015_2019')	('minuto', 'NOUN')	3
# (8.0, '2015_2019')	('gillette', 'ADJ')	3
# (8.0, '2015_2019')	('venus', 'ADP')	3
# (8.0, '2015_2019')	('fare', 'VERB')	2
# (8.0, '2015_2019')	('cinque', 'NUM')	2
# (8.0, '2015_2019')	('5', 'NUM')	2
# (8.0, '2015_2019')	('cosa', 'NOUN')	1
# (8.0, '2015_2019')	('jeans', 'NOUN')	1
#
# (8.0, '2020_2024')	('irritazione', 'NOUN')	12
# (8.0, '2020_2024')	('bomber', 'NOUN')	8
# (8.0, '2020_2024')	('shave', 'ADJ')	7
# (8.0, '2020_2024')	('like', 'X')	7
# (8.0, '2020_2024')	('venus', 'X')	7
# (8.0, '2020_2024')	('bastare', 'VERB')	6
# (8.0, '2020_2024')	('im', 'ADV')	5
# (8.0, '2020_2024')	('gillette', 'VERB')	4
# (8.0, '2020_2024')	('ora', 'ADV')	3
# (8.0, '2020_2024')	('soffrire', 'VERB')	3
#
# (9.0, '1980_1984')	('essere', 'AUX')	39
# (9.0, '1980_1984')	('nuovo', 'ADJ')	11
# (9.0, '1980_1984')	('computer', 'NOUN')	11
# (9.0, '1980_1984')	('kodak', 'PROPN')	9
# (9.0, '1980_1984')	('bello', 'ADJ')	9
# (9.0, '1980_1984')	('programma', 'NOUN')	8
# (9.0, '1980_1984')	('disco', 'NOUN')	7
# (9.0, '1980_1984')	('grande', 'ADJ')	6
# (9.0, '1980_1984')	('calcolo', 'NOUN')	6
# (9.0, '1980_1984')	('fare', 'VERB')	6
#
# (9.0, '1985_1989')	('essere', 'AUX')	83
# (9.0, '1985_1989')	('nuovo', 'ADJ')	31
# (9.0, '1985_1989')	('philips', 'NOUN')	25
# (9.0, '1985_1989')	('grande', 'ADJ')	22
# (9.0, '1985_1989')	('computer', 'NOUN')	21
# (9.0, '1985_1989')	('colore', 'NOUN')	20
# (9.0, '1985_1989')	('avere', 'VERB')	19
# (9.0, '1985_1989')	('tv', 'NOUN')	19
# (9.0, '1985_1989')	('personal', 'ADJ')	17
# (9.0, '1985_1989')	('fare', 'VERB')	17
#
# (9.0, '1990_1994')	('essere', 'AUX')	68
# (9.0, '1990_1994')	('nuovo', 'ADJ')	33
# (9.0, '1990_1994')	('grande', 'ADJ')	29
# (9.0, '1990_1994')	('album', 'NOUN')	17
# (9.0, '1990_1994')	('avere', 'VERB')	16
# (9.0, '1990_1994')	('fare', 'VERB')	15
# (9.0, '1990_1994')	('avere', 'AUX')	14
# (9.0, '1990_1994')	('successo', 'NOUN')	12
# (9.0, '1990_1994')	('solo', 'ADV')	11
# (9.0, '1990_1994')	('vedere', 'VERB')	11
#
# (9.0, '1995_1999')	('essere', 'AUX')	31
# (9.0, '1995_1999')	('nuovo', 'ADJ')	10
# (9.0, '1995_1999')	('philips', 'NOUN')	6
# (9.0, '1995_1999')	('ogni', 'DET')	6
# (9.0, '1995_1999')	('immagine', 'NOUN')	6
# (9.0, '1995_1999')	('avere', 'AUX')	5
# (9.0, '1995_1999')	('fare', 'VERB')	5
# (9.0, '1995_1999')	('volere', 'VERB')	4
# (9.0, '1995_1999')	('migliorare', 'VERB')	4
# (9.0, '1995_1999')	('occhio', 'NOUN')	4
#
# (9.0, '2000_2004')	('essere', 'AUX')	21
# (9.0, '2000_2004')	('nuovo', 'ADJ')	15
# (9.0, '2000_2004')	('potere', 'NOUN')	8
# (9.0, '2000_2004')	('grande', 'ADJ')	7
# (9.0, '2000_2004')	('fare', 'VERB')	6
# (9.0, '2000_2004')	('focus', 'NOUN')	5
# (9.0, '2000_2004')	('cosa', 'NOUN')	5
# (9.0, '2000_2004')	('avere', 'VERB')	5
# (9.0, '2000_2004')	('dance', 'NOUN')	5
# (9.0, '2000_2004')	('contatto', 'NOUN')	4
#
# (9.0, '2005_2009')	('essere', 'AUX')	27
# (9.0, '2005_2009')	('nuovo', 'ADJ')	14
# (9.0, '2005_2009')	('fare', 'VERB')	7
# (9.0, '2005_2009')	('avere', 'AUX')	6
# (9.0, '2005_2009')	('solo', 'ADV')	6
# (9.0, '2005_2009')	('avere', 'VERB')	6
# (9.0, '2005_2009')	('grande', 'ADJ')	5
# (9.0, '2005_2009')	('tv', 'NOUN')	5
# (9.0, '2005_2009')	('molto', 'ADV')	5
# (9.0, '2005_2009')	('volta', 'NOUN')	5
#
# (9.0, '2010_2014')	('burg', 'ADJ')	2
# (9.0, '2010_2014')	('scegliere', 'VERB')	2
# (9.0, '2010_2014')	('hit', 'PROPN')	2
# (9.0, '2010_2014')	('mania', 'PROPN')	2
# (9.0, '2010_2014')	('special', 'ADP')	2
# (9.0, '2010_2014')	('edition', 'NOUN')	2
# (9.0, '2010_2014')	('2014', 'NUM')	2
# (9.0, '2010_2014')	('nuovissimo', 'ADJ')	1
# (9.0, '2010_2014')	('orologiotelefe', 'VERB')	1
# (9.0, '2010_2014')	('permettere', 'VERB')	1
#
# (9.0, '2020_2024')	('essere', 'AUX')	5
# (9.0, '2020_2024')	('my', 'PROPN')	5
# (9.0, '2020_2024')	('john', 'PROPN')	4
# (9.0, '2020_2024')	('why', 'PROPN')	4
# (9.0, '2020_2024')	('do', 'ADP')	4
# (9.0, '2020_2024')	('bad', 'NOUN')	4
# (9.0, '2020_2024')	('you', 'X')	4
# (9.0, '2020_2024')	('too', 'X')	4
# (9.0, '2020_2024')	('nama', 'PROPN')	4
# (9.0, '2020_2024')	('avere', 'AUX')	4
#
# (10.0, '1980_1984')	('essere', 'AUX')	8
# (10.0, '1980_1984')	('personal', 'ADJ')	5
# (10.0, '1980_1984')	('bene', 'ADV')	4
# (10.0, '1980_1984')	('giusto', 'ADJ')	4
# (10.0, '1980_1984')	('akuel', 'VERB')	3
# (10.0, '1980_1984')	('sicurezza', 'NOUN')	3
# (10.0, '1980_1984')	('farmacia', 'NOUN')	3
# (10.0, '1980_1984')	('fare', 'VERB')	3
# (10.0, '1980_1984')	('2003', 'NUM')	3
# (10.0, '1980_1984')	('lamore', 'NOUN')	3
#
# (10.0, '1985_1989')	('lamore', 'NOUN')	25
# (10.0, '1985_1989')	('fare', 'VERB')	18
# (10.0, '1985_1989')	('essere', 'AUX')	17
# (10.0, '1985_1989')	('control', 'NOUN')	17
# (10.0, '1985_1989')	('avere', 'AUX')	10
# (10.0, '1985_1989')	('prova', 'NOUN')	8
# (10.0, '1985_1989')	('hatù', 'VERB')	8
# (10.0, '1985_1989')	('bene', 'ADV')	8
# (10.0, '1985_1989')	('akuel', 'ADJ')	7
# (10.0, '1985_1989')	('sottile', 'ADJ')	7
#
# (10.0, '1990_1994')	('essere', 'AUX')	11
# (10.0, '1990_1994')	('jeans', 'NOUN')	4
# (10.0, '1990_1994')	('akuel', 'VERB')	4
# (10.0, '1990_1994')	('baby', 'PROPN')	4
# (10.0, '1990_1994')	('profilattici', 'ADJ')	3
# (10.0, '1990_1994')	('lamore', 'NOUN')	3
# (10.0, '1990_1994')	('gamba', 'NOUN')	3
# (10.0, '1990_1994')	('solo', 'ADV')	2
# (10.0, '1990_1994')	('finire', 'VERB')	2
# (10.0, '1990_1994')	('andare', 'VERB')	2
#
# (10.0, '1995_1999')	('sperare', 'VERB')	1
# (10.0, '1995_1999')	('meglio', 'ADV')	1
# (10.0, '1995_1999')	('qualunque', 'DET')	1
# (10.0, '1995_1999')	('essere', 'AUX')	1
# (10.0, '1995_1999')	('modo', 'NOUN')	1
# (10.0, '1995_1999')	('concepire', 'VERB')	1
# (10.0, '1995_1999')	('lamore', 'NOUN')	1
# (10.0, '1995_1999')	('avere', 'VERB')	1
# (10.0, '1995_1999')	('profilattico', 'ADJ')	1
# (10.0, '1995_1999')	('volere', 'VERB')	1
#
# (10.0, '2000_2004')	('profilattici', 'ADJ')	2
# (10.0, '2000_2004')	('control', 'NOUN')	2
# (10.0, '2000_2004')	('pop', 'X')	2
# (10.0, '2000_2004')	('up', 'NOUN')	2
# (10.0, '2000_2004')	('colpo', 'NOUN')	2
# (10.0, '2000_2004')	('cercasi', 'AUX')	1
# (10.0, '2000_2004')	('fidanzato', 'VERB')	1
# (10.0, '2000_2004')	('uff', 'DET')	1
# (10.0, '2000_2004')	('frusta', 'NOUN')	1
# (10.0, '2000_2004')	('fulmine', 'ADJ')	1
#
# (10.0, '2005_2009')	('essere', 'AUX')	9
# (10.0, '2005_2009')	('nuovo', 'ADJ')	6
# (10.0, '2005_2009')	('molto', 'ADV')	3
# (10.0, '2005_2009')	('vedere', 'VERB')	3
# (10.0, '2005_2009')	('facile', 'ADJ')	3
# (10.0, '2005_2009')	('indossare', 'VERB')	3
# (10.0, '2005_2009')	('ora', 'ADV')	3
# (10.0, '2005_2009')	('grande', 'ADJ')	3
# (10.0, '2005_2009')	('senza', 'ADP')	3
# (10.0, '2005_2009')	('durex', 'VERB')	2
#
# (10.0, '2010_2014')	('sottotitoli', 'NOUN')	1
# (10.0, '2010_2014')	('creare', 'VERB')	1
# (10.0, '2010_2014')	('comunità', 'NOUN')	1
# (10.0, '2010_2014')	('amaraorg', 'PROPN')	1
# (10.0, '2010_2014')	('wwwamaraorg', 'PROPN')	1
#
# (10.0, '2015_2019')	('tv', 'NOUN')	3
# (10.0, '2015_2019')	('2015', 'NUM')	3
# (10.0, '2015_2019')	('grande', 'ADJ')	3
# (10.0, '2015_2019')	('esperto', 'NOUN')	3
# (10.0, '2015_2019')	('grammatica', 'ADJ')	3
# (10.0, '2015_2019')	('sintasso', 'ADV')	3
# (10.0, '2015_2019')	('italiano', 'ADJ')	3
# (10.0, '2015_2019')	('commercial', 'VERB')	2
# (10.0, '2015_2019')	('commercial', 'ADJ')	1
#
# (10.0, '2020_2024')	('essere', 'AUX')	13
# (10.0, '2020_2024')	('2020', 'NUM')	5
# (10.0, '2020_2024')	('durex', 'VERB')	5
# (10.0, '2020_2024')	('sempre', 'ADV')	4
# (10.0, '2020_2024')	('te', 'PRON')	4
# (10.0, '2020_2024')	('tornare', 'VERB')	4
# (10.0, '2020_2024')	('normalità', 'NOUN')	4
# (10.0, '2020_2024')	('fare', 'VERB')	3
# (10.0, '2020_2024')	('lamore', 'NOUN')	3
# (10.0, '2020_2024')	('preservativo', 'ADJ')	3
#
# (11.0, '1980_1984')	('essere', 'AUX')	25
# (11.0, '1980_1984')	('fare', 'VERB')	12
# (11.0, '1980_1984')	('te', 'PRON')	10
# (11.0, '1980_1984')	('indesit', 'ADJ')	6
# (11.0, '1980_1984')	('inox', 'ADJ')	6
# (11.0, '1980_1984')	('casa', 'NOUN')	6
# (11.0, '1980_1984')	('avere', 'VERB')	6
# (11.0, '1980_1984')	('black', 'ADJ')	5
# (11.0, '1980_1984')	('decker', 'NOUN')	5
# (11.0, '1980_1984')	('indesit', 'VERB')	5
#
# (11.0, '1985_1989')	('essere', 'AUX')	53
# (11.0, '1985_1989')	('fare', 'VERB')	23
# (11.0, '1985_1989')	('solo', 'ADV')	20
# (11.0, '1985_1989')	('nuovo', 'ADJ')	16
# (11.0, '1985_1989')	('scaldasonno', 'VERB')	16
# (11.0, '1985_1989')	('caldo', 'ADJ')	15
# (11.0, '1985_1989')	('yeti', 'NOUN')	15
# (11.0, '1985_1989')	('bello', 'ADJ')	13
# (11.0, '1985_1989')	('gelato', 'ADJ')	13
# (11.0, '1985_1989')	('8000', 'NUM')	12
#
# (11.0, '1990_1994')	('essere', 'AUX')	67
# (11.0, '1990_1994')	('fare', 'VERB')	19
# (11.0, '1990_1994')	('mamma', 'NOUN')	15
# (11.0, '1990_1994')	('avere', 'VERB')	13
# (11.0, '1990_1994')	('nuovo', 'ADJ')	10
# (11.0, '1990_1994')	('andare', 'VERB')	9
# (11.0, '1990_1994')	('rex', 'VERB')	9
# (11.0, '1990_1994')	('super', 'ADJ')	9
# (11.0, '1990_1994')	('avere', 'AUX')	9
# (11.0, '1990_1994')	('bello', 'ADJ')	8
#
# (11.0, '1995_1999')	('essere', 'AUX')	12
# (11.0, '1995_1999')	('due', 'NUM')	6
# (11.0, '1995_1999')	('avere', 'VERB')	5
# (11.0, '1995_1999')	('grande', 'ADJ')	4
# (11.0, '1995_1999')	('bello', 'ADJ')	4
# (11.0, '1995_1999')	('fare', 'VERB')	4
# (11.0, '1995_1999')	('caldo', 'ADJ')	4
# (11.0, '1995_1999')	('caldobagno', 'NOUN')	4
# (11.0, '1995_1999')	('radio', 'NOUN')	4
# (11.0, '1995_1999')	('passìo', 'NOUN')	4
#
# (11.0, '2000_2004')	('nuovo', 'ADJ')	10
# (11.0, '2000_2004')	('essere', 'AUX')	10
# (11.0, '2000_2004')	('fare', 'VERB')	6
# (11.0, '2000_2004')	('primo', 'ADJ')	4
# (11.0, '2000_2004')	('lavatrice', 'ADJ')	4
# (11.0, '2000_2004')	('avere', 'VERB')	4
# (11.0, '2000_2004')	('ariston', 'NOUN')	3
# (11.0, '2000_2004')	('caldo', 'ADJ')	3
# (11.0, '2000_2004')	('caldopanny', 'NOUN')	3
# (11.0, '2000_2004')	('idromassaggio', 'NOUN')	3
#
# (11.0, '2005_2009')	('essere', 'AUX')	13
# (11.0, '2005_2009')	('nuovo', 'ADJ')	4
# (11.0, '2005_2009')	('delonghi', 'DET')	4
# (11.0, '2005_2009')	('sistema', 'NOUN')	4
# (11.0, '2005_2009')	('nespresso', 'VERB')	4
# (11.0, '2005_2009')	('avere', 'VERB')	3
# (11.0, '2005_2009')	('sesto', 'ADJ')	3
# (11.0, '2005_2009')	('senso', 'NOUN')	3
# (11.0, '2005_2009')	('lunico', 'ADJ')	3
# (11.0, '2005_2009')	('climatizzatore', 'NOUN')	3
#
# (11.0, '2010_2014')	('nespresso', 'ADJ')	2
# (11.0, '2010_2014')	('assapurare', 'VERB')	1
# (11.0, '2010_2014')	('qualità', 'NOUN')	1
# (11.0, '2010_2014')	('lasciare', 'VERB')	1
# (11.0, '2010_2014')	('qualcuno', 'PRON')	1
# (11.0, '2010_2014')	('intromettare', 'VERB')	1
# (11.0, '2010_2014')	('fra', 'ADP')	1
# (11.0, '2010_2014')	('te', 'PRON')	1
# (11.0, '2010_2014')	('piacere', 'NOUN')	1
# (11.0, '2010_2014')	('george', 'ADJ')	1
#
# (11.0, '2020_2024')	('essere', 'AUX')	5
# (11.0, '2020_2024')	('ogni', 'DET')	5
# (11.0, '2020_2024')	('solo', 'ADV')	3
# (11.0, '2020_2024')	('sempre', 'ADV')	3
# (11.0, '2020_2024')	('durare', 'VERB')	3
# (11.0, '2020_2024')	('anno', 'NOUN')	3
# (11.0, '2020_2024')	('casa', 'NOUN')	2
# (11.0, '2020_2024')	('sentire', 'VERB')	2
# (11.0, '2020_2024')	('potere', 'NOUN')	2
# (11.0, '2020_2024')	('elettrodomestico', 'ADJ')	2
#
# (12.0, '1980_1984')	('essere', 'AUX')	32
# (12.0, '1980_1984')	('nuovo', 'ADJ')	17
# (12.0, '1980_1984')	('due', 'NUM')	14
# (12.0, '1980_1984')	('renault', 'NOUN')	14
# (12.0, '1980_1984')	('grande', 'ADJ')	14
# (12.0, '1980_1984')	('nuova', 'ADJ')	9
# (12.0, '1980_1984')	('linea', 'NOUN')	8
# (12.0, '1980_1984')	('4', 'NUM')	7
# (12.0, '1980_1984')	('avere', 'VERB')	6
# (12.0, '1980_1984')	('auto', 'NOUN')	6
#
# (12.0, '1985_1989')	('essere', 'AUX')	167
# (12.0, '1985_1989')	('nuovo', 'ADJ')	51
# (12.0, '1985_1989')	('renault', 'NOUN')	49
# (12.0, '1985_1989')	('strada', 'NOUN')	41
# (12.0, '1985_1989')	('oggi', 'ADV')	35
# (12.0, '1985_1989')	('mille', 'NUM')	32
# (12.0, '1985_1989')	('miglia', 'NOUN')	28
# (12.0, '1985_1989')	('milione', 'NOUN')	27
# (12.0, '1985_1989')	('avere', 'VERB')	25
# (12.0, '1985_1989')	('strada', 'VERB')	25
#
# (12.0, '1990_1994')	('essere', 'AUX')	148
# (12.0, '1990_1994')	('nuovo', 'ADJ')	62
# (12.0, '1990_1994')	('milione', 'NOUN')	40
# (12.0, '1990_1994')	('avere', 'VERB')	36
# (12.0, '1990_1994')	('fare', 'VERB')	33
# (12.0, '1990_1994')	('fiat', 'ADJ')	27
# (12.0, '1990_1994')	('oggi', 'ADV')	23
# (12.0, '1990_1994')	('2', 'NUM')	23
# (12.0, '1990_1994')	('tipo', 'NOUN')	19
# (12.0, '1990_1994')	('nuova', 'ADJ')	17
#
# (12.0, '1995_1999')	('essere', 'AUX')	46
# (12.0, '1995_1999')	('nuovo', 'ADJ')	16
# (12.0, '1995_1999')	('avere', 'VERB')	15
# (12.0, '1995_1999')	('potere', 'NOUN')	11
# (12.0, '1995_1999')	('strada', 'NOUN')	10
# (12.0, '1995_1999')	('sicurezza', 'NOUN')	9
# (12.0, '1995_1999')	('fare', 'VERB')	9
# (12.0, '1995_1999')	('ogni', 'DET')	8
# (12.0, '1995_1999')	('fiat', 'ADJ')	8
# (12.0, '1995_1999')	('auto', 'NOUN')	8
#
# (12.0, '2000_2004')	('essere', 'AUX')	66
# (12.0, '2000_2004')	('nuovo', 'ADJ')	31
# (12.0, '2000_2004')	('nuova', 'ADJ')	23
# (12.0, '2000_2004')	('avere', 'VERB')	22
# (12.0, '2000_2004')	('euro', 'NOUN')	19
# (12.0, '2000_2004')	('ford', 'VERB')	16
# (12.0, '2000_2004')	('milione', 'NOUN')	15
# (12.0, '2000_2004')	('solo', 'ADV')	15
# (12.0, '2000_2004')	('rail', 'NOUN')	12
# (12.0, '2000_2004')	('prezzo', 'NOUN')	12
#
# (12.0, '2005_2009')	('─', 'PROPN')	111
# (12.0, '2005_2009')	('essere', 'AUX')	103
# (12.0, '2005_2009')	('euro', 'NOUN')	79
# (12.0, '2005_2009')	('imparare', 'VERB')	51
# (12.0, '2005_2009')	('nuovo', 'ADJ')	45
# (12.0, '2005_2009')	('nuova', 'ADJ')	41
# (12.0, '2005_2009')	('avere', 'VERB')	36
# (12.0, '2005_2009')	('opel', 'ADJ')	33
# (12.0, '2005_2009')	('oggi', 'ADV')	30
# (12.0, '2005_2009')	('potere', 'NOUN')	26
#
# (12.0, '2010_2014')	('essere', 'AUX')	50
# (12.0, '2010_2014')	('nuova', 'ADJ')	22
# (12.0, '2010_2014')	('euro', 'NOUN')	21
# (12.0, '2010_2014')	('nuovo', 'ADJ')	14
# (12.0, '2010_2014')	('avere', 'VERB')	12
# (12.0, '2010_2014')	('solo', 'ADV')	10
# (12.0, '2010_2014')	('fare', 'VERB')	10
# (12.0, '2010_2014')	('panda', 'NOUN')	9
# (12.0, '2010_2014')	('domenica', 'NOUN')	8
# (12.0, '2010_2014')	('creare', 'VERB')	7
#
# (12.0, '2015_2019')	('essere', 'AUX')	45
# (12.0, '2015_2019')	('euro', 'NOUN')	23
# (12.0, '2015_2019')	('solo', 'ADV')	16
# (12.0, '2015_2019')	('avere', 'VERB')	15
# (12.0, '2015_2019')	('nuovo', 'ADJ')	13
# (12.0, '2015_2019')	('fare', 'VERB')	10
# (12.0, '2015_2019')	('nuova', 'ADJ')	8
# (12.0, '2015_2019')	('bmw', 'PROPN')	8
# (12.0, '2015_2019')	('ben', 'ADV')	8
# (12.0, '2015_2019')	('alfa', 'PROPN')	7
#
# (12.0, '2020_2024')	('essere', 'AUX')	44
# (12.0, '2020_2024')	('nuovo', 'ADJ')	15
# (12.0, '2020_2024')	('hybrid', 'PROPN')	13
# (12.0, '2020_2024')	('euro', 'NOUN')	11
# (12.0, '2020_2024')	('suzuki', 'PROPN')	8
# (12.0, '2020_2024')	('fare', 'VERB')	7
# (12.0, '2020_2024')	('vita', 'NOUN')	7
# (12.0, '2020_2024')	('grande', 'ADJ')	7
# (12.0, '2020_2024')	('mese', 'ADJ')	7
# (12.0, '2020_2024')	('vivi', 'ADJ')	6
#
# (13.0, '1980_1984')	('beretta', 'PROPN')	2
# (13.0, '1980_1984')	('virginia', 'NOUN')	1
# (13.0, '1980_1984')	('ferrari', 'ADJ')	1
# (13.0, '1980_1984')	('fucile', 'NOUN')	1
# (13.0, '1980_1984')	('armi', 'NOUN')	1
# (13.0, '1980_1984')	('sport', 'NOUN')	1
#
# (14.0, '1980_1984')	('quartz', 'DET')	4
# (14.0, '1980_1984')	('citizen', 'ADJ')	3
# (14.0, '1980_1984')	('orologio', 'NOUN')	2
# (14.0, '1980_1984')	('ogni', 'DET')	2
# (14.0, '1980_1984')	('incredibilmente', 'ADV')	2
# (14.0, '1980_1984')	('pensare', 'VERB')	2
# (14.0, '1980_1984')	('citizen', 'VERB')	1
# (14.0, '1980_1984')	('orologi', 'NOUN')	1
# (14.0, '1980_1984')	('raffinato', 'ADJ')	1
# (14.0, '1980_1984')	('pratico', 'ADJ')	1
#
# (14.0, '1985_1989')	('essere', 'AUX')	8
# (14.0, '1985_1989')	('solo', 'ADV')	6
# (14.0, '1985_1989')	('avere', 'VERB')	6
# (14.0, '1985_1989')	('braun', 'NOUN')	5
# (14.0, '1985_1989')	('swatch', 'NOUN')	5
# (14.0, '1985_1989')	('secondo', 'ADP')	4
# (14.0, '1985_1989')	('nuovo', 'ADJ')	4
# (14.0, '1985_1989')	('tissot', 'NOUN')	4
# (14.0, '1985_1989')	('tempo', 'NOUN')	4
# (14.0, '1985_1989')	('orologio', 'NOUN')	4
#
# (14.0, '1990_1994')	('rochat', 'VERB')	5
# (14.0, '1990_1994')	('lucien', 'PROPN')	4
# (14.0, '1990_1994')	('longines', 'NUM')	3
# (14.0, '1990_1994')	('essere', 'AUX')	3
# (14.0, '1990_1994')	('eccezionale', 'ADJ')	2
# (14.0, '1990_1994')	('cronografi', 'NOUN')	2
# (14.0, '1990_1994')	('meccanica', 'ADJ')	2
# (14.0, '1990_1994')	('perfetto', 'ADJ')	2
# (14.0, '1990_1994')	('creare', 'VERB')	2
# (14.0, '1990_1994')	('sempre', 'ADV')	2
#
# (14.0, '1995_1999')	('sector', 'NOUN')	2
# (14.0, '1995_1999')	('ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത', 'PROPN')	1
# (14.0, '1995_1999')	('ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്ത്', 'PROPN')	1
# (14.0, '1995_1999')	('sean', 'PROPN')	1
# (14.0, '1995_1999')	('baker', 'PROPN')	1
# (14.0, '1995_1999')	('kayak', 'PROPN')	1
# (14.0, '1995_1999')	('estremo', 'VERB')	1
# (14.0, '1995_1999')	('limits', 'ADJ')	1
#
# (14.0, '2000_2004')	('ieri', 'ADV')	2
# (14.0, '2000_2004')	('oggi', 'ADV')	2
# (14.0, '2000_2004')	('prossimo', 'ADJ')	2
# (14.0, '2000_2004')	('mille', 'NUM')	2
# (14.0, '2000_2004')	('anno', 'NOUN')	2
# (14.0, '2000_2004')	('lanello', 'ADJ')	2
# (14.0, '2000_2004')	('raccontare', 'VERB')	2
# (14.0, '2000_2004')	('storia', 'NOUN')	2
# (14.0, '2000_2004')	('amore', 'NOUN')	2
# (14.0, '2000_2004')	('trilogy', 'ADJ')	2
#
# (14.0, '2005_2009')	('essere', 'AUX')	6
# (14.0, '2005_2009')	('about', 'X')	5
# (14.0, '2005_2009')	('cielo', 'NOUN')	4
# (14.0, '2005_2009')	('sempre', 'ADV')	4
# (14.0, '2005_2009')	('its', 'PROPN')	4
# (14.0, '2005_2009')	('collezione', 'NOUN')	3
# (14.0, '2005_2009')	('gioielli', 'PROPN')	3
# (14.0, '2005_2009')	('us', 'X')	3
# (14.0, '2005_2009')	('vita', 'VERB')	3
# (14.0, '2005_2009')	('the', 'DET')	3
#
# (14.0, '2010_2014')	('bracciale', 'ADJ')	2
# (14.0, '2010_2014')	('te', 'PRON')	2
# (14.0, '2010_2014')	('pandora', 'VERB')	2
# (14.0, '2010_2014')	('pandora', 'ADV')	2
# (14.0, '2010_2014')	('crea', 'VERB')	1
# (14.0, '2010_2014')	('pandora', 'PROPN')	1
# (14.0, '2010_2014')	('joiello', 'PROPN')	1
# (14.0, '2010_2014')	('parla', 'VERB')	1
# (14.0, '2010_2014')	('scopri', 'VERB')	1
# (14.0, '2010_2014')	('collezione', 'NOUN')	1
#
# (14.0, '2015_2019')	('essere', 'AUX')	7
# (14.0, '2015_2019')	('pandora', 'ADV')	3
# (14.0, '2015_2019')	('unico', 'ADJ')	3
# (14.0, '2015_2019')	('amo', 'VERB')	2
# (14.0, '2015_2019')	('natura', 'NOUN')	2
# (14.0, '2015_2019')	('ogni', 'DET')	2
# (14.0, '2015_2019')	('mamma', 'NOUN')	2
# (14.0, '2015_2019')	('gioiello', 'NOUN')	2
# (14.0, '2015_2019')	('donna', 'VERB')	2
# (14.0, '2015_2019')	('migliore', 'ADJ')	2
#
# (14.0, '2020_2024')	('pandora', 'ADV')	4
# (14.0, '2020_2024')	('passengers', 'VERB')	3
# (14.0, '2020_2024')	('grande', 'ADJ')	3
# (14.0, '2020_2024')	('esperto', 'NOUN')	3
# (14.0, '2020_2024')	('grammatica', 'ADJ')	3
# (14.0, '2020_2024')	('sintasso', 'ADV')	3
# (14.0, '2020_2024')	('italiano', 'ADJ')	3
# (14.0, '2020_2024')	('essere', 'AUX')	3
# (14.0, '2020_2024')	('regalo', 'NOUN')	3
# (14.0, '2020_2024')	('cinque', 'NUM')	2
#
# (15.0, '1980_1984')	('zimmermann', 'ADJ')	2
# (15.0, '1980_1984')	('testazione', 'NOUN')	1
# (15.0, '1980_1984')	('tecnico', 'ADJ')	1
# (15.0, '1980_1984')	('etnere', 'VERB')	1
# (15.0, '1980_1984')	('costo', 'NOUN')	1
# (15.0, '1980_1984')	('essere', 'AUX')	1
# (15.0, '1980_1984')	('meno', 'ADV')	1
# (15.0, '1980_1984')	('pensare', 'VERB')	1
# (15.0, '1980_1984')	('zimmermann', 'NOUN')	1
# (15.0, '1980_1984')	('solonque', 'ADJ')	1
#
# (15.0, '1985_1989')	('akai', 'PROPN')	2
# (15.0, '1985_1989')	('perfezione', 'NOUN')	2
# (15.0, '1985_1989')	('akai', 'AUX')	1
# (15.0, '1985_1989')	('presentare', 'VERB')	1
# (15.0, '1985_1989')	('potenza', 'NOUN')	1
# (15.0, '1985_1989')	('radioregistraturo', 'VERB')	1
# (15.0, '1985_1989')	('forza', 'NOUN')	1
# (15.0, '1985_1989')	('ifi', 'ADP')	1
# (15.0, '1985_1989')	('immagine', 'NOUN')	1
# (15.0, '1985_1989')	('videoregistraturo', 'ADJ')	1
#
# (15.0, '1990_1994')	('5', 'NUM')	8
# (15.0, '1990_1994')	('gimmo', 'NOUN')	3
# (15.0, '1990_1994')	('suonare', 'VERB')	2
# (15.0, '1990_1994')	('essere', 'AUX')	2
# (15.0, '1990_1994')	('bontempi', 'NOUN')	2
# (15.0, '1990_1994')	('system', 'X')	2
# (15.0, '1990_1994')	('generazione', 'NOUN')	2
# (15.0, '1990_1994')	('digitale', 'ADJ')	2
# (15.0, '1990_1994')	('volere', 'VERB')	1
# (15.0, '1990_1994')	('sai', 'AUX')	1
#
# (16.0, '1980_1984')	('riuscare', 'VERB')	36
# (16.0, '1980_1984')	('essere', 'AUX')	26
# (16.0, '1980_1984')	('scottex', 'VERB')	13
# (16.0, '1980_1984')	('carta', 'NOUN')	12
# (16.0, '1980_1984')	('casa', 'NOUN')	11
# (16.0, '1980_1984')	('primo', 'ADJ')	8
# (16.0, '1980_1984')	('oggi', 'ADV')	7
# (16.0, '1980_1984')	('computer', 'NOUN')	7
# (16.0, '1980_1984')	('igienica', 'ADJ')	6
# (16.0, '1980_1984')	('morbidezza', 'NOUN')	5
#
# (16.0, '1985_1989')	('essere', 'AUX')	118
# (16.0, '1985_1989')	('primo', 'ADJ')	60
# (16.0, '1985_1989')	('grande', 'ADJ')	52
# (16.0, '1985_1989')	('fascicolo', 'NOUN')	38
# (16.0, '1985_1989')	('casa', 'NOUN')	27
# (16.0, '1985_1989')	('nuovo', 'ADJ')	27
# (16.0, '1985_1989')	('edicola', 'VERB')	26
# (16.0, '1985_1989')	('oggi', 'ADV')	24
# (16.0, '1985_1989')	('avere', 'VERB')	21
# (16.0, '1985_1989')	('settimana', 'NOUN')	19
#
# (16.0, '1990_1994')	('essere', 'AUX')	134
# (16.0, '1990_1994')	('primo', 'ADJ')	69
# (16.0, '1990_1994')	('grande', 'ADJ')	46
# (16.0, '1990_1994')	('ogni', 'DET')	44
# (16.0, '1990_1994')	('fare', 'VERB')	43
# (16.0, '1990_1994')	('avere', 'VERB')	43
# (16.0, '1990_1994')	('nuovo', 'ADJ')	40
# (16.0, '1990_1994')	('settimana', 'NOUN')	35
# (16.0, '1990_1994')	('fascicolo', 'NOUN')	32
# (16.0, '1990_1994')	('lira', 'NOUN')	29
#
# (16.0, '1995_1999')	('essere', 'AUX')	53
# (16.0, '1995_1999')	('primo', 'ADJ')	21
# (16.0, '1995_1999')	('nuovo', 'ADJ')	18
# (16.0, '1995_1999')	('casa', 'NOUN')	16
# (16.0, '1995_1999')	('avere', 'VERB')	14
# (16.0, '1995_1999')	('volere', 'VERB')	11
# (16.0, '1995_1999')	('solo', 'ADV')	11
# (16.0, '1995_1999')	('vedere', 'VERB')	10
# (16.0, '1995_1999')	('grande', 'ADJ')	10
# (16.0, '1995_1999')	('lira', 'NOUN')	10
#
# (16.0, '2000_2004')	('essere', 'AUX')	41
# (16.0, '2000_2004')	('primo', 'ADJ')	22
# (16.0, '2000_2004')	('nuovo', 'ADJ')	21
# (16.0, '2000_2004')	('the', 'DET')	20
# (16.0, '2000_2004')	('solo', 'ADV')	17
# (16.0, '2000_2004')	('grande', 'ADJ')	13
# (16.0, '2000_2004')	('avere', 'VERB')	10
# (16.0, '2000_2004')	('fascicolo', 'NOUN')	10
# (16.0, '2000_2004')	('edicola', 'VERB')	10
# (16.0, '2000_2004')	('you', 'PROPN')	10
#
# (16.0, '2005_2009')	('essere', 'AUX')	47
# (16.0, '2005_2009')	('primo', 'ADJ')	39
# (16.0, '2005_2009')	('solo', 'ADV')	38
# (16.0, '2005_2009')	('euro', 'NOUN')	35
# (16.0, '2005_2009')	('grande', 'ADJ')	24
# (16.0, '2005_2009')	('uscita', 'NOUN')	18
# (16.0, '2005_2009')	('edicola', 'VERB')	15
# (16.0, '2005_2009')	('avere', 'VERB')	15
# (16.0, '2005_2009')	('tv', 'NOUN')	13
# (16.0, '2005_2009')	('nuovo', 'ADJ')	12
#
# (16.0, '2010_2014')	('agenda', 'VERB')	3
# (16.0, '2010_2014')	('bastardidentro', 'PROPN')	3
# (16.0, '2010_2014')	('mamma', 'NOUN')	2
# (16.0, '2010_2014')	('padrone', 'NOUN')	1
# (16.0, '2010_2014')	('avere', 'VERB')	1
# (16.0, '2010_2014')	('diritto', 'NOUN')	1
# (16.0, '2010_2014')	('tre', 'NUM')	1
# (16.0, '2010_2014')	('desidero', 'VERB')	1
# (16.0, '2010_2014')	('volere', 'VERB')	1
# (16.0, '2010_2014')	('gallo', 'NOUN')	1
#
# (16.0, '2015_2019')	('ipnoticam', 'PROPN')	3
# (16.0, '2015_2019')	('de', 'ADP')	3
# (16.0, '2015_2019')	('bastardidentro', 'NOUN')	3
# (16.0, '2015_2019')	('avventura', 'NOUN')	2
# (16.0, '2015_2019')	('bastardidentro', 'PROPN')	1
# (16.0, '2015_2019')	('agenda', 'VERB')	1
# (16.0, '2015_2019')	('2017', 'NUM')	1
# (16.0, '2015_2019')	('ipnoticamente', 'ADV')	1
# (16.0, '2015_2019')	('segreto', 'ADJ')	1
# (16.0, '2015_2019')	('spongebob', 'ADJ')	1
#
# (16.0, '2020_2024')	('essere', 'AUX')	6
# (16.0, '2020_2024')	('libertà', 'NOUN')	3
# (16.0, '2020_2024')	('casa', 'NOUN')	3
# (16.0, '2020_2024')	('valere', 'VERB')	2
# (16.0, '2020_2024')	('te', 'PRON')	2
# (16.0, '2020_2024')	('asciugare', 'VERB')	2
# (16.0, '2020_2024')	('mano', 'NOUN')	2
# (16.0, '2020_2024')	('informare', 'VERB')	1
# (16.0, '2020_2024')	('sapere', 'VERB')	1
# (16.0, '2020_2024')	('capire', 'VERB')	1
#
# (17.0, '1985_1989')	('saratoga', 'ADJ')	3
# (17.0, '1985_1989')	('silicone', 'NOUN')	3
# (17.0, '1985_1989')	('sigillante', 'ADJ')	3
# (17.0, '1985_1989')	('colla', 'ADP')	2
# (17.0, '1985_1989')	('bisonte', 'ADJ')	2
# (17.0, '1985_1989')	('quando', 'SCONJ')	2
# (17.0, '1985_1989')	('incollo', 'VERB')	2
# (17.0, '1985_1989')	('staccare', 'VERB')	2
# (17.0, '1985_1989')	('essere', 'AUX')	2
# (17.0, '1985_1989')	('bison', 'VERB')	1
#
# (17.0, '1990_1994')	('silicone', 'NOUN')	4
# (17.0, '1990_1994')	('sigillante', 'ADJ')	4
# (17.0, '1990_1994')	('saratoga', 'ADJ')	2
# (17.0, '1990_1994')	('saratoga', 'VERB')	2
# (17.0, '1990_1994')	('leader', 'NOUN')	1
#
# (17.0, '1995_1999')	('lavoro', 'NOUN')	2
# (17.0, '1995_1999')	('h40', 'PROPN')	2
# (17.0, '1995_1999')	('ciao', 'NOUN')	1
# (17.0, '1995_1999')	('oggi', 'ADV')	1
# (17.0, '1995_1999')	('avere', 'VERB')	1
# (17.0, '1995_1999')	('fare', 'VERB')	1
# (17.0, '1995_1999')	('buono', 'ADJ')	1
# (17.0, '1995_1999')	('essere', 'AUX')	1
# (17.0, '1995_1999')	('adesivo', 'ADJ')	1
# (17.0, '1995_1999')	('dare', 'VERB')	1
#
# (17.0, '2005_2009')	('silicone', 'NOUN')	3
# (17.0, '2005_2009')	('saratoga', 'ADJ')	2
# (17.0, '2005_2009')	('bostik', 'NOUN')	2
# (17.0, '2005_2009')	('sigillante', 'ADJ')	1
# (17.0, '2005_2009')	('saratoga', 'VERB')	1
# (17.0, '2005_2009')	('elastico', 'ADJ')	1
# (17.0, '2005_2009')	('impenetrabile', 'ADJ')	1
# (17.0, '2005_2009')	('inalterabile', 'ADJ')	1
# (17.0, '2005_2009')	('prova', 'VERB')	1
# (17.0, '2005_2009')	('dacquariare', 'VERB')	1
#
# (18.0, '1980_1984')	('bello', 'ADJ')	6
# (18.0, '1980_1984')	('pelle', 'NOUN')	4
# (18.0, '1980_1984')	('annabella', 'PROPN')	2
# (18.0, '1980_1984')	('solo', 'ADV')	2
# (18.0, '1980_1984')	('combipel', 'ADJ')	2
# (18.0, '1980_1984')	('pelliccia', 'NOUN')	2
# (18.0, '1980_1984')	('gente', 'NOUN')	2
# (18.0, '1980_1984')	('scichissimo', 'ADJ')	2
# (18.0, '1980_1984')	('essere', 'AUX')	2
# (18.0, '1980_1984')	('fuori', 'ADP')	2
#
# (18.0, '1985_1989')	('armony', 'ADJ')	6
# (18.0, '1985_1989')	('essere', 'AUX')	5
# (18.0, '1985_1989')	('pelliccia', 'NOUN')	5
# (18.0, '1985_1989')	('panington', 'PROPN')	4
# (18.0, '1985_1989')	('solo', 'ADV')	4
# (18.0, '1985_1989')	('incredibile', 'ADJ')	4
# (18.0, '1985_1989')	('bisogno', 'NOUN')	4
# (18.0, '1985_1989')	('avere', 'VERB')	4
# (18.0, '1985_1989')	('4', 'NUM')	4
# (18.0, '1985_1989')	('grande', 'ADJ')	3
#
# (18.0, '1990_1994')	('essere', 'AUX')	5
# (18.0, '1990_1994')	('samsonite', 'VERB')	3
# (18.0, '1990_1994')	('bello', 'ADJ')	3
# (18.0, '1990_1994')	('valigia', 'VERB')	3
# (18.0, '1990_1994')	('stare', 'VERB')	2
# (18.0, '1990_1994')	('sacco', 'NOUN')	2
# (18.0, '1990_1994')	('diverso', 'ADJ')	2
# (18.0, '1990_1994')	('scegliere', 'VERB')	2
# (18.0, '1990_1994')	('portare', 'VERB')	2
# (18.0, '1990_1994')	('dietro', 'ADP')	2
#
# (18.0, '1995_1999')	('scuola', 'NOUN')	14
# (18.0, '1995_1999')	('essere', 'AUX')	10
# (18.0, '1995_1999')	('calimero', 'ADJ')	6
# (18.0, '1995_1999')	('millecuori', 'NOUN')	6
# (18.0, '1995_1999')	('tanto', 'ADV')	5
# (18.0, '1995_1999')	('barbie', 'PROPN')	5
# (18.0, '1995_1999')	('volere', 'VERB')	4
# (18.0, '1995_1999')	('zaino', 'PROPN')	4
# (18.0, '1995_1999')	('andare', 'VERB')	4
# (18.0, '1995_1999')	('barbie', 'ADJ')	4
#
# (18.0, '2000_2004')	('essere', 'AUX')	4
# (18.0, '2000_2004')	('hamtaro', 'PROPN')	4
# (18.0, '2000_2004')	('jackie', 'NOUN')	3
# (18.0, '2000_2004')	('chan', 'NOUN')	3
# (18.0, '2000_2004')	('nenuco', 'ADJ')	2
# (18.0, '2000_2004')	('hamtaro', 'NOUN')	2
# (18.0, '2000_2004')	('avere', 'VERB')	2
# (18.0, '2000_2004')	('zaino', 'ADJ')	2
# (18.0, '2000_2004')	('scuola', 'NOUN')	2
# (18.0, '2000_2004')	('giochi', 'NOUN')	2
#
# (18.0, '2005_2009')	('scuola', 'NOUN')	3
# (18.0, '2005_2009')	('essere', 'AUX')	3
# (18.0, '2005_2009')	('dragon', 'VERB')	3
# (18.0, '2005_2009')	('astucci', 'PROPN')	2
# (18.0, '2005_2009')	('diare', 'VERB')	2
# (18.0, '2005_2009')	('by', 'PROPN')	2
# (18.0, '2005_2009')	('arrivare', 'VERB')	1
# (18.0, '2005_2009')	('ball', 'PROPN')	1
# (18.0, '2005_2009')	('mania', 'PROPN')	1
# (18.0, '2005_2009')	('zaini', 'PROPN')	1
#
# (18.0, '2010_2014')	('essere', 'AUX')	5
# (18.0, '2010_2014')	('migliore', 'ADJ')	3
# (18.0, '2010_2014')	('subito', 'ADV')	2
# (18.0, '2010_2014')	('luminoso', 'ADJ')	2
# (18.0, '2010_2014')	('attenzione', 'NOUN')	2
# (18.0, '2010_2014')	('fare', 'VERB')	2
# (18.0, '2010_2014')	('be', 'PROPN')	2
# (18.0, '2010_2014')	('smj', 'AUX')	2
# (18.0, '2010_2014')	('volta', 'NOUN')	1
# (18.0, '2010_2014')	('avere', 'VERB')	1
#
# (18.0, '2015_2019')	('essere', 'AUX')	7
# (18.0, '2015_2019')	('avere', 'VERB')	5
# (18.0, '2015_2019')	('zaini', 'NOUN')	5
# (18.0, '2015_2019')	('trolley', 'PROPN')	4
# (18.0, '2015_2019')	('scuola', 'NOUN')	3
# (18.0, '2015_2019')	('magico', 'ADJ')	3
# (18.0, '2015_2019')	('incanto', 'NOUN')	3
# (18.0, '2015_2019')	('seven', 'ADV')	3
# (18.0, '2015_2019')	('città', 'NOUN')	2
# (18.0, '2015_2019')	('cambiare', 'VERB')	2
#
# (18.0, '2020_2024')	('essere', 'AUX')	10
# (18.0, '2020_2024')	('go', 'ADP')	8
# (18.0, '2020_2024')	('cambiare', 'VERB')	5
# (18.0, '2020_2024')	('zaini', 'NOUN')	4
# (18.0, '2020_2024')	('stile', 'NOUN')	4
# (18.0, '2020_2024')	('pop', 'X')	4
# (18.0, '2020_2024')	('scuola', 'NOUN')	3
# (18.0, '2020_2024')	('nuovo', 'ADJ')	3
# (18.0, '2020_2024')	('zaino', 'ADV')	3
# (18.0, '2020_2024')	('sempre', 'ADV')	3
#
# (19.0, '1980_1984')	('montecchi', 'ADJ')	2
# (19.0, '1980_1984')	('cotto', 'ADJ')	2
# (19.0, '1980_1984')	('montecchi', 'NOUN')	2
# (19.0, '1980_1984')	('firenze', 'NOUN')	2
# (19.0, '1980_1984')	('essere', 'AUX')	1
# (19.0, '1980_1984')	('mortificare', 'VERB')	1
# (19.0, '1980_1984')	('preoccupire', 'VERB')	1
# (19.0, '1980_1984')	('qui', 'ADV')	1
# (19.0, '1980_1984')	('sotto', 'ADP')	1
# (19.0, '1980_1984')	('cotto', 'NOUN')	1
#
# (19.0, '1985_1989')	('atlas', 'NOUN')	5
# (19.0, '1985_1989')	('concorde', 'ADJ')	5
# (19.0, '1985_1989')	('ceramiche', 'NOUN')	2
# (19.0, '1985_1989')	('ceramico', 'ADJ')	2
# (19.0, '1985_1989')	('essere', 'AUX')	1
# (19.0, '1985_1989')	('bello', 'ADJ')	1
# (19.0, '1985_1989')	('sconvolgente', 'ADJ')	1
# (19.0, '1985_1989')	('sopporto', 'VERB')	1
# (19.0, '1985_1989')	('resistente', 'ADJ')	1
# (19.0, '1985_1989')	('preziosi', 'ADJ')	1
#
# (19.0, '2005_2009')	('casa', 'NOUN')	1
# (19.0, '2005_2009')	('arte', 'ADJ')	1
# (19.0, '2005_2009')	('listone', 'NOUN')	1
# (19.0, '2005_2009')	('giordano', 'VERB')	1
#
# (20.0, '1980_1984')	('arredare', 'VERB')	7
# (20.0, '1980_1984')	('plus', 'NOUN')	5
# (20.0, '1980_1984')	('arredamenti', 'ADJ')	5
# (20.0, '1980_1984')	('cucina', 'NOUN')	5
# (20.0, '1980_1984')	('faram', 'ADJ')	5
# (20.0, '1980_1984')	('essere', 'AUX')	4
# (20.0, '1980_1984')	('grand', 'PROPN')	4
# (20.0, '1980_1984')	('soleil', 'PROPN')	4
# (20.0, '1980_1984')	('bambino', 'NOUN')	4
# (20.0, '1980_1984')	('italiano', 'ADJ')	4
#
# (20.0, '1985_1989')	('essere', 'AUX')	19
# ...
# (38.0, '2020_2024')	('sempre', 'ADV')	9
# (38.0, '2020_2024')	('solo', 'ADV')	9
# (38.0, '2020_2024')	('sky', 'AUX')	9
#
# (39.0, '1980_1984')	('essere', 'AUX')	7
# (39.0, '1980_1984')	('carlo', 'PROPN')	4
# (39.0, '1980_1984')	('fantastico', 'ADJ')	2
# (39.0, '1980_1984')	('volare', 'VERB')	2
# (39.0, '1980_1984')	('new', 'PROPN')	2
# (39.0, '1980_1984')	('york', 'PROPN')	2
# (39.0, '1980_1984')	('invece', 'ADV')	2
# (39.0, '1980_1984')	('andare', 'VERB')	2
# (39.0, '1980_1984')	('fare', 'VERB')	2
# (39.0, '1980_1984')	('poi', 'ADV')	2
#
# (39.0, '1985_1989')	('essere', 'AUX')	8
# (39.0, '1985_1989')	('avere', 'VERB')	5
# (39.0, '1985_1989')	('dhl', 'SCONJ')	3
# (39.0, '1985_1989')	('tempo', 'NOUN')	3
# (39.0, '1985_1989')	('lauro', 'NOUN')	2
# (39.0, '1985_1989')	('crociera', 'NOUN')	2
# (39.0, '1985_1989')	('spagna', 'ADJ')	2
# (39.0, '1985_1989')	('portogallo', 'ADJ')	2
# (39.0, '1985_1989')	('marocco', 'ADJ')	2
# (39.0, '1985_1989')	('giorno', 'NOUN')	2
#
# (39.0, '1990_1994')	('essere', 'AUX')	10
# (39.0, '1990_1994')	('fare', 'VERB')	7
# (39.0, '1990_1994')	('volare', 'VERB')	4
# (39.0, '1990_1994')	('alitalia', 'ADJ')	4
# (39.0, '1990_1994')	('express', 'NOUN')	3
# (39.0, '1990_1994')	('vero', 'ADJ')	3
# (39.0, '1990_1994')	('giorno', 'NOUN')	3
# (39.0, '1990_1994')	('sette', 'NUM')	3
# (39.0, '1990_1994')	('avere', 'VERB')	3
# (39.0, '1990_1994')	('qualcuno', 'PRON')	3
#
# (39.0, '1995_1999')	('essere', 'AUX')	6
# (39.0, '1995_1999')	('vino', 'NOUN')	3
# (39.0, '1995_1999')	('avere', 'VERB')	3
# (39.0, '1995_1999')	('lavoro', 'NOUN')	3
# (39.0, '1995_1999')	('delta', 'VERB')	2
# (39.0, '1995_1999')	('fare', 'VERB')	2
# (39.0, '1995_1999')	('volare', 'VERB')	2
# (39.0, '1995_1999')	('servizio', 'NOUN')	2
# (39.0, '1995_1999')	('figlio', 'NOUN')	2
# (39.0, '1995_1999')	('oggi', 'ADV')	2
#
# (39.0, '2000_2004')	('essere', 'AUX')	6
# (39.0, '2000_2004')	('massimo', 'ADJ')	5
# (39.0, '2000_2004')	('comfort', 'NOUN')	3
# (39.0, '2000_2004')	('migliore', 'ADJ')	3
# (39.0, '2000_2004')	('servizio', 'NOUN')	3
# (39.0, '2000_2004')	('funzionare', 'VERB')	3
# (39.0, '2000_2004')	('volare', 'VERB')	2
# (39.0, '2000_2004')	('naturalmente', 'ADV')	2
# (39.0, '2000_2004')	('spazio', 'NOUN')	2
# (39.0, '2000_2004')	('alitalia', 'ADJ')	2
#
# (39.0, '2005_2009')	('zio', 'NOUN')	5
# (39.0, '2005_2009')	('vacanza', 'NOUN')	5
# (39.0, '2005_2009')	('prima', 'ADV')	4
# (39.0, '2005_2009')	('subito', 'ADV')	3
# (39.0, '2005_2009')	('porta', 'PROPN')	3
# (39.0, '2005_2009')	('treno', 'NOUN')	3
# (39.0, '2005_2009')	('essere', 'AUX')	3
# (39.0, '2005_2009')	('giorno', 'ADJ')	3
# (39.0, '2005_2009')	('te', 'PRON')	3
# (39.0, '2005_2009')	('costa', 'VERB')	3
#
# (39.0, '2020_2024')	('energia', 'NOUN')	3
# (39.0, '2020_2024')	('essere', 'AUX')	2
# (39.0, '2020_2024')	('stesso', 'ADJ')	2
# (39.0, '2020_2024')	('diverso', 'ADJ')	2
# (39.0, '2020_2024')	('noleggiare', 'VERB')	1
# (39.0, '2020_2024')	('locauto', 'NOUN')	1
# (39.0, '2020_2024')	('semplice', 'ADJ')	1
# (39.0, '2020_2024')	('veloce', 'ADJ')	1
# (39.0, '2020_2024')	('potere', 'NOUN')	1
# (39.0, '2020_2024')	('entrare', 'VERB')	1
#
# (40.0, '1985_1989')	('colore', 'NOUN')	5
# (40.0, '1985_1989')	('fare', 'VERB')	5
# (40.0, '1985_1989')	('agfa', 'ADJ')	4
# (40.0, '1985_1989')	('color', 'NOUN')	4
# (40.0, '1985_1989')	('essere', 'AUX')	3
# (40.0, '1985_1989')	('service', 'ADJ')	3
# (40.0, '1985_1989')	('vero', 'ADJ')	2
# (40.0, '1985_1989')	('merire', 'VERB')	2
# (40.0, '1985_1989')	('ragazzo', 'NOUN')	2
# (40.0, '1985_1989')	('grazie', 'NOUN')	2
#
# (41.0, '1980_1984')	('essere', 'AUX')	5
# (41.0, '1980_1984')	('computer', 'NOUN')	3
# (41.0, '1980_1984')	('schedina', 'VERB')	3
# (41.0, '1980_1984')	('totocalcio', 'NOUN')	2
# (41.0, '1980_1984')	('facile', 'ADJ')	2
# (41.0, '1980_1984')	('certo', 'ADV')	2
# (41.0, '1980_1984')	('ricopiare', 'VERB')	2
# (41.0, '1980_1984')	('solo', 'ADV')	2
# (41.0, '1980_1984')	('valtellina', 'VERB')	2
# (41.0, '1980_1984')	('entrare', 'VERB')	1
#
# (41.0, '1985_1989')	('essere', 'AUX')	10
# (41.0, '1985_1989')	('premio', 'NOUN')	10
# (41.0, '1985_1989')	('miliardo', 'NOUN')	7
# (41.0, '1985_1989')	('lotteria', 'ADJ')	5
# (41.0, '1985_1989')	('merano', 'VERB')	5
# (41.0, '1985_1989')	('grande', 'ADJ')	4
# (41.0, '1985_1989')	('giocare', 'VERB')	4
# (41.0, '1985_1989')	('totip', 'NOUN')	4
# (41.0, '1985_1989')	('milione', 'NOUN')	4
# (41.0, '1985_1989')	('calcio', 'NOUN')	3
#
# (41.0, '1990_1994')	('essere', 'AUX')	6
# (41.0, '1990_1994')	('lavoro', 'NOUN')	5
# (41.0, '1990_1994')	('gratuito', 'ADJ')	5
# (41.0, '1990_1994')	('tempo', 'NOUN')	5
# (41.0, '1990_1994')	('lotteria', 'ADJ')	5
# (41.0, '1990_1994')	('premio', 'NOUN')	5
# (41.0, '1990_1994')	('totip', 'NOUN')	4
# (41.0, '1990_1994')	('due', 'NUM')	4
# (41.0, '1990_1994')	('vuoi', 'AUX')	4
# (41.0, '1990_1994')	('libretto', 'ADJ')	4
#
# (41.0, '1995_1999')	('subito', 'ADV')	3
# (41.0, '1995_1999')	('essere', 'AUX')	3
# (41.0, '1995_1999')	('167', 'NUM')	3
# (41.0, '1995_1999')	('cepu', 'NOUN')	3
# (41.0, '1995_1999')	('natale', 'ADJ')	2
# (41.0, '1995_1999')	('questanno', 'AUX')	2
# (41.0, '1995_1999')	('avere', 'AUX')	2
# (41.0, '1995_1999')	('fare', 'VERB')	2
# (41.0, '1995_1999')	('fortuna', 'NOUN')	2
# (41.0, '1995_1999')	('sotto', 'ADP')	2
#
# (41.0, '2000_2004')	('tempo', 'NOUN')	8
# (41.0, '2000_2004')	('formazione', 'NOUN')	4
# (41.0, '2000_2004')	('fare', 'VERB')	4
# (41.0, '2000_2004')	('cisco', 'ADJ')	3
# (41.0, '2000_2004')	('comunicazione', 'NOUN')	3
# (41.0, '2000_2004')	('marketing', 'NOUN')	3
# (41.0, '2000_2004')	('viaggio', 'NOUN')	2
# (41.0, '2000_2004')	('programma', 'NOUN')	2
# (41.0, '2000_2004')	('tradizionale', 'ADJ')	2
# (41.0, '2000_2004')	('avere', 'AUX')	2
#
# (41.0, '2005_2009')	('essere', 'AUX')	12
# (41.0, '2005_2009')	('giorno', 'NOUN')	7
# (41.0, '2005_2009')	('talento', 'NOUN')	7
# (41.0, '2005_2009')	('euro', 'NOUN')	7
# (41.0, '2005_2009')	('divertimento', 'NOUN')	6
# (41.0, '2005_2009')	('vincere', 'VERB')	6
# (41.0, '2005_2009')	('subito', 'ADV')	5
# (41.0, '2005_2009')	('numero', 'NOUN')	5
# (41.0, '2005_2009')	('gratis', 'ADV')	4
# (41.0, '2005_2009')	('italia', 'PROPN')	4
#
# (41.0, '2020_2024')	('gioco', 'NOUN')	4
# (41.0, '2020_2024')	('volere', 'VERB')	2
# (41.0, '2020_2024')	('tanto', 'ADV')	2
# (41.0, '2020_2024')	('sottotitoli', 'NOUN')	1
# (41.0, '2020_2024')	('creare', 'VERB')	1
# (41.0, '2020_2024')	('comunità', 'NOUN')	1
# (41.0, '2020_2024')	('amaraorg', 'VERB')	1
# (41.0, '2020_2024')	('giocchi', 'DET')	1
# (41.0, '2020_2024')	('ancora', 'ADV')	1
# (41.0, '2020_2024')	('gioco', 'VERB')	1
#
# (42.0, '1995_1999')	('tv', 'NOUN')	3
# (42.0, '1995_1999')	('mediaset', 'NOUN')	2
# (42.0, '1995_1999')	('on', 'X')	2
# (42.0, '1995_1999')	('line', 'NOUN')	2
# (42.0, '1995_1999')	('volere', 'VERB')	2
# (42.0, '1995_1999')	('te', 'PRON')	2
# (42.0, '1995_1999')	('avere', 'VERB')	1
# (42.0, '1995_1999')	('trovare', 'VERB')	1
# (42.0, '1995_1999')	('qui', 'ADV')	1
# (42.0, '1995_1999')	('guida', 'NOUN')	1
#
# (42.0, '2000_2004')	('essere', 'AUX')	6
# (42.0, '2000_2004')	('apriti', 'NOUN')	5
# (42.0, '2000_2004')	('apriti', 'ADJ')	5
# (42.0, '2000_2004')	('trovare', 'VERB')	4
# (42.0, '2000_2004')	('sedare', 'VERB')	4
# (42.0, '2000_2004')	('oggi', 'ADV')	3
# (42.0, '2000_2004')	('pensare', 'VERB')	3
# (42.0, '2000_2004')	('modo', 'NOUN')	2
# (42.0, '2000_2004')	('nuovo', 'ADJ')	2
# (42.0, '2000_2004')	('cercare', 'VERB')	2
#
# (42.0, '2005_2009')	('codice', 'NOUN')	3
# (42.0, '2005_2009')	('segreto', 'ADJ')	3
# (42.0, '2005_2009')	('settimana', 'NOUN')	2
# (42.0, '2005_2009')	('tv', 'NOUN')	2
# (42.0, '2005_2009')	('essere', 'AUX')	2
# (42.0, '2005_2009')	('potere', 'NOUN')	1
# (42.0, '2005_2009')	('vincere', 'VERB')	1
# (42.0, '2005_2009')	('molto', 'DET')	1
# (42.0, '2005_2009')	('premio', 'NOUN')	1
# (42.0, '2005_2009')	('soggiorno', 'ADP')	1
#
# (42.0, '2020_2024')	('essere', 'AUX')	7
# (42.0, '2020_2024')	('trovare', 'VERB')	5
# (42.0, '2020_2024')	('potere', 'NOUN')	4
# (42.0, '2020_2024')	('tempo', 'NOUN')	3
# (42.0, '2020_2024')	('facile', 'ADJ')	3
# (42.0, '2020_2024')	('inplace', 'ADJ')	3
# (42.0, '2020_2024')	('famiglia', 'NOUN')	2
# (42.0, '2020_2024')	('aiutare', 'VERB')	2
# (42.0, '2020_2024')	('virtuale', 'ADJ')	2
# (42.0, '2020_2024')	('lavoro', 'NOUN')	2
#
# (43.0, '1980_1984')	('essere', 'AUX')	5
# (43.0, '1980_1984')	('viaggi', 'NOUN')	5
# (43.0, '1980_1984')	('alpitour', 'PROPN')	4
# (43.0, '1980_1984')	('viaggio', 'NOUN')	3
# (43.0, '1980_1984')	('presentare', 'VERB')	2
# (43.0, '1980_1984')	('super', 'ADJ')	2
# (43.0, '1980_1984')	('fare', 'VERB')	2
# (43.0, '1980_1984')	('programma', 'NOUN')	2
# (43.0, '1980_1984')	('volare', 'VERB')	2
# (43.0, '1980_1984')	('prenotazione', 'NOUN')	2
#
# (43.0, '1985_1989')	('lontano', 'ADV')	15
# (43.0, '1985_1989')	('essere', 'AUX')	13
# (43.0, '1985_1989')	('vacanza', 'NOUN')	10
# (43.0, '1985_1989')	('hamburger', 'PROPN')	9
# (43.0, '1985_1989')	('hamburger', 'NOUN')	7
# (43.0, '1985_1989')	('alpitour', 'NOUN')	7
# (43.0, '1985_1989')	('italiano', 'ADJ')	6
# (43.0, '1985_1989')	('te', 'PRON')	5
# (43.0, '1985_1989')	('dellavventurare', 'VERB')	5
# (43.0, '1985_1989')	('marlboro', 'ADJ')	5
#
# (43.0, '1990_1994')	('club', 'NOUN')	2
# (43.0, '1990_1994')	('med', 'PROPN')	2
# (43.0, '1990_1994')	('vita', 'VERB')	2
# (43.0, '1990_1994')	('vacanza', 'NOUN')	2
# (43.0, '1990_1994')	('lanzarote', 'NOUN')	2
# (43.0, '1990_1994')	('villaggi', 'NOUN')	2
# (43.0, '1990_1994')	('valtur', 'NOUN')	2
# (43.0, '1990_1994')	('quando', 'SCONJ')	1
# (43.0, '1990_1994')	('vita', 'NOUN')	1
# (43.0, '1990_1994')	('aprire', 'VERB')	1
#
# (43.0, '1995_1999')	('lhaare', 'VERB')	4
# (43.0, '1995_1999')	('avere', 'VERB')	3
# (43.0, '1995_1999')	('soluzione', 'NOUN')	3
# (43.0, '1995_1999')	('essere', 'AUX')	3
# (43.0, '1995_1999')	('imprevisto', 'NOUN')	2
# (43.0, '1995_1999')	('imprevedibile', 'ADJ')	2
# (43.0, '1995_1999')	('alpiturti', 'DET')	2
# (43.0, '1995_1999')	('carta', 'NOUN')	2
# (43.0, '1995_1999')	('blu', 'ADJ')	2
# (43.0, '1995_1999')	('caso', 'VERB')	1
#
# (43.0, '2000_2004')	('essere', 'AUX')	13
# (43.0, '2000_2004')	('it', 'ADP')	9
# (43.0, '2000_2004')	('meal', 'NOUN')	7
# (43.0, '2000_2004')	('ogni', 'DET')	6
# (43.0, '2000_2004')	('im', 'ADP')	6
# (43.0, '2000_2004')	('mcdonalds', 'VERB')	5
# (43.0, '2000_2004')	('happy', 'X')	5
# (43.0, '2000_2004')	('loving', 'NOUN')	5
# (43.0, '2000_2004')	('avere', 'VERB')	4
# (43.0, '2000_2004')	('spizzico', 'ADJ')	4
#
# (43.0, '2005_2009')	('nuovo', 'ADJ')	7
# (43.0, '2005_2009')	('mcdonalds', 'VERB')	5
# (43.0, '2005_2009')	('meal', 'NOUN')	4
# (43.0, '2005_2009')	('solo', 'ADV')	4
# (43.0, '2005_2009')	('cheeseburger', 'NOUN')	3
# (43.0, '2005_2009')	('viare', 'VERB')	3
# (43.0, '2005_2009')	('fare', 'VERB')	2
# (43.0, '2005_2009')	('quando', 'SCONJ')	2
# (43.0, '2005_2009')	('andare', 'VERB')	2
# (43.0, '2005_2009')	('essere', 'AUX')	2
#
# (43.0, '2010_2014')	('essere', 'AUX')	28
# (43.0, '2010_2014')	('mcdonalds', 'VERB')	15
# (43.0, '2010_2014')	('nuovo', 'ADJ')	9
# (43.0, '2010_2014')	('fare', 'VERB')	7
# (43.0, '2010_2014')	('sapere', 'VERB')	7
# (43.0, '2010_2014')	('vincere', 'VERB')	6
# (43.0, '2010_2014')	('big', 'NOUN')	5
# (43.0, '2010_2014')	('avere', 'AUX')	4
# (43.0, '2010_2014')	('ogni', 'DET')	4
# (43.0, '2010_2014')	('gusto', 'NOUN')	4
#
# (43.0, '2015_2019')	('essere', 'AUX')	8
# (43.0, '2015_2019')	('mcdonalds', 'VERB')	5
# (43.0, '2015_2019')	('quattro', 'NUM')	4
# (43.0, '2015_2019')	('menu', 'NOUN')	4
# (43.0, '2015_2019')	('crispy', 'NOUN')	4
# (43.0, '2015_2019')	('fare', 'VERB')	4
# (43.0, '2015_2019')	('avere', 'VERB')	3
# (43.0, '2015_2019')	('nuovo', 'ADJ')	3
# (43.0, '2015_2019')	('big', 'NOUN')	3
# (43.0, '2015_2019')	('buon', 'ADJ')	3
#
# (43.0, '2020_2024')	('sapere', 'VERB')	14
# (43.0, '2020_2024')	('essere', 'AUX')	13
# (43.0, '2020_2024')	('perchè', 'SCONJ')	13
# (43.0, '2020_2024')	('avere', 'VERB')	8
# (43.0, '2020_2024')	('italiano', 'ADJ')	7
# (43.0, '2020_2024')	('sempre', 'ADV')	6
# (43.0, '2020_2024')	('mcdonalds', 'VERB')	6
# (43.0, '2020_2024')	('nuovo', 'ADJ')	5
# (43.0, '2020_2024')	('solo', 'ADV')	5
# (43.0, '2020_2024')	('salsa', 'NOUN')	5
#
# (44.0, '1980_1984')	('capello', 'ADP')	4
# (44.0, '1980_1984')	('centro', 'NOUN')	3
# (44.0, '1980_1984')	('essere', 'AUX')	3
# (44.0, '1980_1984')	('telefonate', 'NOUN')	2
# (44.0, '1980_1984')	('tf', 'ADP')	2
# (44.0, '1980_1984')	('salve', 'ADJ')	2
# (44.0, '1980_1984')	('capello', 'NOUN')	2
# (44.0, '1980_1984')	('subito', 'ADV')	2
# (44.0, '1980_1984')	('problema', 'NOUN')	1
# (44.0, '1980_1984')	('cesare', 'VERB')	1
#
# (44.0, '1985_1989')	('ok', 'X')	110
# (44.0, '1985_1989')	('avere', 'VERB')	8
# (44.0, '1985_1989')	('vedere', 'VERB')	5
# (44.0, '1985_1989')	('problema', 'NOUN')	5
# (44.0, '1985_1989')	('firenze', 'NOUN')	5
# (44.0, '1985_1989')	('soluzione', 'NOUN')	4
# (44.0, '1985_1989')	('cetrin', 'NOUN')	4
# (44.0, '1985_1989')	('parrucchino', 'NOUN')	3
# (44.0, '1985_1989')	('medicenter', 'ADJ')	3
# (44.0, '1985_1989')	('avere', 'AUX')	3
#
# (44.0, '1990_1994')	('essere', 'AUX')	5
# (44.0, '1990_1994')	('calvizia', 'NOUN')	2
# (44.0, '1990_1994')	('problema', 'NOUN')	2
# (44.0, '1990_1994')	('avere', 'VERB')	2
# (44.0, '1990_1994')	('medicenter', 'PROPN')	2
# (44.0, '1990_1994')	('calvo', 'ADJ')	1
# (44.0, '1990_1994')	('sembrare', 'VERB')	1
# (44.0, '1990_1994')	('impossibile', 'ADJ')	1
# (44.0, '1990_1994')	('vero', 'ADJ')	1
# (44.0, '1990_1994')	('avere', 'AUX')	1
#
# (44.0, '1995_1999')	('essere', 'AUX')	6
# (44.0, '1995_1999')	('potere', 'NOUN')	5
# (44.0, '1995_1999')	('centro', 'NOUN')	4
# (44.0, '1995_1999')	('tanto', 'ADV')	2
# (44.0, '1995_1999')	('tradizione', 'NOUN')	2
# (44.0, '1995_1999')	('immagine', 'NOUN')	2
# (44.0, '1995_1999')	('avere', 'VERB')	2
# (44.0, '1995_1999')	('ritrovare', 'VERB')	2
# (44.0, '1995_1999')	('capello', 'ADJ')	2
# (44.0, '1995_1999')	('medicenter', 'PROPN')	2
#
# (44.0, '2000_2004')	('essere', 'AUX')	1
# (44.0, '2000_2004')	('art', 'ADV')	1
# (44.0, '2000_2004')	('hair', 'X')	1
# (44.0, '2000_2004')	('studios', 'NOUN')	1
# (44.0, '2000_2004')	('parrucchiero', 'AUX')	1
# (44.0, '2000_2004')	('volere', 'VERB')	1
#
# (44.0, '2005_2009')	('essere', 'AUX')	5
# (44.0, '2005_2009')	('primo', 'ADJ')	3
# (44.0, '2005_2009')	('gratuito', 'ADJ')	3
# (44.0, '2005_2009')	('chirurgo', 'NOUN')	2
# (44.0, '2005_2009')	('estetico', 'ADJ')	2
# (44.0, '2005_2009')	('potere', 'NOUN')	2
# (44.0, '2005_2009')	('numero', 'NOUN')	2
# (44.0, '2005_2009')	('medico', 'ADJ')	2
# (44.0, '2005_2009')	('trattamento', 'NOUN')	2
# (44.0, '2005_2009')	('realizzare', 'VERB')	2
#
# (45.0, '1985_1989')	('mago', 'ADJ')	3
# (45.0, '1985_1989')	('essere', 'AUX')	3
# (45.0, '1985_1989')	('cosa', 'PRON')	2
# (45.0, '1985_1989')	('napoli', 'ADJ')	2
# (45.0, '1985_1989')	('22', 'NUM')	2
# (45.0, '1985_1989')	('26', 'NUM')	2
# (45.0, '1985_1989')	('ottobre', 'NOUN')	2
# (45.0, '1985_1989')	('volere', 'VERB')	2
# (45.0, '1985_1989')	('certo', 'ADV')	2
# (45.0, '1985_1989')	('democrazia', 'NOUN')	2
#
# (45.0, '1990_1994')	('essere', 'AUX')	12
# (45.0, '1990_1994')	('referendum', 'NOUN')	4
# (45.0, '1990_1994')	('italiano', 'ADJ')	3
# (45.0, '1990_1994')	('fiore', 'ADJ')	3
# (45.0, '1990_1994')	('italia', 'PROPN')	3
# (45.0, '1990_1994')	('fare', 'VERB')	3
# (45.0, '1990_1994')	('potere', 'NOUN')	3
# (45.0, '1990_1994')	('prendere', 'VERB')	3
# (45.0, '1990_1994')	('dobbiamo', 'AUX')	3
# (45.0, '1990_1994')	('sapere', 'VERB')	3
#
# (45.0, '2000_2004')	('sai', 'VERB')	1
# (45.0, '2000_2004')	('cosa', 'NOUN')	1
# (45.0, '2000_2004')	('pensare', 'VERB')	1
# (45.0, '2000_2004')	('avere', 'VERB')	1
# (45.0, '2000_2004')	('bisogno', 'NOUN')	1
# (45.0, '2000_2004')	('entrambi', 'ADJ')	1
# (45.0, '2000_2004')	('compagnia', 'NOUN')	1
# (45.0, '2000_2004')	('femminile', 'ADJ')	1
# (45.0, '2000_2004')	('potremmo', 'AUX')	1
# (45.0, '2000_2004')	('chiacchierare', 'VERB')	1
#
# (45.0, '2005_2009')	('incontrare', 'VERB')	3
# (45.0, '2005_2009')	('persona', 'NOUN')	3
# (45.0, '2005_2009')	('essere', 'AUX')	2
# (45.0, '2005_2009')	('entra', 'VERB')	2
# (45.0, '2005_2009')	('club', 'NOUN')	2
# (45.0, '2005_2009')	('invia', 'ADV')	2
# (45.0, '2005_2009')	('sms', 'NOUN')	2
# (45.0, '2005_2009')	('scritto', 'VERB')	2
# (45.0, '2005_2009')	('foto', 'NOUN')	2
# (45.0, '2005_2009')	('numero', 'NOUN')	2
#
# (45.0, '2020_2024')	('volere', 'VERB')	2
# (45.0, '2020_2024')	('sempre', 'ADV')	2
# (45.0, '2020_2024')	('notte', 'NOUN')	2
# (45.0, '2020_2024')	('verisure', 'ADJ')	2
# (45.0, '2020_2024')	('24', 'NUM')	2
# (45.0, '2020_2024')	('casa', 'NOUN')	1
# (45.0, '2020_2024')	('sentirto', 'ADJ')	1
# (45.0, '2020_2024')	('protetto', 'NOUN')	1
# (45.0, '2020_2024')	('quando', 'SCONJ')	1
# (45.0, '2020_2024')	('vado', 'VERB')	1

# %%
#Print the top 10 ADJECTIVES of every nice class
spots_words = dict()
spots_adj=dict()
for key in dictionary:
     spots_words[key] = pos_tag_italian(dictionary[key])
for key in spots_words:
    if key not in spots_adj:
        spots_adj[key] = []
    for values in spots_words[key]:
        if 'ADJ' in values:  
            spots_adj[key].append(values)
    
spots_adj[28.0, '1980_1984'] #example
# Out:
# [('chicco', 'ADJ'),
#  ('raglio', 'ADJ'),
#  ('classo', 'ADJ'),
#  ('perfetto', 'ADJ'),
#  ('brillantina', 'ADJ'),
#  ('allina', 'ADJ'),
#  ('coloratissimo', 'ADJ'),
#  ('brillantina', 'ADJ'),
#  ('super', 'ADJ'),
#  ('altro', 'ADJ'),
#  ('brillantina', 'ADJ'),
#  ('adesiva', 'ADJ'),
#  ('unesclusivo', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('emozionante', 'ADJ'),
#  ('ragno', 'ADJ'),
#  ('cattivo', 'ADJ'),
#  ('ragno', 'ADJ'),
#  ('provo', 'ADJ'),
#  ('divertente', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('brillo', 'ADJ'),
#  ('inuntro', 'ADJ'),
#  ('piatti', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('core', 'ADJ'),
#  ('lecetto', 'ADJ'),
#  ('cromato', 'ADJ'),
#  ('metallo', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('super', 'ADJ'),
#  ('videogioco', 'ADJ'),
#  ('facile', 'ADJ'),
#  ('difficile', 'ADJ'),
#  ('fantastico', 'ADJ'),
#  ('atari', 'ADJ'),
#  ('attento', 'ADJ'),
#  ('scappare', 'ADJ'),
#  ('gallina', 'ADJ'),
#  ('frisso', 'ADJ'),
#  ('super', 'ADJ'),
#  ('bribido', 'ADJ'),
#  ('incredibile', 'ADJ'),
#  ('super', 'ADJ'),
#  ('moto', 'ADJ'),
#  ('gomito', 'ADJ'),
#  ('rivale', 'ADJ'),
#  ('super', 'ADJ'),
#  ('moto', 'ADJ'),
#  ('vero', 'ADJ'),
#  ('langelo', 'ADJ'),
#  ('super', 'ADJ'),
#  ('moto', 'ADJ'),
#  ('altro', 'ADJ'),
#  ('fantastico', 'ADJ'),
#  ('giocattolo', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('piccolo', 'ADJ'),
#  ('passaporto', 'ADJ'),
#  ('corrivo', 'ADJ'),
#  ('sussurro', 'ADJ'),
#  ('fiore', 'ADJ'),
#  ('felice', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('lunga', 'ADJ'),
#  ('lungo', 'ADJ'),
#  ('splendida', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('raffinato', 'ADJ'),
#  ('barbie', 'ADJ'),
#  ('allegro', 'ADJ'),
#  ('simpatico', 'ADJ'),
#  ('benvenuto', 'ADJ'),
#  ('amico', 'ADJ'),
#  ('aperitivo', 'ADJ'),
#  ('oso', 'ADJ'),
#  ('gelati', 'ADJ'),
#  ('gelatario', 'ADJ'),
#  ('deserto', 'ADJ'),
#  ('gelato', 'ADJ'),
#  ('possenti', 'ADJ'),
#  ('ricco', 'ADJ'),
#  ('apeniristico', 'ADJ'),
#  ('dinosauro', 'ADJ'),
#  ('mito', 'ADJ'),
#  ('perfetto', 'ADJ'),
#  ('invincibile', 'ADJ'),
#  ('diverso', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('appassionante', 'ADJ'),
#  ('prestigioso', 'ADJ'),
#  ('dinosauro', 'ADJ'),
#  ('lultimo', 'ADJ'),
#  ('delluniverso', 'ADJ'),
#  ('grigio', 'ADJ'),
#  ('venetaro', 'ADJ'),
#  ('vissme', 'ADJ'),
#  ('zodac', 'ADJ'),
#  ('avventuroso', 'ADJ'),
#  ('guardato', 'ADJ'),
#  ('topino', 'ADJ'),
#  ('maggiore', 'ADJ'),
#  ('abile', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('diverso', 'ADJ'),
#  ('diverso', 'ADJ'),
#  ('chiotto', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('tane', 'ADJ'),
#  ('feludo', 'ADJ'),
#  ('vero', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('rana', 'ADJ'),
#  ('dovè', 'ADJ'),
#  ('fattorio', 'ADJ'),
#  ('animale', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('prescolastici', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('fattorio', 'ADJ'),
#  ('parlante', 'ADJ'),
#  ('dolce', 'ADJ'),
#  ('mangerelli', 'ADJ'),
#  ('intrepide', 'ADJ'),
#  ('attento', 'ADJ'),
#  ('mangerelli', 'ADJ'),
#  ('mozzafiato', 'ADJ'),
#  ('meraviglioso', 'ADJ'),
#  ('rosa', 'ADJ'),
#  ('portapacco', 'ADJ'),
#  ('barbie', 'ADJ'),
#  ('libero', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('splendido', 'ADJ'),
#  ('allultima', 'ADJ'),
#  ('capello', 'ADJ'),
#  ('barbie', 'ADJ'),
#  ('bellissima', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('passaporto', 'ADJ'),
#  ('giovane', 'ADJ'),
#  ('unesclusivo', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('termale', 'ADJ'),
#  ('fantastico', 'ADJ'),
#  ('entusiasta', 'ADJ'),
#  ('termale', 'ADJ'),
#  ('spumeggiante', 'ADJ'),
#  ('allultimo', 'ADJ'),
#  ('barbie', 'ADJ'),
#  ('splendido', 'ADJ'),
#  ('meraviglioso', 'ADJ'),
#  ('termale', 'ADJ')]

# %%
vocabularies = dict()
for key in dictionary:
    vocabularies[key] = set(spots_adj[key])

frequencies = dict()
for key in dictionary:
    frequencies[key] = Counter(spots_adj[key])

top = 10
previous_key = None

for key in sorted(dictionary):
    if key != previous_key and previous_key is not None:
        print()
    previous_key = key
    words_top = sorted(frequencies[key].items(), key=lambda x: x[1], reverse=True)[:10]
    for word, frequency in words_top:
        print(key, word, frequency, sep='\t')
# Out:
# (1.0, '1980_1984')	('substral', 'ADJ')	1
# (1.0, '1980_1984')	('cuore', 'ADJ')	1
# (1.0, '1980_1984')	('lunico', 'ADJ')	1
# (1.0, '1980_1984')	('chimeral', 'ADJ')	1
# (1.0, '1980_1984')	('fiore', 'ADJ')	1
# (1.0, '1980_1984')	('splendida', 'ADJ')	1
# (1.0, '1980_1984')	('vanitoso', 'ADJ')	1
# (1.0, '1980_1984')	('bello', 'ADJ')	1
# (1.0, '1980_1984')	('allegria', 'ADJ')	1
#
# (1.0, '1985_1989')	('buongiorno', 'ADJ')	1
# (1.0, '1985_1989')	('provo', 'ADJ')	1
# (1.0, '1985_1989')	('difficile', 'ADJ')	1
# (1.0, '1985_1989')	('adesivo', 'ADJ')	1
# (1.0, '1985_1989')	('segreto', 'ADJ')	1
# (1.0, '1985_1989')	('gesal', 'ADJ')	1
#
# (2.0, '1980_1984')	('pratico', 'ADJ')	1
# (2.0, '1980_1984')	('idropitturo', 'ADJ')	1
# (2.0, '1980_1984')	('grande', 'ADJ')	1
# (2.0, '1980_1984')	('spazioso', 'ADJ')	1
# (2.0, '1980_1984')	('magnifico', 'ADJ')	1
# (2.0, '1980_1984')	('lavabile', 'ADJ')	1
# (2.0, '1980_1984')	('nuovo', 'ADJ')	1
# (2.0, '1980_1984')	('soffitto', 'ADJ')	1
# (2.0, '1980_1984')	('compreso', 'ADJ')	1
# (2.0, '1980_1984')	('progredito', 'ADJ')	1
#
# (3.0, '1980_1984')	('nuovo', 'ADJ')	51
# (3.0, '1980_1984')	('bello', 'ADJ')	21
# (3.0, '1980_1984')	('delicato', 'ADJ')	19
# (3.0, '1980_1984')	('sporco', 'ADJ')	19
# (3.0, '1980_1984')	('fresco', 'ADJ')	14
# (3.0, '1980_1984')	('bianco', 'ADJ')	12
# (3.0, '1980_1984')	('morbido', 'ADJ')	11
# (3.0, '1980_1984')	('deodorante', 'ADJ')	10
# (3.0, '1980_1984')	('super', 'ADJ')	10
# (3.0, '1980_1984')	('liquido', 'ADJ')	10
#
# (3.0, '1985_1989')	('nuovo', 'ADJ')	237
# (3.0, '1985_1989')	('liquido', 'ADJ')	67
# (3.0, '1985_1989')	('bianco', 'ADJ')	64
# (3.0, '1985_1989')	('bello', 'ADJ')	53
# (3.0, '1985_1989')	('delicato', 'ADJ')	52
# (3.0, '1985_1989')	('morbido', 'ADJ')	46
# (3.0, '1985_1989')	('super', 'ADJ')	42
# (3.0, '1985_1989')	('detersivo', 'ADJ')	40
# (3.0, '1985_1989')	('grande', 'ADJ')	38
# (3.0, '1985_1989')	('fresco', 'ADJ')	34
#
# (3.0, '1990_1994')	('nuovo', 'ADJ')	249
# (3.0, '1990_1994')	('detersivo', 'ADJ')	71
# (3.0, '1990_1994')	('bianco', 'ADJ')	71
# (3.0, '1990_1994')	('naturale', 'ADJ')	42
# (3.0, '1990_1994')	('delicato', 'ADJ')	40
# (3.0, '1990_1994')	('sporco', 'ADJ')	35
# (3.0, '1990_1994')	('bello', 'ADJ')	35
# (3.0, '1990_1994')	('dolce', 'ADJ')	30
# (3.0, '1990_1994')	('ultra', 'ADJ')	28
# (3.0, '1990_1994')	('facile', 'ADJ')	27
#
# (3.0, '1995_1999')	('nuovo', 'ADJ')	54
# (3.0, '1995_1999')	('bianco', 'ADJ')	25
# (3.0, '1995_1999')	('sano', 'ADJ')	18
# (3.0, '1995_1999')	('neutro', 'ADJ')	15
# (3.0, '1995_1999')	('primo', 'ADJ')	14
# (3.0, '1995_1999')	('delicato', 'ADJ')	14
# (3.0, '1995_1999')	('grande', 'ADJ')	11
# (3.0, '1995_1999')	('perfetto', 'ADJ')	11
# (3.0, '1995_1999')	('attivo', 'ADJ')	10
# (3.0, '1995_1999')	('detersivo', 'ADJ')	10
#
# (3.0, '2000_2004')	('nuovo', 'ADJ')	108
# (3.0, '2000_2004')	('bianco', 'ADJ')	39
# (3.0, '2000_2004')	('naturale', 'ADJ')	16
# (3.0, '2000_2004')	('primo', 'ADJ')	14
# (3.0, '2000_2004')	('elvive', 'ADJ')	14
# (3.0, '2000_2004')	('fresco', 'ADJ')	13
# (3.0, '2000_2004')	('deodorante', 'ADJ')	12
# (3.0, '2000_2004')	('nuova', 'ADJ')	12
# (3.0, '2000_2004')	('forte', 'ADJ')	11
# (3.0, '2000_2004')	('pantene', 'ADJ')	10
#
# (3.0, '2005_2009')	('nuovo', 'ADJ')	98
# (3.0, '2005_2009')	('bianco', 'ADJ')	35
# (3.0, '2005_2009')	('neutro', 'ADJ')	19
# (3.0, '2005_2009')	('fresco', 'ADJ')	17
# (3.0, '2005_2009')	('primo', 'ADJ')	17
# (3.0, '2005_2009')	('attivo', 'ADJ')	16
# (3.0, '2005_2009')	('deodorante', 'ADJ')	16
# (3.0, '2005_2009')	('intimo', 'ADJ')	15
# (3.0, '2005_2009')	('lunico', 'ADJ')	14
# (3.0, '2005_2009')	('sporco', 'ADJ')	14
#
# (3.0, '2010_2014')	('nuovo', 'ADJ')	42
# (3.0, '2010_2014')	('pantene', 'ADJ')	10
# (3.0, '2010_2014')	('bianco', 'ADJ')	8
# (3.0, '2010_2014')	('perfetto', 'ADJ')	8
# (3.0, '2010_2014')	('primo', 'ADJ')	7
# (3.0, '2010_2014')	('efficace', 'ADJ')	7
# (3.0, '2010_2014')	('deodorante', 'ADJ')	6
# (3.0, '2010_2014')	('neutro', 'ADJ')	6
# (3.0, '2010_2014')	('fresco', 'ADJ')	6
# (3.0, '2010_2014')	('naturale', 'ADJ')	5
#
# (3.0, '2015_2019')	('nuovo', 'ADJ')	20
# (3.0, '2015_2019')	('dolce', 'ADJ')	9
# (3.0, '2015_2019')	('forte', 'ADJ')	9
# (3.0, '2015_2019')	('primo', 'ADJ')	9
# (3.0, '2015_2019')	('ultra', 'ADJ')	7
# (3.0, '2015_2019')	('sporco', 'ADJ')	7
# (3.0, '2015_2019')	('naturale', 'ADJ')	6
# (3.0, '2015_2019')	('bianco', 'ADJ')	6
# (3.0, '2015_2019')	('grande', 'ADJ')	6
# (3.0, '2015_2019')	('nuova', 'ADJ')	5
#
# (3.0, '2020_2024')	('nuovo', 'ADJ')	28
# (3.0, '2020_2024')	('sporco', 'ADJ')	21
# (3.0, '2020_2024')	('lavatrice', 'ADJ')	9
# (3.0, '2020_2024')	('forte', 'ADJ')	9
# (3.0, '2020_2024')	('finish', 'ADJ')	8
# (3.0, '2020_2024')	('pril', 'ADJ')	8
# (3.0, '2020_2024')	('ultra', 'ADJ')	7
# (3.0, '2020_2024')	('dolce', 'ADJ')	7
# (3.0, '2020_2024')	('batterio', 'ADJ')	7
# (3.0, '2020_2024')	('efficace', 'ADJ')	6
#
#
# (4.0, '1985_1989')	('bello', 'ADJ')	10
# (4.0, '1985_1989')	('azzurro', 'ADJ')	9
# (4.0, '1985_1989')	('futuro', 'ADJ')	5
# (4.0, '1985_1989')	('conveniente', 'ADJ')	4
# (4.0, '1985_1989')	('super', 'ADJ')	4
# (4.0, '1985_1989')	('sporco', 'ADJ')	4
# (4.0, '1985_1989')	('lario', 'ADJ')	4
# (4.0, '1985_1989')	('grande', 'ADJ')	3
# (4.0, '1985_1989')	('metano', 'ADJ')	3
# (4.0, '1985_1989')	('turbo', 'ADJ')	3
#
# (4.0, '1990_1994')	('dario', 'ADJ')	7
# (4.0, '1990_1994')	('caldo', 'ADJ')	6
# (4.0, '1990_1994')	('milione', 'ADJ')	6
# (4.0, '1990_1994')	('nuovo', 'ADJ')	6
# (4.0, '1990_1994')	('sicuro', 'ADJ')	5
# (4.0, '1990_1994')	('grande', 'ADJ')	4
# (4.0, '1990_1994')	('cielo', 'ADJ')	4
# (4.0, '1990_1994')	('americano', 'ADJ')	4
# (4.0, '1990_1994')	('altro', 'ADJ')	4
# (4.0, '1990_1994')	('bello', 'ADJ')	4
#
# (4.0, '1995_1999')	('grande', 'ADJ')	4
# (4.0, '1995_1999')	('nuovo', 'ADJ')	4
# (4.0, '1995_1999')	('regalo', 'ADJ')	3
# (4.0, '1995_1999')	('agip', 'ADJ')	3
# (4.0, '1995_1999')	('pieno', 'ADJ')	3
# (4.0, '1995_1999')	('lambiente', 'ADJ')	2
# (4.0, '1995_1999')	('bollino', 'ADJ')	2
# (4.0, '1995_1999')	('superate', 'ADJ')	2
# (4.0, '1995_1999')	('comune', 'ADJ')	2
# (4.0, '1995_1999')	('uguale', 'ADJ')	2
#
# (4.0, '2000_2004')	('unopera', 'ADJ')	41
# (4.0, '2000_2004')	('grande', 'ADJ')	3
# (4.0, '2000_2004')	('nuovo', 'ADJ')	3
# (4.0, '2000_2004')	('regalo', 'ADJ')	1
# (4.0, '2000_2004')	('taci', 'ADJ')	1
# (4.0, '2000_2004')	('lieto', 'ADJ')	1
# (4.0, '2000_2004')	('picnic', 'ADJ')	1
# (4.0, '2000_2004')	('vet', 'ADJ')	1
# (4.0, '2000_2004')	('facile', 'ADJ')	1
# (4.0, '2000_2004')	('cellulare', 'ADJ')	1
#
# (4.0, '2005_2009')	('grande', 'ADJ')	5
# (4.0, '2005_2009')	('buongiorno', 'ADJ')	3
# (4.0, '2005_2009')	('ferrari', 'ADJ')	2
# (4.0, '2005_2009')	('nuovo', 'ADJ')	2
# (4.0, '2005_2009')	('premio', 'ADJ')	2
# (4.0, '2005_2009')	('efficiente', 'ADJ')	2
# (4.0, '2005_2009')	('lungo', 'ADJ')	1
# (4.0, '2005_2009')	('gusto', 'ADJ')	1
# (4.0, '2005_2009')	('italiano', 'ADJ')	1
# (4.0, '2005_2009')	('super', 'ADJ')	1
#
# (5.0, '1980_1984')	('linea', 'ADJ')	11
# (5.0, '1980_1984')	('diva', 'ADJ')	10
# (5.0, '1980_1984')	('mini', 'ADJ')	9
# (5.0, '1980_1984')	('bello', 'ADJ')	8
# (5.0, '1980_1984')	('grande', 'ADJ')	8
# (5.0, '1980_1984')	('avvertenza', 'ADJ')	7
# (5.0, '1980_1984')	('efficace', 'ADJ')	7
# (5.0, '1980_1984')	('sottile', 'ADJ')	6
# (5.0, '1980_1984')	('sano', 'ADJ')	6
# (5.0, '1980_1984')	('nuovo', 'ADJ')	6
#
# (5.0, '1985_1989')	('medicinale', 'ADJ')	37
# (5.0, '1985_1989')	('nuovo', 'ADJ')	29
# (5.0, '1985_1989')	('bello', 'ADJ')	16
# (5.0, '1985_1989')	('nuvenia', 'ADJ')	15
# (5.0, '1985_1989')	('primo', 'ADJ')	14
# (5.0, '1985_1989')	('plasmon', 'ADJ')	14
# (5.0, '1985_1989')	('grande', 'ADJ')	12
# (5.0, '1985_1989')	('efficace', 'ADJ')	12
# (5.0, '1985_1989')	('italiano', 'ADJ')	11
# (5.0, '1985_1989')	('sano', 'ADJ')	11
#
# (5.0, '1990_1994')	('nuovo', 'ADJ')	26
# (5.0, '1990_1994')	('plasmon', 'ADJ')	22
# (5.0, '1990_1994')	('grande', 'ADJ')	16
# (5.0, '1990_1994')	('nuvenia', 'ADJ')	14
# (5.0, '1990_1994')	('primo', 'ADJ')	11
# (5.0, '1990_1994')	('lines', 'ADJ')	11
# (5.0, '1990_1994')	('lungo', 'ADJ')	10
# (5.0, '1990_1994')	('asciutto', 'ADJ')	9
# (5.0, '1990_1994')	('sicuro', 'ADJ')	9
# (5.0, '1990_1994')	('medicinale', 'ADJ')	9
#
# (5.0, '1995_1999')	('medicinale', 'ADJ')	16
# (5.0, '1995_1999')	('illustrativo', 'ADJ')	11
# (5.0, '1995_1999')	('collaterale', 'ADJ')	6
# (5.0, '1995_1999')	('nuovo', 'ADJ')	6
# (5.0, '1995_1999')	('testa', 'ADJ')	5
# (5.0, '1995_1999')	('leggera', 'ADJ')	4
# (5.0, '1995_1999')	('naturale', 'ADJ')	4
# (5.0, '1995_1999')	('leggero', 'ADJ')	4
# (5.0, '1995_1999')	('nasale', 'ADJ')	4
# (5.0, '1995_1999')	('adesivo', 'ADJ')	4
#
# (5.0, '2000_2004')	('medicinale', 'ADJ')	29
# (5.0, '2000_2004')	('illustrativo', 'ADJ')	25
# (5.0, '2000_2004')	('nuovo', 'ADJ')	21
# (5.0, '2000_2004')	('leggera', 'ADJ')	9
# (5.0, '2000_2004')	('collaterale', 'ADJ')	7
# (5.0, '2000_2004')	('pampers', 'ADJ')	6
# (5.0, '2000_2004')	('verde', 'ADJ')	6
# (5.0, '2000_2004')	('morbido', 'ADJ')	5
# (5.0, '2000_2004')	('blu', 'ADJ')	5
# (5.0, '2000_2004')	('pronto', 'ADJ')	5
#
# (5.0, '2005_2009')	('medicinale', 'ADJ')	37
# (5.0, '2005_2009')	('nuovo', 'ADJ')	23
# (5.0, '2005_2009')	('illustrativo', 'ADJ')	19
# (5.0, '2005_2009')	('attivo', 'ADJ')	12
# (5.0, '2005_2009')	('seta', 'ADJ')	8
# (5.0, '2005_2009')	('naturale', 'ADJ')	8
# (5.0, '2005_2009')	('leggera', 'ADJ')	7
# (5.0, '2005_2009')	('gola', 'ADJ')	7
# (5.0, '2005_2009')	('verde', 'ADJ')	7
# (5.0, '2005_2009')	('diverso', 'ADJ')	6
#
# (5.0, '2010_2014')	('medicinale', 'ADJ')	22
# (5.0, '2010_2014')	('grave', 'ADJ')	15
# (5.0, '2010_2014')	('gola', 'ADJ')	15
# (5.0, '2010_2014')	('illustrativo', 'ADJ')	13
# (5.0, '2010_2014')	('nuvenia', 'ADJ')	8
# (5.0, '2010_2014')	('nuovo', 'ADJ')	8
# (5.0, '2010_2014')	('capsule', 'ADJ')	5
# (5.0, '2010_2014')	('rapido', 'ADJ')	5
# (5.0, '2010_2014')	('ciao', 'ADJ')	5
# (5.0, '2010_2014')	('forte', 'ADJ')	5
#
# (5.0, '2015_2019')	('nuovo', 'ADJ')	10
# (5.0, '2015_2019')	('medicinale', 'ADJ')	10
# (5.0, '2015_2019')	('primo', 'ADJ')	9
# (5.0, '2015_2019')	('testa', 'ADJ')	8
# (5.0, '2015_2019')	('grave', 'ADJ')	7
# (5.0, '2015_2019')	('influenzale', 'ADJ')	7
# (5.0, '2015_2019')	('rapido', 'ADJ')	6
# (5.0, '2015_2019')	('bello', 'ADJ')	6
# (5.0, '2015_2019')	('nasale', 'ADJ')	6
# (5.0, '2015_2019')	('gola', 'ADJ')	6
#
# (5.0, '2020_2024')	('gola', 'ADJ')	8
# (5.0, '2020_2024')	('nuovo', 'ADJ')	8
# (5.0, '2020_2024')	('medicinale', 'ADJ')	7
# (5.0, '2020_2024')	('rapido', 'ADJ')	7
# (5.0, '2020_2024')	('influenzale', 'ADJ')	5
# (5.0, '2020_2024')	('forte', 'ADJ')	4
# (5.0, '2020_2024')	('testa', 'ADJ')	4
# (5.0, '2020_2024')	('nasale', 'ADJ')	4
# (5.0, '2020_2024')	('lenex', 'ADJ')	3
# (5.0, '2020_2024')	('liquido', 'ADJ')	3
#
# (6.0, '1980_1984')	('mamoli', 'ADJ')	3
# (6.0, '1980_1984')	('frattini', 'ADJ')	2
# (6.0, '1980_1984')	('chiudo', 'ADJ')	2
# (6.0, '1980_1984')	('quarzomix', 'ADJ')	1
# (6.0, '1980_1984')	('lavabo', 'ADJ')	1
# (6.0, '1980_1984')	('rubinetti', 'ADJ')	1
# (6.0, '1980_1984')	('qualificato', 'ADJ')	1
# (6.0, '1980_1984')	('brio', 'ADJ')	1
# (6.0, '1980_1984')	('micellatori', 'ADJ')	1
# (6.0, '1980_1984')	('comune', 'ADJ')	1
#
# (6.0, '1985_1989')	('brio', 'ADJ')	2
# (6.0, '1985_1989')	('miscelatori', 'ADJ')	1
# (6.0, '1985_1989')	('piloti', 'ADJ')	1
# (6.0, '1985_1989')	('dacqua', 'ADJ')	1
# (6.0, '1985_1989')	('zucchetti', 'ADJ')	1
# (6.0, '1985_1989')	('pieno', 'ADJ')	1
# (6.0, '1985_1989')	('frattini', 'ADJ')	1
# (6.0, '1985_1989')	('impermeabile', 'ADJ')	1
# (6.0, '1985_1989')	('definitivo', 'ADJ')	1
# (6.0, '1985_1989')	('vantaggioso', 'ADJ')	1
#
# (6.0, '2005_2009')	('scatoletta', 'ADJ')	1
# (6.0, '2005_2009')	('sottile', 'ADJ')	1
# (6.0, '2005_2009')	('dalluminio', 'ADJ')	1
# (6.0, '2005_2009')	('semplice', 'ADJ')	1
# (6.0, '2005_2009')	('lattino', 'ADJ')	1
#
# (6.0, '2020_2024')	('oknoplast', 'ADJ')	3
# (6.0, '2020_2024')	('bella', 'ADJ')	2
# (6.0, '2020_2024')	('reale', 'ADJ')	1
# (6.0, '2020_2024')	('vero', 'ADJ')	1
# (6.0, '2020_2024')	('cemento', 'ADJ')	1
# (6.0, '2020_2024')	('sottile', 'ADJ')	1
# (6.0, '2020_2024')	('centrale', 'ADJ')	1
# (6.0, '2020_2024')	('elegante', 'ADJ')	1
# (6.0, '2020_2024')	('bello', 'ADJ')	1
# (6.0, '2020_2024')	('leggero', 'ADJ')	1
#
# (7.0, '1980_1984')	('simac', 'ADJ')	5
# (7.0, '1980_1984')	('sporco', 'ADJ')	3
# (7.0, '1980_1984')	('nuovo', 'ADJ')	2
# (7.0, '1980_1984')	('solletico', 'ADJ')	2
# (7.0, '1980_1984')	('vivo', 'ADJ')	2
# (7.0, '1980_1984')	('sgrassare', 'ADJ')	2
# (7.0, '1980_1984')	('garantito', 'ADJ')	2
# (7.0, '1980_1984')	('fiseldem', 'ADJ')	2
# (7.0, '1980_1984')	('ceccherini', 'ADJ')	2
# (7.0, '1980_1984')	('facile', 'ADJ')	1
#
# (7.0, '1985_1989')	('nuovo', 'ADJ')	7
# (7.0, '1985_1989')	('elettronico', 'ADJ')	5
# (7.0, '1985_1989')	('sporco', 'ADJ')	4
# (7.0, '1985_1989')	('candele', 'ADJ')	4
# (7.0, '1985_1989')	('magneti', 'ADJ')	4
# (7.0, '1985_1989')	('marelli', 'ADJ')	4
# (7.0, '1985_1989')	('completo', 'ADJ')	2
# (7.0, '1985_1989')	('caro', 'ADJ')	2
# (7.0, '1985_1989')	('pronto', 'ADJ')	2
# (7.0, '1985_1989')	('rilave', 'ADJ')	2
#
# (7.0, '1990_1994')	('vaporetto', 'ADJ')	6
# (7.0, '1990_1994')	('nuovo', 'ADJ')	6
# (7.0, '1990_1994')	('faac', 'ADJ')	3
# (7.0, '1990_1994')	('potente', 'ADJ')	3
# (7.0, '1990_1994')	('saeco', 'ADJ')	3
# (7.0, '1990_1994')	('lacqua', 'ADJ')	2
# (7.0, '1990_1994')	('sanitrit', 'ADJ')	2
# (7.0, '1990_1994')	('sanitaria', 'ADJ')	2
# (7.0, '1990_1994')	('idraulico', 'ADJ')	2
# (7.0, '1990_1994')	('escosivo', 'ADJ')	2
#
# (7.0, '1995_1999')	('cisco', 'ADJ')	6
# (7.0, '1995_1999')	('deumidificatore', 'ADJ')	3
# (7.0, '1995_1999')	('polti', 'ADJ')	3
# (7.0, '1995_1999')	('pratika', 'ADJ')	3
# (7.0, '1995_1999')	('tasciugo', 'ADJ')	2
# (7.0, '1995_1999')	('cantina', 'ADJ')	2
# (7.0, '1995_1999')	('panica', 'ADJ')	1
# (7.0, '1995_1999')	('buono', 'ADJ')	1
# (7.0, '1995_1999')	('cremoso', 'ADJ')	1
# (7.0, '1995_1999')	('perfetto', 'ADJ')	1
#
# (7.0, '2000_2004')	('nuovo', 'ADJ')	3
# (7.0, '2000_2004')	('canal', 'ADJ')	2
# (7.0, '2000_2004')	('stesso', 'ADJ')	1
# (7.0, '2000_2004')	('leviga', 'ADJ')	1
# (7.0, '2000_2004')	('massimo', 'ADJ')	1
# (7.0, '2000_2004')	('levigatrico', 'ADJ')	1
# (7.0, '2000_2004')	('aria', 'ADJ')	1
# (7.0, '2000_2004')	('biancheria', 'ADJ')	1
# (7.0, '2000_2004')	('cesco', 'ADJ')	1
# (7.0, '2000_2004')	('buona', 'ADJ')	1
#
# (7.0, '2005_2009')	('nuovo', 'ADJ')	3
# (7.0, '2005_2009')	('vapormate', 'ADJ')	1
# (7.0, '2005_2009')	('sporco', 'ADJ')	1
# (7.0, '2005_2009')	('future', 'ADJ')	1
# (7.0, '2005_2009')	('compatibile', 'ADJ')	1
# (7.0, '2005_2009')	('megapixel', 'ADJ')	1
# (7.0, '2005_2009')	('semplice', 'ADJ')	1
# (7.0, '2005_2009')	('perfetto', 'ADJ')	1
# (7.0, '2005_2009')	('buone', 'ADJ')	1
# (7.0, '2005_2009')	('modo', 'ADJ')	1
#
# (7.0, '2020_2024')	('chicco', 'ADJ')	2
# (7.0, '2020_2024')	('perfetto', 'ADJ')	2
# (7.0, '2020_2024')	('nuovo', 'ADJ')	1
# (7.0, '2020_2024')	('bevanda', 'ADJ')	1
# (7.0, '2020_2024')	('freddo', 'ADJ')	1
# (7.0, '2020_2024')	('nuova', 'ADJ')	1
# (7.0, '2020_2024')	('tazzina', 'ADJ')	1
#
# (8.0, '1980_1984')	('perfetto', 'ADJ')	5
# (8.0, '1980_1984')	('bravo', 'ADJ')	5
# (8.0, '1980_1984')	('bello', 'ADJ')	3
# (8.0, '1980_1984')	('bic', 'ADJ')	2
# (8.0, '1980_1984')	('gillette', 'ADJ')	2
# (8.0, '1980_1984')	('barbo', 'ADJ')	1
# (8.0, '1980_1984')	('dolce', 'ADJ')	1
# (8.0, '1980_1984')	('giusto', 'ADJ')	1
# (8.0, '1980_1984')	('vincente', 'ADJ')	1
# (8.0, '1980_1984')	('nuovo', 'ADJ')	1
#
# (8.0, '1985_1989')	('nuovo', 'ADJ')	10
# (8.0, '1985_1989')	('massimo', 'ADJ')	10
# (8.0, '1985_1989')	('elettronico', 'ADJ')	9
# (8.0, '1985_1989')	('ricaricabile', 'ADJ')	9
# (8.0, '1985_1989')	('gillette', 'ADJ')	9
# (8.0, '1985_1989')	('profondo', 'ADJ')	7
# (8.0, '1985_1989')	('dolce', 'ADJ')	7
# (8.0, '1985_1989')	('carica', 'ADJ')	4
# (8.0, '1985_1989')	('lesclusivo', 'ADJ')	3
# (8.0, '1985_1989')	('primo', 'ADJ')	3
#
# (8.0, '1990_1994')	('nuovo', 'ADJ')	21
# (8.0, '1990_1994')	('gillette', 'ADJ')	7
# (8.0, '1990_1994')	('migliore', 'ADJ')	7
# (8.0, '1990_1994')	('sensibile', 'ADJ')	6
# (8.0, '1990_1994')	('braun', 'ADJ')	6
# (8.0, '1990_1994')	('sensorexcel', 'ADJ')	6
# (8.0, '1990_1994')	('esclusivo', 'ADJ')	5
# (8.0, '1990_1994')	('caratteristica', 'ADJ')	4
# (8.0, '1990_1994')	('unico', 'ADJ')	4
# (8.0, '1990_1994')	('bello', 'ADJ')	4
#
# (8.0, '1995_1999')	('sensorexcel', 'ADJ')	4
# (8.0, '1995_1999')	('seta', 'ADJ')	1
# (8.0, '1995_1999')	('lesclusivo', 'ADJ')	1
# (8.0, '1995_1999')	('protettivo', 'ADJ')	1
# (8.0, '1995_1999')	('piccolo', 'ADJ')	1
# (8.0, '1995_1999')	('mistero', 'ADJ')	1
# (8.0, '1995_1999')	('gillette', 'ADJ')	1
# (8.0, '1995_1999')	('adattare', 'ADJ')	1
# (8.0, '1995_1999')	('flessibile', 'ADJ')	1
# (8.0, '1995_1999')	('series', 'ADJ')	1
#
# (8.0, '2000_2004')	('facile', 'ADJ')	6
# (8.0, '2000_2004')	('nuovo', 'ADJ')	4
# (8.0, '2000_2004')	('braun', 'ADJ')	2
# (8.0, '2000_2004')	('syncro', 'ADJ')	2
# (8.0, '2000_2004')	('philishave', 'ADJ')	2
# (8.0, '2000_2004')	('activator', 'ADJ')	2
# (8.0, '2000_2004')	('caldo', 'ADJ')	1
# (8.0, '2000_2004')	('l83', 'ADJ')	1
# (8.0, '2000_2004')	('brivido', 'ADJ')	1
# (8.0, '2000_2004')	('freddo', 'ADJ')	1
#
# (8.0, '2005_2009')	('nuovo', 'ADJ')	6
# (8.0, '2005_2009')	('gillette', 'ADJ')	4
# (8.0, '2005_2009')	('migliore', 'ADJ')	3
# (8.0, '2005_2009')	('mini', 'ADJ')	2
# (8.0, '2005_2009')	('imetec', 'ADJ')	2
# (8.0, '2005_2009')	('bellissima', 'ADJ')	2
# (8.0, '2005_2009')	('unghio', 'ADJ')	2
# (8.0, '2005_2009')	('gut', 'ADJ')	2
# (8.0, '2005_2009')	('lincredibile', 'ADJ')	1
# (8.0, '2005_2009')	('use', 'ADJ')	1
#
# (8.0, '2010_2014')	('nuovo', 'ADJ')	2
# (8.0, '2010_2014')	('curva', 'ADJ')	2
# (8.0, '2010_2014')	('nomasvello', 'ADJ')	1
# (8.0, '2010_2014')	('permanente', 'ADJ')	1
# (8.0, '2010_2014')	('indolore', 'ADJ')	1
# (8.0, '2010_2014')	('altro', 'ADJ')	1
# (8.0, '2010_2014')	('gillette', 'ADJ')	1
# (8.0, '2010_2014')	('flexball', 'ADJ')	1
# (8.0, '2010_2014')	('massima', 'ADJ')	1
# (8.0, '2010_2014')	('difficile', 'ADJ')	1
#
# (8.0, '2015_2019')	('pronto', 'ADJ')	4
# (8.0, '2015_2019')	('gillette', 'ADJ')	3
# (8.0, '2015_2019')	('bikine', 'ADJ')	1
# (8.0, '2015_2019')	('lestate', 'ADJ')	1
# (8.0, '2015_2019')	('rapido', 'ADJ')	1
#
# (8.0, '2020_2024')	('shave', 'ADJ')	7
# (8.0, '2020_2024')	('nuovo', 'ADJ')	3
# (8.0, '2020_2024')	('innovativo', 'ADJ')	3
# (8.0, '2020_2024')	('bastare', 'ADJ')	3
# (8.0, '2020_2024')	('rasatura', 'ADJ')	2
# (8.0, '2020_2024')	('superiore', 'ADJ')	2
# (8.0, '2020_2024')	('vero', 'ADJ')	1
# (8.0, '2020_2024')	('calmo', 'ADJ')	1
# (8.0, '2020_2024')	('im', 'ADJ')	1
# (8.0, '2020_2024')	('lunico', 'ADJ')	1
#
# (9.0, '1980_1984')	('nuovo', 'ADJ')	11
# (9.0, '1980_1984')	('bello', 'ADJ')	9
# (9.0, '1980_1984')	('grande', 'ADJ')	6
# (9.0, '1980_1984')	('pronto', 'ADJ')	5
# (9.0, '1980_1984')	('piccolo', 'ADJ')	4
# (9.0, '1980_1984')	('video', 'ADJ')	4
# (9.0, '1980_1984')	('altro', 'ADJ')	4
# (9.0, '1980_1984')	('digitale', 'ADJ')	4
# (9.0, '1980_1984')	('sharp', 'ADJ')	3
# (9.0, '1980_1984')	('polaroid', 'ADJ')	3
#
# (9.0, '1985_1989')	('nuovo', 'ADJ')	31
# (9.0, '1985_1989')	('grande', 'ADJ')	22
# (9.0, '1985_1989')	('personal', 'ADJ')	17
# (9.0, '1985_1989')	('video', 'ADJ')	15
# (9.0, '1985_1989')	('digitale', 'ADJ')	12
# (9.0, '1985_1989')	('sanyo', 'ADJ')	10
# (9.0, '1985_1989')	('altro', 'ADJ')	10
# (9.0, '1985_1989')	('bello', 'ADJ')	9
# (9.0, '1985_1989')	('futuro', 'ADJ')	9
# (9.0, '1985_1989')	('gringos', 'ADJ')	9
#
# (9.0, '1990_1994')	('nuovo', 'ADJ')	33
# (9.0, '1990_1994')	('grande', 'ADJ')	29
# (9.0, '1990_1994')	('altro', 'ADJ')	8
# (9.0, '1990_1994')	('primo', 'ADJ')	8
# (9.0, '1990_1994')	('video', 'ADJ')	8
# (9.0, '1990_1994')	('bello', 'ADJ')	7
# (9.0, '1990_1994')	('black', 'ADJ')	6
# (9.0, '1990_1994')	('natale', 'ADJ')	5
# (9.0, '1990_1994')	('classico', 'ADJ')	5
# (9.0, '1990_1994')	('super', 'ADJ')	5
#
# (9.0, '1995_1999')	('nuovo', 'ADJ')	10
# (9.0, '1995_1999')	('top', 'ADJ')	3
# (9.0, '1995_1999')	('nuove', 'ADJ')	3
# (9.0, '1995_1999')	('nokia', 'ADJ')	3
# (9.0, '1995_1999')	('grande', 'ADJ')	3
# (9.0, '1995_1999')	('potente', 'ADJ')	2
# (9.0, '1995_1999')	('pile', 'ADJ')	2
# (9.0, '1995_1999')	('ultra', 'ADJ')	2
# (9.0, '1995_1999')	('principe', 'ADJ')	2
# (9.0, '1995_1999')	('occhiali', 'ADJ')	2
#
# (9.0, '2000_2004')	('nuovo', 'ADJ')	15
# (9.0, '2000_2004')	('grande', 'ADJ')	7
# (9.0, '2000_2004')	('cellulare', 'ADJ')	3
# (9.0, '2000_2004')	('blu', 'ADJ')	3
# (9.0, '2000_2004')	('nokia', 'ADJ')	3
# (9.0, '2000_2004')	('laura', 'ADJ')	3
# (9.0, '2000_2004')	('intelligent', 'ADJ')	3
# (9.0, '2000_2004')	('forte', 'ADJ')	3
# (9.0, '2000_2004')	('elix', 'ADJ')	3
# (9.0, '2000_2004')	('lento', 'ADJ')	2
#
# (9.0, '2005_2009')	('nuovo', 'ADJ')	14
# (9.0, '2005_2009')	('grande', 'ADJ')	5
# (9.0, '2005_2009')	('primo', 'ADJ')	4
# (9.0, '2005_2009')	('nero', 'ADJ')	3
# (9.0, '2005_2009')	('facile', 'ADJ')	3
# (9.0, '2005_2009')	('fine', 'ADJ')	3
# (9.0, '2005_2009')	('elisa', 'ADJ')	3
# (9.0, '2005_2009')	('italiano', 'ADJ')	3
# (9.0, '2005_2009')	('pegaso', 'ADJ')	2
# (9.0, '2005_2009')	('occhiale', 'ADJ')	2
#
# (9.0, '2010_2014')	('burg', 'ADJ')	2
# (9.0, '2010_2014')	('nuovissimo', 'ADJ')	1
# (9.0, '2010_2014')	('tima', 'ADJ')	1
# (9.0, '2010_2014')	('occhiale', 'ADJ')	1
# (9.0, '2010_2014')	('visivo', 'ADJ')	1
# (9.0, '2010_2014')	('semplice', 'ADJ')	1
# (9.0, '2010_2014')	('ottico', 'ADJ')	1
# (9.0, '2010_2014')	('zeiss', 'ADJ')	1
# (9.0, '2010_2014')	('fantastico', 'ADJ')	1
# (9.0, '2010_2014')	('inedicola', 'ADJ')	1
#
# (9.0, '2020_2024')	('real', 'ADJ')	2
# (9.0, '2020_2024')	('everybodys', 'ADJ')	2
# (9.0, '2020_2024')	('xiaomi', 'ADJ')	2
# (9.0, '2020_2024')	('difficile', 'ADJ')	1
# (9.0, '2020_2024')	('debole', 'ADJ')	1
# (9.0, '2020_2024')	('chrome', 'ADJ')	1
# (9.0, '2020_2024')	('altro', 'ADJ')	1
# (9.0, '2020_2024')	('nuovo', 'ADJ')	1
# (9.0, '2020_2024')	('mese', 'ADJ')	1
# (9.0, '2020_2024')	('are', 'ADJ')	1
#
# (10.0, '1980_1984')	('personal', 'ADJ')	5
# (10.0, '1980_1984')	('giusto', 'ADJ')	4
# (10.0, '1980_1984')	('anticoncezionale', 'ADJ')	2
# (10.0, '1980_1984')	('freddo', 'ADJ')	2
# (10.0, '1980_1984')	('contraccettivo', 'ADJ')	1
# (10.0, '1980_1984')	('paese', 'ADJ')	1
# (10.0, '1980_1984')	('sicuri', 'ADJ')	1
# (10.0, '1980_1984')	('naturale', 'ADJ')	1
# (10.0, '1980_1984')	('akuel', 'ADJ')	1
# (10.0, '1980_1984')	('familiare', 'ADJ')	1
#
# (10.0, '1985_1989')	('akuel', 'ADJ')	7
# (10.0, '1985_1989')	('sottile', 'ADJ')	7
# (10.0, '1985_1989')	('personal', 'ADJ')	5
# (10.0, '1985_1989')	('profilattico', 'ADJ')	5
# (10.0, '1985_1989')	('nuovo', 'ADJ')	3
# (10.0, '1985_1989')	('super', 'ADJ')	3
# (10.0, '1985_1989')	('parlarte', 'ADJ')	2
# (10.0, '1985_1989')	('contraccettivo', 'ADJ')	2
# (10.0, '1985_1989')	('sicuro', 'ADJ')	2
# (10.0, '1985_1989')	('naturale', 'ADJ')	2
#
# (10.0, '1990_1994')	('profilattici', 'ADJ')	3
# (10.0, '1990_1994')	('ritmico', 'ADJ')	2
# (10.0, '1990_1994')	('piccolo', 'ADJ')	2
# (10.0, '1990_1994')	('morbido', 'ADJ')	2
# (10.0, '1990_1994')	('bianco', 'ADJ')	1
# (10.0, '1990_1994')	('liberi', 'ADJ')	1
# (10.0, '1990_1994')	('battito', 'ADJ')	1
# (10.0, '1990_1994')	('alternato', 'ADJ')	1
# (10.0, '1990_1994')	('naturale', 'ADJ')	1
# (10.0, '1990_1994')	('uva', 'ADJ')	1
#
# (10.0, '1995_1999')	('profilattico', 'ADJ')	1
# (10.0, '1995_1999')	('chiedi', 'ADJ')	1
#
# (10.0, '2000_2004')	('profilattici', 'ADJ')	2
# (10.0, '2000_2004')	('fulmine', 'ADJ')	1
#
# (10.0, '2005_2009')	('nuovo', 'ADJ')	6
# (10.0, '2005_2009')	('facile', 'ADJ')	3
# (10.0, '2005_2009')	('grande', 'ADJ')	3
# (10.0, '2005_2009')	('luso', 'ADJ')	2
# (10.0, '2005_2009')	('confortevole', 'ADJ')	2
# (10.0, '2005_2009')	('piccolo', 'ADJ')	2
# (10.0, '2005_2009')	('digitale', 'ADJ')	2
# (10.0, '2005_2009')	('comodissimo', 'ADJ')	1
# (10.0, '2005_2009')	('profilattico', 'ADJ')	1
# (10.0, '2005_2009')	('ampio', 'ADJ')	1
#
#
# (10.0, '2015_2019')	('grande', 'ADJ')	3
# (10.0, '2015_2019')	('grammatica', 'ADJ')	3
# (10.0, '2015_2019')	('italiano', 'ADJ')	3
# (10.0, '2015_2019')	('commercial', 'ADJ')	1
#
# (10.0, '2020_2024')	('preservativo', 'ADJ')	3
# (10.0, '2020_2024')	('normale', 'ADJ')	3
# (10.0, '2020_2024')	('solare', 'ADJ')	2
# (10.0, '2020_2024')	('pronto', 'ADJ')	2
# (10.0, '2020_2024')	('calore', 'ADJ')	1
# (10.0, '2020_2024')	('ovvio', 'ADJ')	1
# (10.0, '2020_2024')	('lessenziale', 'ADJ')	1
# (10.0, '2020_2024')	('sole', 'ADJ')	1
# (10.0, '2020_2024')	('usa', 'ADJ')	1
# (10.0, '2020_2024')	('caldo', 'ADJ')	1
#
# (11.0, '1980_1984')	('indesit', 'ADJ')	6
# (11.0, '1980_1984')	('inox', 'ADJ')	6
# (11.0, '1980_1984')	('black', 'ADJ')	5
# (11.0, '1980_1984')	('grande', 'ADJ')	5
# (11.0, '1980_1984')	('accessorio', 'ADJ')	3
# (11.0, '1980_1984')	('bello', 'ADJ')	3
# (11.0, '1980_1984')	('nuovo', 'ADJ')	3
# (11.0, '1980_1984')	('caldo', 'ADJ')	3
# (11.0, '1980_1984')	('bravosimac', 'ADJ')	3
# (11.0, '1980_1984')	('regalo', 'ADJ')	2
#
# (11.0, '1985_1989')	('nuovo', 'ADJ')	16
# (11.0, '1985_1989')	('caldo', 'ADJ')	15
# (11.0, '1985_1989')	('bello', 'ADJ')	13
# (11.0, '1985_1989')	('gelato', 'ADJ')	13
# (11.0, '1985_1989')	('imetec', 'ADJ')	7
# (11.0, '1985_1989')	('sicuro', 'ADJ')	7
# (11.0, '1985_1989')	('super', 'ADJ')	7
# (11.0, '1985_1989')	('pronto', 'ADJ')	6
# (11.0, '1985_1989')	('vero', 'ADJ')	6
# (11.0, '1985_1989')	('grande', 'ADJ')	6
#
# (11.0, '1990_1994')	('nuovo', 'ADJ')	10
# (11.0, '1990_1994')	('super', 'ADJ')	9
# (11.0, '1990_1994')	('bello', 'ADJ')	8
# (11.0, '1990_1994')	('freddo', 'ADJ')	8
# (11.0, '1990_1994')	('teuco', 'ADJ')	8
# (11.0, '1990_1994')	('facile', 'ADJ')	7
# (11.0, '1990_1994')	('pinguino', 'ADJ')	6
# (11.0, '1990_1994')	('elettrodomestico', 'ADJ')	4
# (11.0, '1990_1994')	('italiano', 'ADJ')	4
# (11.0, '1990_1994')	('fritto', 'ADJ')	4
#
# (11.0, '1995_1999')	('grande', 'ADJ')	4
# (11.0, '1995_1999')	('bello', 'ADJ')	4
# (11.0, '1995_1999')	('caldo', 'ADJ')	4
# (11.0, '1995_1999')	('lunico', 'ADJ')	3
# (11.0, '1995_1999')	('caldobagno', 'ADJ')	3
# (11.0, '1995_1999')	('lario', 'ADJ')	3
# (11.0, '1995_1999')	('panasonic', 'ADJ')	3
# (11.0, '1995_1999')	('stiro', 'ADJ')	2
# (11.0, '1995_1999')	('nuovo', 'ADJ')	2
# (11.0, '1995_1999')	('russo', 'ADJ')	2
#
# (11.0, '2000_2004')	('nuovo', 'ADJ')	10
# (11.0, '2000_2004')	('primo', 'ADJ')	4
# (11.0, '2000_2004')	('lavatrice', 'ADJ')	4
# (11.0, '2000_2004')	('caldo', 'ADJ')	3
# (11.0, '2000_2004')	('perfetto', 'ADJ')	2
# (11.0, '2000_2004')	('basso', 'ADJ')	2
# (11.0, '2000_2004')	('elettrodomestico', 'ADJ')	2
# (11.0, '2000_2004')	('titan', 'ADJ')	2
# (11.0, '2000_2004')	('ultrasuone', 'ADJ')	2
# (11.0, '2000_2004')	('grande', 'ADJ')	1
#
# (11.0, '2005_2009')	('nuovo', 'ADJ')	4
# (11.0, '2005_2009')	('sesto', 'ADJ')	3
# (11.0, '2005_2009')	('lunico', 'ADJ')	3
# (11.0, '2005_2009')	('grande', 'ADJ')	3
# (11.0, '2005_2009')	('delonghi', 'ADJ')	3
# (11.0, '2005_2009')	('living', 'ADJ')	2
# (11.0, '2005_2009')	('lg', 'ADJ')	2
# (11.0, '2005_2009')	('semplice', 'ADJ')	2
# (11.0, '2005_2009')	('rexelectrolux', 'ADJ')	2
# (11.0, '2005_2009')	('imetec', 'ADJ')	2
#
# (11.0, '2010_2014')	('nespresso', 'ADJ')	2
# (11.0, '2010_2014')	('george', 'ADJ')	1
# (11.0, '2010_2014')	('clooney', 'ADJ')	1
# (11.0, '2010_2014')	('grande', 'ADJ')	1
# (11.0, '2010_2014')	('grammatica', 'ADJ')	1
# (11.0, '2010_2014')	('italiano', 'ADJ')	1
#
# (11.0, '2020_2024')	('elettrodomestico', 'ADJ')	2
# (11.0, '2020_2024')	('regalarto', 'ADJ')	2
# (11.0, '2020_2024')	('massimo', 'ADJ')	2
# (11.0, '2020_2024')	('stesso', 'ADJ')	1
# (11.0, '2020_2024')	('perfetto', 'ADJ')	1
# (11.0, '2020_2024')	('proteggerto', 'ADJ')	1
# (11.0, '2020_2024')	('grande', 'ADJ')	1
# (11.0, '2020_2024')	('sostenibile', 'ADJ')	1
# (11.0, '2020_2024')	('farto', 'ADJ')	1
# (11.0, '2020_2024')	('unico', 'ADJ')	1
#
# (12.0, '1980_1984')	('nuovo', 'ADJ')	17
# (12.0, '1980_1984')	('grande', 'ADJ')	14
# (12.0, '1980_1984')	('nuova', 'ADJ')	9
# (12.0, '1980_1984')	('opel', 'ADJ')	6
# (12.0, '1980_1984')	('graziella', 'ADJ')	4
# (12.0, '1980_1984')	('concessionario', 'ADJ')	4
# (12.0, '1980_1984')	('elegante', 'ADJ')	4
# (12.0, '1980_1984')	('buongiorno', 'ADJ')	3
# (12.0, '1980_1984')	('consumo', 'ADJ')	3
# (12.0, '1980_1984')	('affidabile', 'ADJ')	3
#
# (12.0, '1985_1989')	('nuovo', 'ADJ')	51
# (12.0, '1985_1989')	('nuova', 'ADJ')	22
# (12.0, '1985_1989')	('grande', 'ADJ')	20
# (12.0, '1985_1989')	('fiat', 'ADJ')	19
# (12.0, '1985_1989')	('bello', 'ADJ')	12
# (12.0, '1985_1989')	('chicco', 'ADJ')	12
# (12.0, '1985_1989')	('boxer', 'ADJ')	11
# (12.0, '1985_1989')	('concessionario', 'ADJ')	11
# (12.0, '1985_1989')	('impossibile', 'ADJ')	10
# (12.0, '1985_1989')	('super', 'ADJ')	10
#
# (12.0, '1990_1994')	('nuovo', 'ADJ')	62
# (12.0, '1990_1994')	('fiat', 'ADJ')	27
# (12.0, '1990_1994')	('nuova', 'ADJ')	17
# (12.0, '1990_1994')	('grande', 'ADJ')	17
# (12.0, '1990_1994')	('bello', 'ADJ')	15
# (12.0, '1990_1994')	('audi', 'ADJ')	10
# (12.0, '1990_1994')	('natale', 'ADJ')	9
# (12.0, '1990_1994')	('primo', 'ADJ')	8
# (12.0, '1990_1994')	('cinquecento', 'ADJ')	8
# (12.0, '1990_1994')	('amico', 'ADJ')	7
#
# (12.0, '1995_1999')	('nuovo', 'ADJ')	16
# (12.0, '1995_1999')	('fiat', 'ADJ')	8
# (12.0, '1995_1999')	('nuova', 'ADJ')	6
# (12.0, '1995_1999')	('dovè', 'ADJ')	5
# (12.0, '1995_1999')	('bello', 'ADJ')	4
# (12.0, '1995_1999')	('migliore', 'ADJ')	3
# (12.0, '1995_1999')	('costante', 'ADJ')	3
# (12.0, '1995_1999')	('lunico', 'ADJ')	3
# (12.0, '1995_1999')	('importante', 'ADJ')	2
# (12.0, '1995_1999')	('assetto', 'ADJ')	2
#
# (12.0, '2000_2004')	('nuovo', 'ADJ')	31
# (12.0, '2000_2004')	('nuova', 'ADJ')	23
# (12.0, '2000_2004')	('fiat', 'ADJ')	11
# (12.0, '2000_2004')	('grande', 'ADJ')	10
# (12.0, '2000_2004')	('micra', 'ADJ')	8
# (12.0, '2000_2004')	('primo', 'ADJ')	6
# (12.0, '2000_2004')	('opel', 'ADJ')	6
# (12.0, '2000_2004')	('piccolo', 'ADJ')	5
# (12.0, '2000_2004')	('massimo', 'ADJ')	4
# (12.0, '2000_2004')	('auto', 'ADJ')	4
#
# (12.0, '2005_2009')	('nuovo', 'ADJ')	45
# (12.0, '2005_2009')	('nuova', 'ADJ')	41
# (12.0, '2005_2009')	('opel', 'ADJ')	33
# (12.0, '2005_2009')	('grande', 'ADJ')	10
# (12.0, '2005_2009')	('gamma', 'ADJ')	10
# (12.0, '2005_2009')	('lunico', 'ADJ')	9
# (12.0, '2005_2009')	('vero', 'ADJ')	8
# (12.0, '2005_2009')	('incentivo', 'ADJ')	8
# (12.0, '2005_2009')	('geniale', 'ADJ')	7
# (12.0, '2005_2009')	('tasso', 'ADJ')	7
#
# (12.0, '2010_2014')	('nuova', 'ADJ')	22
# (12.0, '2010_2014')	('nuovo', 'ADJ')	14
# (12.0, '2010_2014')	('vero', 'ADJ')	7
# (12.0, '2010_2014')	('bello', 'ADJ')	7
# (12.0, '2010_2014')	('grande', 'ADJ')	4
# (12.0, '2010_2014')	('drive', 'ADJ')	3
# (12.0, '2010_2014')	('massimo', 'ADJ')	3
# (12.0, '2010_2014')	('stesso', 'ADJ')	3
# (12.0, '2010_2014')	('pieno', 'ADJ')	3
# (12.0, '2010_2014')	('tedesco', 'ADJ')	3
#
# (12.0, '2015_2019')	('nuovo', 'ADJ')	13
# (12.0, '2015_2019')	('nuova', 'ADJ')	8
# (12.0, '2015_2019')	('concessionaria', 'ADJ')	7
# (12.0, '2015_2019')	('vero', 'ADJ')	6
# (12.0, '2015_2019')	('grande', 'ADJ')	5
# (12.0, '2015_2019')	('unico', 'ADJ')	4
# (12.0, '2015_2019')	('semplice', 'ADJ')	4
# (12.0, '2015_2019')	('mese', 'ADJ')	4
# (12.0, '2015_2019')	('bello', 'ADJ')	4
# (12.0, '2015_2019')	('super', 'ADJ')	3
#
# (12.0, '2020_2024')	('nuovo', 'ADJ')	15
# (12.0, '2020_2024')	('grande', 'ADJ')	7
# (12.0, '2020_2024')	('mese', 'ADJ')	7
# (12.0, '2020_2024')	('vivi', 'ADJ')	6
# (12.0, '2020_2024')	('grammatica', 'ADJ')	6
# (12.0, '2020_2024')	('italiano', 'ADJ')	6
# (12.0, '2020_2024')	('futuro', 'ADJ')	6
# (12.0, '2020_2024')	('nuova', 'ADJ')	5
# (12.0, '2020_2024')	('concessionaria', 'ADJ')	4
# (12.0, '2020_2024')	('primo', 'ADJ')	4
#
# (13.0, '1980_1984')	('ferrari', 'ADJ')	1
#
# (14.0, '1980_1984')	('citizen', 'ADJ')	3
# (14.0, '1980_1984')	('raffinato', 'ADJ')	1
# (14.0, '1980_1984')	('pratico', 'ADJ')	1
# (14.0, '1980_1984')	('elegante', 'ADJ')	1
# (14.0, '1980_1984')	('sottile', 'ADJ')	1
# (14.0, '1980_1984')	('perfetto', 'ADJ')	1
# (14.0, '1980_1984')	('elettronico', 'ADJ')	1
# (14.0, '1980_1984')	('dellera', 'ADJ')	1
# (14.0, '1980_1984')	('spaziale', 'ADJ')	1
#
# (14.0, '1985_1989')	('nuovo', 'ADJ')	4
# (14.0, '1985_1989')	('diamante', 'ADJ')	3
# (14.0, '1985_1989')	('secondo', 'ADJ')	3
# (14.0, '1985_1989')	('altro', 'ADJ')	2
# (14.0, '1985_1989')	('voice', 'ADJ')	2
# (14.0, '1985_1989')	('sintesi', 'ADJ')	2
# (14.0, '1985_1989')	('buongiorno', 'ADJ')	2
# (14.0, '1985_1989')	('spaziale', 'ADJ')	2
# (14.0, '1985_1989')	('casio', 'ADJ')	2
# (14.0, '1985_1989')	('prima', 'ADJ')	1
#
# (14.0, '1990_1994')	('eccezionale', 'ADJ')	2
# (14.0, '1990_1994')	('meccanica', 'ADJ')	2
# (14.0, '1990_1994')	('perfetto', 'ADJ')	2
# (14.0, '1990_1994')	('meccanico', 'ADJ')	2
# (14.0, '1990_1994')	('totale', 'ADJ')	2
# (14.0, '1990_1994')	('salvini', 'ADJ')	1
# (14.0, '1990_1994')	('jamaica', 'ADJ')	1
# (14.0, '1990_1994')	('ritmo', 'ADJ')	1
# (14.0, '1990_1994')	('breil', 'ADJ')	1
# (14.0, '1990_1994')	('preciso', 'ADJ')	1
#
# (14.0, '1995_1999')	('limits', 'ADJ')	1
#
# (14.0, '2000_2004')	('prossimo', 'ADJ')	2
# (14.0, '2000_2004')	('lanello', 'ADJ')	2
# (14.0, '2000_2004')	('trilogy', 'ADJ')	2
# (14.0, '2000_2004')	('centesimo', 'ADJ')	1
# (14.0, '2000_2004')	('secondo', 'ADJ')	1
# (14.0, '2000_2004')	('solo', 'ADJ')	1
# (14.0, '2000_2004')	('primo', 'ADJ')	1
#
# (14.0, '2005_2009')	('nuova', 'ADJ')	2
# (14.0, '2005_2009')	('natale', 'ADJ')	2
# (14.0, '2005_2009')	('lotus', 'ADJ')	2
# (14.0, '2005_2009')	('grande', 'ADJ')	1
# (14.0, '2005_2009')	('grammatica', 'ADJ')	1
# (14.0, '2005_2009')	('italiano', 'ADJ')	1
# (14.0, '2005_2009')	('cielo', 'ADJ')	1
# (14.0, '2005_2009')	('chiara', 'ADJ')	1
# (14.0, '2005_2009')	('arte', 'ADJ')	1
# (14.0, '2005_2009')	('prossimamente', 'ADJ')	1
#
# (14.0, '2010_2014')	('bracciale', 'ADJ')	2
# (14.0, '2010_2014')	('migliori', 'ADJ')	1
# (14.0, '2010_2014')	('regalo', 'ADJ')	1
# (14.0, '2010_2014')	('migliore', 'ADJ')	1
# (14.0, '2010_2014')	('sottotitoli', 'ADJ')	1
#
# (14.0, '2015_2019')	('unico', 'ADJ')	3
# (14.0, '2015_2019')	('migliore', 'ADJ')	2
# (14.0, '2015_2019')	('prezioso', 'ADJ')	2
# (14.0, '2015_2019')	('stroili', 'ADJ')	2
# (14.0, '2015_2019')	('rosa', 'ADJ')	1
# (14.0, '2015_2019')	('nuovo', 'ADJ')	1
# (14.0, '2015_2019')	('speciale', 'ADJ')	1
# (14.0, '2015_2019')	('sorpresa', 'ADJ')	1
# (14.0, '2015_2019')	('amico', 'ADJ')	1
# (14.0, '2015_2019')	('piccolo', 'ADJ')	1
#
# (14.0, '2020_2024')	('grande', 'ADJ')	3
# (14.0, '2020_2024')	('grammatica', 'ADJ')	3
# (14.0, '2020_2024')	('italiano', 'ADJ')	3
# (14.0, '2020_2024')	('bracciale', 'ADJ')	2
# (14.0, '2020_2024')	('limitato', 'ADJ')	2
# (14.0, '2020_2024')	('vivo', 'ADJ')	1
# (14.0, '2020_2024')	('assaggia', 'ADJ')	1
# (14.0, '2020_2024')	('grancereale', 'ADJ')	1
# (14.0, '2020_2024')	('caotica', 'ADJ')	1
# (14.0, '2020_2024')	('piena', 'ADJ')	1
#
# (15.0, '1980_1984')	('zimmermann', 'ADJ')	2
# (15.0, '1980_1984')	('tecnico', 'ADJ')	1
# (15.0, '1980_1984')	('solonque', 'ADJ')	1
# (15.0, '1980_1984')	('garantito', 'ADJ')	1
#
# (15.0, '1985_1989')	('videoregistraturo', 'ADJ')	1
# (15.0, '1985_1989')	('spida', 'ADJ')	1
#
# (15.0, '1990_1994')	('digitale', 'ADJ')	2
# (15.0, '1990_1994')	('facile', 'ADJ')	1
# (15.0, '1990_1994')	('datti', 'ADJ')	1
# (15.0, '1990_1994')	('tanti', 'ADJ')	1
# (15.0, '1990_1994')	('festa', 'ADJ')	1
# (15.0, '1990_1994')	('nuovo', 'ADJ')	1
# (15.0, '1990_1994')	('versatile', 'ADJ')	1
# (15.0, '1990_1994')	('creativo', 'ADJ')	1
# (15.0, '1990_1994')	('pianoforte', 'ADJ')	1
# (15.0, '1990_1994')	('forte', 'ADJ')	1
#
# (16.0, '1980_1984')	('primo', 'ADJ')	8
# (16.0, '1980_1984')	('igienica', 'ADJ')	6
# (16.0, '1980_1984')	('morbido', 'ADJ')	4
# (16.0, '1980_1984')	('nuovo', 'ADJ')	3
# (16.0, '1980_1984')	('regalo', 'ADJ')	3
# (16.0, '1980_1984')	('secondo', 'ADJ')	3
# (16.0, '1980_1984')	('prezioso', 'ADJ')	3
# (16.0, '1980_1984')	('unorchestra', 'ADJ')	3
# (16.0, '1980_1984')	('igienico', 'ADJ')	2
# (16.0, '1980_1984')	('moltissima', 'ADJ')	2
#
# (16.0, '1985_1989')	('primo', 'ADJ')	60
# (16.0, '1985_1989')	('grande', 'ADJ')	52
# (16.0, '1985_1989')	('nuovo', 'ADJ')	27
# (16.0, '1985_1989')	('inedicola', 'ADJ')	16
# (16.0, '1985_1989')	('pratico', 'ADJ')	15
# (16.0, '1985_1989')	('settimanale', 'ADJ')	12
# (16.0, '1985_1989')	('facile', 'ADJ')	11
# (16.0, '1985_1989')	('italiano', 'ADJ')	10
# (16.0, '1985_1989')	('bello', 'ADJ')	8
# (16.0, '1985_1989')	('regalo', 'ADJ')	8
#
# (16.0, '1990_1994')	('primo', 'ADJ')	69
# (16.0, '1990_1994')	('grande', 'ADJ')	46
# (16.0, '1990_1994')	('nuovo', 'ADJ')	40
# (16.0, '1990_1994')	('inedicola', 'ADJ')	19
# (16.0, '1990_1994')	('regalo', 'ADJ')	18
# (16.0, '1990_1994')	('italiano', 'ADJ')	15
# (16.0, '1990_1994')	('bello', 'ADJ')	13
# (16.0, '1990_1994')	('sole', 'ADJ')	13
# (16.0, '1990_1994')	('completo', 'ADJ')	10
# (16.0, '1990_1994')	('prezioso', 'ADJ')	9
#
# (16.0, '1995_1999')	('primo', 'ADJ')	21
# (16.0, '1995_1999')	('nuovo', 'ADJ')	18
# (16.0, '1995_1999')	('grande', 'ADJ')	10
# (16.0, '1995_1999')	('facile', 'ADJ')	7
# (16.0, '1995_1999')	('sole', 'ADJ')	6
# (16.0, '1995_1999')	('belli', 'ADJ')	5
# (16.0, '1995_1999')	('bello', 'ADJ')	5
# (16.0, '1995_1999')	('altro', 'ADJ')	4
# (16.0, '1995_1999')	('giusto', 'ADJ')	4
# (16.0, '1995_1999')	('video', 'ADJ')	4
#
# (16.0, '2000_2004')	('primo', 'ADJ')	22
# (16.0, '2000_2004')	('nuovo', 'ADJ')	21
# (16.0, '2000_2004')	('grande', 'ADJ')	13
# (16.0, '2000_2004')	('futuro', 'ADJ')	9
# (16.0, '2000_2004')	('sole', 'ADJ')	6
# (16.0, '2000_2004')	('inedicola', 'ADJ')	5
# (16.0, '2000_2004')	('top', 'ADJ')	5
# (16.0, '2000_2004')	('regalo', 'ADJ')	4
# (16.0, '2000_2004')	('facile', 'ADJ')	4
# (16.0, '2000_2004')	('solo', 'ADJ')	4
#
# (16.0, '2005_2009')	('primo', 'ADJ')	39
# (16.0, '2005_2009')	('grande', 'ADJ')	24
# (16.0, '2005_2009')	('nuovo', 'ADJ')	12
# (16.0, '2005_2009')	('sole', 'ADJ')	5
# (16.0, '2005_2009')	('inedicola', 'ADJ')	5
# (16.0, '2005_2009')	('dipiù', 'ADJ')	5
# (16.0, '2005_2009')	('lungo', 'ADJ')	5
# (16.0, '2005_2009')	('facile', 'ADJ')	4
# (16.0, '2005_2009')	('regalo', 'ADJ')	4
# (16.0, '2005_2009')	('prima', 'ADJ')	4
#
# (16.0, '2010_2014')	('camelo', 'ADJ')	1
#
# (16.0, '2015_2019')	('segreto', 'ADJ')	1
# (16.0, '2015_2019')	('spongebob', 'ADJ')	1
# (16.0, '2015_2019')	('spugna', 'ADJ')	1
# (16.0, '2015_2019')	('pazzo', 'ADJ')	1
# (16.0, '2015_2019')	('amico', 'ADJ')	1
# (16.0, '2015_2019')	('padri', 'ADJ')	1
# (16.0, '2015_2019')	('completare', 'ADJ')	1
# (16.0, '2015_2019')	('shop', 'ADJ')	1
#
# (16.0, '2020_2024')	('lofferta', 'ADJ')	1
# (16.0, '2020_2024')	('tuttofamily', 'ADJ')	1
# (16.0, '2020_2024')	('digitale', 'ADJ')	1
# (16.0, '2020_2024')	('quotidiano', 'ADJ')	1
# (16.0, '2020_2024')	('familiare', 'ADJ')	1
# (16.0, '2020_2024')	('stiro', 'ADJ')	1
# (16.0, '2020_2024')	('rilave', 'ADJ')	1
# (16.0, '2020_2024')	('solito', 'ADJ')	1
# (16.0, '2020_2024')	('famoso', 'ADJ')	1
# (16.0, '2020_2024')	('bastare', 'ADJ')	1
#
# (17.0, '1985_1989')	('saratoga', 'ADJ')	3
# (17.0, '1985_1989')	('sigillante', 'ADJ')	3
# (17.0, '1985_1989')	('bisonte', 'ADJ')	2
# (17.0, '1985_1989')	('nuovo', 'ADJ')	1
# (17.0, '1985_1989')	('incolla', 'ADJ')	1
# (17.0, '1985_1989')	('bison', 'ADJ')	1
# (17.0, '1985_1989')	('inalterabile', 'ADJ')	1
# (17.0, '1985_1989')	('impenetrabile', 'ADJ')	1
# (17.0, '1985_1989')	('ladesivo', 'ADJ')	1
# (17.0, '1985_1989')	('istantane', 'ADJ')	1
#
# (17.0, '1990_1994')	('sigillante', 'ADJ')	4
# (17.0, '1990_1994')	('saratoga', 'ADJ')	2
#
# (17.0, '1995_1999')	('buono', 'ADJ')	1
# (17.0, '1995_1999')	('adesivo', 'ADJ')	1
# (17.0, '1995_1999')	('massimo', 'ADJ')	1
# (17.0, '1995_1999')	('posa', 'ADJ')	1
# (17.0, '1995_1999')	('porcellanato', 'ADJ')	1
# (17.0, '1995_1999')	('grande', 'ADJ')	1
# (17.0, '1995_1999')	('sorriso', 'ADJ')	1
#
# (17.0, '2005_2009')	('saratoga', 'ADJ')	2
# (17.0, '2005_2009')	('sigillante', 'ADJ')	1
# (17.0, '2005_2009')	('elastico', 'ADJ')	1
# (17.0, '2005_2009')	('impenetrabile', 'ADJ')	1
# (17.0, '2005_2009')	('inalterabile', 'ADJ')	1
# (17.0, '2005_2009')	('super', 'ADJ')	1
# (17.0, '2005_2009')	('ricarico', 'ADJ')	1
# (17.0, '2005_2009')	('uniscere', 'ADJ')	1
#
# (18.0, '1980_1984')	('bello', 'ADJ')	6
# (18.0, '1980_1984')	('combipel', 'ADJ')	2
# (18.0, '1980_1984')	('scichissimo', 'ADJ')	2
# (18.0, '1980_1984')	('pelole', 'ADJ')	2
# (18.0, '1980_1984')	('pelliccia', 'ADJ')	1
# (18.0, '1980_1984')	('annabella', 'ADJ')	1
# (18.0, '1980_1984')	('buenos', 'ADJ')	1
# (18.0, '1980_1984')	('belle', 'ADJ')	1
# (18.0, '1980_1984')	('acofur', 'ADJ')	1
# (18.0, '1980_1984')	('mosso', 'ADJ')	1
#
# (18.0, '1985_1989')	('armony', 'ADJ')	6
# (18.0, '1985_1989')	('incredibile', 'ADJ')	4
# (18.0, '1985_1989')	('grande', 'ADJ')	3
# (18.0, '1985_1989')	('grammatica', 'ADJ')	3
# (18.0, '1985_1989')	('italiano', 'ADJ')	3
# (18.0, '1985_1989')	('pelliccia', 'ADJ')	3
# (18.0, '1985_1989')	('sorpresa', 'ADJ')	3
# (18.0, '1985_1989')	('chiesa', 'ADJ')	3
# (18.0, '1985_1989')	('elegante', 'ADJ')	2
# (18.0, '1985_1989')	('classico', 'ADJ')	2
#
# (18.0, '1990_1994')	('bello', 'ADJ')	3
# (18.0, '1990_1994')	('diverso', 'ADJ')	2
# (18.0, '1990_1994')	('italiano', 'ADJ')	2
# (18.0, '1990_1994')	('patente', 'ADJ')	1
# (18.0, '1990_1994')	('docchiale', 'ADJ')	1
# (18.0, '1990_1994')	('gonfie', 'ADJ')	1
# (18.0, '1990_1994')	('पाँवाजा़ाइं', 'ADJ')	1
# (18.0, '1990_1994')	('capace', 'ADJ')	1
# (18.0, '1990_1994')	('rigido', 'ADJ')	1
# (18.0, '1990_1994')	('morbido', 'ADJ')	1
#
# (18.0, '1995_1999')	('calimero', 'ADJ')	6
# (18.0, '1995_1999')	('barbie', 'ADJ')	4
# (18.0, '1995_1999')	('prezioso', 'ADJ')	3
# (18.0, '1995_1999')	('fiore', 'ADJ')	3
# (18.0, '1995_1999')	('diario', 'ADJ')	2
# (18.0, '1995_1999')	('magico', 'ADJ')	2
# (18.0, '1995_1999')	('scettro', 'ADJ')	2
# (18.0, '1995_1999')	('cuoricino', 'ADJ')	2
# (18.0, '1995_1999')	('segreto', 'ADJ')	2
# (18.0, '1995_1999')	('fiori', 'ADJ')	2
#
# (18.0, '2000_2004')	('nenuco', 'ADJ')	2
# (18.0, '2000_2004')	('zaino', 'ADJ')	2
# (18.0, '2000_2004')	('prezioso', 'ADJ')	2
# (18.0, '2000_2004')	('mare', 'ADJ')	1
# (18.0, '2000_2004')	('frigo', 'ADJ')	1
# (18.0, '2000_2004')	('lavatrice', 'ADJ')	1
# (18.0, '2000_2004')	('sperro', 'ADJ')	1
# (18.0, '2000_2004')	('sole', 'ADJ')	1
# (18.0, '2000_2004')	('coprio', 'ADJ')	1
# (18.0, '2000_2004')	('bello', 'ADJ')	1
#
# (18.0, '2005_2009')	('spettacolare', 'ADJ')	1
# (18.0, '2005_2009')	('schienale', 'ADJ')	1
# (18.0, '2005_2009')	('ergonomico', 'ADJ')	1
# (18.0, '2005_2009')	('spallaccio', 'ADJ')	1
# (18.0, '2005_2009')	('tasca', 'ADJ')	1
# (18.0, '2005_2009')	('laterale', 'ADJ')	1
# (18.0, '2005_2009')	('straordinario', 'ADJ')	1
# (18.0, '2005_2009')	('quaderno', 'ADJ')	1
# (18.0, '2005_2009')	('preparato', 'ADJ')	1
# (18.0, '2005_2009')	('usa', 'ADJ')	1
#
# (18.0, '2010_2014')	('migliore', 'ADJ')	3
# (18.0, '2010_2014')	('luminoso', 'ADJ')	2
# (18.0, '2010_2014')	('unaltro', 'ADJ')	1
# (18.0, '2010_2014')	('collezione', 'ADJ')	1
# (18.0, '2010_2014')	('scivoli', 'ADJ')	1
# (18.0, '2010_2014')	('comporre', 'ADJ')	1
# (18.0, '2010_2014')	('invicta', 'ADJ')	1
# (18.0, '2010_2014')	('pronto', 'ADJ')	1
# (18.0, '2010_2014')	('esclusivo', 'ADJ')	1
# (18.0, '2010_2014')	('facile', 'ADJ')	1
#
# (18.0, '2015_2019')	('magico', 'ADJ')	3
# (18.0, '2015_2019')	('nuovo', 'ADJ')	2
# (18.0, '2015_2019')	('triplicabile', 'ADJ')	2
# (18.0, '2015_2019')	('pronto', 'ADJ')	2
# (18.0, '2015_2019')	('impriro', 'ADJ')	1
# (18.0, '2015_2019')	('fine', 'ADJ')	1
# (18.0, '2015_2019')	('lamerica', 'ADJ')	1
# (18.0, '2015_2019')	('sireno', 'ADJ')	1
# (18.0, '2015_2019')	('primo', 'ADJ')	1
# (18.0, '2015_2019')	('invicta', 'ADJ')	1
#
# (18.0, '2020_2024')	('nuovo', 'ADJ')	3
# (18.0, '2020_2024')	('super', 'ADJ')	2
# (18.0, '2020_2024')	('prezioso', 'ADJ')	2
# (18.0, '2020_2024')	('zaino', 'ADJ')	1
# (18.0, '2020_2024')	('leggerissimi', 'ADJ')	1
# (18.0, '2020_2024')	('colorato', 'ADJ')	1
# (18.0, '2020_2024')	('invicta', 'ADJ')	1
# (18.0, '2020_2024')	('grande', 'ADJ')	1
# (18.0, '2020_2024')	('grammatica', 'ADJ')	1
# (18.0, '2020_2024')	('italiano', 'ADJ')	1
#
# (19.0, '1980_1984')	('montecchi', 'ADJ')	2
# (19.0, '1980_1984')	('cotto', 'ADJ')	2
# (19.0, '1980_1984')	('pavimenti', 'ADJ')	1
# (19.0, '1980_1984')	('caldo', 'ADJ')	1
# (19.0, '1980_1984')	('famoso', 'ADJ')	1
# (19.0, '1980_1984')	('perfetto', 'ADJ')	1
#
# (19.0, '1985_1989')	('concorde', 'ADJ')	5
# (19.0, '1985_1989')	('ceramico', 'ADJ')	2
# (19.0, '1985_1989')	('bello', 'ADJ')	1
# (19.0, '1985_1989')	('sconvolgente', 'ADJ')	1
# (19.0, '1985_1989')	('resistente', 'ADJ')	1
# (19.0, '1985_1989')	('preziosi', 'ADJ')	1
# (19.0, '1985_1989')	('prestoso', 'ADJ')	1
#
# (19.0, '2005_2009')	('arte', 'ADJ')	1
#
# (20.0, '1980_1984')	('arredamenti', 'ADJ')	5
# (20.0, '1980_1984')	('faram', 'ADJ')	5
# (20.0, '1980_1984')	('italiano', 'ADJ')	4
# (20.0, '1980_1984')	('febal', 'ADJ')	3
# (20.0, '1980_1984')	('bistro', 'ADJ')	3
# (20.0, '1980_1984')	('completo', 'ADJ')	2
# (20.0, '1980_1984')	('fasciatoi', 'ADJ')	2
# (20.0, '1980_1984')	('mobile', 'ADJ')	2
# (20.0, '1980_1984')	('bello', 'ADJ')	2
# (20.0, '1980_1984')	('superiore', 'ADJ')	1
#
# (20.0, '1985_1989')	('italiano', 'ADJ')	4
# (20.0, '1985_1989')	('calore', 'ADJ')	3
# (20.0, '1985_1989')	('mobile', 'ADJ')	3
# (20.0, '1985_1989')	('bello', 'ADJ')	2
# (20.0, '1985_1989')	('magico', 'ADJ')	2
# (20.0, '1985_1989')	('debole', 'ADJ')	2
# (20.0, '1985_1989')	('cucine', 'ADJ')	2
# (20.0, '1985_1989')	('alto', 'ADJ')	2
# (20.0, '1985_1989')	('vero', 'ADJ')	2
# (20.0, '1985_1989')	('allegro', 'ADJ')	1
#
# (20.0, '1990_1994')	('italiano', 'ADJ')	3
# (20.0, '1990_1994')	('vero', 'ADJ')	2
# (20.0, '1990_1994')	('grande', 'ADJ')	2
# (20.0, '1990_1994')	('segreto', 'ADJ')	2
# (20.0, '1990_1994')	('scavolino', 'ADJ')	2
# (20.0, '1990_1994')	('fantastici', 'ADJ')	1
# (20.0, '1990_1994')	('ceramica', 'ADJ')	1
# (20.0, '1990_1994')	('interno', 'ADJ')	1
# (20.0, '1990_1994')	('serbo', 'ADJ')	1
# (20.0, '1990_1994')	('meglio', 'ADJ')	1
#
# (20.0, '1995_1999')	('snaidero', 'ADJ')	6
# (20.0, '1995_1999')	('pensile', 'ADJ')	3
# (20.0, '1995_1999')	('solo', 'ADJ')	2
# (20.0, '1995_1999')	('ottimo', 'ADJ')	2
# (20.0, '1995_1999')	('comprore', 'ADJ')	2
# (20.0, '1995_1999')	('pronto', 'ADJ')	2
# (20.0, '1995_1999')	('compongo', 'ADJ')	2
# (20.0, '1995_1999')	('completo', 'ADJ')	2
# (20.0, '1995_1999')	('elettrodomestico', 'ADJ')	2
# (20.0, '1995_1999')	('borsellino', 'ADJ')	2
#
# (20.0, '2000_2004')	('bello', 'ADJ')	3
# (20.0, '2000_2004')	('primo', 'ADJ')	2
# (20.0, '2000_2004')	('vero', 'ADJ')	2
# (20.0, '2000_2004')	('italiano', 'ADJ')	2
# (20.0, '2000_2004')	('autentico', 'ADJ')	2
# (20.0, '2000_2004')	('ebbsestile', 'ADJ')	1
# (20.0, '2000_2004')	('ebsestile', 'ADJ')	1
# (20.0, '2000_2004')	('febal', 'ADJ')	1
# (20.0, '2000_2004')	('comoda', 'ADJ')	1
# (20.0, '2000_2004')	('comodo', 'ADJ')	1
#
# (20.0, '2005_2009')	('nuovo', 'ADJ')	3
# (20.0, '2005_2009')	('buongiorno', 'ADJ')	2
# (20.0, '2005_2009')	('vecchio', 'ADJ')	2
# (20.0, '2005_2009')	('riposo', 'ADJ')	2
# (20.0, '2005_2009')	('dorelan', 'ADJ')	2
# (20.0, '2005_2009')	('italiano', 'ADJ')	2
# (20.0, '2005_2009')	('migliore', 'ADJ')	2
# (20.0, '2005_2009')	('dovè', 'ADJ')	1
# (20.0, '2005_2009')	('stanco', 'ADJ')	1
# (20.0, '2005_2009')	('impossibile', 'ADJ')	1
#
# (20.0, '2020_2024')	('stoso', 'ADJ')	2
# (20.0, '2020_2024')	('cucina', 'ADJ')	1
# (20.0, '2020_2024')	('rendertie', 'ADJ')	1
# (20.0, '2020_2024')	('semplice', 'ADJ')	1
# (20.0, '2020_2024')	('singolo', 'ADJ')	1
# (20.0, '2020_2024')	('importante', 'ADJ')	1
# (20.0, '2020_2024')	('adatto', 'ADJ')	1
# (20.0, '2020_2024')	('design', 'ADJ')	1
# (20.0, '2020_2024')	('materiale', 'ADJ')	1
# (20.0, '2020_2024')	('diverso', 'ADJ')	1
#
# (21.0, '1980_1984')	('nuovo', 'ADJ')	4
# (21.0, '1980_1984')	('speciale', 'ADJ')	4
# (21.0, '1980_1984')	('giornaliero', 'ADJ')	4
# (21.0, '1980_1984')	('lagostina', 'ADJ')	2
# (21.0, '1980_1984')	('lato', 'ADJ')	2
# (21.0, '1980_1984')	('caldo', 'ADJ')	1
# (21.0, '1980_1984')	('calda', 'ADJ')	1
# (21.0, '1980_1984')	('indipendente', 'ADJ')	1
# (21.0, '1980_1984')	('primo', 'ADJ')	1
# (21.0, '1980_1984')	('alimentare', 'ADJ')	1
#
# (21.0, '1985_1989')	('nuovo', 'ADJ')	8
# (21.0, '1985_1989')	('scopa', 'ADJ')	5
# (21.0, '1985_1989')	('vero', 'ADJ')	4
# (21.0, '1985_1989')	('resistente', 'ADJ')	3
# (21.0, '1985_1989')	('aria', 'ADJ')	3
# (21.0, '1985_1989')	('nuova', 'ADJ')	3
# (21.0, '1985_1989')	('lunico', 'ADJ')	3
# (21.0, '1985_1989')	('grande', 'ADJ')	3
# (21.0, '1985_1989')	('forte', 'ADJ')	3
# (21.0, '1985_1989')	('aeternum', 'ADJ')	3
#
# (21.0, '1990_1994')	('spin', 'ADJ')	17
# (21.0, '1990_1994')	('gengivo', 'ADJ')	8
# (21.0, '1990_1994')	('dente', 'ADJ')	7
# (21.0, '1990_1994')	('fresco', 'ADJ')	5
# (21.0, '1990_1994')	('nuovo', 'ADJ')	5
# (21.0, '1990_1994')	('forte', 'ADJ')	4
# (21.0, '1990_1994')	('sporco', 'ADJ')	3
# (21.0, '1990_1994')	('speciale', 'ADJ')	3
# (21.0, '1990_1994')	('occhiale', 'ADJ')	3
# (21.0, '1990_1994')	('inserite', 'ADJ')	2
#
# (21.0, '1995_1999')	('super', 'ADJ')	3
# (21.0, '1995_1999')	('sporco', 'ADJ')	3
# (21.0, '1995_1999')	('nuovo', 'ADJ')	2
# (21.0, '1995_1999')	('profondo', 'ADJ')	2
# (21.0, '1995_1999')	('ernesto', 'ADJ')	2
# (21.0, '1995_1999')	('portasacchetti', 'ADJ')	2
# (21.0, '1995_1999')	('micro', 'ADJ')	2
# (21.0, '1995_1999')	('detersivo', 'ADJ')	2
# (21.0, '1995_1999')	('bello', 'ADJ')	2
# (21.0, '1995_1999')	('pratico', 'ADJ')	1
#
# (21.0, '2000_2004')	('nuovo', 'ADJ')	11
# (21.0, '2000_2004')	('sporco', 'ADJ')	4
# (21.0, '2000_2004')	('swiffer', 'ADJ')	4
# (21.0, '2000_2004')	('ordinello', 'ADJ')	3
# (21.0, '2000_2004')	('normale', 'ADJ')	2
# (21.0, '2000_2004')	('profondo', 'ADJ')	2
# (21.0, '2000_2004')	('bianco', 'ADJ')	2
# (21.0, '2000_2004')	('naturale', 'ADJ')	2
# (21.0, '2000_2004')	('lunico', 'ADJ')	2
# (21.0, '2000_2004')	('incredibile', 'ADJ')	2
#
# (21.0, '2005_2009')	('nuovo', 'ADJ')	13
# (21.0, '2005_2009')	('swiffer', 'ADJ')	7
# (21.0, '2005_2009')	('soffi', 'ADJ')	6
# (21.0, '2005_2009')	('stesso', 'ADJ')	3
# (21.0, '2005_2009')	('laccogliente', 'ADJ')	3
# (21.0, '2005_2009')	('buio', 'ADJ')	3
# (21.0, '2005_2009')	('linnovativo', 'ADJ')	2
# (21.0, '2005_2009')	('cattura', 'ADJ')	2
# (21.0, '2005_2009')	('lungo', 'ADJ')	2
# (21.0, '2005_2009')	('difficile', 'ADJ')	2
#
# (21.0, '2010_2014')	('swiffer', 'ADJ')	3
# (21.0, '2010_2014')	('nuovo', 'ADJ')	1
# (21.0, '2010_2014')	('elettrostatico', 'ADJ')	1
# (21.0, '2010_2014')	('tradizionale', 'ADJ')	1
# (21.0, '2010_2014')	('doppio', 'ADJ')	1
# (21.0, '2010_2014')	('duro', 'ADJ')	1
# ...
#
# (38.0, '2000_2004')	('natale', 'ADJ')	16
# (38.0, '2000_2004')	('nuovo', 'ADJ')	10
# (38.0, '2000_2004')	('bello', 'ADJ')	8
# (38.0, '2000_2004')	('stesso', 'ADJ')	7
# (38.0, '2000_2004')	('altro', 'ADJ')	7
# (38.0, '2000_2004')	('primo', 'ADJ')	6
# (38.0, '2000_2004')	('grande', 'ADJ')	6
# (38.0, '2000_2004')	('blu', 'ADJ')	5
# (38.0, '2000_2004')	('ricaricabile', 'ADJ')	5
# (38.0, '2000_2004')	('gratuito', 'ADJ')	5
#
# (38.0, '2005_2009')	('unaltro', 'ADJ')	26
# (38.0, '2005_2009')	('nuovo', 'ADJ')	22
# (38.0, '2005_2009')	('bello', 'ADJ')	20
# (38.0, '2005_2009')	('grande', 'ADJ')	19
# (38.0, '2005_2009')	('centesimo', 'ADJ')	17
# (38.0, '2005_2009')	('primo', 'ADJ')	14
# (38.0, '2005_2009')	('natale', 'ADJ')	12
# (38.0, '2005_2009')	('umts', 'ADJ')	12
# (38.0, '2005_2009')	('mese', 'ADJ')	11
# (38.0, '2005_2009')	('pronto', 'ADJ')	10
#
# (38.0, '2010_2014')	('grande', 'ADJ')	9
# (38.0, '2010_2014')	('hd', 'ADJ')	6
# (38.0, '2010_2014')	('live', 'ADJ')	5
# (38.0, '2010_2014')	('primo', 'ADJ')	4
# (38.0, '2010_2014')	('natale', 'ADJ')	4
# (38.0, '2010_2014')	('chiara', 'ADJ')	3
# (38.0, '2010_2014')	('pronto', 'ADJ')	3
# (38.0, '2010_2014')	('mese', 'ADJ')	3
# (38.0, '2010_2014')	('italiano', 'ADJ')	3
# (38.0, '2010_2014')	('mondiali', 'ADJ')	3
#
# (38.0, '2015_2019')	('lultimo', 'ADJ')	5
# (38.0, '2015_2019')	('grande', 'ADJ')	4
# (38.0, '2015_2019')	('bello', 'ADJ')	3
# (38.0, '2015_2019')	('ciao', 'ADJ')	3
# (38.0, '2015_2019')	('bravo', 'ADJ')	2
# (38.0, '2015_2019')	('primo', 'ADJ')	2
# (38.0, '2015_2019')	('lestate', 'ADJ')	2
# (38.0, '2015_2019')	('mese', 'ADJ')	2
# (38.0, '2015_2019')	('charlie', 'ADJ')	2
# (38.0, '2015_2019')	('nuovo', 'ADJ')	2
#
# (38.0, '2020_2024')	('nuovo', 'ADJ')	9
# (38.0, '2020_2024')	('bello', 'ADJ')	7
# (38.0, '2020_2024')	('pronto', 'ADJ')	7
# (38.0, '2020_2024')	('futuro', 'ADJ')	5
# (38.0, '2020_2024')	('primo', 'ADJ')	5
# (38.0, '2020_2024')	('grande', 'ADJ')	4
# (38.0, '2020_2024')	('fastweb', 'ADJ')	3
# (38.0, '2020_2024')	('blu', 'ADJ')	3
# (38.0, '2020_2024')	('italiano', 'ADJ')	3
# (38.0, '2020_2024')	('giusto', 'ADJ')	2
#
# (39.0, '1980_1984')	('fantastico', 'ADJ')	2
# (39.0, '1980_1984')	('mediterraneo', 'ADJ')	2
# (39.0, '1980_1984')	('torino', 'ADJ')	1
# (39.0, '1980_1984')	('stesso', 'ADJ')	1
# (39.0, '1980_1984')	('amico', 'ADJ')	1
# (39.0, '1980_1984')	('straniero', 'ADJ')	1
# (39.0, '1980_1984')	('grande', 'ADJ')	1
# (39.0, '1980_1984')	('vero', 'ADJ')	1
# (39.0, '1980_1984')	('stretto', 'ADJ')	1
# (39.0, '1980_1984')	('pieno', 'ADJ')	1
#
# (39.0, '1985_1989')	('spagna', 'ADJ')	2
# (39.0, '1985_1989')	('portogallo', 'ADJ')	2
# (39.0, '1985_1989')	('marocco', 'ADJ')	2
# (39.0, '1985_1989')	('sicuro', 'ADJ')	2
# (39.0, '1985_1989')	('federal', 'ADJ')	2
# (39.0, '1985_1989')	('lamerica', 'ADJ')	2
# (39.0, '1985_1989')	('inaugurare', 'ADJ')	1
# (39.0, '1985_1989')	('nuovo', 'ADJ')	1
# (39.0, '1985_1989')	('itinerario', 'ADJ')	1
# (39.0, '1985_1989')	('bordo', 'ADJ')	1
#
# (39.0, '1990_1994')	('alitalia', 'ADJ')	4
# (39.0, '1990_1994')	('vero', 'ADJ')	3
# (39.0, '1990_1994')	('aereo', 'ADJ')	3
# (39.0, '1990_1994')	('bello', 'ADJ')	2
# (39.0, '1990_1994')	('miglio', 'ADJ')	2
# (39.0, '1990_1994')	('grande', 'ADJ')	2
# (39.0, '1990_1994')	('airways', 'ADJ')	2
# (39.0, '1990_1994')	('voice', 'ADJ')	2
# (39.0, '1990_1994')	('particolare', 'ADJ')	2
# (39.0, '1990_1994')	('consumo', 'ADJ')	1
#
# (39.0, '1995_1999')	('altro', 'ADJ')	1
# (39.0, '1995_1999')	('aereo', 'ADJ')	1
# (39.0, '1995_1999')	('ottimo', 'ADJ')	1
# (39.0, '1995_1999')	('18°', 'ADJ')	1
# (39.0, '1995_1999')	('strano', 'ADJ')	1
# (39.0, '1995_1999')	('volo', 'ADJ')	1
# (39.0, '1995_1999')	('divertimento', 'ADJ')	1
# (39.0, '1995_1999')	('ricco', 'ADJ')	1
# (39.0, '1995_1999')	('limportante', 'ADJ')	1
# (39.0, '1995_1999')	('alitalia', 'ADJ')	1
#
# (39.0, '2000_2004')	('massimo', 'ADJ')	5
# (39.0, '2000_2004')	('migliore', 'ADJ')	3
# (39.0, '2000_2004')	('alitalia', 'ADJ')	2
# (39.0, '2000_2004')	('puntuale', 'ADJ')	2
# (39.0, '2000_2004')	('preparato', 'ADJ')	1
# (39.0, '2000_2004')	('affidabile', 'ADJ')	1
# (39.0, '2000_2004')	('vincente', 'ADJ')	1
# (39.0, '2000_2004')	('carico', 'ADJ')	1
# (39.0, '2000_2004')	('piacere', 'ADJ')	1
# (39.0, '2000_2004')	('vero', 'ADJ')	1
#
# (39.0, '2005_2009')	('giorno', 'ADJ')	3
# (39.0, '2005_2009')	('edison', 'ADJ')	2
# (39.0, '2005_2009')	('elettrico', 'ADJ')	2
# (39.0, '2005_2009')	('italiane', 'ADJ')	2
# (39.0, '2005_2009')	('edo', 'ADJ')	1
# (39.0, '2005_2009')	('importante', 'ADJ')	1
# (39.0, '2005_2009')	('lamoro', 'ADJ')	1
# (39.0, '2005_2009')	('certo', 'ADJ')	1
# (39.0, '2005_2009')	('paccocelere1', 'ADJ')	1
# (39.0, '2005_2009')	('nellultimo', 'ADJ')	1
#
# (39.0, '2020_2024')	('stesso', 'ADJ')	2
# (39.0, '2020_2024')	('diverso', 'ADJ')	2
# (39.0, '2020_2024')	('semplice', 'ADJ')	1
# (39.0, '2020_2024')	('veloce', 'ADJ')	1
# (39.0, '2020_2024')	('locautorentecom', 'ADJ')	1
# (39.0, '2020_2024')	('incontrere', 'ADJ')	1
# (39.0, '2020_2024')	('milione', 'ADJ')	1
# (39.0, '2020_2024')	('enilive', 'ADJ')	1
# (39.0, '2020_2024')	('unico', 'ADJ')	1
#
# (40.0, '1985_1989')	('agfa', 'ADJ')	4
# (40.0, '1985_1989')	('service', 'ADJ')	3
# (40.0, '1985_1989')	('vero', 'ADJ')	2
# (40.0, '1985_1989')	('fotografo', 'ADJ')	2
# (40.0, '1985_1989')	('resto', 'ADJ')	2
# (40.0, '1985_1989')	('stampo', 'ADJ')	2
# (40.0, '1985_1989')	('primo', 'ADJ')	2
# (40.0, '1985_1989')	('laboratorio', 'ADJ')	2
# (40.0, '1985_1989')	('affida', 'ADJ')	1
# (40.0, '1985_1989')	('color', 'ADJ')	1
#
# (41.0, '1980_1984')	('facile', 'ADJ')	2
# (41.0, '1980_1984')	('totocalcio', 'ADJ')	1
# (41.0, '1980_1984')	('dica', 'ADJ')	1
# (41.0, '1980_1984')	('sulluno', 'ADJ')	1
# (41.0, '1980_1984')	('sistemista', 'ADJ')	1
# (41.0, '1980_1984')	('sicuro', 'ADJ')	1
# (41.0, '1980_1984')	('ricopio', 'ADJ')	1
# (41.0, '1980_1984')	('alpino', 'ADJ')	1
# (41.0, '1980_1984')	('futuro', 'ADJ')	1
# (41.0, '1980_1984')	('tecnico', 'ADJ')	1
#
# (41.0, '1985_1989')	('lotteria', 'ADJ')	5
# (41.0, '1985_1989')	('grande', 'ADJ')	4
# (41.0, '1985_1989')	('primo', 'ADJ')	3
# (41.0, '1985_1989')	('nobile', 'ADJ')	2
# (41.0, '1985_1989')	('altro', 'ADJ')	2
# (41.0, '1985_1989')	('settimanale', 'ADJ')	2
# (41.0, '1985_1989')	('complessivo', 'ADJ')	2
# (41.0, '1985_1989')	('super', 'ADJ')	2
# (41.0, '1985_1989')	('platini', 'ADJ')	1
# (41.0, '1985_1989')	('altobelli', 'ADJ')	1
#
# (41.0, '1990_1994')	('gratuito', 'ADJ')	5
# (41.0, '1990_1994')	('lotteria', 'ADJ')	5
# (41.0, '1990_1994')	('libretto', 'ADJ')	4
# (41.0, '1990_1994')	('esperto', 'ADJ')	3
# (41.0, '1990_1994')	('sicuro', 'ADJ')	3
# (41.0, '1990_1994')	('facile', 'ADJ')	2
# (41.0, '1990_1994')	('maggiore', 'ADJ')	2
# (41.0, '1990_1994')	('richiedi', 'ADJ')	2
# (41.0, '1990_1994')	('libero', 'ADJ')	2
# (41.0, '1990_1994')	('completo', 'ADJ')	2
#
# (41.0, '1995_1999')	('natale', 'ADJ')	2
# (41.0, '1995_1999')	('lotteria', 'ADJ')	2
# (41.0, '1995_1999')	('verde', 'ADJ')	2
# (41.0, '1995_1999')	('nuovo', 'ADJ')	1
# (41.0, '1995_1999')	('ricco', 'ADJ')	1
# (41.0, '1995_1999')	('lotterio', 'ADJ')	1
# (41.0, '1995_1999')	('augurio', 'ADJ')	1
# (41.0, '1995_1999')	('lunico', 'ADJ')	1
# (41.0, '1995_1999')	('vincerto', 'ADJ')	1
# (41.0, '1995_1999')	('buonasera', 'ADJ')	1
#
# (41.0, '2000_2004')	('cisco', 'ADJ')	3
# (41.0, '2000_2004')	('tradizionale', 'ADJ')	2
# (41.0, '2000_2004')	('nuovo', 'ADJ')	2
# (41.0, '2000_2004')	('master', 'ADJ')	2
# (41.0, '2000_2004')	('sbadie', 'ADJ')	1
# (41.0, '2000_2004')	('intermet', 'ADJ')	1
# (41.0, '2000_2004')	('fantastico', 'ADJ')	1
# (41.0, '2000_2004')	('milionario', 'ADJ')	1
# (41.0, '2000_2004')	('giovane', 'ADJ')	1
# (41.0, '2000_2004')	('pronto', 'ADJ')	1
#
# (41.0, '2005_2009')	('multimediale', 'ADJ')	4
# (41.0, '2005_2009')	('vivi', 'ADJ')	3
# (41.0, '2005_2009')	('concerto', 'ADJ')	3
# (41.0, '2005_2009')	('nuovo', 'ADJ')	3
# (41.0, '2005_2009')	('prima', 'ADJ')	3
# (41.0, '2005_2009')	('grande', 'ADJ')	3
# (41.0, '2005_2009')	('verdi', 'ADJ')	2
# (41.0, '2005_2009')	('dalessandro', 'ADJ')	2
# (41.0, '2005_2009')	('vivo', 'ADJ')	2
# (41.0, '2005_2009')	('classico', 'ADJ')	2
#
# (41.0, '2020_2024')	('divertiti', 'ADJ')	1
#
# (42.0, '1995_1999')	('completo', 'ADJ')	1
# (42.0, '1995_1999')	('ricco', 'ADJ')	1
# (42.0, '1995_1999')	('divo', 'ADJ')	1
# (42.0, '1995_1999')	('preferito', 'ADJ')	1
# (42.0, '1995_1999')	('dedica', 'ADJ')	1
# (42.0, '1995_1999')	('rubrica', 'ADJ')	1
#
# (42.0, '2000_2004')	('apriti', 'ADJ')	5
# (42.0, '2000_2004')	('nuovo', 'ADJ')	2
# (42.0, '2000_2004')	('facile', 'ADJ')	2
# (42.0, '2000_2004')	('bastarda', 'ADJ')	2
# (42.0, '2000_2004')	('avresta', 'ADJ')	2
# (42.0, '2000_2004')	('wwwstepstoneit', 'ADJ')	1
# (42.0, '2000_2004')	('online', 'ADJ')	1
# (42.0, '2000_2004')	('primo', 'ADJ')	1
# (42.0, '2000_2004')	('solido', 'ADJ')	1
# (42.0, '2000_2004')	('futuro', 'ADJ')	1
#
# (42.0, '2005_2009')	('segreto', 'ADJ')	3
# (42.0, '2005_2009')	('multimediale', 'ADJ')	1
# (42.0, '2005_2009')	('nuovo', 'ADJ')	1
# (42.0, '2005_2009')	('portale', 'ADJ')	1
# (42.0, '2005_2009')	('bello', 'ADJ')	1
# (42.0, '2005_2009')	('semplice', 'ADJ')	1
# (42.0, '2005_2009')	('pronti', 'ADJ')	1
# (42.0, '2005_2009')	('sfida', 'ADJ')	1
#
# (42.0, '2020_2024')	('facile', 'ADJ')	3
# (42.0, '2020_2024')	('inplace', 'ADJ')	3
# (42.0, '2020_2024')	('virtuale', 'ADJ')	2
# (42.0, '2020_2024')	('giornaliero', 'ADJ')	1
# (42.0, '2020_2024')	('limite', 'ADJ')	1
# (42.0, '2020_2024')	('scopri', 'ADJ')	1
# (42.0, '2020_2024')	('strumento', 'ADJ')	1
# (42.0, '2020_2024')	('sano', 'ADJ')	1
# (42.0, '2020_2024')	('giorno', 'ADJ')	1
# (42.0, '2020_2024')	('vigile', 'ADJ')	1
#
# (43.0, '1980_1984')	('super', 'ADJ')	2
# (43.0, '1980_1984')	('uninitiativo', 'ADJ')	2
# (43.0, '1980_1984')	('giusto', 'ADJ')	1
# (43.0, '1980_1984')	('chiedi', 'ADJ')	1
# (43.0, '1980_1984')	('brasile', 'ADJ')	1
# (43.0, '1980_1984')	('viaggio', 'ADJ')	1
# (43.0, '1980_1984')	('bello', 'ADJ')	1
# (43.0, '1980_1984')	('mediterraneo', 'ADJ')	1
# (43.0, '1980_1984')	('giuste', 'ADJ')	1
# (43.0, '1980_1984')	('italiano', 'ADJ')	1
#
# (43.0, '1985_1989')	('italiano', 'ADJ')	6
# (43.0, '1985_1989')	('marlboro', 'ADJ')	5
# (43.0, '1985_1989')	('valley', 'ADJ')	4
# (43.0, '1985_1989')	('gusto', 'ADJ')	4
# (43.0, '1985_1989')	('grande', 'ADJ')	4
# (43.0, '1985_1989')	('lontano', 'ADJ')	4
# (43.0, '1985_1989')	('duro', 'ADJ')	3
# (43.0, '1985_1989')	('gran', 'ADJ')	3
# (43.0, '1985_1989')	('natale', 'ADJ')	3
# (43.0, '1985_1989')	('rothmans', 'ADJ')	3
#
# (43.0, '1990_1994')	('unico', 'ADJ')	1
# (43.0, '1990_1994')	('irripetibile', 'ADJ')	1
# (43.0, '1990_1994')	('singolare', 'ADJ')	1
# (43.0, '1990_1994')	('vieni', 'ADJ')	1
# (43.0, '1990_1994')	('straordinario', 'ADJ')	1
# (43.0, '1990_1994')	('lanzarote', 'ADJ')	1
# (43.0, '1990_1994')	('antidepressivo', 'ADJ')	1
# (43.0, '1990_1994')	('estivo', 'ADJ')	1
#
# (43.0, '1995_1999')	('imprevedibile', 'ADJ')	2
# (43.0, '1995_1999')	('blu', 'ADJ')	2
# (43.0, '1995_1999')	('laereo', 'ADJ')	1
# (43.0, '1995_1999')	('bello', 'ADJ')	1
# (43.0, '1995_1999')	('ventaglio', 'ADJ')	1
# (43.0, '1995_1999')	('nellario', 'ADJ')	1
# (43.0, '1995_1999')	('beh', 'ADJ')	1
#
# (43.0, '2000_2004')	('spizzico', 'ADJ')	4
# (43.0, '2000_2004')	('fast', 'ADJ')	4
# (43.0, '2000_2004')	('gelato', 'ADJ')	3
# (43.0, '2000_2004')	('nuovo', 'ADJ')	3
# (43.0, '2000_2004')	('tanto', 'ADJ')	3
# (43.0, '2000_2004')	('rapina', 'ADJ')	2
# (43.0, '2000_2004')	('im', 'ADJ')	2
# (43.0, '2000_2004')	('mcnuggets', 'ADJ')	2
# (43.0, '2000_2004')	('completo', 'ADJ')	2
# (43.0, '2000_2004')	('ovvi', 'ADJ')	1
#
# (43.0, '2005_2009')	('nuovo', 'ADJ')	7
# (43.0, '2005_2009')	('bello', 'ADJ')	2
# (43.0, '2005_2009')	('fresco', 'ADJ')	2
# (43.0, '2005_2009')	('coca', 'ADJ')	2
# (43.0, '2005_2009')	('grande', 'ADJ')	1
# (43.0, '2005_2009')	('ricco', 'ADJ')	1
# (43.0, '2005_2009')	('prosciutto', 'ADJ')	1
# (43.0, '2005_2009')	('cotto', 'ADJ')	1
# (43.0, '2005_2009')	('spyro', 'ADJ')	1
# (43.0, '2005_2009')	('crash', 'ADJ')	1
#
# (43.0, '2010_2014')	('nuovo', 'ADJ')	9
# (43.0, '2010_2014')	('altro', 'ADJ')	3
# (43.0, '2010_2014')	('italiano', 'ADJ')	3
# (43.0, '2010_2014')	('mcdonalds', 'ADJ')	3
# (43.0, '2010_2014')	('fantastico', 'ADJ')	2
# (43.0, '2010_2014')	('mondiale', 'ADJ')	2
# (43.0, '2010_2014')	('prossimo', 'ADJ')	2
# (43.0, '2010_2014')	('gusto', 'ADJ')	2
# (43.0, '2010_2014')	('primo', 'ADJ')	2
# (43.0, '2010_2014')	('buon', 'ADJ')	2
#
# (43.0, '2015_2019')	('nuovo', 'ADJ')	3
# (43.0, '2015_2019')	('buon', 'ADJ')	3
# (43.0, '2015_2019')	('grande', 'ADJ')	3
# (43.0, '2015_2019')	('gran', 'ADJ')	3
# (43.0, '2015_2019')	('croccante', 'ADJ')	2
# (43.0, '2015_2019')	('diverso', 'ADJ')	2
# (43.0, '2015_2019')	('mcdrive', 'ADJ')	2
# (43.0, '2015_2019')	('buono', 'ADJ')	2
# (43.0, '2015_2019')	('mcbacon', 'ADJ')	2
# (43.0, '2015_2019')	('altro', 'ADJ')	1
#
# (43.0, '2020_2024')	('italiano', 'ADJ')	7
# (43.0, '2020_2024')	('nuovo', 'ADJ')	5
# (43.0, '2020_2024')	('fermo', 'ADJ')	4
# (43.0, '2020_2024')	('migliore', 'ADJ')	4
# (43.0, '2020_2024')	('primo', 'ADJ')	3
# (43.0, '2020_2024')	('grande', 'ADJ')	3
# (43.0, '2020_2024')	('croccante', 'ADJ')	3
# (43.0, '2020_2024')	('factory', 'ADJ')	2
# (43.0, '2020_2024')	('esperto', 'ADJ')	2
# (43.0, '2020_2024')	('lesclusivo', 'ADJ')	2
#
# (44.0, '1980_1984')	('salve', 'ADJ')	2
# (44.0, '1980_1984')	('favolosa', 'ADJ')	1
# (44.0, '1980_1984')	('meraviglioso', 'ADJ')	1
# (44.0, '1980_1984')	('vero', 'ADJ')	1
# (44.0, '1980_1984')	('up', 'ADJ')	1
# (44.0, '1980_1984')	('gratuito', 'ADJ')	1
# (44.0, '1980_1984')	('ciao', 'ADJ')	1
# (44.0, '1980_1984')	('traumatico', 'ADJ')	1
# (44.0, '1980_1984')	('artroso', 'ADJ')	1
# (44.0, '1980_1984')	('magnetoterapia', 'ADJ')	1
#
# (44.0, '1985_1989')	('medicenter', 'ADJ')	3
# (44.0, '1985_1989')	('sicuro', 'ADJ')	2
# (44.0, '1985_1989')	('lunico', 'ADJ')	2
# (44.0, '1985_1989')	('accurato', 'ADJ')	2
# (44.0, '1985_1989')	('adatto', 'ADJ')	2
# (44.0, '1985_1989')	('capello', 'ADJ')	2
# (44.0, '1985_1989')	('allistituto', 'ADJ')	2
# (44.0, '1985_1989')	('listituto', 'ADJ')	1
# (44.0, '1985_1989')	('famoso', 'ADJ')	1
# (44.0, '1985_1989')	('pelato', 'ADJ')	1
#
# (44.0, '1990_1994')	('calvo', 'ADJ')	1
# (44.0, '1990_1994')	('impossibile', 'ADJ')	1
# (44.0, '1990_1994')	('vero', 'ADJ')	1
# (44.0, '1990_1994')	('avanzato', 'ADJ')	1
# (44.0, '1990_1994')	('risultato', 'ADJ')	1
# (44.0, '1990_1994')	('sicuro', 'ADJ')	1
# (44.0, '1990_1994')	('gratuito', 'ADJ')	1
#
# (44.0, '1995_1999')	('capello', 'ADJ')	2
# (44.0, '1995_1999')	('naturale', 'ADJ')	2
# (44.0, '1995_1999')	('buono', 'ADJ')	1
# (44.0, '1995_1999')	('fresco', 'ADJ')	1
# (44.0, '1995_1999')	('antico', 'ADJ')	1
# (44.0, '1995_1999')	('grande', 'ADJ')	1
# (44.0, '1995_1999')	('calvo', 'ADJ')	1
# (44.0, '1995_1999')	('altro', 'ADJ')	1
# (44.0, '1995_1999')	('stesso', 'ADJ')	1
# (44.0, '1995_1999')	('graduale', 'ADJ')	1
#
#
# (44.0, '2005_2009')	('primo', 'ADJ')	3
# (44.0, '2005_2009')	('gratuito', 'ADJ')	3
# (44.0, '2005_2009')	('estetico', 'ADJ')	2
# (44.0, '2005_2009')	('medico', 'ADJ')	2
# (44.0, '2005_2009')	('plastico', 'ADJ')	1
# (44.0, '2005_2009')	('difetto', 'ADJ')	1
# (44.0, '2005_2009')	('italiano', 'ADJ')	1
# (44.0, '2005_2009')	('medicina', 'ADJ')	1
# (44.0, '2005_2009')	('personale', 'ADJ')	1
# (44.0, '2005_2009')	('specialisto', 'ADJ')	1
#
# (45.0, '1985_1989')	('mago', 'ADJ')	3
# (45.0, '1985_1989')	('napoli', 'ADJ')	2
# (45.0, '1985_1989')	('locale', 'ADJ')	2
# (45.0, '1985_1989')	('grado', 'ADJ')	1
# (45.0, '1985_1989')	('brevissimo', 'ADJ')	1
# (45.0, '1985_1989')	('pratico', 'ADJ')	1
# (45.0, '1985_1989')	('vero', 'ADJ')	1
# (45.0, '1985_1989')	('nero', 'ADJ')	1
# (45.0, '1985_1989')	('solo', 'ADJ')	1
# (45.0, '1985_1989')	('telefono', 'ADJ')	1
#
# (45.0, '1990_1994')	('italiano', 'ADJ')	3
# (45.0, '1990_1994')	('fiore', 'ADJ')	3
# (45.0, '1990_1994')	('bello', 'ADJ')	3
# (45.0, '1990_1994')	('inevitabile', 'ADJ')	2
# (45.0, '1990_1994')	('necessario', 'ADJ')	1
# (45.0, '1990_1994')	('vasto', 'ADJ')	1
# (45.0, '1990_1994')	('politica', 'ADJ')	1
# (45.0, '1990_1994')	('sociale', 'ADJ')	1
# (45.0, '1990_1994')	('efficace', 'ADJ')	1
# (45.0, '1990_1994')	('lareo', 'ADJ')	1
#
# (45.0, '2000_2004')	('entrambi', 'ADJ')	1
# (45.0, '2000_2004')	('femminile', 'ADJ')	1
#
# (45.0, '2005_2009')	('speciale', 'ADJ')	2
# (45.0, '2005_2009')	('mms', 'ADJ')	2
# (45.0, '2005_2009')	('ricco', 'ADJ')	2
# (45.0, '2005_2009')	('massimo', 'ADJ')	2
# (45.0, '2005_2009')	('bello', 'ADJ')	1
# (45.0, '2005_2009')	('milione', 'ADJ')	1
# (45.0, '2005_2009')	('collegati', 'ADJ')	1
# (45.0, '2005_2009')	('anima', 'ADJ')	1
# (45.0, '2005_2009')	('gemello', 'ADJ')	1
#
# (45.0, '2020_2024')	('verisure', 'ADJ')	2
# (45.0, '2020_2024')	('sentirto', 'ADJ')	1
# (45.0, '2020_2024')	('sicuro', 'ADJ')	1
# (45.0, '2020_2024')	('immediato', 'ADJ')	1

# %%
#Print the top 10 NOUNS of every nice class
spots_words = dict()
spots_noun=dict()
for key in dictionary:
     spots_words[key] = pos_tag_italian(dictionary[key])
for key in spots_words:
    if key not in spots_noun:
        spots_noun[key] = []
    for values in spots_words[key]:
        if 'NOUN' in values:  
            spots_noun[key].append(values)
    
spots_noun[28.0, '1980_1984'] #example
# Out:
# [('acceleratore', 'NOUN'),
#  ('cambio', 'NOUN'),
#  ('bisogno', 'NOUN'),
#  ('motore', 'NOUN'),
#  ('nome', 'NOUN'),
#  ('rimbalzina', 'NOUN'),
#  ('divertitevi', 'NOUN'),
#  ('rimbalzina', 'NOUN'),
#  ('pallina', 'NOUN'),
#  ('rimbalzina', 'NOUN'),
#  ('linea', 'NOUN'),
#  ('occhio', 'NOUN'),
#  ('capello', 'NOUN'),
#  ('biondi', 'NOUN'),
#  ('saltaragno', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('attenzione', 'NOUN'),
#  ('potere', 'NOUN'),
#  ('ragnatela', 'NOUN'),
#  ('anchio', 'NOUN'),
#  ('attenzione', 'NOUN'),
#  ('aiuto', 'NOUN'),
#  ('saltaragno', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('editore', 'NOUN'),
#  ('giochi', 'NOUN'),
#  ('formelli', 'NOUN'),
#  ('luntro', 'NOUN'),
#  ('sennuore', 'NOUN'),
#  ('qualità', 'NOUN'),
#  ('bento', 'NOUN'),
#  ('cagliote', 'NOUN'),
#  ('gamia', 'NOUN'),
#  ('laszello', 'NOUN'),
#  ('sennuore', 'NOUN'),
#  ('qualità', 'NOUN'),
#  ('limone', 'NOUN'),
#  ('paglietta', 'NOUN'),
#  ('limone', 'NOUN'),
#  ('cassetta', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('tv', 'NOUN'),
#  ('punto', 'NOUN'),
#  ('atari', 'NOUN'),
#  ('wow', 'NOUN'),
#  ('cancello', 'NOUN'),
#  ('eroe', 'NOUN'),
#  ('stunt', 'NOUN'),
#  ('motore', 'NOUN'),
#  ('competizione', 'NOUN'),
#  ('velocità', 'NOUN'),
#  ('potere', 'NOUN'),
#  ('pilota', 'NOUN'),
#  ('stunt', 'NOUN'),
#  ('gomito', 'NOUN'),
#  ('batteria', 'NOUN'),
#  ('stunt', 'NOUN'),
#  ('potere', 'NOUN'),
#  ('muro', 'NOUN'),
#  ('equilibrio', 'NOUN'),
#  ('stunt', 'NOUN'),
#  ('harbert', 'NOUN'),
#  ('linea', 'NOUN'),
#  ('sport', 'NOUN'),
#  ('grazie', 'NOUN'),
#  ('visione', 'NOUN'),
#  ('bambola', 'NOUN'),
#  ('camilla', 'NOUN'),
#  ('mondo', 'NOUN'),
#  ('camilla', 'NOUN'),
#  ('mammino', 'NOUN'),
#  ('cullame', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('storia', 'NOUN'),
#  ('incantato', 'NOUN'),
#  ('nellorecchio', 'NOUN'),
#  ('mimmino', 'NOUN'),
#  ('mare', 'NOUN'),
#  ('re', 'NOUN'),
#  ('mimmino', 'NOUN'),
#  ('parolina', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('casa', 'NOUN'),
#  ('ambiente', 'NOUN'),
#  ('amico', 'NOUN'),
#  ('pranzo', 'NOUN'),
#  ('salotto', 'NOUN'),
#  ('piscina', 'NOUN'),
#  ('ciochi', 'NOUN'),
#  ('baby', 'NOUN'),
#  ('cioco', 'NOUN'),
#  ('mattel', 'NOUN'),
#  ('gelati', 'NOUN'),
#  ('piacere', 'NOUN'),
#  ('eroe', 'NOUN'),
#  ('tecnologia', 'NOUN'),
#  ('robot', 'NOUN'),
#  ('nascita', 'NOUN'),
#  ('computer', 'NOUN'),
#  ('trasformazione', 'NOUN'),
#  ('robot', 'NOUN'),
#  ('robot', 'NOUN'),
#  ('generazione', 'NOUN'),
#  ('serie', 'NOUN'),
#  ('linea', 'NOUN'),
#  ('mattel', 'NOUN'),
#  ('masters', 'NOUN'),
#  ('dominatore', 'NOUN'),
#  ('castello', 'NOUN'),
#  ('tessio', 'NOUN'),
#  ('strato', 'NOUN'),
#  ('uomo', 'NOUN'),
#  ('uccello', 'NOUN'),
#  ('spalla', 'NOUN'),
#  ('aiuto', 'NOUN'),
#  ('potere', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('pesta', 'NOUN'),
#  ('lisola', 'NOUN'),
#  ('lhanno', 'NOUN'),
#  ('larca', 'NOUN'),
#  ('eroe', 'NOUN'),
#  ('ragazzi', 'NOUN'),
#  ('formaggio', 'NOUN'),
#  ('abilità', 'NOUN'),
#  ('tano', 'NOUN'),
#  ('numero', 'NOUN'),
#  ('formaggio', 'NOUN'),
#  ('cosa', 'NOUN'),
#  ('cosa', 'NOUN'),
#  ('cosa', 'NOUN'),
#  ('affare', 'NOUN'),
#  ('braccio', 'NOUN'),
#  ('mezzo', 'NOUN'),
#  ('rana', 'NOUN'),
#  ('crac', 'NOUN'),
#  ('crac', 'NOUN'),
#  ('crac', 'NOUN'),
#  ('crac', 'NOUN'),
#  ('gallo', 'NOUN'),
#  ('gallo', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('voce', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('gioco', 'NOUN'),
#  ('bambino', 'NOUN'),
#  ('ragazzi', 'NOUN'),
#  ('squalo', 'NOUN'),
#  ('paura', 'NOUN'),
#  ('squalo', 'NOUN'),
#  ('piacere', 'NOUN'),
#  ('motorino', 'NOUN'),
#  ('casco', 'NOUN'),
#  ('fila', 'NOUN'),
#  ('libro', 'NOUN'),
#  ('gas', 'NOUN'),
#  ('trucco', 'NOUN'),
#  ('moda', 'NOUN'),
#  ('occhio', 'NOUN'),
#  ('colore', 'NOUN'),
#  ('ornamento', 'NOUN'),
#  ('confezione', 'NOUN'),
#  ('barbie', 'NOUN'),
#  ('ora', 'NOUN'),
#  ('piccolina', 'NOUN'),
#  ('mondo', 'NOUN'),
#  ('camilla', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('spettacolo', 'NOUN'),
#  ('pallone', 'NOUN'),
#  ('campione', 'NOUN'),
#  ('mondo', 'NOUN'),
#  ('bagno', 'NOUN'),
#  ('bollicine', 'NOUN'),
#  ('bolla', 'NOUN'),
#  ('riprodure', 'NOUN'),
#  ('bagno', 'NOUN'),
#  ('eccola', 'NOUN'),
#  ('bellezza', 'NOUN'),
#  ('shampoo', 'NOUN'),
#  ('mere', 'NOUN'),
#  ('moda', 'NOUN'),
#  ('ore', 'NOUN'),
#  ('bagno', 'NOUN'),
#  ('listitere', 'NOUN')]

# %%
vocabularies = dict()
for key in dictionary:
    vocabularies[key] = set(spots_noun[key])

frequencies = dict()
for key in dictionary:
    frequencies[key] = Counter(spots_noun[key])

top = 10
previous_key = None

for key in sorted(dictionary):
    if key != previous_key and previous_key is not None:
        print()
    previous_key = key
    words_top = sorted(frequencies[key].items(), key=lambda x: x[1], reverse=True)[:10]
    for word, frequency in words_top:
              print(key, word, frequency, sep='\t')
# Out:
# (1.0, '1980_1984')	('sabato', 'NOUN')	1
# (1.0, '1980_1984')	('giorno', 'NOUN')	1
# (1.0, '1980_1984')	('foglia', 'NOUN')	1
# (1.0, '1980_1984')	('substral', 'NOUN')	1
# (1.0, '1980_1984')	('piante', 'NOUN')	1
#
# (1.0, '1985_1989')	('bostik', 'NOUN')	2
# (1.0, '1985_1989')	('primavera', 'NOUN')	2
# (1.0, '1985_1989')	('cocrepe', 'NOUN')	1
# (1.0, '1985_1989')	('disastro', 'NOUN')	1
# (1.0, '1985_1989')	('servo', 'NOUN')	1
# (1.0, '1985_1989')	('assembler', 'NOUN')	1
# (1.0, '1985_1989')	('bisogno', 'NOUN')	1
# (1.0, '1985_1989')	('cura', 'NOUN')	1
# (1.0, '1985_1989')	('liquido', 'NOUN')	1
# (1.0, '1985_1989')	('pianta', 'NOUN')	1
#
# (2.0, '1980_1984')	('casacolor', 'NOUN')	2
# (2.0, '1980_1984')	('stanza', 'NOUN')	2
# (2.0, '1980_1984')	('colore', 'NOUN')	2
# (2.0, '1980_1984')	('prova', 'NOUN')	1
# (2.0, '1980_1984')	('lira', 'NOUN')	1
# (2.0, '1980_1984')	('potere', 'NOUN')	1
# (2.0, '1980_1984')	('superficie', 'NOUN')	1
# (2.0, '1980_1984')	('tecnologia', 'NOUN')	1
# (2.0, '1980_1984')	('meyer', 'NOUN')	1
#
# (3.0, '1980_1984')	('shampoo', 'NOUN')	34
# (3.0, '1980_1984')	('potere', 'NOUN')	25
# (3.0, '1980_1984')	('pelle', 'NOUN')	24
# (3.0, '1980_1984')	('profumo', 'NOUN')	16
# (3.0, '1980_1984')	('colore', 'NOUN')	16
# (3.0, '1980_1984')	('sapone', 'NOUN')	15
# (3.0, '1980_1984')	('giorno', 'NOUN')	14
# (3.0, '1980_1984')	('piatto', 'NOUN')	14
# (3.0, '1980_1984')	('schiuma', 'NOUN')	12
# (3.0, '1980_1984')	('piacere', 'NOUN')	11
#
# (3.0, '1985_1989')	('potere', 'NOUN')	94
# (3.0, '1985_1989')	('pelle', 'NOUN')	73
# (3.0, '1985_1989')	('giorno', 'NOUN')	70
# (3.0, '1985_1989')	('shampoo', 'NOUN')	62
# (3.0, '1985_1989')	('profumo', 'NOUN')	53
# (3.0, '1985_1989')	('colore', 'NOUN')	52
# (3.0, '1985_1989')	('dixan', 'NOUN')	45
# (3.0, '1985_1989')	('lana', 'NOUN')	41
# (3.0, '1985_1989')	('macchia', 'NOUN')	41
# (3.0, '1985_1989')	('mano', 'NOUN')	38
#
# (3.0, '1990_1994')	('shampoo', 'NOUN')	95
# (3.0, '1990_1994')	('pelle', 'NOUN')	81
# (3.0, '1990_1994')	('giorno', 'NOUN')	67
# (3.0, '1990_1994')	('macchia', 'NOUN')	54
# (3.0, '1990_1994')	('potere', 'NOUN')	48
# (3.0, '1990_1994')	('colore', 'NOUN')	45
# (3.0, '1990_1994')	('ace', 'NOUN')	43
# (3.0, '1990_1994')	('profumo', 'NOUN')	35
# (3.0, '1990_1994')	('bagno', 'NOUN')	34
# (3.0, '1990_1994')	('morbidezza', 'NOUN')	34
#
# (3.0, '1995_1999')	('pelle', 'NOUN')	27
# (3.0, '1995_1999')	('forza', 'NOUN')	21
# (3.0, '1995_1999')	('gel', 'NOUN')	19
# (3.0, '1995_1999')	('giorno', 'NOUN')	19
# (3.0, '1995_1999')	('freschezza', 'NOUN')	17
# (3.0, '1995_1999')	('shampoo', 'NOUN')	16
# (3.0, '1995_1999')	('colore', 'NOUN')	16
# (3.0, '1995_1999')	('macchia', 'NOUN')	15
# (3.0, '1995_1999')	('crema', 'NOUN')	12
# (3.0, '1995_1999')	('capello', 'NOUN')	11
#
# (3.0, '2000_2004')	('pelle', 'NOUN')	51
# (3.0, '2000_2004')	('colore', 'NOUN')	42
# (3.0, '2000_2004')	('shampoo', 'NOUN')	22
# (3.0, '2000_2004')	('gel', 'NOUN')	21
# (3.0, '2000_2004')	('giorno', 'NOUN')	21
# (3.0, '2000_2004')	('potere', 'NOUN')	20
# (3.0, '2000_2004')	('crema', 'NOUN')	17
# (3.0, '2000_2004')	('protezione', 'NOUN')	16
# (3.0, '2000_2004')	('settimana', 'NOUN')	15
# (3.0, '2000_2004')	('forza', 'NOUN')	15
#
# (3.0, '2005_2009')	('pelle', 'NOUN')	40
# (3.0, '2005_2009')	('potere', 'NOUN')	32
# (3.0, '2005_2009')	('roberts', 'NOUN')	20
# (3.0, '2005_2009')	('volta', 'NOUN')	18
# (3.0, '2005_2009')	('protezione', 'NOUN')	18
# (3.0, '2005_2009')	('colore', 'NOUN')	17
# (3.0, '2005_2009')	('odore', 'NOUN')	17
# (3.0, '2005_2009')	('gel', 'NOUN')	16
# (3.0, '2005_2009')	('giorno', 'NOUN')	16
# (3.0, '2005_2009')	('crema', 'NOUN')	16
#
# (3.0, '2010_2014')	('potere', 'NOUN')	12
# (3.0, '2010_2014')	('borotalco', 'NOUN')	11
# (3.0, '2010_2014')	('giorno', 'NOUN')	8
# (3.0, '2010_2014')	('capello', 'NOUN')	7
# (3.0, '2010_2014')	('colore', 'NOUN')	7
# (3.0, '2010_2014')	('olio', 'NOUN')	7
# (3.0, '2010_2014')	('pelle', 'NOUN')	7
# (3.0, '2010_2014')	('effetto', 'NOUN')	7
# (3.0, '2010_2014')	('linea', 'NOUN')	7
# (3.0, '2010_2014')	('garnier', 'NOUN')	6
#
# (3.0, '2015_2019')	('potere', 'NOUN')	12
# (3.0, '2015_2019')	('pelle', 'NOUN')	11
# (3.0, '2015_2019')	('macchia', 'NOUN')	11
# (3.0, '2015_2019')	('capelli', 'NOUN')	9
# (3.0, '2015_2019')	('capello', 'NOUN')	8
# (3.0, '2015_2019')	('olio', 'NOUN')	7
# (3.0, '2015_2019')	('profumo', 'NOUN')	7
# (3.0, '2015_2019')	('dixan', 'NOUN')	7
# (3.0, '2015_2019')	('giorno', 'NOUN')	6
# (3.0, '2015_2019')	('spot', 'NOUN')	6
#
# (3.0, '2020_2024')	('potere', 'NOUN')	14
# (3.0, '2020_2024')	('pelle', 'NOUN')	13
# (3.0, '2020_2024')	('volta', 'NOUN')	10
# (3.0, '2020_2024')	('lavaggio', 'NOUN')	9
# (3.0, '2020_2024')	('segno', 'NOUN')	8
# (3.0, '2020_2024')	('gel', 'NOUN')	8
# (3.0, '2020_2024')	('parola', 'NOUN')	7
# (3.0, '2020_2024')	('freschezza', 'NOUN')	7
# (3.0, '2020_2024')	('germo', 'NOUN')	7
# (3.0, '2020_2024')	('candeggina', 'NOUN')	7
#
# (4.0, '1980_1984')	('nome', 'NOUN')	1
# (4.0, '1980_1984')	('strada', 'NOUN')	1
# (4.0, '1980_1984')	('stagione', 'NOUN')	1
#
# (4.0, '1985_1989')	('mano', 'NOUN')	11
# (4.0, '1985_1989')	('riscaldamento', 'NOUN')	8
# (4.0, '1985_1989')	('potere', 'NOUN')	7
# (4.0, '1985_1989')	('lenergia', 'NOUN')	5
# (4.0, '1985_1989')	('motore', 'NOUN')	5
# (4.0, '1985_1989')	('casa', 'NOUN')	5
# (4.0, '1985_1989')	('calore', 'NOUN')	5
# (4.0, '1985_1989')	('sint', 'NOUN')	4
# (4.0, '1985_1989')	('potenza', 'NOUN')	4
# (4.0, '1985_1989')	('impurità', 'NOUN')	4
#
# (4.0, '1990_1994')	('dollaro', 'NOUN')	9
# (4.0, '1990_1994')	('gas', 'NOUN')	7
# (4.0, '1990_1994')	('benzina', 'NOUN')	6
# (4.0, '1990_1994')	('papà', 'NOUN')	4
# (4.0, '1990_1994')	('sogno', 'NOUN')	4
# (4.0, '1990_1994')	('ricambio', 'NOUN')	4
# (4.0, '1990_1994')	('sicurezza', 'NOUN')	4
# (4.0, '1990_1994')	('abitudine', 'NOUN')	4
# (4.0, '1990_1994')	('casa', 'NOUN')	3
# (4.0, '1990_1994')	('potere', 'NOUN')	3
#
# (4.0, '1995_1999')	('benzina', 'NOUN')	4
# (4.0, '1995_1999')	('professore', 'NOUN')	3
# (4.0, '1995_1999')	('servizio', 'NOUN')	3
# (4.0, '1995_1999')	('regalo', 'NOUN')	3
# (4.0, '1995_1999')	('gestore', 'NOUN')	2
# (4.0, '1995_1999')	('piombo', 'NOUN')	2
# (4.0, '1995_1999')	('stazione', 'NOUN')	2
# (4.0, '1995_1999')	('promozione', 'NOUN')	2
# (4.0, '1995_1999')	('lolio', 'NOUN')	2
# (4.0, '1995_1999')	('vento', 'NOUN')	2
#
# (4.0, '2000_2004')	('promozione', 'NOUN')	5
# (4.0, '2000_2004')	('benzina', 'NOUN')	1
# (4.0, '2000_2004')	('band', 'NOUN')	1
# (4.0, '2000_2004')	('tariff', 'NOUN')	1
# (4.0, '2000_2004')	('lusso', 'NOUN')	1
# (4.0, '2000_2004')	('omitel', 'NOUN')	1
# (4.0, '2000_2004')	('zaino', 'NOUN')	1
# (4.0, '2000_2004')	('omnitel', 'NOUN')	1
# (4.0, '2000_2004')	('alcatel', 'NOUN')	1
# (4.0, '2000_2004')	('famiglia', 'NOUN')	1
#
# (4.0, '2005_2009')	('motore', 'NOUN')	6
# (4.0, '2005_2009')	('strada', 'NOUN')	4
# (4.0, '2005_2009')	('api', 'NOUN')	4
# (4.0, '2005_2009')	('gruppo', 'NOUN')	3
# (4.0, '2005_2009')	('giorno', 'NOUN')	2
# (4.0, '2005_2009')	('bollino', 'NOUN')	2
# (4.0, '2005_2009')	('premio', 'NOUN')	2
# (4.0, '2005_2009')	('punto', 'NOUN')	2
# (4.0, '2005_2009')	('club', 'NOUN')	2
# (4.0, '2005_2009')	('potenza', 'NOUN')	1
#
# (5.0, '1980_1984')	('potere', 'NOUN')	14
# (5.0, '1980_1984')	('avvertenza', 'NOUN')	8
# (5.0, '1980_1984')	('lalimentazione', 'NOUN')	7
# (5.0, '1980_1984')	('fegato', 'NOUN')	6
# (5.0, '1980_1984')	('lines', 'NOUN')	6
# (5.0, '1980_1984')	('giorno', 'NOUN')	5
# (5.0, '1980_1984')	('vita', 'NOUN')	5
# (5.0, '1980_1984')	('volo', 'NOUN')	5
# (5.0, '1980_1984')	('sintomo', 'NOUN')	4
# (5.0, '1980_1984')	('occhio', 'NOUN')	4
#
# (5.0, '1985_1989')	('lines', 'NOUN')	40
# (5.0, '1985_1989')	('potere', 'NOUN')	39
# (5.0, '1985_1989')	('cautela', 'NOUN')	30
# (5.0, '1985_1989')	('gola', 'NOUN')	20
# (5.0, '1985_1989')	('pelle', 'NOUN')	12
# (5.0, '1985_1989')	('dieta', 'NOUN')	11
# (5.0, '1985_1989')	('tosse', 'NOUN')	11
# (5.0, '1985_1989')	('modo', 'NOUN')	11
# (5.0, '1985_1989')	('mattina', 'NOUN')	11
# (5.0, '1985_1989')	('sicurezza', 'NOUN')	10
#
# (5.0, '1990_1994')	('potere', 'NOUN')	28
# (5.0, '1990_1994')	('lines', 'NOUN')	26
# (5.0, '1990_1994')	('giorno', 'NOUN')	19
# (5.0, '1990_1994')	('gola', 'NOUN')	18
# (5.0, '1990_1994')	('specialità', 'NOUN')	15
# (5.0, '1990_1994')	('pelle', 'NOUN')	14
# (5.0, '1990_1994')	('biscotto', 'NOUN')	10
# (5.0, '1990_1994')	('effetto', 'NOUN')	9
# (5.0, '1990_1994')	('piacere', 'NOUN')	8
# (5.0, '1990_1994')	('naso', 'NOUN')	8
#
# (5.0, '1995_1999')	('foglio', 'NOUN')	13
# (5.0, '1995_1999')	('potere', 'NOUN')	12
# (5.0, '1995_1999')	('tosse', 'NOUN')	12
# (5.0, '1995_1999')	('lines', 'NOUN')	8
# (5.0, '1995_1999')	('anno', 'NOUN')	7
# (5.0, '1995_1999')	('bambino', 'NOUN')	6
# (5.0, '1995_1999')	('controindicazione', 'NOUN')	5
# (5.0, '1995_1999')	('problema', 'NOUN')	5
# (5.0, '1995_1999')	('effetto', 'NOUN')	5
# (5.0, '1995_1999')	('medico', 'NOUN')	4
#
# (5.0, '2000_2004')	('potere', 'NOUN')	24
# (5.0, '2000_2004')	('foglio', 'NOUN')	22
# (5.0, '2000_2004')	('dolore', 'NOUN')	15
# (5.0, '2000_2004')	('gel', 'NOUN')	12
# (5.0, '2000_2004')	('giorno', 'NOUN')	10
# (5.0, '2000_2004')	('anno', 'NOUN')	10
# (5.0, '2000_2004')	('tosse', 'NOUN')	10
# (5.0, '2000_2004')	('bambino', 'NOUN')	10
# (5.0, '2000_2004')	('base', 'NOUN')	9
# (5.0, '2000_2004')	('lines', 'NOUN')	7
#
# (5.0, '2005_2009')	('potere', 'NOUN')	33
# (5.0, '2005_2009')	('foglio', 'NOUN')	27
# (5.0, '2005_2009')	('dolore', 'NOUN')	21
# (5.0, '2005_2009')	('lines', 'NOUN')	20
# (5.0, '2005_2009')	('giorno', 'NOUN')	18
# (5.0, '2005_2009')	('effetto', 'NOUN')	18
# (5.0, '2005_2009')	('gola', 'NOUN')	13
# (5.0, '2005_2009')	('base', 'NOUN')	10
# (5.0, '2005_2009')	('anno', 'NOUN')	10
# (5.0, '2005_2009')	('bambino', 'NOUN')	9
#
# (5.0, '2010_2014')	('potere', 'NOUN')	41
# (5.0, '2010_2014')	('effetto', 'NOUN')	17
# (5.0, '2010_2014')	('dolore', 'NOUN')	16
# (5.0, '2010_2014')	('base', 'NOUN')	15
# (5.0, '2010_2014')	('foglio', 'NOUN')	14
# (5.0, '2010_2014')	('gola', 'NOUN')	12
# (5.0, '2010_2014')	('testa', 'NOUN')	7
# (5.0, '2010_2014')	('sintomo', 'NOUN')	7
# (5.0, '2010_2014')	('linfiammazione', 'NOUN')	6
# (5.0, '2010_2014')	('benagol', 'NOUN')	6
#
# (5.0, '2015_2019')	('potere', 'NOUN')	49
# (5.0, '2015_2019')	('dolore', 'NOUN')	19
# (5.0, '2015_2019')	('effetto', 'NOUN')	14
# (5.0, '2015_2019')	('sintomo', 'NOUN')	13
# (5.0, '2015_2019')	('azione', 'NOUN')	8
# (5.0, '2015_2019')	('lines', 'NOUN')	7
# (5.0, '2015_2019')	('casa', 'NOUN')	6
# (5.0, '2015_2019')	('minuto', 'NOUN')	6
# (5.0, '2015_2019')	('gola', 'NOUN')	6
# (5.0, '2015_2019')	('gioco', 'NOUN')	5
#
# (5.0, '2020_2024')	('potere', 'NOUN')	37
# (5.0, '2020_2024')	('dolore', 'NOUN')	13
# (5.0, '2020_2024')	('gola', 'NOUN')	11
# (5.0, '2020_2024')	('lines', 'NOUN')	10
# (5.0, '2020_2024')	('ciclo', 'NOUN')	10
# (5.0, '2020_2024')	('notte', 'NOUN')	7
# (5.0, '2020_2024')	('testa', 'NOUN')	7
# (5.0, '2020_2024')	('donna', 'NOUN')	6
# (5.0, '2020_2024')	('meclon', 'NOUN')	6
# (5.0, '2020_2024')	('sintomo', 'NOUN')	6
#
# (6.0, '1980_1984')	('bagno', 'NOUN')	3
# (6.0, '1980_1984')	('standard', 'NOUN')	2
# (6.0, '1980_1984')	('quarzomix', 'NOUN')	1
# (6.0, '1980_1984')	('doccia', 'NOUN')	1
# (6.0, '1980_1984')	('lacqua', 'NOUN')	1
# (6.0, '1980_1984')	('mano', 'NOUN')	1
# (6.0, '1980_1984')	('perfezione', 'NOUN')	1
# (6.0, '1980_1984')	('centro', 'NOUN')	1
# (6.0, '1980_1984')	('arredamento', 'NOUN')	1
# (6.0, '1980_1984')	('modello', 'NOUN')	1
#
# (6.0, '1985_1989')	('onduline', 'NOUN')	3
# (6.0, '1985_1989')	('standard', 'NOUN')	2
# (6.0, '1985_1989')	('paini', 'NOUN')	1
# (6.0, '1985_1989')	('libertà', 'NOUN')	1
# (6.0, '1985_1989')	('lacqua', 'NOUN')	1
# (6.0, '1985_1989')	('giornata', 'NOUN')	1
# (6.0, '1985_1989')	('mishilatori', 'NOUN')	1
# (6.0, '1985_1989')	('fratelli', 'NOUN')	1
# (6.0, '1985_1989')	('soluzione', 'NOUN')	1
# (6.0, '1985_1989')	('rivenditore', 'NOUN')	1
#
# (6.0, '2005_2009')	('raccolta', 'NOUN')	3
# (6.0, '2005_2009')	('lattina', 'NOUN')	2
# (6.0, '2005_2009')	('potere', 'NOUN')	2
# (6.0, '2005_2009')	('principio', 'NOUN')	1
# (6.0, '2005_2009')	('foglio', 'NOUN')	1
#
# (6.0, '2020_2024')	('pecchio', 'NOUN')	1
# (6.0, '2020_2024')	('letro', 'NOUN')	1
# (6.0, '2020_2024')	('scena', 'NOUN')	1
# (6.0, '2020_2024')	('finestra', 'NOUN')	1
# (6.0, '2020_2024')	('muro', 'NOUN')	1
# (6.0, '2020_2024')	('azione', 'NOUN')	1
# (6.0, '2020_2024')	('vista', 'NOUN')	1
# (6.0, '2020_2024')	('cornice', 'NOUN')	1
# (6.0, '2020_2024')	('profilo', 'NOUN')	1
# (6.0, '2020_2024')	('luce', 'NOUN')	1
#
# (7.0, '1980_1984')	('caffè', 'NOUN')	10
# (7.0, '1980_1984')	('grado', 'NOUN')	6
# (7.0, '1980_1984')	('vapore', 'NOUN')	4
# (7.0, '1980_1984')	('defendi', 'NOUN')	2
# (7.0, '1980_1984')	('casa', 'NOUN')	2
# (7.0, '1980_1984')	('piastrella', 'NOUN')	2
# (7.0, '1980_1984')	('diavolo', 'NOUN')	2
# (7.0, '1980_1984')	('spazzolone', 'NOUN')	2
# (7.0, '1980_1984')	('forza', 'NOUN')	2
# (7.0, '1980_1984')	('grasso', 'NOUN')	2
#
# (7.0, '1985_1989')	('vapore', 'NOUN')	6
# (7.0, '1985_1989')	('cucina', 'NOUN')	6
# (7.0, '1985_1989')	('grado', 'NOUN')	5
# (7.0, '1985_1989')	('caffè', 'NOUN')	5
# (7.0, '1985_1989')	('pavimento', 'NOUN')	4
# (7.0, '1985_1989')	('braun', 'NOUN')	4
# (7.0, '1985_1989')	('forza', 'NOUN')	4
# (7.0, '1985_1989')	('blackdecker', 'NOUN')	4
# (7.0, '1985_1989')	('vapor', 'NOUN')	3
# (7.0, '1985_1989')	('sprint', 'NOUN')	3
#
# (7.0, '1990_1994')	('casa', 'NOUN')	9
# (7.0, '1990_1994')	('caffè', 'NOUN')	7
# (7.0, '1990_1994')	('blackdecker', 'NOUN')	4
# (7.0, '1990_1994')	('chiave', 'NOUN')	3
# (7.0, '1990_1994')	('fatica', 'NOUN')	3
# (7.0, '1990_1994')	('vapore', 'NOUN')	3
# (7.0, '1990_1994')	('scarico', 'NOUN')	2
# (7.0, '1990_1994')	('potere', 'NOUN')	2
# (7.0, '1990_1994')	('parere', 'NOUN')	2
# (7.0, '1990_1994')	('negozio', 'NOUN')	2
#
# (7.0, '1995_1999')	('lumidità', 'NOUN')	4
# (7.0, '1995_1999')	('cosa', 'NOUN')	3
# (7.0, '1995_1999')	('casa', 'NOUN')	3
# (7.0, '1995_1999')	('delonghi', 'NOUN')	2
# (7.0, '1995_1999')	('biancheria', 'NOUN')	2
# (7.0, '1995_1999')	('canale', 'NOUN')	2
# (7.0, '1995_1999')	('cappuccino', 'NOUN')	2
# (7.0, '1995_1999')	('tazza', 'NOUN')	2
# (7.0, '1995_1999')	('epitome', 'NOUN')	1
# (7.0, '1995_1999')	('comè', 'NOUN')	1
#
# (7.0, '2000_2004')	('sistema', 'NOUN')	3
# (7.0, '2000_2004')	('microfilter', 'NOUN')	2
# (7.0, '2000_2004')	('uomo', 'NOUN')	1
# (7.0, '2000_2004')	('idea', 'NOUN')	1
# (7.0, '2000_2004')	('lavoro', 'NOUN')	1
# (7.0, '2000_2004')	('pulizia', 'NOUN')	1
# (7.0, '2000_2004')	('tasciugo', 'NOUN')	1
# (7.0, '2000_2004')	('casa', 'NOUN')	1
# (7.0, '2000_2004')	('lumidità', 'NOUN')	1
#
# (7.0, '2005_2009')	('vorwerk', 'NOUN')	2
# (7.0, '2005_2009')	('blackdecker', 'NOUN')	2
# (7.0, '2005_2009')	('lecoaspira', 'NOUN')	2
# (7.0, '2005_2009')	('generazione', 'NOUN')	1
# (7.0, '2005_2009')	('pulizia', 'NOUN')	1
# (7.0, '2005_2009')	('vapore', 'NOUN')	1
# (7.0, '2005_2009')	('generation', 'NOUN')	1
# (7.0, '2005_2009')	('obiettivo', 'NOUN')	1
# (7.0, '2005_2009')	('serie', 'NOUN')	1
# (7.0, '2005_2009')	('fotogramma', 'NOUN')	1
#
# (7.0, '2020_2024')	('explore', 'NOUN')	2
# (7.0, '2020_2024')	('delonghi', 'NOUN')	2
# (7.0, '2020_2024')	('macchina', 'NOUN')	1
# (7.0, '2020_2024')	('caffè', 'NOUN')	1
# (7.0, '2020_2024')	('tocco', 'NOUN')	1
# (7.0, '2020_2024')	('tipo', 'NOUN')	1
# (7.0, '2020_2024')	('brew', 'NOUN')	1
# (7.0, '2020_2024')	('eletta', 'NOUN')	1
#
# (8.0, '1980_1984')	('lamarasoio', 'NOUN')	3
# (8.0, '1980_1984')	('qualità', 'NOUN')	2
# (8.0, '1980_1984')	('bic', 'NOUN')	2
# (8.0, '1980_1984')	('taglio', 'NOUN')	2
# (8.0, '1980_1984')	('dovere', 'NOUN')	1
# (8.0, '1980_1984')	('mattino', 'NOUN')	1
# (8.0, '1980_1984')	('anno', 'NOUN')	1
# (8.0, '1980_1984')	('piacere', 'NOUN')	1
# (8.0, '1980_1984')	('cominci', 'NOUN')	1
# (8.0, '1980_1984')	('potere', 'NOUN')	1
#
# (8.0, '1985_1989')	('rasatura', 'NOUN')	19
# (8.0, '1985_1989')	('rasoio', 'NOUN')	11
# (8.0, '1985_1989')	('philips', 'NOUN')	10
# (8.0, '1985_1989')	('contour', 'NOUN')	9
# (8.0, '1985_1989')	('plus', 'NOUN')	9
# (8.0, '1985_1989')	('fondo', 'NOUN')	5
# (8.0, '1985_1989')	('pelle', 'NOUN')	4
# (8.0, '1985_1989')	('pelo', 'NOUN')	4
# (8.0, '1985_1989')	('braun', 'NOUN')	4
# (8.0, '1985_1989')	('controllo', 'NOUN')	3
#
# (8.0, '1990_1994')	('rasoio', 'NOUN')	17
# (8.0, '1990_1994')	('rasatura', 'NOUN')	16
# (8.0, '1990_1994')	('uomo', 'NOUN')	14
# (8.0, '1990_1994')	('fondo', 'NOUN')	10
# (8.0, '1990_1994')	('sistema', 'NOUN')	9
# (8.0, '1990_1994')	('philips', 'NOUN')	9
# (8.0, '1990_1994')	('control', 'NOUN')	9
# (8.0, '1990_1994')	('modo', 'NOUN')	7
# (8.0, '1990_1994')	('viso', 'NOUN')	6
# (8.0, '1990_1994')	('molla', 'NOUN')	6
#
# (8.0, '1995_1999')	('pelle', 'NOUN')	2
# (8.0, '1995_1999')	('sensazione', 'NOUN')	1
# (8.0, '1995_1999')	('antiscivolo', 'NOUN')	1
# (8.0, '1995_1999')	('sicurezza', 'NOUN')	1
# (8.0, '1995_1999')	('uomo', 'NOUN')	1
# (8.0, '1995_1999')	('vita', 'NOUN')	1
# (8.0, '1995_1999')	('giorno', 'NOUN')	1
# (8.0, '1995_1999')	('lame', 'NOUN')	1
# (8.0, '1995_1999')	('molla', 'NOUN')	1
# (8.0, '1995_1999')	('viso', 'NOUN')	1
#
# (8.0, '2000_2004')	('rasatura', 'NOUN')	4
# (8.0, '2000_2004')	('pelo', 'NOUN')	3
# (8.0, '2000_2004')	('fondo', 'NOUN')	3
# (8.0, '2000_2004')	('sistema', 'NOUN')	3
# (8.0, '2000_2004')	('rasoio', 'NOUN')	2
# (8.0, '2000_2004')	('sensazione', 'NOUN')	2
# (8.0, '2000_2004')	('giorno', 'NOUN')	2
# (8.0, '2000_2004')	('pelle', 'NOUN')	2
# (8.0, '2000_2004')	('mac', 'NOUN')	2
# (8.0, '2000_2004')	('brivido', 'NOUN')	1
#
# (8.0, '2005_2009')	('das', 'NOUN')	5
# (8.0, '2005_2009')	('es', 'NOUN')	4
# (8.0, '2005_2009')	('lame', 'NOUN')	3
# (8.0, '2005_2009')	('viso', 'NOUN')	3
# (8.0, '2005_2009')	('philips', 'NOUN')	3
# (8.0, '2005_2009')	('ist', 'NOUN')	3
# (8.0, '2005_2009')	('sensor', 'NOUN')	2
# (8.0, '2005_2009')	('getto', 'NOUN')	2
# (8.0, '2005_2009')	('molla', 'NOUN')	2
# (8.0, '2005_2009')	('rasoio', 'NOUN')	2
#
# (8.0, '2010_2014')	('piacere', 'NOUN')	1
# (8.0, '2010_2014')	('depilazione', 'NOUN')	1
# (8.0, '2010_2014')	('luce', 'NOUN')	1
# (8.0, '2010_2014')	('pulsata', 'NOUN')	1
# (8.0, '2010_2014')	('centro', 'NOUN')	1
# (8.0, '2010_2014')	('prezzo', 'NOUN')	1
# (8.0, '2010_2014')	('tecnologia', 'NOUN')	1
# (8.0, '2010_2014')	('aderenza', 'NOUN')	1
# (8.0, '2010_2014')	('potere', 'NOUN')	1
# (8.0, '2010_2014')	('punto', 'NOUN')	1
#
# (8.0, '2015_2019')	('minuto', 'NOUN')	3
# (8.0, '2015_2019')	('cosa', 'NOUN')	1
# (8.0, '2015_2019')	('jeans', 'NOUN')	1
# (8.0, '2015_2019')	('party', 'NOUN')	1
# (8.0, '2015_2019')	('ragazzo', 'NOUN')	1
# (8.0, '2015_2019')	('gillette', 'NOUN')	1
# (8.0, '2015_2019')	('grazie', 'NOUN')	1
# (8.0, '2015_2019')	('occasione', 'NOUN')	1
# (8.0, '2015_2019')	('sito', 'NOUN')	1
# (8.0, '2015_2019')	('potere', 'NOUN')	1
#
# (8.0, '2020_2024')	('irritazione', 'NOUN')	12
# (8.0, '2020_2024')	('bomber', 'NOUN')	8
# (8.0, '2020_2024')	('skingard', 'NOUN')	3
# (8.0, '2020_2024')	('tecnologia', 'NOUN')	3
# (8.0, '2020_2024')	('potere', 'NOUN')	3
# (8.0, '2020_2024')	('rasatura', 'NOUN')	2
# (8.0, '2020_2024')	('vapore', 'NOUN')	1
# (8.0, '2020_2024')	('baby', 'NOUN')	1
# (8.0, '2020_2024')	('livello', 'NOUN')	1
# (8.0, '2020_2024')	('labs', 'NOUN')	1
#
# (9.0, '1980_1984')	('computer', 'NOUN')	11
# (9.0, '1980_1984')	('programma', 'NOUN')	8
# (9.0, '1980_1984')	('disco', 'NOUN')	7
# (9.0, '1980_1984')	('calcolo', 'NOUN')	6
# (9.0, '1980_1984')	('canzone', 'NOUN')	4
# (9.0, '1980_1984')	('musica', 'NOUN')	4
# (9.0, '1980_1984')	('funzione', 'NOUN')	4
# (9.0, '1980_1984')	('colore', 'NOUN')	4
# (9.0, '1980_1984')	('scotch', 'NOUN')	4
# (9.0, '1980_1984')	('produzione', 'NOUN')	4
#
# (9.0, '1985_1989')	('philips', 'NOUN')	25
# (9.0, '1985_1989')	('computer', 'NOUN')	21
# (9.0, '1985_1989')	('colore', 'NOUN')	20
# (9.0, '1985_1989')	('tv', 'NOUN')	19
# (9.0, '1985_1989')	('color', 'NOUN')	12
# (9.0, '1985_1989')	('disco', 'NOUN')	12
# (9.0, '1985_1989')	('registratore', 'NOUN')	11
# (9.0, '1985_1989')	('programma', 'NOUN')	10
# (9.0, '1985_1989')	('tecnologia', 'NOUN')	10
# (9.0, '1985_1989')	('musica', 'NOUN')	9
#
# (9.0, '1990_1994')	('album', 'NOUN')	17
# (9.0, '1990_1994')	('successo', 'NOUN')	12
# (9.0, '1990_1994')	('anno', 'NOUN')	11
# (9.0, '1990_1994')	('philips', 'NOUN')	10
# (9.0, '1990_1994')	('compilation', 'NOUN')	10
# (9.0, '1990_1994')	('computer', 'NOUN')	8
# (9.0, '1990_1994')	('musica', 'NOUN')	8
# (9.0, '1990_1994')	('canzone', 'NOUN')	8
# (9.0, '1990_1994')	('colore', 'NOUN')	7
# (9.0, '1990_1994')	('clock', 'NOUN')	7
#
# (9.0, '1995_1999')	('philips', 'NOUN')	6
# (9.0, '1995_1999')	('immagine', 'NOUN')	6
# (9.0, '1995_1999')	('occhio', 'NOUN')	4
# (9.0, '1995_1999')	('mondo', 'NOUN')	4
# (9.0, '1995_1999')	('tv', 'NOUN')	4
# (9.0, '1995_1999')	('potere', 'NOUN')	3
# (9.0, '1995_1999')	('ten', 'NOUN')	3
# (9.0, '1995_1999')	('compilation', 'NOUN')	3
# (9.0, '1995_1999')	('numero', 'NOUN')	3
# (9.0, '1995_1999')	('televisore', 'NOUN')	3
#
# (9.0, '2000_2004')	('potere', 'NOUN')	8
# (9.0, '2000_2004')	('focus', 'NOUN')	5
# (9.0, '2000_2004')	('cosa', 'NOUN')	5
# (9.0, '2000_2004')	('dance', 'NOUN')	5
# (9.0, '2000_2004')	('contatto', 'NOUN')	4
# (9.0, '2000_2004')	('dailies', 'NOUN')	4
# (9.0, '2000_2004')	('musica', 'NOUN')	4
# (9.0, '2000_2004')	('album', 'NOUN')	4
# (9.0, '2000_2004')	('rolling', 'NOUN')	4
# (9.0, '2000_2004')	('stones', 'NOUN')	4
#
# (9.0, '2005_2009')	('tv', 'NOUN')	5
# (9.0, '2005_2009')	('volta', 'NOUN')	5
# (9.0, '2005_2009')	('immagine', 'NOUN')	4
# (9.0, '2005_2009')	('telefono', 'NOUN')	4
# (9.0, '2005_2009')	('design', 'NOUN')	4
# (9.0, '2005_2009')	('euro', 'NOUN')	4
# (9.0, '2005_2009')	('successo', 'NOUN')	4
# (9.0, '2005_2009')	('mondo', 'NOUN')	4
# (9.0, '2005_2009')	('canzone', 'NOUN')	4
# (9.0, '2005_2009')	('musica', 'NOUN')	3
#
# (9.0, '2010_2014')	('edition', 'NOUN')	2
# (9.0, '2010_2014')	('its', 'NOUN')	1
# (9.0, '2010_2014')	('phone', 'NOUN')	1
# (9.0, '2010_2014')	('paio', 'NOUN')	1
# (9.0, '2010_2014')	('correggere', 'NOUN')	1
# (9.0, '2010_2014')	('modo', 'NOUN')	1
# (9.0, '2010_2014')	('mondo', 'NOUN')	1
# (9.0, '2010_2014')	('qualità', 'NOUN')	1
# (9.0, '2010_2014')	('vita', 'NOUN')	1
# (9.0, '2010_2014')	('chiedi', 'NOUN')	1
#
# (9.0, '2020_2024')	('bad', 'NOUN')	4
# (9.0, '2020_2024')	('mooneygo', 'NOUN')	3
# (9.0, '2020_2024')	('capolavoro', 'NOUN')	3
# (9.0, '2020_2024')	('password', 'NOUN')	2
# (9.0, '2020_2024')	('casello', 'NOUN')	2
# (9.0, '2020_2024')	('two', 'NOUN')	2
# (9.0, '2020_2024')	('more', 'NOUN')	2
# (9.0, '2020_2024')	('okay', 'NOUN')	2
# (9.0, '2020_2024')	('yeah', 'NOUN')	2
# (9.0, '2020_2024')	('good', 'NOUN')	2
#
# (10.0, '1980_1984')	('sicurezza', 'NOUN')	3
# (10.0, '1980_1984')	('farmacia', 'NOUN')	3
# (10.0, '1980_1984')	('lamore', 'NOUN')	3
# (10.0, '1980_1984')	('amore', 'NOUN')	2
# (10.0, '1980_1984')	('plus', 'NOUN')	2
# (10.0, '1980_1984')	('sostegno', 'NOUN')	2
# (10.0, '1980_1984')	('calore', 'NOUN')	2
# (10.0, '1980_1984')	('marchio', 'NOUN')	1
# (10.0, '1980_1984')	('mondo', 'NOUN')	1
# (10.0, '1980_1984')	('dallespositore', 'NOUN')	1
#
# (10.0, '1985_1989')	('lamore', 'NOUN')	25
# (10.0, '1985_1989')	('control', 'NOUN')	17
# (10.0, '1985_1989')	('prova', 'NOUN')	8
# (10.0, '1985_1989')	('damore', 'NOUN')	6
# (10.0, '1985_1989')	('sicurezza', 'NOUN')	6
# (10.0, '1985_1989')	('contatto', 'NOUN')	5
# (10.0, '1985_1989')	('spessore', 'NOUN')	4
# (10.0, '1985_1989')	('cosa', 'NOUN')	3
# (10.0, '1985_1989')	('allamore', 'NOUN')	3
# (10.0, '1985_1989')	('sento', 'NOUN')	3
#
# (10.0, '1990_1994')	('jeans', 'NOUN')	4
# (10.0, '1990_1994')	('lamore', 'NOUN')	3
# (10.0, '1990_1994')	('gamba', 'NOUN')	3
# (10.0, '1990_1994')	('pelle', 'NOUN')	2
# (10.0, '1990_1994')	('motivo', 'NOUN')	2
# (10.0, '1990_1994')	('giorno', 'NOUN')	2
# (10.0, '1990_1994')	('mister', 'NOUN')	2
# (10.0, '1990_1994')	('seno', 'NOUN')	2
# (10.0, '1990_1994')	('secret', 'NOUN')	1
# (10.0, '1990_1994')	('control', 'NOUN')	1
#
# (10.0, '1995_1999')	('modo', 'NOUN')	1
# (10.0, '1995_1999')	('lamore', 'NOUN')	1
# (10.0, '1995_1999')	('sicurezza', 'NOUN')	1
# (10.0, '1995_1999')	('confezione', 'NOUN')	1
#
# (10.0, '2000_2004')	('control', 'NOUN')	2
# (10.0, '2000_2004')	('up', 'NOUN')	2
# (10.0, '2000_2004')	('colpo', 'NOUN')	2
# (10.0, '2000_2004')	('frusta', 'NOUN')	1
#
# (10.0, '2005_2009')	('medico', 'NOUN')	2
# (10.0, '2005_2009')	('istruzione', 'NOUN')	2
# (10.0, '2005_2009')	('design', 'NOUN')	2
# (10.0, '2005_2009')	('bioprint', 'NOUN')	2
# (10.0, '2005_2009')	('premium', 'NOUN')	2
# (10.0, '2005_2009')	('camerino', 'NOUN')	1
# (10.0, '2005_2009')	('confortevolo', 'NOUN')	1
# (10.0, '2005_2009')	('provartelo', 'NOUN')	1
# (10.0, '2005_2009')	('mercato', 'NOUN')	1
# (10.0, '2005_2009')	('ingresso', 'NOUN')	1
#
# (10.0, '2010_2014')	('sottotitoli', 'NOUN')	1
# (10.0, '2010_2014')	('comunità', 'NOUN')	1
#
# (10.0, '2015_2019')	('tv', 'NOUN')	3
# (10.0, '2015_2019')	('esperto', 'NOUN')	3
#
# (10.0, '2020_2024')	('normalità', 'NOUN')	4
# (10.0, '2020_2024')	('lamore', 'NOUN')	3
# (10.0, '2020_2024')	('piede', 'NOUN')	3
# (10.0, '2020_2024')	('estate', 'NOUN')	2
# (10.0, '2020_2024')	('protezione', 'NOUN')	2
# (10.0, '2020_2024')	('proteggio', 'NOUN')	2
# (10.0, '2020_2024')	('summer', 'NOUN')	2
# (10.0, '2020_2024')	('sesso', 'NOUN')	2
# (10.0, '2020_2024')	('ondata', 'NOUN')	1
# (10.0, '2020_2024')	('cosa', 'NOUN')	1
#
# (11.0, '1980_1984')	('casa', 'NOUN')	6
# (11.0, '1980_1984')	('decker', 'NOUN')	5
# (11.0, '1980_1984')	('bagno', 'NOUN')	5
# (11.0, '1980_1984')	('tempo', 'NOUN')	4
# (11.0, '1980_1984')	('potere', 'NOUN')	3
# (11.0, '1980_1984')	('acciaio', 'NOUN')	3
# (11.0, '1980_1984')	('metà', 'NOUN')	3
# (11.0, '1980_1984')	('braun', 'NOUN')	3
# (11.0, '1980_1984')	('biancheria', 'NOUN')	3
# (11.0, '1980_1984')	('vapor', 'NOUN')	3
#
# (11.0, '1985_1989')	('yeti', 'NOUN')	15
# (11.0, '1985_1989')	('philips', 'NOUN')	10
# (11.0, '1985_1989')	('candy', 'NOUN')	8
# (11.0, '1985_1989')	('condizionatore', 'NOUN')	8
# (11.0, '1985_1989')	('castor', 'NOUN')	8
# (11.0, '1985_1989')	('forno', 'NOUN')	8
# (11.0, '1985_1989')	('letto', 'NOUN')	7
# (11.0, '1985_1989')	('giorno', 'NOUN')	7
# (11.0, '1985_1989')	('congelatore', 'NOUN')	7
# (11.0, '1985_1989')	('forza', 'NOUN')	6
#
# (11.0, '1990_1994')	('mamma', 'NOUN')	15
# (11.0, '1990_1994')	('casa', 'NOUN')	6
# (11.0, '1990_1994')	('donna', 'NOUN')	6
# (11.0, '1990_1994')	('piacere', 'NOUN')	5
# (11.0, '1990_1994')	('lavatrice', 'NOUN')	5
# (11.0, '1990_1994')	('candy', 'NOUN')	5
# (11.0, '1990_1994')	('anno', 'NOUN')	5
# (11.0, '1990_1994')	('cosa', 'NOUN')	5
# (11.0, '1990_1994')	('numero', 'NOUN')	5
# (11.0, '1990_1994')	('marce', 'NOUN')	5
#
# (11.0, '1995_1999')	('caldobagno', 'NOUN')	4
# (11.0, '1995_1999')	('radio', 'NOUN')	4
# (11.0, '1995_1999')	('passìo', 'NOUN')	4
# (11.0, '1995_1999')	('potenza', 'NOUN')	3
# (11.0, '1995_1999')	('doccia', 'NOUN')	3
# (11.0, '1995_1999')	('caldaia', 'NOUN')	3
# (11.0, '1995_1999')	('benessere', 'NOUN')	3
# (11.0, '1995_1999')	('bagno', 'NOUN')	3
# (11.0, '1995_1999')	('ferro', 'NOUN')	2
# (11.0, '1995_1999')	('philips', 'NOUN')	2
#
# (11.0, '2000_2004')	('ariston', 'NOUN')	3
# (11.0, '2000_2004')	('caldopanny', 'NOUN')	3
# (11.0, '2000_2004')	('idromassaggio', 'NOUN')	3
# (11.0, '2000_2004')	('hydrosonic', 'NOUN')	3
# (11.0, '2000_2004')	('forno', 'NOUN')	2
# (11.0, '2000_2004')	('margherita', 'NOUN')	2
# (11.0, '2000_2004')	('temperatura', 'NOUN')	2
# (11.0, '2000_2004')	('classe', 'NOUN')	2
# (11.0, '2000_2004')	('lavaggio', 'NOUN')	2
# (11.0, '2000_2004')	('minuto', 'NOUN')	2
#
# (11.0, '2005_2009')	('sistema', 'NOUN')	4
# (11.0, '2005_2009')	('senso', 'NOUN')	3
# (11.0, '2005_2009')	('climatizzatore', 'NOUN')	3
# (11.0, '2005_2009')	('mano', 'NOUN')	3
# (11.0, '2005_2009')	('mitsubishi', 'NOUN')	2
# (11.0, '2005_2009')	('difference', 'NOUN')	2
# (11.0, '2005_2009')	('delonghi', 'NOUN')	2
# (11.0, '2005_2009')	('innovation', 'NOUN')	2
# (11.0, '2005_2009')	('vapore', 'NOUN')	2
# (11.0, '2005_2009')	('aromio', 'NOUN')	2
#
# (11.0, '2010_2014')	('qualità', 'NOUN')	1
# (11.0, '2010_2014')	('piacere', 'NOUN')	1
# (11.0, '2010_2014')	('spot', 'NOUN')	1
# (11.0, '2010_2014')	('esperto', 'NOUN')	1
#
# (11.0, '2020_2024')	('anno', 'NOUN')	3
# (11.0, '2020_2024')	('casa', 'NOUN')	2
# (11.0, '2020_2024')	('potere', 'NOUN')	2
# (11.0, '2020_2024')	('tempo', 'NOUN')	2
# (11.0, '2020_2024')	('cosa', 'NOUN')	1
# (11.0, '2020_2024')	('perfezione', 'NOUN')	1
# (11.0, '2020_2024')	('momento', 'NOUN')	1
# (11.0, '2020_2024')	('sentimento', 'NOUN')	1
# (11.0, '2020_2024')	('giorno', 'NOUN')	1
# (11.0, '2020_2024')	('grazie', 'NOUN')	1
#
# (12.0, '1980_1984')	('renault', 'NOUN')	14
# (12.0, '1980_1984')	('linea', 'NOUN')	8
# (12.0, '1980_1984')	('auto', 'NOUN')	6
# (12.0, '1980_1984')	('lira', 'NOUN')	6
# (12.0, '1980_1984')	('metro', 'NOUN')	6
# (12.0, '1980_1984')	('benzina', 'NOUN')	5
# (12.0, '1980_1984')	('chilometro', 'NOUN')	4
# (12.0, '1980_1984')	('consumo', 'NOUN')	4
# (12.0, '1980_1984')	('prezzo', 'NOUN')	4
# (12.0, '1980_1984')	('mese', 'NOUN')	4
#
# (12.0, '1985_1989')	('renault', 'NOUN')	49
# (12.0, '1985_1989')	('strada', 'NOUN')	41
# (12.0, '1985_1989')	('miglia', 'NOUN')	28
# (12.0, '1985_1989')	('milione', 'NOUN')	27
# (12.0, '1985_1989')	('peugeot', 'NOUN')	20
# (12.0, '1985_1989')	('interesse', 'NOUN')	17
# (12.0, '1985_1989')	('tempo', 'NOUN')	14
# (12.0, '1985_1989')	('sicurezza', 'NOUN')	13
# (12.0, '1985_1989')	('potere', 'NOUN')	11
# (12.0, '1985_1989')	('anno', 'NOUN')	11
#
# (12.0, '1990_1994')	('milione', 'NOUN')	40
# (12.0, '1990_1994')	('tipo', 'NOUN')	19
# (12.0, '1990_1994')	('potere', 'NOUN')	16
# (12.0, '1990_1994')	('dovere', 'NOUN')	16
# (12.0, '1990_1994')	('serie', 'NOUN')	14
# (12.0, '1990_1994')	('auto', 'NOUN')	14
# (12.0, '1990_1994')	('piacere', 'NOUN')	13
# (12.0, '1990_1994')	('sicurezza', 'NOUN')	13
# (12.0, '1990_1994')	('rap', 'NOUN')	11
# (12.0, '1990_1994')	('anno', 'NOUN')	11
#
# (12.0, '1995_1999')	('potere', 'NOUN')	11
# (12.0, '1995_1999')	('strada', 'NOUN')	10
# (12.0, '1995_1999')	('sicurezza', 'NOUN')	9
# (12.0, '1995_1999')	('auto', 'NOUN')	8
# (12.0, '1995_1999')	('punto', 'NOUN')	6
# (12.0, '1995_1999')	('anno', 'NOUN')	5
# (12.0, '1995_1999')	('serie', 'NOUN')	5
# (12.0, '1995_1999')	('spazio', 'NOUN')	5
# (12.0, '1995_1999')	('potenza', 'NOUN')	5
# (12.0, '1995_1999')	('alfa', 'NOUN')	5
#
# (12.0, '2000_2004')	('euro', 'NOUN')	19
# (12.0, '2000_2004')	('milione', 'NOUN')	15
# (12.0, '2000_2004')	('rail', 'NOUN')	12
# (12.0, '2000_2004')	('prezzo', 'NOUN')	12
# (12.0, '2000_2004')	('punto', 'NOUN')	11
# (12.0, '2000_2004')	('sabato', 'NOUN')	11
# (12.0, '2000_2004')	('domenica', 'NOUN')	11
# (12.0, '2000_2004')	('climatizzatore', 'NOUN')	9
# (12.0, '2000_2004')	('focus', 'NOUN')	9
# (12.0, '2000_2004')	('peugeot', 'NOUN')	8
#
# (12.0, '2005_2009')	('euro', 'NOUN')	79
# (12.0, '2005_2009')	('potere', 'NOUN')	26
# (12.0, '2005_2009')	('domenica', 'NOUN')	21
# (12.0, '2005_2009')	('anno', 'NOUN')	18
# (12.0, '2005_2009')	('sabato', 'NOUN')	17
# (12.0, '2005_2009')	('finanziamento', 'NOUN')	15
# (12.0, '2005_2009')	('vantaggio', 'NOUN')	13
# (12.0, '2005_2009')	('anticipo', 'NOUN')	11
# (12.0, '2005_2009')	('focus', 'NOUN')	11
# (12.0, '2005_2009')	('gamma', 'NOUN')	11
#
# (12.0, '2010_2014')	('euro', 'NOUN')	21
# (12.0, '2010_2014')	('panda', 'NOUN')	9
# (12.0, '2010_2014')	('domenica', 'NOUN')	8
# (12.0, '2010_2014')	('comunità', 'NOUN')	6
# (12.0, '2010_2014')	('lusso', 'NOUN')	6
# (12.0, '2010_2014')	('sabato', 'NOUN')	6
# (12.0, '2010_2014')	('potere', 'NOUN')	6
# (12.0, '2010_2014')	('renault', 'NOUN')	6
# (12.0, '2010_2014')	('fiat', 'NOUN')	6
# (12.0, '2010_2014')	('sottotitoli', 'NOUN')	5
#
# (12.0, '2015_2019')	('euro', 'NOUN')	23
# (12.0, '2015_2019')	('comunità', 'NOUN')	6
# (12.0, '2015_2019')	('potere', 'NOUN')	6
# (12.0, '2015_2019')	('domenica', 'NOUN')	5
# (12.0, '2015_2019')	('auto', 'NOUN')	5
# (12.0, '2015_2019')	('sottotitoli', 'NOUN')	5
# (12.0, '2015_2019')	('serie', 'NOUN')	5
# (12.0, '2015_2019')	('peugeot', 'NOUN')	5
# (12.0, '2015_2019')	('tecnologia', 'NOUN')	5
# (12.0, '2015_2019')	('giulietta', 'NOUN')	5
#
# (12.0, '2020_2024')	('euro', 'NOUN')	11
# (12.0, '2020_2024')	('vita', 'NOUN')	7
# (12.0, '2020_2024')	('esperto', 'NOUN')	6
# (12.0, '2020_2024')	('duster', 'NOUN')	5
# (12.0, '2020_2024')	('viaggio', 'NOUN')	4
# (12.0, '2020_2024')	('auto', 'NOUN')	4
# (12.0, '2020_2024')	('plugin', 'NOUN')	4
# (12.0, '2020_2024')	('tecnologia', 'NOUN')	4
# (12.0, '2020_2024')	('guida', 'NOUN')	3
# (12.0, '2020_2024')	('mondo', 'NOUN')	3
#
# (13.0, '1980_1984')	('virginia', 'NOUN')	1
# (13.0, '1980_1984')	('fucile', 'NOUN')	1
# (13.0, '1980_1984')	('armi', 'NOUN')	1
# (13.0, '1980_1984')	('sport', 'NOUN')	1
#
# (14.0, '1980_1984')	('orologio', 'NOUN')	2
# (14.0, '1980_1984')	('orologi', 'NOUN')	1
# (14.0, '1980_1984')	('situazione', 'NOUN')	1
# (14.0, '1980_1984')	('età', 'NOUN')	1
# (14.0, '1980_1984')	('citizen', 'NOUN')	1
# (14.0, '1980_1984')	('quarzo', 'NOUN')	1
# (14.0, '1980_1984')	('lora', 'NOUN')	1
# (14.0, '1980_1984')	('perfezione', 'NOUN')	1
# (14.0, '1980_1984')	('originalità', 'NOUN')	1
# (14.0, '1980_1984')	('regalo', 'NOUN')	1
#
# (14.0, '1985_1989')	('braun', 'NOUN')	5
# (14.0, '1985_1989')	('swatch', 'NOUN')	5
# (14.0, '1985_1989')	('tissot', 'NOUN')	4
# (14.0, '1985_1989')	('tempo', 'NOUN')	4
# (14.0, '1985_1989')	('orologio', 'NOUN')	4
# (14.0, '1985_1989')	('minuto', 'NOUN')	3
# (14.0, '1985_1989')	('sector', 'NOUN')	3
# (14.0, '1985_1989')	('titanium', 'NOUN')	3
# (14.0, '1985_1989')	('potere', 'NOUN')	2
# (14.0, '1985_1989')	('piacere', 'NOUN')	2
#
# (14.0, '1990_1994')	('cronografi', 'NOUN')	2
# (14.0, '1990_1994')	('orologio', 'NOUN')	2
# (14.0, '1990_1994')	('watch', 'NOUN')	2
# (14.0, '1990_1994')	('qualità', 'NOUN')	2
# (14.0, '1990_1994')	('donna', 'NOUN')	1
# (14.0, '1990_1994')	('gioielli', 'NOUN')	1
# (14.0, '1990_1994')	('sport', 'NOUN')	1
# (14.0, '1990_1994')	('azione', 'NOUN')	1
# (14.0, '1990_1994')	('easy', 'NOUN')	1
# (14.0, '1990_1994')	('armonie', 'NOUN')	1
#
# (14.0, '1995_1999')	('sector', 'NOUN')	2
#
# (14.0, '2000_2004')	('anno', 'NOUN')	2
# (14.0, '2000_2004')	('storia', 'NOUN')	2
# (14.0, '2000_2004')	('amore', 'NOUN')	2
# (14.0, '2000_2004')	('speedmaster', 'NOUN')	1
# (14.0, '2000_2004')	('terra', 'NOUN')	1
# (14.0, '2000_2004')	('luna', 'NOUN')	1
# (14.0, '2000_2004')	('sector', 'NOUN')	1
#
# (14.0, '2005_2009')	('cielo', 'NOUN')	4
# (14.0, '2005_2009')	('collezione', 'NOUN')	3
# (14.0, '2005_2009')	('will', 'NOUN')	3
# (14.0, '2005_2009')	('rock', 'NOUN')	3
# (14.0, '2005_2009')	('your', 'NOUN')	3
# (14.0, '2005_2009')	('numero', 'NOUN')	2
# (14.0, '2005_2009')	('sogno', 'NOUN')	2
# (14.0, '2005_2009')	('dont', 'NOUN')	2
# (14.0, '2005_2009')	('baby', 'NOUN')	2
# (14.0, '2005_2009')	('esperto', 'NOUN')	1
#
# (14.0, '2010_2014')	('collezione', 'NOUN')	1
# (14.0, '2010_2014')	('nelles', 'NOUN')	1
# (14.0, '2010_2014')	('momento', 'NOUN')	1
# (14.0, '2010_2014')	('sceglie', 'NOUN')	1
# (14.0, '2010_2014')	('dargento', 'NOUN')	1
# (14.0, '2010_2014')	('negozio', 'NOUN')	1
# (14.0, '2010_2014')	('gioiellerio', 'NOUN')	1
# (14.0, '2010_2014')	('comunità', 'NOUN')	1
#
# (14.0, '2015_2019')	('natura', 'NOUN')	2
# (14.0, '2015_2019')	('mamma', 'NOUN')	2
# (14.0, '2015_2019')	('gioiello', 'NOUN')	2
# (14.0, '2015_2019')	('vita', 'NOUN')	2
# (14.0, '2015_2019')	('cosa', 'NOUN')	1
# (14.0, '2015_2019')	('collezione', 'NOUN')	1
# (14.0, '2015_2019')	('celebra', 'NOUN')	1
# (14.0, '2015_2019')	('maggio', 'NOUN')	1
# (14.0, '2015_2019')	('giorno', 'NOUN')	1
# (14.0, '2015_2019')	('figlia', 'NOUN')	1
#
# (14.0, '2020_2024')	('esperto', 'NOUN')	3
# (14.0, '2020_2024')	('regalo', 'NOUN')	3
# (14.0, '2020_2024')	('storia', 'NOUN')	2
# (14.0, '2020_2024')	('negozio', 'NOUN')	2
# (14.0, '2020_2024')	('edizione', 'NOUN')	2
# (14.0, '2020_2024')	('annosa', 'NOUN')	1
# (14.0, '2020_2024')	('ammira', 'NOUN')	1
# (14.0, '2020_2024')	('minuto', 'NOUN')	1
# (14.0, '2020_2024')	('senso', 'NOUN')	1
# (14.0, '2020_2024')	('risveglio', 'NOUN')	1
#
# (15.0, '1980_1984')	('testazione', 'NOUN')	1
# (15.0, '1980_1984')	('costo', 'NOUN')	1
# (15.0, '1980_1984')	('zimmermann', 'NOUN')	1
# (15.0, '1980_1984')	('tacco', 'NOUN')	1
# (15.0, '1980_1984')	('ricordo', 'NOUN')	1
#
# (15.0, '1985_1989')	('perfezione', 'NOUN')	2
# (15.0, '1985_1989')	('potenza', 'NOUN')	1
# (15.0, '1985_1989')	('forza', 'NOUN')	1
# (15.0, '1985_1989')	('immagine', 'NOUN')	1
# (15.0, '1985_1989')	('suono', 'NOUN')	1
#
# (15.0, '1990_1994')	('gimmo', 'NOUN')	3
# (15.0, '1990_1994')	('bontempi', 'NOUN')	2
# (15.0, '1990_1994')	('generazione', 'NOUN')	2
# (15.0, '1990_1994')	('dito', 'NOUN')	1
# (15.0, '1990_1994')	('livello', 'NOUN')	1
# (15.0, '1990_1994')	('suono', 'NOUN')	1
# (15.0, '1990_1994')	('musica', 'NOUN')	1
# (15.0, '1990_1994')	('system', 'NOUN')	1
# (15.0, '1990_1994')	('gimmi', 'NOUN')	1
# (15.0, '1990_1994')	('dora', 'NOUN')	1
#
# (16.0, '1980_1984')	('carta', 'NOUN')	12
# (16.0, '1980_1984')	('casa', 'NOUN')	11
# (16.0, '1980_1984')	('computer', 'NOUN')	7
# (16.0, '1980_1984')	('morbidezza', 'NOUN')	5
# (16.0, '1980_1984')	('convenienza', 'NOUN')	4
# (16.0, '1980_1984')	('piano', 'NOUN')	4
# (16.0, '1980_1984')	('volume', 'NOUN')	4
# (16.0, '1980_1984')	('potere', 'NOUN')	4
# (16.0, '1980_1984')	('tv', 'NOUN')	4
# (16.0, '1980_1984')	('copertina', 'NOUN')	3
#
# (16.0, '1985_1989')	('fascicolo', 'NOUN')	38
# (16.0, '1985_1989')	('casa', 'NOUN')	27
# (16.0, '1985_1989')	('settimana', 'NOUN')	19
# (16.0, '1985_1989')	('tv', 'NOUN')	15
# (16.0, '1985_1989')	('numero', 'NOUN')	10
# (16.0, '1985_1989')	('enciclopedia', 'NOUN')	9
# (16.0, '1985_1989')	('regalo', 'NOUN')	9
# (16.0, '1985_1989')	('editore', 'NOUN')	9
# (16.0, '1985_1989')	('canzoni', 'NOUN')	9
# (16.0, '1985_1989')	('fabbri', 'NOUN')	9
#
# (16.0, '1990_1994')	('settimana', 'NOUN')	35
# (16.0, '1990_1994')	('fascicolo', 'NOUN')	32
# (16.0, '1990_1994')	('lira', 'NOUN')	29
# (16.0, '1990_1994')	('editore', 'NOUN')	27
# (16.0, '1990_1994')	('donna', 'NOUN')	24
# (16.0, '1990_1994')	('casa', 'NOUN')	24
# (16.0, '1990_1994')	('tv', 'NOUN')	18
# (16.0, '1990_1994')	('giorno', 'NOUN')	17
# (16.0, '1990_1994')	('tempo', 'NOUN')	17
# (16.0, '1990_1994')	('uscita', 'NOUN')	17
#
# (16.0, '1995_1999')	('casa', 'NOUN')	16
# (16.0, '1995_1999')	('lira', 'NOUN')	10
# (16.0, '1995_1999')	('fascicolo', 'NOUN')	8
# (16.0, '1995_1999')	('uscita', 'NOUN')	7
# (16.0, '1995_1999')	('settimana', 'NOUN')	6
# (16.0, '1995_1999')	('rock', 'NOUN')	6
# (16.0, '1995_1999')	('mondo', 'NOUN')	6
# (16.0, '1995_1999')	('vita', 'NOUN')	6
# (16.0, '1995_1999')	('film', 'NOUN')	6
# (16.0, '1995_1999')	('storia', 'NOUN')	5
#
# (16.0, '2000_2004')	('fascicolo', 'NOUN')	10
# (16.0, '2000_2004')	('word', 'NOUN')	10
# (16.0, '2000_2004')	('lira', 'NOUN')	9
# (16.0, '2000_2004')	('settimana', 'NOUN')	9
# (16.0, '2000_2004')	('cdrom', 'NOUN')	6
# (16.0, '2000_2004')	('euro', 'NOUN')	6
# (16.0, '2000_2004')	('tempo', 'NOUN')	5
# (16.0, '2000_2004')	('collezione', 'NOUN')	5
# (16.0, '2000_2004')	('uscita', 'NOUN')	5
# (16.0, '2000_2004')	('potere', 'NOUN')	5
#
# (16.0, '2005_2009')	('euro', 'NOUN')	35
# (16.0, '2005_2009')	('uscita', 'NOUN')	18
# (16.0, '2005_2009')	('tv', 'NOUN')	13
# (16.0, '2005_2009')	('film', 'NOUN')	10
# (16.0, '2005_2009')	('collezione', 'NOUN')	9
# (16.0, '2005_2009')	('gioco', 'NOUN')	9
# (16.0, '2005_2009')	('donna', 'NOUN')	9
# (16.0, '2005_2009')	('numero', 'NOUN')	7
# (16.0, '2005_2009')	('volume', 'NOUN')	7
# (16.0, '2005_2009')	('storia', 'NOUN')	7
#
# (16.0, '2010_2014')	('mamma', 'NOUN')	2
# (16.0, '2010_2014')	('padrone', 'NOUN')	1
# (16.0, '2010_2014')	('diritto', 'NOUN')	1
# (16.0, '2010_2014')	('gallo', 'NOUN')	1
# (16.0, '2010_2014')	('testa', 'NOUN')	1
#
# (16.0, '2015_2019')	('bastardidentro', 'NOUN')	3
# (16.0, '2015_2019')	('avventura', 'NOUN')	2
# (16.0, '2015_2019')	('saggia', 'NOUN')	1
# (16.0, '2015_2019')	('mr', 'NOUN')	1
# (16.0, '2015_2019')	('collezione', 'NOUN')	1
#
# (16.0, '2020_2024')	('libertà', 'NOUN')	3
# (16.0, '2020_2024')	('casa', 'NOUN')	3
# (16.0, '2020_2024')	('mano', 'NOUN')	2
# (16.0, '2020_2024')	('idea', 'NOUN')	1
# (16.0, '2020_2024')	('cosa', 'NOUN')	1
# (16.0, '2020_2024')	('euro', 'NOUN')	1
# (16.0, '2020_2024')	('settimana', 'NOUN')	1
# (16.0, '2020_2024')	('sera', 'NOUN')	1
# (16.0, '2020_2024')	('accesso', 'NOUN')	1
# (16.0, '2020_2024')	('alledizione', 'NOUN')	1
#
# (17.0, '1985_1989')	('silicone', 'NOUN')	3
# (17.0, '1985_1989')	('bison', 'NOUN')	1
# (17.0, '1985_1989')	('energia', 'NOUN')	1
# (17.0, '1985_1989')	('bliz', 'NOUN')	1
#
# (17.0, '1990_1994')	('silicone', 'NOUN')	4
# (17.0, '1990_1994')	('leader', 'NOUN')	1
#
# (17.0, '1995_1999')	('lavoro', 'NOUN')	2
# (17.0, '1995_1999')	('ciao', 'NOUN')	1
# (17.0, '1995_1999')	('gres', 'NOUN')	1
# (17.0, '1995_1999')	('formato', 'NOUN')	1
# (17.0, '1995_1999')	('numero', 'NOUN')	1
#
# (17.0, '2005_2009')	('silicone', 'NOUN')	3
# (17.0, '2005_2009')	('bostik', 'NOUN')	2
# (17.0, '2005_2009')	('distanza', 'NOUN')	1
# (17.0, '2005_2009')	('potere', 'NOUN')	1
# (17.0, '2005_2009')	('giorno', 'NOUN')	1
# (17.0, '2005_2009')	('videofonine', 'NOUN')	1
# (17.0, '2005_2009')	('euro', 'NOUN')	1
#
# (18.0, '1980_1984')	('pelle', 'NOUN')	4
# (18.0, '1980_1984')	('pelliccia', 'NOUN')	2
# (18.0, '1980_1984')	('gente', 'NOUN')	2
# (18.0, '1980_1984')	('perfetta', 'NOUN')	2
# (18.0, '1980_1984')	('sogno', 'NOUN')	1
# (18.0, '1980_1984')	('tasti', 'NOUN')	1
# (18.0, '1980_1984')	('colugno', 'NOUN')	1
# (18.0, '1980_1984')	('aires', 'NOUN')	1
# (18.0, '1980_1984')	('bellinzona', 'NOUN')	1
# (18.0, '1980_1984')	('bello', 'NOUN')	1
#
# (18.0, '1985_1989')	('pelliccia', 'NOUN')	5
# (18.0, '1985_1989')	('bisogno', 'NOUN')	4
# (18.0, '1985_1989')	('esperto', 'NOUN')	3
# (18.0, '1985_1989')	('prezzo', 'NOUN')	3
# (18.0, '1985_1989')	('milione', 'NOUN')	3
# (18.0, '1985_1989')	('credits', 'NOUN')	2
# (18.0, '1985_1989')	('volta', 'NOUN')	2
# (18.0, '1985_1989')	('esempio', 'NOUN')	2
# (18.0, '1985_1989')	('lira', 'NOUN')	2
# (18.0, '1985_1989')	('bellissime', 'NOUN')	2
#
# (18.0, '1990_1994')	('sacco', 'NOUN')	2
# (18.0, '1990_1994')	('vita', 'NOUN')	2
# (18.0, '1990_1994')	('samsonite', 'NOUN')	2
# (18.0, '1990_1994')	('manfibio', 'NOUN')	1
# (18.0, '1990_1994')	('mare', 'NOUN')	1
# (18.0, '1990_1994')	('frento', 'NOUN')	1
# (18.0, '1990_1994')	('potere', 'NOUN')	1
# (18.0, '1990_1994')	('splash', 'NOUN')	1
# (18.0, '1990_1994')	('balene', 'NOUN')	1
# (18.0, '1990_1994')	('matematica', 'NOUN')	1
#
# (18.0, '1995_1999')	('scuola', 'NOUN')	14
# (18.0, '1995_1999')	('millecuori', 'NOUN')	6
# (18.0, '1995_1999')	('sailor', 'NOUN')	3
# (18.0, '1995_1999')	('sogno', 'NOUN')	3
# (18.0, '1995_1999')	('cuore', 'NOUN')	3
# (18.0, '1995_1999')	('magia', 'NOUN')	3
# (18.0, '1995_1999')	('mostrartio', 'NOUN')	2
# (18.0, '1995_1999')	('copertina', 'NOUN')	2
# (18.0, '1995_1999')	('zaino', 'NOUN')	2
# (18.0, '1995_1999')	('potere', 'NOUN')	2
#
# (18.0, '2000_2004')	('jackie', 'NOUN')	3
# (18.0, '2000_2004')	('chan', 'NOUN')	3
# (18.0, '2000_2004')	('hamtaro', 'NOUN')	2
# (18.0, '2000_2004')	('scuola', 'NOUN')	2
# (18.0, '2000_2004')	('giochi', 'NOUN')	2
# (18.0, '2000_2004')	('piacere', 'NOUN')	1
# (18.0, '2000_2004')	('campagna', 'NOUN')	1
# (18.0, '2000_2004')	('potere', 'NOUN')	1
# (18.0, '2000_2004')	('stagionone', 'NOUN')	1
# (18.0, '2000_2004')	('fasciatoio', 'NOUN')	1
#
# (18.0, '2005_2009')	('scuola', 'NOUN')	3
# (18.0, '2005_2009')	('shock', 'NOUN')	1
# (18.0, '2005_2009')	('absorber', 'NOUN')	1
# (18.0, '2005_2009')	('denergio', 'NOUN')	1
# (18.0, '2005_2009')	('eroe', 'NOUN')	1
# (18.0, '2005_2009')	('collezione', 'NOUN')	1
# (18.0, '2005_2009')	('lenergia', 'NOUN')	1
# (18.0, '2005_2009')	('forza', 'NOUN')	1
# (18.0, '2005_2009')	('anno', 'NOUN')	1
# (18.0, '2005_2009')	('ball', 'NOUN')	1
#
# (18.0, '2010_2014')	('attenzione', 'NOUN')	2
# (18.0, '2010_2014')	('volta', 'NOUN')	1
# (18.0, '2010_2014')	('bisogno', 'NOUN')	1
# (18.0, '2010_2014')	('amico', 'NOUN')	1
# (18.0, '2010_2014')	('display', 'NOUN')	1
# (18.0, '2010_2014')	('emozione', 'NOUN')	1
# (18.0, '2010_2014')	('storia', 'NOUN')	1
# (18.0, '2010_2014')	('scuola', 'NOUN')	1
# (18.0, '2010_2014')	('cartelleria', 'NOUN')	1
# (18.0, '2010_2014')	('brands', 'NOUN')	1
#
# (18.0, '2015_2019')	('zaini', 'NOUN')	5
# (18.0, '2015_2019')	('scuola', 'NOUN')	3
# (18.0, '2015_2019')	('incanto', 'NOUN')	3
# (18.0, '2015_2019')	('città', 'NOUN')	2
# (18.0, '2015_2019')	('mondo', 'NOUN')	2
# (18.0, '2015_2019')	('jack', 'NOUN')	2
# (18.0, '2015_2019')	('foto', 'NOUN')	2
# (18.0, '2015_2019')	('colore', 'NOUN')	2
# (18.0, '2015_2019')	('venerdì', 'NOUN')	1
# (18.0, '2015_2019')	('sera', 'NOUN')	1
#
# (18.0, '2020_2024')	('zaini', 'NOUN')	4
# (18.0, '2020_2024')	('stile', 'NOUN')	4
# (18.0, '2020_2024')	('scuola', 'NOUN')	3
# (18.0, '2020_2024')	('zaino', 'NOUN')	2
# (18.0, '2020_2024')	('giochi', 'NOUN')	2
# (18.0, '2020_2024')	('appack', 'NOUN')	1
# (18.0, '2020_2024')	('seven', 'NOUN')	1
# (18.0, '2020_2024')	('mitama', 'NOUN')	1
# (18.0, '2020_2024')	('strong', 'NOUN')	1
# (18.0, '2020_2024')	('potere', 'NOUN')	1
#
# (19.0, '1980_1984')	('montecchi', 'NOUN')	2
# (19.0, '1980_1984')	('firenze', 'NOUN')	2
# (19.0, '1980_1984')	('cotto', 'NOUN')	1
# (19.0, '1980_1984')	('fascino', 'NOUN')	1
# (19.0, '1980_1984')	('colore', 'NOUN')	1
# (19.0, '1980_1984')	('tradizione', 'NOUN')	1
# (19.0, '1980_1984')	('leleganza', 'NOUN')	1
# (19.0, '1980_1984')	('ambiente', 'NOUN')	1
# (19.0, '1980_1984')	('manifatture', 'NOUN')	1
# (19.0, '1980_1984')	('pavimento', 'NOUN')	1
#
# (19.0, '1985_1989')	('atlas', 'NOUN')	5
# (19.0, '1985_1989')	('ceramiche', 'NOUN')	2
# (19.0, '1985_1989')	('raffinato', 'NOUN')	1
#
# (19.0, '2005_2009')	('casa', 'NOUN')	1
# (19.0, '2005_2009')	('listone', 'NOUN')	1
#
# (20.0, '1980_1984')	('plus', 'NOUN')	5
# (20.0, '1980_1984')	('cucina', 'NOUN')	5
# (20.0, '1980_1984')	('bambino', 'NOUN')	4
# (20.0, '1980_1984')	('felicità', 'NOUN')	2
# (20.0, '1980_1984')	('garanzia', 'NOUN')	2
# (20.0, '1980_1984')	('decoro', 'NOUN')	2
# (20.0, '1980_1984')	('materassi', 'NOUN')	2
# (20.0, '1980_1984')	('sprint', 'NOUN')	2
# (20.0, '1980_1984')	('seggioloni', 'NOUN')	2
# (20.0, '1980_1984')	('box', 'NOUN')	2
#
# (20.0, '1985_1989')	('cucina', 'NOUN')	7
# (20.0, '1985_1989')	('scavolini', 'NOUN')	7
# (20.0, '1985_1989')	('momento', 'NOUN')	4
# (20.0, '1985_1989')	('debolezza', 'NOUN')	4
# (20.0, '1985_1989')	('spazio', 'NOUN')	4
# (20.0, '1985_1989')	('aiazzone', 'NOUN')	4
# (20.0, '1985_1989')	('casa', 'NOUN')	4
# (20.0, '1985_1989')	('amore', 'NOUN')	3
# (20.0, '1985_1989')	('lamore', 'NOUN')	3
# (20.0, '1985_1989')	('famiglia', 'NOUN')	3
#
# (20.0, '1990_1994')	('casa', 'NOUN')	2
# (20.0, '1990_1994')	('qualità', 'NOUN')	2
# (20.0, '1990_1994')	('cucina', 'NOUN')	2
# (20.0, '1990_1994')	('aresio', 'NOUN')	1
# (20.0, '1990_1994')	('pavimento', 'NOUN')	1
# (20.0, '1990_1994')	('porte', 'NOUN')	1
# (20.0, '1990_1994')	('acchiocciolo', 'NOUN')	1
# (20.0, '1990_1994')	('giorno', 'NOUN')	1
# (20.0, '1990_1994')	('misura', 'NOUN')	1
# (20.0, '1990_1994')	('idromassaggio', 'NOUN')	1
#
# (20.0, '1995_1999')	('cucina', 'NOUN')	7
# (20.0, '1995_1999')	('metro', 'NOUN')	6
# (20.0, '1995_1999')	('qualità', 'NOUN')	5
# (20.0, '1995_1999')	('potere', 'NOUN')	4
# (20.0, '1995_1999')	('cooking', 'NOUN')	3
# (20.0, '1995_1999')	('problema', 'NOUN')	2
# (20.0, '1995_1999')	('prezzo', 'NOUN')	2
# (20.0, '1995_1999')	('base', 'NOUN')	2
# (20.0, '1995_1999')	('parere', 'NOUN')	2
# (20.0, '1995_1999')	('serie', 'NOUN')	2
#
# (20.0, '2000_2004')	('scavolini', 'NOUN')	4
# (20.0, '2000_2004')	('qualità', 'NOUN')	3
# (20.0, '2000_2004')	('casa', 'NOUN')	3
# (20.0, '2000_2004')	('vita', 'NOUN')	2
# (20.0, '2000_2004')	('dettaglio', 'NOUN')	2
# (20.0, '2000_2004')	('volta', 'NOUN')	2
# (20.0, '2000_2004')	('mondo', 'NOUN')	2
# (20.0, '2000_2004')	('grazie', 'NOUN')	1
# (20.0, '2000_2004')	('cucina', 'NOUN')	1
# (20.0, '2000_2004')	('giovedì', 'NOUN')	1
#
# (20.0, '2005_2009')	('sconto', 'NOUN')	7
# (20.0, '2005_2009')	('prezzo', 'NOUN')	4
# (20.0, '2005_2009')	('euro', 'NOUN')	3
# (20.0, '2005_2009')	('sofà', 'NOUN')	3
# (20.0, '2005_2009')	('casa', 'NOUN')	3
# (20.0, '2005_2009')	('cucina', 'NOUN')	3
# (20.0, '2005_2009')	('qualità', 'NOUN')	3
# (20.0, '2005_2009')	('febbraio', 'NOUN')	2
# (20.0, '2005_2009')	('dimensione', 'NOUN')	2
# (20.0, '2005_2009')	('immagine', 'NOUN')	2
#
# (20.0, '2020_2024')	('cucina', 'NOUN')	4
# (20.0, '2020_2024')	('cosa', 'NOUN')	3
# (20.0, '2020_2024')	('potere', 'NOUN')	2
# (20.0, '2020_2024')	('sacrifici', 'NOUN')	1
# (20.0, '2020_2024')	('vita', 'NOUN')	1
# (20.0, '2020_2024')	('bello', 'NOUN')	1
# (20.0, '2020_2024')	('lecosostenibilità', 'NOUN')	1
# (20.0, '2020_2024')	('cura', 'NOUN')	1
# (20.0, '2020_2024')	('stile', 'NOUN')	1
# (20.0, '2020_2024')	('tecnologia', 'NOUN')	1
#
# (21.0, '1980_1984')	('splendore', 'NOUN')	5
# (21.0, '1980_1984')	('pressione', 'NOUN')	2
# (21.0, '1980_1984')	('piatto', 'NOUN')	2
# (21.0, '1980_1984')	('lagostina', 'NOUN')	2
# (21.0, '1980_1984')	('idee', 'NOUN')	2
# (21.0, '1980_1984')	('cucina', 'NOUN')	2
# (21.0, '1980_1984')	('vetro', 'NOUN')	2
# (21.0, '1980_1984')	('spontex', 'NOUN')	2
# (21.0, '1980_1984')	('spazzolo', 'NOUN')	1
# (21.0, '1980_1984')	('filo', 'NOUN')	1
#
# (21.0, '1985_1989')	('giòstyle', 'NOUN')	10
# (21.0, '1985_1989')	('mano', 'NOUN')	7
# (21.0, '1985_1989')	('mocio', 'NOUN')	6
# (21.0, '1985_1989')	('pippo', 'NOUN')	4
# (21.0, '1985_1989')	('lavoro', 'NOUN')	4
# (21.0, '1985_1989')	('modello', 'NOUN')	4
# (21.0, '1985_1989')	('ficcanaso', 'NOUN')	3
# (21.0, '1985_1989')	('gled', 'NOUN')	3
# (21.0, '1985_1989')	('potere', 'NOUN')	3
# (21.0, '1985_1989')	('casa', 'NOUN')	3
#
# (21.0, '1990_1994')	('deo', 'NOUN')	17
# (21.0, '1990_1994')	('gled', 'NOUN')	15
# (21.0, '1990_1994')	('idea', 'NOUN')	8
# (21.0, '1990_1994')	('giorno', 'NOUN')	7
# (21.0, '1990_1994')	('meliconi', 'NOUN')	7
# (21.0, '1990_1994')	('profumo', 'NOUN')	5
# (21.0, '1990_1994')	('mese', 'NOUN')	5
# (21.0, '1990_1994')	('spazzolino', 'NOUN')	5
# (21.0, '1990_1994')	('moneta', 'NOUN')	5
# (21.0, '1990_1994')	('salute', 'NOUN')	4
#
# (21.0, '1995_1999')	('mocio', 'NOUN')	6
# (21.0, '1995_1999')	('freschezza', 'NOUN')	5
# (21.0, '1995_1999')	('tocco', 'NOUN')	4
# (21.0, '1995_1999')	('ordinett', 'NOUN')	3
# (21.0, '1995_1999')	('spray', 'NOUN')	3
# ...
# (38.0, '2015_2019')	('passione', 'NOUN')	4
# (38.0, '2015_2019')	('mese', 'NOUN')	4
# (38.0, '2015_2019')	('film', 'NOUN')	4
# (38.0, '2015_2019')	('euro', 'NOUN')	4
# (38.0, '2015_2019')	('wind', 'NOUN')	4
#
# (38.0, '2020_2024')	('tv', 'NOUN')	14
# (38.0, '2020_2024')	('fibra', 'NOUN')	9
# (38.0, '2020_2024')	('ciao', 'NOUN')	7
# (38.0, '2020_2024')	('connessione', 'NOUN')	7
# (38.0, '2020_2024')	('glass', 'NOUN')	7
# (38.0, '2020_2024')	('film', 'NOUN')	6
# (38.0, '2020_2024')	('potere', 'NOUN')	6
# (38.0, '2020_2024')	('casa', 'NOUN')	5
# (38.0, '2020_2024')	('forza', 'NOUN')	4
# (38.0, '2020_2024')	('uo', 'NOUN')	4
#
# (39.0, '1980_1984')	('business', 'NOUN')	2
# (39.0, '1980_1984')	('fila', 'NOUN')	2
# (39.0, '1980_1984')	('viaggi', 'NOUN')	2
# (39.0, '1980_1984')	('crociera', 'NOUN')	2
# (39.0, '1980_1984')	('autobus', 'NOUN')	1
# (39.0, '1980_1984')	('genova', 'NOUN')	1
# (39.0, '1980_1984')	('compagnia', 'NOUN')	1
# (39.0, '1980_1984')	('macchina', 'NOUN')	1
# (39.0, '1980_1984')	('nebbia', 'NOUN')	1
# (39.0, '1980_1984')	('cecchine', 'NOUN')	1
#
# (39.0, '1985_1989')	('tempo', 'NOUN')	3
# (39.0, '1985_1989')	('lauro', 'NOUN')	2
# (39.0, '1985_1989')	('crociera', 'NOUN')	2
# (39.0, '1985_1989')	('giorno', 'NOUN')	2
# (39.0, '1985_1989')	('mondo', 'NOUN')	2
# (39.0, '1985_1989')	('energia', 'NOUN')	2
# (39.0, '1985_1989')	('express', 'NOUN')	2
# (39.0, '1985_1989')	('potere', 'NOUN')	2
# (39.0, '1985_1989')	('vita', 'NOUN')	2
# (39.0, '1985_1989')	('qualità', 'NOUN')	2
#
# (39.0, '1990_1994')	('express', 'NOUN')	3
# (39.0, '1990_1994')	('giorno', 'NOUN')	3
# (39.0, '1990_1994')	('linea', 'NOUN')	3
# (39.0, '1990_1994')	('tempo', 'NOUN')	2
# (39.0, '1990_1994')	('crociera', 'NOUN')	2
# (39.0, '1990_1994')	('potere', 'NOUN')	2
# (39.0, '1990_1994')	('firenze', 'NOUN')	2
# (39.0, '1990_1994')	('servizio', 'NOUN')	2
# (39.0, '1990_1994')	('comodi', 'NOUN')	2
# (39.0, '1990_1994')	('anno', 'NOUN')	2
#
# (39.0, '1995_1999')	('vino', 'NOUN')	3
# (39.0, '1995_1999')	('lavoro', 'NOUN')	3
# (39.0, '1995_1999')	('servizio', 'NOUN')	2
# (39.0, '1995_1999')	('figlio', 'NOUN')	2
# (39.0, '1995_1999')	('express', 'NOUN')	2
# (39.0, '1995_1999')	('club', 'NOUN')	2
# (39.0, '1995_1999')	('passione', 'NOUN')	2
# (39.0, '1995_1999')	('anno', 'NOUN')	1
# (39.0, '1995_1999')	('passeggero', 'NOUN')	1
# (39.0, '1995_1999')	('compagnia', 'NOUN')	1
#
# (39.0, '2000_2004')	('comfort', 'NOUN')	3
# (39.0, '2000_2004')	('servizio', 'NOUN')	3
# (39.0, '2000_2004')	('spazio', 'NOUN')	2
# (39.0, '2000_2004')	('cargo', 'NOUN')	2
# (39.0, '2000_2004')	('potere', 'NOUN')	2
# (39.0, '2000_2004')	('partenza', 'NOUN')	1
# (39.0, '2000_2004')	('passione', 'NOUN')	1
# (39.0, '2000_2004')	('ferrovia', 'NOUN')	1
# (39.0, '2000_2004')	('passeggero', 'NOUN')	1
# (39.0, '2000_2004')	('acqua', 'NOUN')	1
#
# (39.0, '2005_2009')	('zio', 'NOUN')	5
# (39.0, '2005_2009')	('vacanza', 'NOUN')	5
# (39.0, '2005_2009')	('treno', 'NOUN')	3
# (39.0, '2005_2009')	('lenergia', 'NOUN')	2
# (39.0, '2005_2009')	('cosa', 'NOUN')	2
# (39.0, '2005_2009')	('via', 'NOUN')	2
# (39.0, '2005_2009')	('telefono', 'NOUN')	2
# (39.0, '2005_2009')	('storia', 'NOUN')	2
# (39.0, '2005_2009')	('anno', 'NOUN')	2
# (39.0, '2005_2009')	('prenoto', 'NOUN')	2
#
# (39.0, '2020_2024')	('energia', 'NOUN')	3
# (39.0, '2020_2024')	('locauto', 'NOUN')	1
# (39.0, '2020_2024')	('potere', 'NOUN')	1
# (39.0, '2020_2024')	('logo', 'NOUN')	1
# (39.0, '2020_2024')	('persona', 'NOUN')	1
# (39.0, '2020_2024')	('volta', 'NOUN')	1
# (39.0, '2020_2024')	('giorno', 'NOUN')	1
# (39.0, '2020_2024')	('momento', 'NOUN')	1
# (39.0, '2020_2024')	('milione', 'NOUN')	1
# (39.0, '2020_2024')	('casa', 'NOUN')	1
#
# (40.0, '1985_1989')	('colore', 'NOUN')	5
# (40.0, '1985_1989')	('color', 'NOUN')	4
# (40.0, '1985_1989')	('ragazzo', 'NOUN')	2
# (40.0, '1985_1989')	('grazie', 'NOUN')	2
# (40.0, '1985_1989')	('consiglio', 'NOUN')	2
# (40.0, '1985_1989')	('cliente', 'NOUN')	2
# (40.0, '1985_1989')	('carta', 'NOUN')	2
# (40.0, '1985_1989')	('laboratorio', 'NOUN')	2
# (40.0, '1985_1989')	('qualità', 'NOUN')	2
# (40.0, '1985_1989')	('parte', 'NOUN')	2
#
# (41.0, '1980_1984')	('computer', 'NOUN')	3
# (41.0, '1980_1984')	('totocalcio', 'NOUN')	2
# (41.0, '1980_1984')	('lautomazione', 'NOUN')	1
# (41.0, '1980_1984')	('signore', 'NOUN')	1
# (41.0, '1980_1984')	('croce', 'NOUN')	1
# (41.0, '1980_1984')	('sullex', 'NOUN')	1
# (41.0, '1980_1984')	('sullio', 'NOUN')	1
# (41.0, '1980_1984')	('potere', 'NOUN')	1
# (41.0, '1980_1984')	('colonna', 'NOUN')	1
# (41.0, '1980_1984')	('servizio', 'NOUN')	1
#
# (41.0, '1985_1989')	('premio', 'NOUN')	10
# (41.0, '1985_1989')	('miliardo', 'NOUN')	7
# (41.0, '1985_1989')	('totip', 'NOUN')	4
# (41.0, '1985_1989')	('milione', 'NOUN')	4
# (41.0, '1985_1989')	('calcio', 'NOUN')	3
# (41.0, '1985_1989')	('settembre', 'NOUN')	2
# (41.0, '1985_1989')	('fortuna', 'NOUN')	2
# (41.0, '1985_1989')	('sivori', 'NOUN')	1
# (41.0, '1985_1989')	('anno', 'NOUN')	1
# (41.0, '1985_1989')	('juve', 'NOUN')	1
#
# (41.0, '1990_1994')	('lavoro', 'NOUN')	5
# (41.0, '1990_1994')	('tempo', 'NOUN')	5
# (41.0, '1990_1994')	('premio', 'NOUN')	5
# (41.0, '1990_1994')	('totip', 'NOUN')	4
# (41.0, '1990_1994')	('scuola', 'NOUN')	4
# (41.0, '1990_1994')	('radio', 'NOUN')	4
# (41.0, '1990_1994')	('miliardo', 'NOUN')	4
# (41.0, '1990_1994')	('potere', 'NOUN')	3
# (41.0, '1990_1994')	('programma', 'NOUN')	3
# (41.0, '1990_1994')	('milione', 'NOUN')	3
#
# (41.0, '1995_1999')	('cepu', 'NOUN')	3
# (41.0, '1995_1999')	('fortuna', 'NOUN')	2
# (41.0, '1995_1999')	('neve', 'NOUN')	2
# (41.0, '1995_1999')	('potere', 'NOUN')	2
# (41.0, '1995_1999')	('milione', 'NOUN')	2
# (41.0, '1995_1999')	('furia', 'NOUN')	2
# (41.0, '1995_1999')	('miliardo', 'NOUN')	2
# (41.0, '1995_1999')	('lavoro', 'NOUN')	2
# (41.0, '1995_1999')	('tempo', 'NOUN')	2
# (41.0, '1995_1999')	('numero', 'NOUN')	2
#
# (41.0, '2000_2004')	('tempo', 'NOUN')	8
# (41.0, '2000_2004')	('formazione', 'NOUN')	4
# (41.0, '2000_2004')	('comunicazione', 'NOUN')	3
# (41.0, '2000_2004')	('marketing', 'NOUN')	3
# (41.0, '2000_2004')	('viaggio', 'NOUN')	2
# (41.0, '2000_2004')	('programma', 'NOUN')	2
# (41.0, '2000_2004')	('denaro', 'NOUN')	2
# (41.0, '2000_2004')	('dellinformazione', 'NOUN')	2
# (41.0, '2000_2004')	('limite', 'NOUN')	2
# (41.0, '2000_2004')	('spazio', 'NOUN')	2
#
# (41.0, '2005_2009')	('giorno', 'NOUN')	7
# (41.0, '2005_2009')	('talento', 'NOUN')	7
# (41.0, '2005_2009')	('euro', 'NOUN')	7
# (41.0, '2005_2009')	('divertimento', 'NOUN')	6
# (41.0, '2005_2009')	('numero', 'NOUN')	5
# (41.0, '2005_2009')	('master', 'NOUN')	4
# (41.0, '2005_2009')	('mirabilandia', 'NOUN')	3
# (41.0, '2005_2009')	('campus', 'NOUN')	3
# (41.0, '2005_2009')	('comunicazione', 'NOUN')	3
# (41.0, '2005_2009')	('informazione', 'NOUN')	3
#
# (41.0, '2020_2024')	('gioco', 'NOUN')	4
# (41.0, '2020_2024')	('sottotitoli', 'NOUN')	1
# (41.0, '2020_2024')	('comunità', 'NOUN')	1
# (41.0, '2020_2024')	('giocodigitalegama', 'NOUN')	1
# (41.0, '2020_2024')	('divertimento', 'NOUN')	1
#
# (42.0, '1995_1999')	('tv', 'NOUN')	3
# (42.0, '1995_1999')	('mediaset', 'NOUN')	2
# (42.0, '1995_1999')	('line', 'NOUN')	2
# (42.0, '1995_1999')	('guida', 'NOUN')	1
# (42.0, '1995_1999')	('programma', 'NOUN')	1
# (42.0, '1995_1999')	('televisione', 'NOUN')	1
# (42.0, '1995_1999')	('novità', 'NOUN')	1
# (42.0, '1995_1999')	('potere', 'NOUN')	1
# (42.0, '1995_1999')	('via', 'NOUN')	1
# (42.0, '1995_1999')	('email', 'NOUN')	1
#
# (42.0, '2000_2004')	('apriti', 'NOUN')	5
# (42.0, '2000_2004')	('modo', 'NOUN')	2
# (42.0, '2000_2004')	('lavoro', 'NOUN')	2
# (42.0, '2000_2004')	('stepstone', 'NOUN')	2
# (42.0, '2000_2004')	('amore', 'NOUN')	2
# (42.0, '2000_2004')	('porta', 'NOUN')	2
# (42.0, '2000_2004')	('servizio', 'NOUN')	1
# (42.0, '2000_2004')	('opportunità', 'NOUN')	1
# (42.0, '2000_2004')	('settore', 'NOUN')	1
# (42.0, '2000_2004')	('passo', 'NOUN')	1
#
# (42.0, '2005_2009')	('codice', 'NOUN')	3
# (42.0, '2005_2009')	('settimana', 'NOUN')	2
# (42.0, '2005_2009')	('tv', 'NOUN')	2
# (42.0, '2005_2009')	('potere', 'NOUN')	1
# (42.0, '2005_2009')	('premio', 'NOUN')	1
# (42.0, '2005_2009')	('valturo', 'NOUN')	1
# (42.0, '2005_2009')	('cd', 'NOUN')	1
# (42.0, '2005_2009')	('scegnelco', 'NOUN')	1
# (42.0, '2005_2009')	('gioco', 'NOUN')	1
# (42.0, '2005_2009')	('mediasetit', 'NOUN')	1
#
# (42.0, '2020_2024')	('potere', 'NOUN')	4
# (42.0, '2020_2024')	('tempo', 'NOUN')	3
# (42.0, '2020_2024')	('famiglia', 'NOUN')	2
# (42.0, '2020_2024')	('lavoro', 'NOUN')	2
# (42.0, '2020_2024')	('limite', 'NOUN')	1
# (42.0, '2020_2024')	('figlio', 'NOUN')	1
# (42.0, '2020_2024')	('lapp', 'NOUN')	1
# (42.0, '2020_2024')	('giorno', 'NOUN')	1
# (42.0, '2020_2024')	('accordo', 'NOUN')	1
# (42.0, '2020_2024')	('abitudine', 'NOUN')	1
#
# (43.0, '1980_1984')	('viaggi', 'NOUN')	5
# (43.0, '1980_1984')	('viaggio', 'NOUN')	3
# (43.0, '1980_1984')	('programma', 'NOUN')	2
# (43.0, '1980_1984')	('prenotazione', 'NOUN')	2
# (43.0, '1980_1984')	('alpitour', 'NOUN')	2
# (43.0, '1980_1984')	('leader', 'NOUN')	2
# (43.0, '1980_1984')	('france', 'NOUN')	1
# (43.0, '1980_1984')	('informazione', 'NOUN')	1
# (43.0, '1980_1984')	('agenzia', 'NOUN')	1
# (43.0, '1980_1984')	('casa', 'NOUN')	1
#
# (43.0, '1985_1989')	('vacanza', 'NOUN')	10
# (43.0, '1985_1989')	('hamburger', 'NOUN')	7
# (43.0, '1985_1989')	('alpitour', 'NOUN')	7
# (43.0, '1985_1989')	('squadra', 'NOUN')	5
# (43.0, '1985_1989')	('adventure', 'NOUN')	4
# (43.0, '1985_1989')	('vittoria', 'NOUN')	4
# (43.0, '1985_1989')	('patatina', 'NOUN')	4
# (43.0, '1985_1989')	('leader', 'NOUN')	4
# (43.0, '1985_1989')	('racing', 'NOUN')	4
# (43.0, '1985_1989')	('viaggi', 'NOUN')	4
#
# (43.0, '1990_1994')	('club', 'NOUN')	2
# (43.0, '1990_1994')	('vacanza', 'NOUN')	2
# (43.0, '1990_1994')	('lanzarote', 'NOUN')	2
# (43.0, '1990_1994')	('villaggi', 'NOUN')	2
# (43.0, '1990_1994')	('valtur', 'NOUN')	2
# (43.0, '1990_1994')	('vita', 'NOUN')	1
# (43.0, '1990_1994')	('braccio', 'NOUN')	1
# (43.0, '1990_1994')	('cuore', 'NOUN')	1
# (43.0, '1990_1994')	('clouds', 'NOUN')	1
# (43.0, '1990_1994')	('youre', 'NOUN')	1
#
# (43.0, '1995_1999')	('soluzione', 'NOUN')	3
# (43.0, '1995_1999')	('imprevisto', 'NOUN')	2
# (43.0, '1995_1999')	('carta', 'NOUN')	2
# (43.0, '1995_1999')	('potere', 'NOUN')	1
# (43.0, '1995_1999')	('viaggi', 'NOUN')	1
# (43.0, '1995_1999')	('divertimento', 'NOUN')	1
# (43.0, '1995_1999')	('stanza', 'NOUN')	1
#
# (43.0, '2000_2004')	('meal', 'NOUN')	7
# (43.0, '2000_2004')	('loving', 'NOUN')	5
# (43.0, '2000_2004')	('lovin', 'NOUN')	4
# (43.0, '2000_2004')	('vacanze', 'NOUN')	4
# (43.0, '2000_2004')	('casa', 'NOUN')	3
# (43.0, '2000_2004')	('euro', 'NOUN')	3
# (43.0, '2000_2004')	('potresta', 'NOUN')	3
# (43.0, '2000_2004')	('possibilità', 'NOUN')	3
# (43.0, '2000_2004')	('spizzico', 'NOUN')	2
# (43.0, '2000_2004')	('food', 'NOUN')	2
#
# (43.0, '2005_2009')	('meal', 'NOUN')	4
# (43.0, '2005_2009')	('cheeseburger', 'NOUN')	3
# (43.0, '2005_2009')	('sapore', 'NOUN')	2
# (43.0, '2005_2009')	('azione', 'NOUN')	2
# (43.0, '2005_2009')	('gioco', 'NOUN')	2
# (43.0, '2005_2009')	('cola', 'NOUN')	2
# (43.0, '2005_2009')	('mcmenu', 'NOUN')	2
# (43.0, '2005_2009')	('plus', 'NOUN')	2
# (43.0, '2005_2009')	('menu', 'NOUN')	2
# (43.0, '2005_2009')	('casa', 'NOUN')	1
#
# (43.0, '2010_2014')	('big', 'NOUN')	5
# (43.0, '2010_2014')	('gusto', 'NOUN')	4
# (43.0, '2010_2014')	('mondo', 'NOUN')	3
# (43.0, '2010_2014')	('campioni', 'NOUN')	3
# (43.0, '2010_2014')	('sapore', 'NOUN')	3
# (43.0, '2010_2014')	('colazione', 'NOUN')	3
# (43.0, '2010_2014')	('sottotitoli', 'NOUN')	2
# (43.0, '2010_2014')	('meal', 'NOUN')	2
# (43.0, '2010_2014')	('lavoro', 'NOUN')	2
# (43.0, '2010_2014')	('prova', 'NOUN')	2
#
# (43.0, '2015_2019')	('menu', 'NOUN')	4
# (43.0, '2015_2019')	('crispy', 'NOUN')	4
# (43.0, '2015_2019')	('big', 'NOUN')	3
# (43.0, '2015_2019')	('appetito', 'NOUN')	3
# (43.0, '2015_2019')	('settimana', 'NOUN')	2
# (43.0, '2015_2019')	('mac', 'NOUN')	2
# (43.0, '2015_2019')	('dovere', 'NOUN')	2
# (43.0, '2015_2019')	('differenza', 'NOUN')	2
# (43.0, '2015_2019')	('pausa', 'NOUN')	2
# (43.0, '2015_2019')	('menù', 'NOUN')	2
#
# (43.0, '2020_2024')	('salsa', 'NOUN')	5
# (43.0, '2020_2024')	('®', 'NOUN')	5
# (43.0, '2020_2024')	('spicy', 'NOUN')	5
# (43.0, '2020_2024')	('big', 'NOUN')	4
# (43.0, '2020_2024')	('fuoco', 'NOUN')	4
# (43.0, '2020_2024')	('caffè', 'NOUN')	3
# (43.0, '2020_2024')	('persona', 'NOUN')	3
# (43.0, '2020_2024')	('petto', 'NOUN')	3
# (43.0, '2020_2024')	('selection', 'NOUN')	3
# (43.0, '2020_2024')	('carne', 'NOUN')	3
#
# (44.0, '1980_1984')	('centro', 'NOUN')	3
# (44.0, '1980_1984')	('telefonate', 'NOUN')	2
# (44.0, '1980_1984')	('capello', 'NOUN')	2
# (44.0, '1980_1984')	('problema', 'NOUN')	1
# (44.0, '1980_1984')	('ragazzi', 'NOUN')	1
# (44.0, '1980_1984')	('potere', 'NOUN')	1
# (44.0, '1980_1984')	('testa', 'NOUN')	1
# (44.0, '1980_1984')	('idea', 'NOUN')	1
# (44.0, '1980_1984')	('tempo', 'NOUN')	1
# (44.0, '1980_1984')	('bello', 'NOUN')	1
#
# (44.0, '1985_1989')	('problema', 'NOUN')	5
# (44.0, '1985_1989')	('firenze', 'NOUN')	5
# (44.0, '1985_1989')	('soluzione', 'NOUN')	4
# (44.0, '1985_1989')	('cetrin', 'NOUN')	4
# (44.0, '1985_1989')	('parrucchino', 'NOUN')	3
# (44.0, '1985_1989')	('persona', 'NOUN')	2
# (44.0, '1985_1989')	('capello', 'NOUN')	2
# (44.0, '1985_1989')	('esame', 'NOUN')	2
# (44.0, '1985_1989')	('tricologico', 'NOUN')	1
# (44.0, '1985_1989')	('telefono', 'NOUN')	1
#
# (44.0, '1990_1994')	('calvizia', 'NOUN')	2
# (44.0, '1990_1994')	('problema', 'NOUN')	2
# (44.0, '1990_1994')	('listitere', 'NOUN')	1
# (44.0, '1990_1994')	('metodo', 'NOUN')	1
# (44.0, '1990_1994')	('certezza', 'NOUN')	1
# (44.0, '1990_1994')	('firenze', 'NOUN')	1
# (44.0, '1990_1994')	('appuntamento', 'NOUN')	1
# (44.0, '1990_1994')	('consulenza', 'NOUN')	1
#
# (44.0, '1995_1999')	('potere', 'NOUN')	5
# (44.0, '1995_1999')	('centro', 'NOUN')	4
# (44.0, '1995_1999')	('tradizione', 'NOUN')	2
# (44.0, '1995_1999')	('immagine', 'NOUN')	2
# (44.0, '1995_1999')	('studio', 'NOUN')	2
# (44.0, '1995_1999')	('giorno', 'NOUN')	1
# (44.0, '1995_1999')	('pescatore', 'NOUN')	1
# (44.0, '1995_1999')	('mare', 'NOUN')	1
# (44.0, '1995_1999')	('esperienza', 'NOUN')	1
# (44.0, '1995_1999')	('pesce', 'NOUN')	1
#
# (44.0, '2000_2004')	('studios', 'NOUN')	1
#
# (44.0, '2005_2009')	('chirurgo', 'NOUN')	2
# (44.0, '2005_2009')	('potere', 'NOUN')	2
# (44.0, '2005_2009')	('numero', 'NOUN')	2
# (44.0, '2005_2009')	('trattamento', 'NOUN')	2
# (44.0, '2005_2009')	('volta', 'NOUN')	1
# (44.0, '2005_2009')	('organizzazione', 'NOUN')	1
# (44.0, '2005_2009')	('specialista', 'NOUN')	1
# (44.0, '2005_2009')	('chirurgia', 'NOUN')	1
# (44.0, '2005_2009')	('visita', 'NOUN')	1
# (44.0, '2005_2009')	('advisor', 'NOUN')	1
#
# (45.0, '1985_1989')	('ottobre', 'NOUN')	2
# (45.0, '1985_1989')	('democrazia', 'NOUN')	2
# (45.0, '1985_1989')	('maggio', 'NOUN')	2
# (45.0, '1985_1989')	('fiducia', 'NOUN')	2
# (45.0, '1985_1989')	('barba', 'NOUN')	1
# (45.0, '1985_1989')	('felicità', 'NOUN')	1
# (45.0, '1985_1989')	('persona', 'NOUN')	1
# (45.0, '1985_1989')	('tempo', 'NOUN')	1
# (45.0, '1985_1989')	('fattura', 'NOUN')	1
# (45.0, '1985_1989')	('mondo', 'NOUN')	1
#
# (45.0, '1990_1994')	('referendum', 'NOUN')	4
# (45.0, '1990_1994')	('potere', 'NOUN')	3
# (45.0, '1990_1994')	('governo', 'NOUN')	2
# (45.0, '1990_1994')	('partito', 'NOUN')	2
# (45.0, '1990_1994')	('bisogno', 'NOUN')	2
# (45.0, '1990_1994')	('giugno', 'NOUN')	2
# (45.0, '1990_1994')	('alleconomia', 'NOUN')	2
# (45.0, '1990_1994')	('vita', 'NOUN')	2
# (45.0, '1990_1994')	('istituzione', 'NOUN')	1
# (45.0, '1990_1994')	('malessere', 'NOUN')	1
#
# (45.0, '2000_2004')	('cosa', 'NOUN')	1
# (45.0, '2000_2004')	('bisogno', 'NOUN')	1
# (45.0, '2000_2004')	('compagnia', 'NOUN')	1
# (45.0, '2000_2004')	('lovet', 'NOUN')	1
# (45.0, '2000_2004')	('potere', 'NOUN')	1
# (45.0, '2000_2004')	('colpo', 'NOUN')	1
# (45.0, '2000_2004')	('casa', 'NOUN')	1
# (45.0, '2000_2004')	('wwwlycosit', 'NOUN')	1
#
# (45.0, '2005_2009')	('persona', 'NOUN')	3
# (45.0, '2005_2009')	('club', 'NOUN')	2
# (45.0, '2005_2009')	('sms', 'NOUN')	2
# (45.0, '2005_2009')	('foto', 'NOUN')	2
# (45.0, '2005_2009')	('numero', 'NOUN')	2
# (45.0, '2005_2009')	('messaggio', 'NOUN')	2
# (45.0, '2005_2009')	('casa', 'NOUN')	1
# (45.0, '2005_2009')	('internet', 'NOUN')	1
# (45.0, '2005_2009')	('meetic', 'NOUN')	1
#
# (45.0, '2020_2024')	('notte', 'NOUN')	2
# (45.0, '2020_2024')	('casa', 'NOUN')	1
# (45.0, '2020_2024')	('protetto', 'NOUN')	1
# (45.0, '2020_2024')	('famiglia', 'NOUN')	1
# (45.0, '2020_2024')	('lallarme', 'NOUN')	1
# (45.0, '2020_2024')	('sicurezza', 'NOUN')	1
# (45.0, '2020_2024')	('intervento', 'NOUN')	1
# (45.0, '2020_2024')	('chiamalo', 'NOUN')	1
# (45.0, '2020_2024')	('verisureit', 'NOUN')	1

# %% [markdown]
# ## Most frequent words in LUSTRA

# %%
#Grouping all by lustrum
dictionary =df_total.groupby('lustrum')['transcription'].apply(list).to_dict()

# %%
dictionary['1980_1984']
# Out:
# ['essere persona potere permettere stare casa quando fare brutto tempo primo sintomo raffreddore influenza presto aspirinare aspirina andare bene presto seguire attentamente avvertenza modalità duso',
#  'qui volere black decker potere forare materiale accessorio trasformare sega circolare perfetto levigatrice dirai lho fatto black decker accessorio trapano black decker partire 33200 lira natale gamma black decker trovare sempre regalo utile regalo durare sempre black decker',
#  'carciofo ricco qualità naturale cynar aperitivo base carciofo dopo pranzo cynar liscio bere liscio cynar essere ottimo amaro scelta naturale',
#  'volere raffreddore uninfluenza guardare avere qualcosa te cebiopirina effervescente vitamina raffreddore influenza male testa primo sintomo cebiopirina effervescente vitamina cebiopirina effervescente cebiopirina effervescente essere prodotto bracco seguire attentamente avvertenza modalità duso',
#  'linea graziella simpatia due ruota buongiorno fabio ciao fabio linea graziella simpatia due ruota buongiorno stefano buongiorno signorinare linea graziella simpatia due ruota graziella essere prodotto carnielli',
#  'prodotto ligiene intimo certo parte potere fare vedere dare risultato piacivolo potere fare vedere prodotto essere chilly soluzione salviettino ligiena intimo provalo vedere',
#  'citizen quartz citizen quartz citizen quartz orologi raffinato orologio pratico orologio elegante ogni situazione ogni età incredibilmente sottile incredibilmente perfetto citizen quartz citizen gioielli quarzo',
#  'adesso sapere cosè dentifricio dentifricio speciale formula scientificamente avanzare nuovo colgare fluor mfp fluoro cosa fare immaginate gessetto essere dente fluor mfp vedere fluor mfp fissare dente rinforzare colgata fluor mfp unaccurato pulizia dente azione igienico aiutare prevenire lacquario dare sempre lalire presto nuovo colgare fluor mfp',
#  'cosa dietro famoso sorriso turbo essere naturale sapore bocca fresco dare famiglia piacere lavare bene però mica male casa piacere sapore boccare fresco turbo stare meglio quando bocca fresco sapore menta appena colgere casa piacere sapore boccare fresco turbo',
#  'fabbri 75 anno bontà frutta fabbri liquore proposta fabbri macedonia fabbri 75 anno bontà',
#  'fin primo poppare bimbo avere bisogno protezione puoi usare casa protezione milton solo sterilizzare poppatoio tettarella milton proteggere infezione sicurezza protegge infezione delicatezza protezione piccolo grande potere usare milton casa milton proteggere infezione leggere attentamente advertenza',
#  'avere mangiare confettura sapere confetturare santa rosa tanto bello frutta fresco peccatone né colorante né conservante santa rosa frutta fresco zucchero ragazzo nutrimolo intelligenza negoziante regalo ladesivo santa rosa potere vincere super sacca santa rosa confettura santa rosa',
#  'paola fare tardi cinema stare fare bello vedere molto molto bello nuovo camay cosha nuovo avere nuovo profumo delicato prezioso francese naturalmente nuovo camay essere carezza pelle carezza ehi fare tardi cinema cinema nuovo camay pizzico fascino',
#  'sai essere proprio ottimo sughia ragù qui pomodorissimo squisito praticissimo pomodorissimo tutta fragranza essere sapore pomodoro crudo pomodorissimo essere solo santa rosa',
#  'freschezza dellacqua profumo fiore nuovo deodorante obao obao freschezza mattino corpo obao freschezza pelle giornata nuovo deodorante obao freschezza mattino obao fresco corpo',
#  'vigorsol evvia grinta vigorsol chewing gum confetto grinta chewing gum confetto gusto forte fortissimo',
#  'oro china martini oggi essere giornata',
#  'vivere oggi lavoro impegno finalmente borotalco volere bene tanto agonismo impegno intenso poi borotalco volere bene borotalco essere tenero delicato te stesso borotalco volere bene',
#  'tanto barbo eccolo qui lamarasoio bic dovere usare quando svegliare mattino avere anno rassaturare dolce perfetto bello piacere lamarasoio qualità qualità bello radere bravo bravo bello radere bravo bravo perfetto perfetto perfetto bravo bic lamarasoio bic',
#  'pizzette pizzettino catarì essere segreto avere fame fare passare avere fame fare venire pizzette catarì alre fame stuzzicano lappetito pizzette catarì ora vho capire',
#  'essere forma lalimentazione essere importante tanto scelgono certosa galbani formaggio leggero nutriente certosa galbani essere conveniente potere fare tanto porzione certosa galbani essere comodo contorno diventare unottimo cena certosa galbani prodotto fiducia galbani volere dire fiducia',
#  'succedere gengivo fare male attento gengiva essere importante guarda essere qui dente gengire placca batterico formare va bene potere fare volere comunque lare regolarmente dente dentificio disinfettante gengivo defend plus combattere placca batterico avere gengivo forte defend plus gengivo forte denne',
#  'prosciutto parma sapere essere diverso speciale prosciutto parma nascere suine selezionato lavorazione essere fare maniera tradizionale controllato ogni fase fino stagionatura ultimato ecco essere dolce fragrante inimitabile volere prosciutto chiedetelo nome dire volere parma dovere dare prosciutto marchio consorzio prosciutto parma',
#  'nutriente completo appetitoso ciappi nutriente completo appetitoso ciappi hopla nutriente completo appetitoso ciappi essere sparsa voce ciappi essere pasto nutriente completo appetitoso ciappi tanto appetitoso varietà mantenere forma mmmh ciappi ciappi essere sparsa voce',
#  'cosè stasera secondo sorpresa secondo sorpresa sofficini sofficini secondo sofficini findus portare tavola cambiare sorpresa sofficissimo sorpreso sorprendere troppo appessivo adorare bontà sorpresa sofficissimo sorpreso sorprendere morbidissimo ripieno bontàre sofficini findus buono secondo corro dietro ogni volta sorpresa',
#  'mago g mago g chiudere occhio aprire bocca mago g mago g quasi locchio lallico zalet galbusera frollini malto miele buono prendere gurre g galbusera g galbusera chiudere occhio aprire bocca mago g mago g zalet galbusera buono prendere gurre',
#  'indesit indesit elettrodomestici indesit elettrodomestici alto fedeltà indesit',
#  'quando cantare gallo fare primo colazione kellogg ’s corn flakes 12 pannocco ogni grande scatata kellogg ’s corn flakes fiocchi grano turco latte buono abitudine mattino kellogg ’s',
#  'conosci oil of olaz fluido aiutare pelle mantenere aspetto giovane oil of olaz compensare perdita acqua pelle subire venire subito assorbire senza lasciare traccia oil of olaz potere aiutarto sembrare giovane',
#  'gelato caramello pralinato gusto cioccolare voglia mattare avventura avere toseroni son sicuro lho toseroni gelato chiamare blob blob provare gusto blob provare gusto blob provare gurre buon appetito',
#  'fare perfetto armonia dellaranciare crodo base succo daranciare aranciare crodo garantire grande casa aranciata crodo',
#  'sporco impossibile unto cucina sporco federa unto pelle qui camicia lunto impossibile esistere sporco impossibile bio presto bucato mano bio presto bucato mano liquidare lunto bio presto sciogliere sporco impossibile solito venire via vedere pulire bio presto bucato mano niente sporco impossibile nessuno asciugato cucina nessuno camicia nessuno federa bio presto bucato mano liquidare sporco impossibile bucato',
#  'happy mentos you happy mentos today happy mentos happy mentos happy mentos the way mentos nuovo caramella dare piacere masticare freschezza menta',
#  'renault 5 essere proprio inconfondibile insuperabile incredibile inimitabile imbattibile ineguagliabile impareggabile',
#  'ecco favoloso proposta sposi ’ 82 cucina laminato plastico lira 1200000 camera letto palissandro lira 850000 aiazzone pagamento pino 3 anno senza cambiale aiazzone aiazzone serio immobile mazare',
#  'akuel essere sicurezza amore akuel solo contraccettivo marchio essere sicurezza paese mondo sicuri naturale essere nulla akuel direttamente dallespositore solo farmacia akuel essere pianificazione familiare',
#  'charms girare loretta goggi dovere cambiare gomma certo cambia gomma gumstrip gungelli gumbol charms nuovo swingum linea rosso',
#  'avere mettere litro benzina due macchina uguale due avere quattro freno disco ponte de dion due carburatore doppio corpo essere tredicesimo chilometro fermare avere finire benzina essere giulietta laltra continuare essere giulietta essere nuovo giulietta consumo ridotto alfa romeo avere ridurre consumo fino 14 alfa romeo quando tecnologia essere arte',
#  'antiarena presentare bello figlio pollo crocchella carne pollo fungo spinace formaggio pomodoro asparagio zac dimanjo buona uffa essere stufare solito piatto complicare peppa crocchella idea secondo buone crocchelle arena mangiare allegro contento',
#  'bello camicia pulito beh avere scegliere medio temperatura sennò avere 2 colore vedere qualche traccia grasso scega nuovo ariel lavatrice ariel lavatrice pulire fondo senza acqua bollente ecco camicia sporco ostinare grasso olio laviamone metà ariel ariel traccia grasso olio pulire colore bucato essere perfetto nuovo ariel lavatrice pulire fondo senza acqua bollente accarezzare colore',
#  'ehi moto chicco acceleratore raglio specchietto classo cambio perfetto lg corda ora senza bisogno motore',
#  'cominciare qui discorso birra scegliere birra essere scelta intelligente comperarla vuoto rendere essere intelligente ancora fare spreco risparmiare spendere meno comprare poi parlare quando bevere adesso esempio potere permettere ritrovare rimbambito avere mangiare fare dovere andare lavorare bere birra essere leggero bevanda alcolico oppure adesso festeggiare fatto essere aumentare fuga etto essere perfetto preso forno bere birra ingastare avere pochissime caloria meno succo pompemmo sapevata oppure adesso dovere avere sprint menta lucido datereppa tenere peso formare mente lucido vivere sprint andare tranquillo birra proprio volere andare forte vai piano lalcol vai birra meditate gente meditare',
#  'cosè dentifricio scientificamente avanzare colgare fluore mfp usare tre volta giorno aiutare prevenire carie cario fare immaginate gessetto essere dente fluore mfp quando lavare dente fluore mfp fissare dente rinforzandolo colgare fluore mfp corretto igiene orale aiutare prevenire carie colgate fluore mfp',
#  'collezione shampoo elseve oreal presentare elseve frequens lavaggio frequente dolcezza permettere frequenza rispettare vita capello rendere fresco pulito brillante elseve frequens collezione elseve 4 shampoo cosmetico trattare dolcemente',
#  'vedi dici stare attento dire potere stare tranquillo dovere controllare appunto essere controllare talmente sottile proprio impaltabile bravo durex lhaare prendere londra teso trovare farmacia italia lho vedere buggiarda bugiardare adesso bastare parlare durex adesso dimmi fare bene dire fare bene',
#  'grattacieli vertiginoso danza tribale essere keptown qui bel paese galbani formaggio conoscere mondo carillon mari plazae famoso birrerio essere monaco baviera qui bel paese formaggio conoscere mondo gusto morbido delicato cucina bel paese galbani aiutare preparare nuovo piatto ricco sapore bel paese galbani conveniere resa bel paese galbani prodotto fiducia galbani volere dire fiducia',
#  'carne nipiol bambino mangia venire qui proprio qui bello campagna umbrare famiglia buitoni allere direttamente manzio vitello omogeneizzato nipiol essere certo avere carno assolutamente sicura genuino certezza grande esperienza buitoni andare finire qui sotto sigillo garanzia nipiol completo limpegno famiglia cinque generazione cura bambino',
#  '20° anniversario conad presentare splendore negozio supermercato qualità garantito tonno marinel genumidità dellolio extravergine sabrinare sapore burro prato verde perfezione cottura riso dorire qualità scelto farina conad delicato fragranza colomba conad conad scegliere bene',
#  'mago piacere essere essere mago aladino aladino nonno fare sparire cosa fare abra cadabra prendere due carta scomparse poi fare apparire due scrigno abra cadabrare fare sparire biscotto plasmon biscotti diventare grande piacere grande',
#  'ehi avere camicetto uguale essere uguale essere scolorito essere sporco avere dovere lavare acqua caldo ora volere lacqua caldo scolorire ariel essere fare apposta pulire acqua freddo scolorire tagliamo camicetta metà lavare volta acqua caldo metà stesso volta ariel essere acqua freddo ecco due pulito lavare ariel avere colore nuovo guarda colore avere ragione traccio sporco ariel essere proprio pulito ariel freddare sporco accarezza colore',
#  'oro pilla brandy italiano oro pilla scudo nero oro pilla grande paese grande brandy',
#  'occhio collirio alfa collirio alfa difendere salute occhio quando essere irritare stanco qualche goccia collirio alfa ottenere unazione decongestionante rapido efficace collirio alfa specialità salute occhio leggere attentamente avvertenza',
#  'veglia suonare essere lora buono ecco pronto caffè te vogliare caffè philips fare te lucida poi qua stigla ripassa là essere bello stella fonte aiutare pensare lasciale fare essere bravo essere versione bello philips fare te',
#  'doremifive cantiamo five grande sorpresa piccolo amico canale cinque doremifive cantiamo five bambino pinocchio laura munchichi getchmen canzone eroe preferire lp musica sette prezzo speciale negozio disney',
#  'avere lavorare migliorare sapone rendere cremoso essere nascere super soap super soap sapone liquido oggi ancora cremoso ricco sostanza moliento sai cremoso sapone morbidare pelle super soap sapone liquido cremoso',
#  'essere mozzarelli surgela essere secondo piatto gustoso essere bocconcino mozzarella impanato niente altro essere prodotto nuovo sai cosa dentro mozzarelli surgela',
#  'sapone nuovo essere sapone flacone super soap prendere doso tanta schiuma delicato super soap essere cremoso pelle essere cremoso profumato super soap super soap sapone liquido cremoso',
#  'cirano marlowe otello ferocce saladino oggi essere nino castelnuovo certo moto importante tavola olio cuore aiutare stare forma olio cuore cuore mais essere olio seme mais dietetico olio cuore saporito leggero gustoso dare sapore mais olio cuore mangiar bene sentire forma',
#  'cosa dentro te forse sai cuore panna cuore panna momento tenero cornetto algida cuore panna',
#  'brillantina essere pallina parente allina brillantina comodino pallina nome essere brillantina brillantina rimbalzina coloratissimo brillantissimo essere pallina divertitevi brillantina rimbalzina pallina super rimbalzare ogni altro pallina brillantina rimbalzina adesiva personalizzante essere unesclusivo linea g',
#  'nuovo generazione angelo libero nascere nuovo generazione shampoo shampoo balsamo post post shampoo neutro balsamo proteina finalmente insieme shampoo balsamo post mentre lavare delicatamente capello proteggere rendere docile splendente capelli angelo libero shampoo balsamo post',
#  'andare guardare trovare confrontare laffare valere plus arredamenti entrare girare parlare arredare qualità plus arredamenti calore colore stile superiore convenienza plus arredamenti sognare pregustare felice acquistare sognare avverare plus arredamenti plus arredamenti via golgi pavia ora grande nellesposizione',
#  'pomodoro uninvenzione cirio passata cirio essere casa pomodori passato sale nientaltro passata cirio sugo sapore pomodoro sud essere cirio passata verace',
#  'vincere volere buono partenza lavatrice nuovo bio presto sistema taed essere detersivo sostanza attivo lavorare fino dallinizio forza equilibrare bio presto sistema taed agire primo agire fondo ecco oggi dare pulito migliore medio basso temperatura bio presto sistema taed pulito migliore medio basso temperatura',
#  'immaginare panettone quando tagliare sospirare profumo metale fetta piatto essere fiore fragrante essere glorioso candito ovetto sofofe morbido leggero invece immaginare panettone pasticceria volere cioccolato ricopra nascondare dentro sorpresa immaginare panettone mottare ragazzo mmm mottare',
#  'fruttinsieme fabbri liquore fruttinsieme macedonia grande qualità fruttinsieme ottimo insieme 5 monto fruttinsieme fabbri liquore macedonia pronto albicocco prugna ananas uvetto ottime frutta fabbri liquore famoso ciliegia fabbri oltre 75 anno bontà',
#  'amaro ramazzotti avere fare grande passo avanti essere lunico arricchire jin sen stop stop perfetto perfetto bravo bravo vaire feo tornare indietro salve laveto sentire bene amaro ramazzotti essere lunico mondo arricchire jin sen radice vita oriente secolo chiamare vogliamo assaggiare visto ramazzotti essere amaro inimitabile unico davvero eccezionale johnny sana voglio vivere fare sempre bene amaro ramazzotti lunico arricchire jin sen',
#  'pronto ciao essere mister baby guarda bello cosa avere te biberon mister baby lesclusivo doppio valvola lasciare passare latta unario seno mamma mister baby linea bubere bebé',
#  'isola paradiso lamore esprimere gesto temero delicato naso naso isola paradiso donna avere incurgere profumo fidjii essere profumo fidjii profumo paradiso trovare',
#  'avere realizzare unintervista interessante fegato andare quando cambiare stagione essere doppio fatica cambiano abitudine lalimentazione potere capitare mangiare male troppo troppo poco vuole dare qualche consiglio almeno moderare lalimentazione solo caso necessità amaro medicinale giuliani quando necessitare facilitare digestione stimolare funzione fegato amaro medicinale giuliani digestivo aiutare fegato leggere attento vertenza',
#  'rinassatevi bagnolatte nidra essere piccolo vacanza bagnolatte nidra ammorbidire distenda proteggia latte pelle modo naturale tanta schiuma tanto distensione bagnolatte nidra morbido distensione latte',
#  'quando mulino essere bianco storia cominciare p pannocchia storia fragrante mais pannocchie nuovo sapore bontà mais colore sole domattina pannocchia mulino bianco dentro bontà mais mangia sano torna natura biscotto mulino bianco barilla buon appetito',
#  'attenanato nuovo lines svelto neonare lines usare reparto maternità guarda mamma lines svelto neonato avere nuovo filtrante stare asciutto scacciare bagnato restare asciutto nuovo filtrante macchiare nemmeno vedere essere senza colla quindi essere ancora morbido poi fluff lines famoso lassorbenza attenanato nuovo lines svelto neonare lines usare reparto maternità',
#  'momento avere profumo sapore martini rosso martini rosso quando volere volere volere martini rosso martini essere',
#  'attenzione gara forza macista circo fortissimo spingere essere essere forte trentasei forza pane cuoco mangiare bastoncini findus bastoncini findus pesce bue forza niente spina essere essere essere forte trentasei capito bastoncini findus pesce bue forza niente spine',
#  'occhio grande grande capello biondi biondi essere candy candy candy candy candy candy candy candy essere fare quattro essere candy candy',
#  'nuovo passo samba ecco nuovo samba cabriolet bello scoperta cambio 5 velocità 160 chilometro fascino unauto esclusivo firmare ninfarina scoprire samba cabriolet concessionario beigeot talbot',
#  'studente statistico progettista ecco nuovo calcolatrico scientifico sharp sharp studente legge formula scrivo avere 38 funzione calcolo 6 livello parentesi sharp statistico 52 funzione calcolo 38 passo programma sharp progettista convisore alfanumerico scorrevolo 63 funzione calcolo 80 passo programma sharp calcolo calcolo sharp',
#  'dimmi dimmi baby shampoo fare te mandare rispore essere baby garnier garnier baby essere nuovo shampoo dolce delicato ogni giorno discreto essere clinicamente sperimentato dimmi dimmi baby shampoo fare te mandare rispore essere baby garnier garantito laboratorio garnier parigi garnier baby dolce baby dolce mamma garantito laboratorio garnier parigi',
#  'nuovo a112 sapete essere segreto essere unautomobile essere due volere due automobile fare una112 volere giovane affidabile maneggevolissimo volere unaltro personale raffinato elegante nuovo a112 unauto unico grazie',
#  'barilla ritrovi gusto mezzogiorno barilla 93 specialità pasta sempre dente',
#  'atene los angeles storia dellolimpiadere storia dellatletica usa essere conquirre fino oggi 207 medaglia olimpico essere preparare los angeles 1984 avere iniziare kappa sponsor ufficiale squadra nazionale datletico americano wwwkappaorg',
#  'renault 5 rubacuori',
#  'campari soda altro campari soda altro',
#  'acciaio inox vincere corrosione tempo acciaio inox solo cesto vasca nuovo lavatrice candy formula inox lunica tecnologia robotizzato esclusivo candy assemblare cesto vasca inox struttura mano dacciaio solidità eccezionale ecco straordinario durata nuovo candy formula inox costruire sfidare tempo',
#  'michele volere mettere prova fama intenditore whisky vedere riconoscare colore chiaro essere whisky malto gusto pulire potere essere glen grant bravo glen grant avere gusto incomponibile poi essere whisky preferito essere intenditore michele gusto pulire glen grant piacere molto glen grant gusto pulito whisky puro malto',
#  'golia bianca galvanizza lugola golia bianca titillare papilla golia bianca strizzola velo pendulo trovare credere',
#  'contour spiune barba ricco corposo dolce perfetto rasatura dopobarba contour profumo fresco discreto pelle gillette contour nuovo piacere dellartiglio contour',
#  'lu presentare delizio merenda biscotti fiaba fragranto mangiare occhio essere tanto ancora tutta bontà fragranza mille delizia lu',
#  'febal cucine presentare romina power felicità essere cucina febal dare garanzia',
#  'giovane lamore ragazza poi bastare niente guardare stare giù quando essere lontano sempre modo ritornare amare fare telefonata gesto semplice naturale ritrovare stare insieme sentire vicino telefono voce',
#  'quando mulino essere bianco grano essere amare curato rispettare fetta biscottato mulino bianco fare grano solo ingrediente naturale mangia sano torna natura fetta biscottato mulino bianco barilla',
#  'fernet branca conquista gusto pieno maturo dopotavola fernet branca forte generoso raffinato fernet branca linconfondibile fernet branca conquista gusto pieno maturo fernet branca',
#  'avere calore avere provare lamore lallegrio gioventù caldo abbraccio scurderaare sensazione lieto vivrai bello pregiada modello realizzare sogno volere qualità convenienza troverai supermercato pellicceria lodi corso roma 24 aprire domenica mattina lodi centro commerciale piacenza via legnano 3 brescia via vittorio veneto 3',
#  'buono latte nascere fresco certosa galbani preferire tanto essere ricominciare scuola riprendere fatica studio volere qualcosa sostanzioso certosa galbani essere conveniente tavola potere fare tanto porzione certosa galbani aiutare essere sempre forma certosa galbani potere preparare fretta cena gustoso graditare certosa galbani essere facilmente digeribile sicuro essere certosa galbani galbani volere dire fiducia grazie',
#  'mago mago mago galbusera galbusera essere natale panettone galbusera magia natale galbusera mago bontà',
#  'ehi guardare essere tornare marco marco essere vero essere tornare bello sorpresa avere capello disordine capello invece essere posto morbidio nuovo balsamojohnsons posto pronto accarezzare nuovo childrens balsamojohnsons capello posto morbidio johnsonjohnson',
#  'eccolo stazione stellare terra danito due astronauta evviva però essere astronaere essere esportatore galatticio scusa nuovo danone danito formaggio fresco frutta ricco proteina calcio crescita danito danito piccolo fare grande fa grande',
#  'saltaragno nuovo gioco emozionante attenzione ragno essere cattivo potere salvare animaletto catturare ragno toccare ragnatela voglio provare anchio paurare adesso provo attenzione aiuto emozionante divertente saltaragno nuovo gioco editore giochi',
#  'lolio cucina delicare burro dare sapore oggi bonnè primo condimento vegetale completo bonnè volere tanto sapore delicatezza bonnè volere delicatezza sapore dà solo delicato dare sapore insieme bonnè bonnè carne slugare verdura bonnè primo condimento vegetale completo kraft cose buono mondo',
#  'cosa dentro te forse sai piccolo cuore panna cuore panna momento fredelo cornetto algida cuore panna',
#  'borov san marzano borsci san marzano uova fresco zucchero latte borov san marzano borsci',
#  'lacqua minerale ferrarelle nascere naturalmente ricco sale minerale repervescenza naturale nascere venire imbocugnare senza aggiungere nulla acqua minerale ferrarelle effervescente naturale',
#  'stampa stampa stampa stampa essere fantastico essere irresistibile crodino piacere crodino impattare crodino allegro crodino frissare stampa crodino stampa crodino essere fantasia crodino essere simpatia crodino essere allegrio crodino piacere piacere piacere piacere sembrare stampa crodino',
#  'carta igienico due vedere carta igienica scottex vincere convenienza avere molto moltissima carta sceglie fare morbidezza carta igienica scottex essere morbido 10 piano morbidezza oggi essere nuovo formato 10 rotore carta igienica scottex 10 piano morbidezza 10 rotore convenienza',
#  'mondo figlio mollo difendilo insieme wwf fondo mondiale natura',
#  'provaci sbagliera 7up potere perdere fresco 7up scelta naturale sete calmare differenza essere chiaro 7up',
#  'cosa venire mente dire fiuggi acqua sorgere fuoco oligo minerale fiuggi terma casa fiuggi invito salute',
#  'pensa bambino giocare prato pomeriggio giorno incantare contadino tempo lavoro grano durco sembrare tesoro essere mondo aia ogni giorno te essere mondo aia raccolto campo ecco vecchino fare crescere sano tachino aia poveruno essere mondo aia aia carno casa',
#  'aiazzone bialla operazione sposi 83 salotto tessere 350000 salotto vero pelle 690000 salotto tessere 390000 salotto angolare 4 elemento estero 650000 aiazzone bialla operazione sposi 83 salotto 5 anno senza cambiale aiazzone gratis',
#  'air fresh stick up deodorante piccolo ambiente qual essere posto giusto stick up essere posto giusto stick up essere posto giusto stick up deodorante piccolo ambiente tre profumazione duro settimana essere autoadesivo nascondi volere air fresh stick up deodorante piccolo ambiente',
#  'ala zignago fino quando avere bisogno te avere bisogno latte latte ala zignago te nutrire amare',
#  'tarm girare loretta goggi dovere cambiare pastiglia qui certo cambia pastiglia point nuovo confetto charms ripieno gusto morbido grazie',
#  'alemagna presentare krafen krafen qui krafen albicoccare ecco krafen cacao cucca albicocca teggati coccola cacao krafen krafen scoppiare lotta cacao albicoccare te toccare giudicare scegli krafen parere',
#  'autobus allitalio malpensa torino genova fantastico essere stesso volare new york amico carlo invece volare compagnia straniero andare new york magari essere alzare allalba essere andare macchina nebbia allaeroporto avere fare cecchine bagaglia adesso volo carlo questora fare coda poi salire aereo zurigo parigi frankfurt poi scendere aspettare due ora coincidenza grande business classre allitalia vero salotto due fila poltrona carlo invece essere stretto business class pieno gente tre fila stare carlo strettare allitalia circonda comfort',
#  'bravo bravo tanto bravo prere formelli brillo novello inuntro listantire cogli luntro piatti ora brillare sennuore bravo essere qua essere grande qualità bento core coltello cagliote gamia laszello lecetto cromato metallo essere bello vedere brillare sennuore bravo essere qua essere grande qualità bravo bravo limone bravo bravo bravo paglietta saponare brillare limone',
#  'bellezza bicicletta giorno disinvolta vaire assorbento nuvenia potere permetterto qualsiasi movimento grazie speciale adesivo allalto potere assorbente scegli nuvenia nuvenia dare lextra sottile metà gombro pari protezione nuvenia giorno proteggi slip sentirto sempre posto giorno nuvenia muovi sicura',
#  'essere tranquillo essere buono solo sciolto minestra spaghetto verdura bambino mangiare gusto locatelli fare cosa bene',
#  'adesso scoperta merai gusto allaroma kronenbourg kronenbourg scottare gusto kronenbourg beve innamore kronenbourg birra kronenbourg gusto amerai',
#  'porto qui tenere qua mettere qui porto scuola portare qua nessuno rinunciare avere dente alito sempre ok ufficio dovunque sempre ora dentifricio forhans tascabile vero spazzolino componibile trovato ricambio omaggio ricordare vero gioiello completo tascabile essere dentifricio forhans',
#  'invernizzi gim autogorgonzola dorigine invernizzi idee fresco campagna',
#  'vita dieta crusken aiutare tre quattro compressa prima ogni pasto attenuare senso fame tipico dieta povero fibra aiutare lintestino lavorare bene assorbere meno caloria vita pesante crusken snellire compressa piccolo senza zucchero crusken aiutare stare dieta pere chilo restare forma crusken farmacia garantire midy crusken farmacia garantire midy',
#  'kutiba kutiba bravo grazie ehi essere finire punto nero spariti essere kutiba problema cutaenei giovanile sistema completo kutiba prima kutiba 1 pulire lefficacia kutiba stare microgranulo essere microgranulo giorno dopo giorno pulire pore profondità liberandolo punto nero sedimente grasso poi kutiba 2 proteggia protegge pelle fino allapplicazione successivo sistema kutiba lunico microgranulo laboratorio farmaceutico angeline',
#  'peccato gola fare volentieri spesso pagare dopopranzo unalimentazione sano moderato essere sempre consigliabile tuttavia quando bruciore acidità pesantezzo stomaco fare sentire digestivo antonetto aiutare buono gusto erba naturale essere gradevole masticare prendere senza acqua digestivo antonetto laiere stomaco leggi reattentamente avvertenza',
#  'squisito latte puro cacao zucchero candidare farino altro cosa buono essere squisito budi parmalat offrire gusto cacao giandugliare creme caramella vaniglia budi solo essere squisire contenere né colorante né conservante budi essere alimento ideale ora essere prezioso amico dessert importante essere sempre squisire budi',
#  'postalmarket festeggiare 25 anno catalogo mese postalmarket edizione speciale trovare edicola',
#  'nuovo a112 sapete essere segreto essere unautomobile essere due giovane economico scattante personale elegante raffinato nuova a112 due auto unauto buona notte',
#  'shape forma pensare shape shape ridurre peso nutre correttamente poi disfancheggolosi potere scegliere shape vaniglia lampone nocciola toffè cioccolato shape welcome shape shape forma nuovo dietetico americano completo bilanciare farmacia',
#  'sottotitoli creare comunità amaraorg iaocchio scegliere dreher',
#  'secondo cosa preparare carne simmenthal carne simmenthal secondo certo essere buono carne magro gelatina carità portare tavola secondo figlio poi lavevo abituare certo piatto verdura vedere essere secondo gustoso mmm bello idea simmenthal piacere mangerao giorno cosa avere dire caro simmenthal essere proprio grande secondo secondo carne simmenthal gusto davvero speciale',
#  'fare festa nu buono gelato gelati sanson gustare pace gelato vieni sanson vieni sanson benvenuto sanson avere segreto',
#  'quando aprire philadelphia quando spalmo philadelphia avere sapore delicato fresco morbido cremone cura dentro sentire sapore kraft cose buono mondo',
#  'passato dovere prendere scottare pelare passare oppure dovere prendere pomi ’ passato pomodoro fresco pronto essere insaporire oggi dunque pomi ’ pomi ’ essere parmalat',
#  'findus scegliere momento giusto raccogliere pisello findus mantenere naturale freschezza tenero dolce sapore grazie metodo semplice naturale freddo famiglia potere gustare dolce tenero fresco pisello lanno findus stagione pisello fresco finire',
#  'tenga grazie birra essere talmente buono genuino ancora buono quando essere fresco produzione qui essere proprio birra fare italia sapere sentire sentire essere fare qui pane essere buono qui vicino forno birra produrre italia arrivare bicchiere senza avere fare lungo viaggio spostamento capire freschezza meditate gente meditare birra sai cosa beve',
#  'quell colpino morbido essere nuovo lavare perlana ammorbidente comprore subito morbido essere nuovo lavare perlana ammorbidente volere wow morbido nuovo lavare perlana ammorbidente fantastico morbido essere nuovo lavare perlani ammorbidente te rubare perlana ammorbidente passaparola',
#  'sottiletta piccante piccante dolce piccadolce piccadolce kraft nuovo sottiletta gorgonzola sottilette piccadolce kraft cose buono mondo',
#  'scoprire scopro avere gurre vivo chinotto sanpellegrino chinotto sanpellegrino laltro modo bere scuro',
#  'parola dottore caselli consiglio damministrazione situazione essere grave latmosfero ateso lingegner costa essere addirittura affranto eccolo felice polo ragno ora dottore losi dottoresso gatti riappaiono smaglianto ragno ragno ragno riaccendere lottimismo polo pullovere maglietta tshirt ragno laltra maglierio desiderio stare meglio',
#  'comandante comandante radio mare essere radiosquash lunico radio galleggiare vincie concorso bagno schiuma doce schiuma vidal',
#  'nuovo paulista stupendo stupere volere sapere segreto laiuta laiuta laiuta dire segreto paulista tornerare avere dire aiuto capito gravisti dolata te dovere dire aiuto arrivo direzza aiuto avere sognare certo caro segreto paulista essere salvo nuovo paulista stupendo dire via tv prendilo caldo lascare',
#  'totocalcio essere entrare nellera computer ora lautomazione totocalcio essere facile dica signore certo essere molto facile nulla ricopiare mettere croce sulluno sullex sullio sistemista solo schedina potere arrivare fino 4096 colonna essere sicuro bastare solo schedina ricopiare pensare computer certo computer calcola ricopio convalido ecco fare schedina totocalcio servizio sport',
#  'chevron nome ogni strada ogni stagione vai sempre bene quando scegliere chevron chevron pensare te',
#  'pium bavare giù dappertutto cerano fantasmine inseguivare essere videogioco super certo essere atari cambiare cassetta cambiare gioco colpire davvero attaccare tv punto fare voglia giocare mettare avere chiudere videogioco atari essere facile volere difficile fare fantastico sperare comprino atari magari prova atari niente divertire wow atari',
#  'sibille volte giuro rivedremo prestissimo quando prestissimo ciao ciao presto vicino amare penso diamore credere amore eccomare futuro essere scrivere sibille sibille sperlari',
#  'stati uniti freedent primo chewing gum attaccare dente sicuramente avere molto problema lavoro chewing gum attaccare dente avere scegliere freedent freedent avere buono sapore menta rinfrere lalire soprattutto attaccare lavoro dentista essere importante avere problema dente freedent piacere quattro gusto freedent primo chewing gum attaccare dente lunico stati uniti feel free chew freedent freedent gum',
#  'scarpine babyzeta vendere solo farmacia primo passo sano sviluppo piede speciale plantario sostegno posteriore scarpine babyzeta favorire sano sviluppo pedino figlio babyzeta scarpina zambeletti',
#  'combinato ocean roba uomo superuomino metà frigo servire subito metà congelatore servire qui alleternità',
#  'pranzo eccezionale davvero spingere adesso piatto lavare piatto lavare nelson piatti volere lavare nelson piatti fare veloce velocissimo bastare poco essere concentrare ecco qua due quattro cento mille piatto essere pulire nelson piatti essere velocissimo piatto essere pulito piatto piatto nelson piatti andare lavare nelson piatti confezione due cinque chilo dichiarare pulito',
#  'essere arrivare sveglia biscotto felice mattino mela porto scuola tardare ufficio stare meglio tavolo sai potere avere bastare raccogliere 50 punto oggi trovare nuovo confezione speciale 400 grammo felice mattino motta dare sveglia anzi te regalare',
#  'martini rosso quando volere volere volere martini rosso martini essere',
#  'primo personal plus spermicida ottenere sicuro effetto anticoncezionale personal plus spermicida sicurezza',
#  'presentare merci fori tavolettare dentro invitante varietà squisito cioccolare carta oro pronto offrire unoccasione lasciartela sfuggir ogni attimo essere gioia pienamente gustar merci idea tondente caffè nocciola latte dire merce merce cioccolato nuovo style tanto gusto gusto unaltro idea lazzaroni',
#  'buongiorno frescheggere buongiorno fioragna fiorello solo latta panna fiore essere ricco essere delicato puoi gustare solo dessert preferito prova fiorello oggi stessù dira buongiorno frescheggere buongiorno fioragna locatelli fare cosa bene',
#  'gressino essere molto fragile tonno rio mare essere molto tenero tenero tagliare gressino tonno rio mare',
#  'bon ciok bon ciok bon ciok bon ciok bon ciok avere bisogno tanto energia preparo bon ciok bello uso dolce gelato festare casa bon ciok bon ciok ben cioccolato caldo',
#  'yomo banana piacere sai piccolo dicevo sempre yomo dire yogurt sapere yomo essere nome marca yomo clingmuso dentro essere cosa fare bene tanto vero frutta niente artificiale conservante aromio invece yomo avere tanto fermento lattice beh te spieghare quando grande yomo limportanza nome',
#  'numero linea grintare arriva peugeot 205 gt 170 dieselre 155 peugeot 205 numero benzina 950 1300 dieselre 1700',
#  'oggi uomo nuovo questuomo essere padrone basic prima unico enciclopedia dellinformatico mino personal computer primo fascicola essere unicola 2000 lira regalo secondo copertina primo volume basic linguaggio computer armare curcio editore',
#  '7 febbraio sintonizzare sullemittentire radiofonico importante città giorno legamento concessionario ford indovire quiz vai concessionario ricevere subito regalo linvire ritornare domenica 13 febbraio carnaval fiesta smascherare targa vinci nuovo fiesta quad essere bene 10 vincere',
#  'forte agile economico ecco turboleggeri volvo 95 133 quintale volvo turbo entrare città turboleggeri volvo finalmente ciò volere',
#  'fido gatto bocconcini carne pesce fido gatto essere pranzo goloso digeribile ricco vitamina proteina indispensabile salute gatto fido gatto ogni gatto andare matto',
#  'pronto asilo liceo upim elementari elementare upim elementari medio upim elementari liceo upim medie elementare upim asilo liceo vedere essere upim exclusi bambino scuola upim tenere banco dallasilo liceo prezzo upim sempre',
#  'smog nemico insidioso tenace instancabile giorno dopo giorno corrode smog andare togliere pelle evitare danno irreparabile giorno dopo giorno avere creare latte irradiato innoxare latte irradiato innoxa pulire fondo pore togliere smog latte irradiare innoxa ridono viso giovinezza giorno dopo giorno',
#  'ehi bebire baby doso shampoo delicato baby doso delicato baby doso baby dozore baby doso essere modo badedas essere shampoo doso dopo doso giorno baby doso essere shampoo giusto te baby',
#  'essere prova pratico dimostrare 25000 lira potere comparare tanto idropitturo casacolor dipingere superficie grande stanza molto spazioso scegliere 15 magnifico colore casacolor essere lavabile traspiranta pensate bastare 25000 lira fare nuovo stanza soffitto compreso casacolor lidropitturare progredito tecnologia max meyer naturalmente casacolor tanto colore poco soldo',
#  'solo cracker riconoscare tramite gaillard pacco nuovo premium saiwa buono buono avere 23 ora lievitazione naturale lievitation buono protetto pacco corazzato darto sempre massimo fragata oggi premium saiwa offrire 10 porzione nuovo pacco corazzare mezzo chilo mezzo chilo for nation',
#  'cosa importare piovere fare freddo umilità giusto sostegno giusto calore dr gibaud venite freddo essere divertente quando essere proteggere cintura dr gibaud donna bambino luomo ognuno gibaud giusto sostegno giusto calore',
#  'nuova copiatrice portatile canon pc20 veramente piccolo nuovo stampa tre colore carta colorare ogni tipo formato eccezionale manutenzione nessun controllo essere possibile cuore eccolo parte consumare dentro cartuccia intercambiabile rivoluzionaria chissà costare meno due milione essere geniale nuova canon pc20 genio fotocopia',
#  'bauli essere segno bontà segno tradizione segno novità bauli essere segno festa bauli essere segno',
#  'invernizzi mozary mozzarella mozzarella formaggio fresco',
#  'ufficio presto ora dixan premiatissima 83 biglietto trovare solo fustino fustone dixan potere vincere 500 milione lanno scorso biglietto vincente essere sfuggire questanno dovere essere ogni costa pronto essere arrivare camion perfetto fate scaricare fustino toccatelo occupare personalmente dixan premiatissima 83 affare mezzo miliardo',
#  'buono dentifricio pasta capitano contenere ingrediente naturale fluoro dare pasta morbido cremosa ecco pasta capitano avere fiducia sempre',
#  'senza zucchero senza zucchero gurre gurre bibite dietor sanpellegrino provatevi',
#  'betaglio carne provenienza nazionale essere qualità volere vino proprio speciale perfetto cena stasera tornare ancora coop essere proprio conveniente certo coop essere unassociazione consumatore coop comprare vendere essere essere stesso cosa',
#  'azione kway kway vento pioggia kway lactione',
#  'mamma mamma essere arrivare bilancia crackers motta babbo avere pancia glielha dire bilancia quattro crackers unarancia bello bilancia volere anchio bilancia potere essere 40 bilanciapunte trovato confezione crackers motta due tipo salare superficie farina integrale grande richiesta concorso vinci lancia continuare fino 31 agosto crackers motta peso vincente',
#  'jb scotch whisky svitare amare',
#  'cera volta spiga buono grano donare donare picco dorare grazie spiga racchiubire ricchezza grano intero buono fragrante fetta buitone farina integrale buone fare bene fette biscottate buitoni vitaminizzare fette farina integrale fetta dolce latte miele buone fare bene',
#  'dolce euchessina saggio consiglio conoscete regola tre m movimento camminare pedalare mangiare sano vario masticare bene lungo organismo potere funzionare meglio lintestinare essere ancora sbogliato dolce euchessina due pastiglia euchessina sera mattino sentire meglio sapere ante dolcezza ottenere leggere attentamente avvertenza',
#  'disastro sporco mollo qui volere dora liquido bucato mano flacone due litro dora bucato mano essere liquido liquido dora essere liquido finalmente cambiare avere pensare nelsen',
#  'essere nuovo volkswagen golf bello spazioso contenuto consumo veloce golf nuova golf avere migliorare meglio vicino concessionario volkswagen',
#  'sapore sempre cercare piccolo grande momento morbido leggero fresco davvero unico essere gusto heineken unico fantasia unico allegria essere gusto heineken sapore certo momento potere essere heineken',
#  'bello jazz vero fare pensare allamerico magari parente amico avere là bastare pensare bisognare rendere felice telefonata magari ebbene italcable bastare fare prefisso numero telefonico essere subito ok oltretutto costare poco pensate tre minuto teleselezione new orleans costare meno disco certo essere unaltro musica',
#  'carlo bistefano sbaglere sempre cosa fare panettone altro essere stare impastandole volta impastano cinque volta restare dolce soffico essere pazzo panettone cinque impasta solo rosso duovare addirittura miele essere babbo natale',
#  'signore risparmiare dovere rinunciare morbidezza vernel ok oggi vernellone quattro litro autentico vernel due tre quarto quarto essere gratis pagare solo tre costare bucato menù cento lira rinunci morbidezza vernel oggi vernellone vernelone vernelone risparmio morbidezza imbattibile ok',
#  'doria doriano cracker bontà guarda bolla ragazzo bolla bene lievitare scheggiamolo doriano essere croccante sbriciolare parere piace essere vedere ruba posto tavola doriano essere cracker giusto allieritazione naturale meraviglioso digeribilità essere soffio cracker doriano salatine doria doria bontà essere casa',
#  'sai andare cominci rg gillette seditare meglio giusto essere posto ok bilama fare sattrattare bilama incominciare comincia bene cominco rg gillette',
#  'quando immaginere fare colorare trasformare prendere vita te quando pellicola essere fare colorare trasformare kodak solo kodak avere creare quattro nuovo pellicola kodakolor vr kodak bello sapere',
#  'fresca neve chiaro fresco sprite chiara cielo guardala vedere fresca sete scoprire gusto lai sprite chiaro sprite fresco sprite coglia ancora gusto lasciare sete limpida chiaro fresco sprite sete limpida chiaro fresco sprite',
#  'fonzies croccantine mais formaggio costo forno lumacato croccato croccato croccare fonzies mollicato croccato croccato croccare fonzies croccati fonzies originale fonzies essere solo scritta fonzies',
#  'carica inquadra metti fuoco scatta kodakolor quando pellicola essere kodak essere bello sapere',
#  'grandi buste arena essere chilo pulito pulire verdura surgelato verdura fresco lanno ottimo qualità buona confezione piccolo bello convenienza sempre arena insomma grande busta piccolo prezzo grandi buste arena pizelli pagiolini finaci patate fritte minestruri arena',
#  'mani arrossare freddo sos glysolid mani segnare giornata sos glysolid glysolid riduola morbidezza mano crema glicerina glysolid specialista mano',
#  'selsun blu essere shampoo antiforfora selsun blu potere essere usare normale shampoo azione efficace delicato dare capello sano morbidio bello selsun blu essere blu essere dedicare essere efficace avere selsun blu essere segno avere forforare vendita solo farmacia',
#  'sai grande novità oggi coccolino concentrato tre volta concentrare pratico guarda solo terzo dosaggio dare morbidezza coccolino essere coccolino dare morbidezza sempre vantaggio coccolino concentrato costare molto meno coccolino concentrato morbidezza sempre ancora meno caro',
#  'buonasera scusate intromettere essere solo ricordare potere essere bello rientrare sera casa essere attendere libro essere affatto vero essere solo libro aiutare creare mondo fantastico stare cercare fare trovare affascinante fatelo grazie avere ascoltare dimenticavo prestare libro regalatelo estate mondadori leggere essere moda',
#  'buonanotte estitichezza buonanotte verecolene quando occorrere regolare intestino dolcemente verecolene complesso delicato azione lassativo leggere attentamente avvertenza',
#  'bello tavola trovare tavernello assieme ragazzo stare bere buono vino qualità tavernello sapere stare tavola diventare subito nuovo abitudine quando vino essere buono qua dentro conservare meglio problema meno tavernello nuovo vestito tradizionale gusto san giovese trebbiano tavernello essere prodotto firmare consorzio corovin',
#  'momenti polaroid scoprire magia momento polaroid scatta guardare festa essere ancora bello essere tempo regalo vesti natale magia colore lallegria momento polaroid polaroid 630 dosaluce lira 79900',
#  'bene bene buongiorno lavoro nobilito caldo debilitare ufficio smobilitare dovere fare installare ventilatore subito vortice elettricista vortice ventilazione riscaldamento',
#  'stupitevare defendi brother essere facile lavorare maglia crowd defendi presentare nuovo macchina linea 2000 lavorare bene imparare presto scuola maglieria presso concessionario defendi signore vorre provare nuovo linea 2000 volere consegnare porta profumo grande stilista nodo vendere italia',
#  'rosso martino martini rosso essere lora martini rosso martini rosso volere volere volere martini rosso essere',
#  'quando incontro amico fare barbaro zucca',
#  'tavola bisognare essere moderare talvolta mangiare troppo necessario poi vita sedentario consentire smaltire superfluo appesantire corpo fare aiutiamolo fave fuca prodotto vegetale base alga marino fava fuca regolare lintestino fave fuca organismo puoi avere linea agile snella buono funzionamento dellintestino leggere attento avertezza',
#  'attente sole bianco bello bianco sessanta grado sole bianco semplice detersivo quasi persona lavare ingegno mostruoso temperatura pregare',
#  'ricordare lho mettere salvelox salvelox numero cerotto',
#  'esercito cuoco casa bravosimac secondo velocità diverso ogni funzione lunico lama affettatore regolabile fare ricetta mondo libro bravosimac bravosimac secondo macchina cucina completo mondo',
#  'migliaio anno fa antico civiltà scolpivare roccia passato preservare futuro stesso motivo 1956 lindustria televisivo mondiale registrare avvenimento secolo videocassetto scotch emozione videocassette scotch videocassette scotch memoria tempo',
# ...
#  'due modo friggere essere meglio essere super friggitrice elettrico tefal acciaio inox avere filtro antiodore sprecare stesso olio tantissime frittura frigge senza schizzo coperchio chiuso comodo cestello fritti croccante dorato soprattutto leggerare finalmente fritto intelligente friggitrice elettrico tefal piccolo grande famiglia vita fare',
#  'belle fuori perfetta dentro pelole bello fuori perfetta dentro essere solo acofur firenze via ponte mosso',
#  'ceccherini te fare mia6 combinazione lavorare legno offerta speciale mia6 dare pialla filo pialla spessore presa verticale bucatore mortase sega circolare carrellino inclinato te mia6 pratica combinare oggi ceccherini',
#  'pellice donna modelli tentazionere pelole dunque avere visone americano grande pellicceria viareggio',
#  'scuso signore pensare appartamento montagna avere progettare boscolungo cuore betone essere bilocale completamente arredare fino stoviglia soluzione comodo razionale prevedere facile trasformazione giorno notte boscolungo lusuoso hotel residence piscina discotecare ristorante cinema prezzo conveniente venire trovare boscolungo telefoni 0573 60 376',
#  'apri occhio ventanni fiat lotti essere meglio',
#  'germania chiamare kuss dire italia iaaa bacio essere birra germania dire henninger henninger birra dire francoforte',
#  'sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony sintony ayudič aleo sintony aieo sintony aieo sintony aieo sintony aieo sintony aieo sintony aieo sintony aieo sintony aieo',
#  'logic cip bit lock linguaggio nuovo futuro essere presente computer corso pratico informatica personal mini computer insegnare fin subito utilizzare linformatico studio lavoro casa tempo libero modo semplice divertente entra mondo dellinformatico computer edicola primo due fascicolo uneccezionale offrire acquistare computer commodore computer essere proposta deagostini',
#  'fortunare cucina febal pratica razionale bello febal pretende cucina felicità essere cucina febal dare garanzia',
#  'aiax tornado bianco nuovo profumo fresco vediamo ehi taglio subito grasso segnaccio essere proprio aiax certo forza aiax nuovo profumo fresco',
#  'postume traumatico reumatismo artroso curare lenergia natura magnetoterapia ronefor campi magnetico pulsare cura affettuare centro ronefor italia consultare elenco telefonico',
#  'bere te pirandello sempre thè lipton essere unabitudine essere amico fare accompagnare momento pausa poi essere rito thè lipton beve essere sempre speciale',
#  'sorridi scoprire nuovo modo usare shampoo sapone bagno schiuma essere magic soap dosatore domestico magic soap essere comodo moderno ricaricare attimo applicare senza forare soprattutto servire giusto doso magic soap essere disponibile 10 giovane colore costare solo 14900 euro magic soap essere prodotto polymec vendita presso casalingo arredobagno idrosanitario',
#  'prodotto specifico troppo liquido scivola incrostazione nemico delligiene abitare tranquillo oggi sator sator fino 20 volta denso spazza via incrostazione sator niente efficace ligiene butter',
#  'grandi buste arena verdura fresca prezzo molto conveniente arena grande qualità piccolo prezzo grandi buste arena piselli patato spinace minestrone tanto altro verdura',
#  'five viaggi presentare legitto cleopatra essere film essere nuovo favoloso programma five viaggi portare leggendario terra farauli nido scoperta valle rei stile five viaggi rivivrere mitico egitto volare egiptero informazione prenotazione presto agenzia viaggio essere uninitiativo five viaggi',
#  'essere arrivare amico mattino novità paveso primo colazione qui cominciare nuovo storia biscotto giusto equilibrio bontà nutrimento nascere dallesperienza paveso amico mattino nuovo storia biscotto pavesi esperienza antico bontà motivo',
#  'fazzoletto scottex essere ancora morbidio morbidio fazzoletto fazzoletto scottex posto morbido mettere naro',
#  'oerre ventilormille aspirare ventilare oerre aspirare ventilare riscaldare oerre padrone dellario',
#  'avere ricevere regalo caro essere fare regalo bello senti avere bello casa lavoro piacere moglie affascinante poi oggi essere sabato parere ridassare regalo chivas regal prestigioso raffinato regale whisky cosa meglio serata casa chivas regal regale whisky',
#  'italia essere molto ottimo spumante essere brut tanto ottimo brut essere metodo champenoise ottimo champenoise rimanere provengere solo vigneto trentino anzi mmm castel monreale raro trovare castel monreale brut poco poco',
#  'amaro montenegro sapore vero vita essere fare soddisfazione gente cosa unico lamaro montenegro amaro montenegro avere sapore sapore sbagliare riconoscare subito amaro montenegro sapore vero',
#  'magia andare vero potere piuttosto fare masticare dentiere avere problema usare crema adesivo chiamare kukident prima ogni pasto usare ladesivo ogni pasto basta mettere volta restare ora crema adesivo kukident formare sottile velo protettivo fissare dentiera lungo ogni punto finalmente bravo lhai provare',
#  'mamma dovere badare famiglia quando occorrere sera guttalax avere bisogno guttalax lassativo goccia avere doso giusto ognuno guttalax essere odoro sapore leggere attento avvertenza',
#  'barbie nuovo bagno termale mille bollicine essere fantastico bolla continuare riprodure barbie essere entusiasta dopo bagno termale eccola allistitere bellezza unaccurata mettere piega shampoo spumeggiante mere allultimo moda barbie essere splendido ore meraviglioso bagno termale barbie listitere bellezza',
#  'numero 1 bello amato italiano certo applauso successo fare sempre molto piacere però bisognare meritarselo scavolini fare cucina amare italiano belle curare ogni particolare completo soluzione adatto ogni famiglia materiale fare durare cucina scavolini amato italiano',
#  'qualcuno ruba fiore te sotto sotto impulse nuovo fiammante impulse temptation parfum deodorante',
#  'piacere certo baby shampoo johnson essere nascere essere delicato lacrima nato solo delicato te baby shampoo johnson delicato',
#  'sport fare capello dovere lavare spesso altro quindi shampoo essere neutro neutro neutro roberts',
#  'maxilattina',
#  'finito tempo dentifrico vecchio tubetto benefit ora essere flexitubo indeformabile spremi qui qui flexitubo avere sempre bellaspetto rompere uso fino fondo benefit famiglia dentifricio',
#  'vim liquido vim liquido superammonio concentrato pulire spazio fondo essere sempre sicuro pulito sicura vim liquido forza vim liquido senza pietà sporco sporco',
#  'essere proprio a112 avere ancora pagare lira zero lira anticipo avere ristormiare mezzo milione capisce pari mezzo strada capisco guardare strada essere cinquecentocinquantamila lira risparmio pago 48 mese rato sava 35 riduzione interesse ascolti 35 riduzione interesse unoccasione sava a112 15 maggio 15 giugno',
#  'nonna guardare uh qui cracker certo doriano doria preparato solo olio vegetale ricetta nannina essere ritossale buono farino doria bontà essere casa',
#  'dire soflan dare massimo sicurezza dire soflan dare massimo sicurezza ecco esempio golf avere regalare marito natale tenere molto essere soltanto delicare lana questintare pelle soflan avere continuare lavare avere rimanere sempre morbido sofofe colore essere vivaci splendente dire sinceramente soflan sentire sicuro soflan liquido nessuno dare sicurezza',
#  'dire telefono cioccolatissimo budino royal sai rispondere budino pronto capire dire essere sempre solito bontà mondo royal',
#  'presentare colgate fluor minerale dispenser colgate fase iniziale carie potere essere fermare quando dente perdere minerale potere iniziare carie colgate fluor minerale ricco minerale restituire dente minerale perduto fase iniziale carie potere essere fermare colgate fluor minerale tubo dispenser',
#  'gabriella dorio campione italiano mezzofore olimpiadi donna attivo cura proprio corpo deodorante rexona naturale sicurezza grande deodorante rexona piantare asso',
#  'signore signore ecco protagonista grande concorso street magic fruit succhio frutta sprint gusto diverso scheda cancelle vinci potere dare frutto rossi personal computer sinclair potere vincere frutto rossi participate centinaia personal computer migliaio succo sprint gratis plasmon sprint',
#  'lyso form casa pulito sicuro disinfettare puoi usare ogni giorno pavimento piastrella superfice lavabile lyso form casa pulito sicuro disinfettare',
#  'dire vienare qui mapetite morbido cerita creme caramel royal bionda tuomino bontà mondo royal',
#  'buono buono lavazza essere lavazza essere lavazza caffè avere piacere essere buono piacere essere essere lavazza mmmh bue buono sfido essere buere qualità oro lavazza pacco 200 400 grammo gustalo bellissimo caffettiera carmesitare poi lavazza essere lovante giù titilesso',
#  'dire quando avere setia essere molto semplice bere linfa royal dire dire domani bontà mondo royal',
#  'primo dora essere sentire morbido mira ambra glicerina purezza trasparente ricca glicerina ricco morbidezza mira ambra glicerina saponetta cosmetico naturale',
#  'giorno bello andare insieme volentieri mezzogiorno dimagrisco bionorm drink sera lho voglio fragola vaniglia cioccolato caffè bionorm drink dimagrire pesare',
#  'bello dia provvista sugo pomodoro genuino incontrare monna pasto fare bellinchino tre minuto cottura lincontro due cuore monna pasto provvista cucina son signore provvista sugo de rica conquista cucina',
#  'galletto amburghese vallespluga presentare bene essere leggero digeribilissimo dare tucco classe menù galletti amburghese vallespluga essere giovano veloce cucinare ecco fare teneri grasso diverso pollo galletti amburghese piacere certamente attenzione essere gallere amburghese avere scudetto rosso vallespluga',
#  'essere essere bene bagnoschiuma mantovani bagnoschiuma neutro mantovani rispettare natura pelle',
#  'avere mangiare confettura sapere papà avere fine cena essere vero confetture santa rosa frutta fresco pezzettone piaci grande confetture santa rosa piaci grande',
#  'jocca essere diventare piacevole abitudine essere fresco delicato essere fiocco latta essere tanto magro avere meno 6 grasso linea latte jocca fresco gusto magro linea',
#  'oggi inizio semifreddo cameo caffè semifreddo cameo preparano',
#  'semifreddo cameo preparalo',
#  'sai dovè casa diavolo piastrella laltrare ecco lorigo diavolo sporco detersivo sguazzare spazzolone fare solletico oggi avere 100 grado forza vivo vapore 100 grado arrivare sporco disgregare grasso sgrassare macchia smacchiare 100 grado vapore garantito fiseldem oggi pulistiro gratis',
#  'conicare cinque minuto girare pronto occhio arrossati dovere fare primo piano prendere collirio stilla borsa ecco due goccia stilla via stanchezza occhio sicura certo collirio stilla essere farmaco sai riposa decongestionare soprattutto bruciare stilla potere avere occhio sano riposare occhio sano stilla',
#  'ragazzo acqua danone svegliarmi mattina pesare quando bello danone mare giù doccia molto freddo essere fare pesare bilancia senza dirai danone magro danone magro danone invitare prova prova diventa ragazzo acqua danone scegli danone altro',
#  'punto weight watchers linea sete legge avvertenza',
#  'avere realizzare unintervista interessante fegato andare quando cambiare stagione essere doppio fatica cambiano abitudine lalimentazione potere capitare mangiare male troppo troppo poco qualche consiglio almeno moderare lalimentazione quando necessitare amaro medicinale giuliani digestivo aiutare fegato',
#  'avere polpa dovere prendere pomodoro appena cogliere velarlo tagliare oppure aprire polpabello bello buono polpabella star bella buono appena tagliare',
#  'esempio oggi avere fare biscotto poi mettere vasetti durare settimana biscotto fare casa casa forza pastamatic biscotti pasticcino torta crostare potere fare forza venti braccio',
#  'santàl tutta frutta punto bastare santàl tutta frutta punto bastare',
#  'moschettiero pulito spontex presentare splendore giornaliero splendore giornaliero mettere fine sporco acciaio alluminio lato argento lucido paglietta senza ruccine senza odore lato spugno sciacqua asciugo splendore giornaliero spontex nuovo splendore pentola fornello splendore giornaliero linea abrasivo spontex',
#  'buongiorno ometto dormire tanto bagnato ora avere scoprire pampers maxi plus tenere asciutto finalmente ragione coshai maxi plus oltre speciale strato avere molto materiale assorbente guarda bagnare tanto tanto maxi plus essere assorbente garantire riserva asciutto essere incredibile pampers essere massimo nuovo maxi plus massimo dellasciutto pampers',
#  'dire soflan dare massimo sicurezza dire soflan dare massimo sicurezza essere camicia notte qui laltro tenere molto essere essere regalare marito quindi tenere molto lavo proprio amore usando soflan mantengo tale quando lha regalare sempre bello oltre essere naturalmente pulito soflan lavatrice nessuno dare sicurezza',
#  'fare insieme torta frutta nuovo bontà dolce genuino mettare ingrediente fresco cammeo dosere resto gelatinare cammeo cammeo fare tanto torta squisito cammeo bontà dolce genuino cammeo',
#  'essere dimagrito ecco cosa avere fare laura slimfast consiglio dietetico avere perdere chilo troppo gusto cacao nuovo cappuccino cosa avere fare laura slimfast essere farmacia fallo',
#  'radiosquash vidal volta scappare questanno vincie compri prezzo fantastico sempre solo bagnoschiuma docciaschiumere vidal',
#  'dire crema tavola royal essere sformabile re diventare abile pensiero profondo bontà mondo royal',
#  'nuovo olà dare pulito completo pulizia freschezza insieme nuovo olà penetrare fibra pulire fondo aggiungere capo fresco pulito campo fiore nuovo olà fresco pulito campo fiore',
#  'mamma novità lines misura grande super bambino grande fare tanto pipì misura grande super largo alto vita assordente lines misura grande super lines svelto elastico',
#  'vitamina deodorare vitamina deovit eliminare lazione ossidante batterio sudore restare odore deovit deodorante famiglia deovit idim',
#  'galletti amburghese vallespluga presentare bene essere leggero digeribilissimo dare tocco classe menu galletti amburghese vallespluga essere giovano veloce cucinare ecco fare tenero grasso diverso pollo galletti amburghese piacere certamente attenzione essere gallere amburghese avere scudetto rosso vallespluga',
#  'dovessare fare male salvelox salvelox numero cerotto',
#  'barilla fare sentire sempre dente',
#  'sai grande novità oggi coccolino concentrato tre volta concentrare pratico guarda solo terzo dosaggio dare morbidezza coccolino essere coccolino dare morbidezza sentre vantaggio coccolino concentrato costare molto meno coccolino concentrato morbidezza sentre ancora meno caro',
#  'finito ecco fare camicia sbagliare candeggio uso ace tovaglia essere perfetto ace smacchiere fondo senza danno ace smacchio fondo senza strada oggi ace festeggiare ventanni regalare splendido tovaglia puro cotone graziosa legge istruzione speciale confezione ace compiere ventannio regalare ventimila tovaglia',
#  'grande novità unilines lassorbente linus ripiegare bustina singolo sigillata unilines essere igienico pratico discreto bella idea unilines',
#  'mini linea rinocciare nulla mini linea volere restare snemma linea sapere sacrifico avere fare sacrificio dimagrisco seguire metodo alimentare dottoressa tirone vedi mangio cibo ricco variare mini linea essere facile mini linea contenere tavoletta vegetale tisana erba seguire metodo dottoressa tirone essere vero dimagrire essere inutile saltare pasto bastare seguire unalimentazione bilanciato naturale mini linea rinunciare']

# %%
for key, value in dictionary.items():
    dictionary[key] = ' '.join(value)

# %%
dictionary['1980_1984']
# Out:
# 'essere persona potere permettere stare casa quando fare brutto tempo primo sintomo raffreddore influenza presto aspirinare aspirina andare bene presto seguire attentamente avvertenza modalità duso qui volere black decker potere forare materiale accessorio trasformare sega circolare perfetto levigatrice dirai lho fatto black decker accessorio trapano black decker partire 33200 lira natale gamma black decker trovare sempre regalo utile regalo durare sempre black decker carciofo ricco qualità naturale cynar aperitivo base carciofo dopo pranzo cynar liscio bere liscio cynar essere ottimo amaro scelta naturale volere raffreddore uninfluenza guardare avere qualcosa te cebiopirina effervescente vitamina raffreddore influenza male testa primo sintomo cebiopirina effervescente vitamina cebiopirina effervescente cebiopirina effervescente essere prodotto bracco seguire attentamente avvertenza modalità duso linea graziella simpatia due ruota buongiorno fabio ciao fabio linea graziella simpatia due ruota buongiorno stefano buongiorno signorinare linea graziella simpatia due ruota graziella essere prodotto carnielli prodotto ligiene intimo certo parte potere fare vedere dare risultato piacivolo potere fare vedere prodotto essere chilly soluzione salviettino ligiena intimo provalo vedere citizen quartz citizen quartz citizen quartz orologi raffinato orologio pratico orologio elegante ogni situazione ogni età incredibilmente sottile incredibilmente perfetto citizen quartz citizen gioielli quarzo adesso sapere cosè dentifricio dentifricio speciale formula scientificamente avanzare nuovo colgare fluor mfp fluoro cosa fare immaginate gessetto essere dente fluor mfp vedere fluor mfp fissare dente rinforzare colgata fluor mfp unaccurato pulizia dente azione igienico aiutare prevenire lacquario dare sempre lalire presto nuovo colgare fluor mfp cosa dietro famoso sorriso turbo essere naturale sapore bocca fresco dare famiglia piacere lavare bene però mica male casa piacere sapore boccare fresco turbo stare meglio quando bocca fresco sapore menta appena colgere casa piacere sapore boccare fresco turbo fabbri 75 anno bontà frutta fabbri liquore proposta fabbri macedonia fabbri 75 anno bontà fin primo poppare bimbo avere bisogno protezione puoi usare casa protezione milton solo sterilizzare poppatoio tettarella milton proteggere infezione sicurezza protegge infezione delicatezza protezione piccolo grande potere usare milton casa milton proteggere infezione leggere attentamente advertenza avere mangiare confettura sapere confetturare santa rosa tanto bello frutta fresco peccatone né colorante né conservante santa rosa frutta fresco zucchero ragazzo nutrimolo intelligenza negoziante regalo ladesivo santa rosa potere vincere super sacca santa rosa confettura santa rosa paola fare tardi cinema stare fare bello vedere molto molto bello nuovo camay cosha nuovo avere nuovo profumo delicato prezioso francese naturalmente nuovo camay essere carezza pelle carezza ehi fare tardi cinema cinema nuovo camay pizzico fascino sai essere proprio ottimo sughia ragù qui pomodorissimo squisito praticissimo pomodorissimo tutta fragranza essere sapore pomodoro crudo pomodorissimo essere solo santa rosa freschezza dellacqua profumo fiore nuovo deodorante obao obao freschezza mattino corpo obao freschezza pelle giornata nuovo deodorante obao freschezza mattino obao fresco corpo vigorsol evvia grinta vigorsol chewing gum confetto grinta chewing gum confetto gusto forte fortissimo oro china martini oggi essere giornata vivere oggi lavoro impegno finalmente borotalco volere bene tanto agonismo impegno intenso poi borotalco volere bene borotalco essere tenero delicato te stesso borotalco volere bene tanto barbo eccolo qui lamarasoio bic dovere usare quando svegliare mattino avere anno rassaturare dolce perfetto bello piacere lamarasoio qualità qualità bello radere bravo bravo bello radere bravo bravo perfetto perfetto perfetto bravo bic lamarasoio bic pizzette pizzettino catarì e ...

# %%
spots_words = dict()
for key in dictionary:
    spots_words[key] = pos_tag_italian(dictionary[key])
spots_words['1980_1984']
# Out:
# [('essere', 'AUX'),
#  ('persona', 'VERB'),
#  ('potere', 'NOUN'),
#  ('permettere', 'VERB'),
#  ('stare', 'VERB'),
#  ('casa', 'NOUN'),
#  ('quando', 'SCONJ'),
#  ('fare', 'VERB'),
#  ('brutto', 'ADJ'),
#  ('tempo', 'NOUN'),
#  ('primo', 'ADJ'),
#  ('sintomo', 'NOUN'),
#  ('raffreddore', 'ADJ'),
#  ('influenza', 'NOUN'),
#  ('presto', 'ADV'),
#  ('aspirinare', 'VERB'),
#  ('aspirina', 'VERB'),
#  ('andare', 'VERB'),
#  ('bene', 'ADV'),
#  ('presto', 'ADV'),
#  ('seguire', 'VERB'),
#  ('attentamente', 'ADV'),
#  ('avvertenza', 'ADJ'),
#  ('modalità', 'NOUN'),
#  ('duso', 'ADJ'),
#  ('qui', 'ADV'),
#  ('volere', 'VERB'),
#  ('black', 'ADJ'),
#  ('decker', 'NOUN'),
#  ('potere', 'NOUN'),
#  ('forare', 'VERB'),
#  ('materiale', 'NOUN'),
#  ('accessorio', 'ADJ'),
#  ('trasformare', 'VERB'),
#  ('sega', 'NOUN'),
#  ('circolare', 'ADJ'),
#  ('perfetto', 'ADJ'),
#  ('levigatrice', 'NOUN'),
#  ('dirai', 'VERB'),
#  ('lho', 'ADV'),
#  ('fatto', 'NOUN'),
#  ('black', 'ADJ'),
#  ('decker', 'NOUN'),
#  ('accessorio', 'ADJ'),
#  ('trapano', 'VERB'),
#  ('black', 'ADJ'),
#  ('decker', 'NOUN'),
#  ('partire', 'VERB'),
#  ('33200', 'NUM'),
#  ('lira', 'NOUN'),
#  ('natale', 'ADJ'),
#  ('gamma', 'NOUN'),
#  ('black', 'ADJ'),
#  ('decker', 'NOUN'),
#  ('trovare', 'VERB'),
#  ('sempre', 'ADV'),
#  ('regalo', 'ADJ'),
#  ('utile', 'ADJ'),
#  ('regalo', 'ADJ'),
#  ('durare', 'VERB'),
#  ('sempre', 'ADV'),
#  ('black', 'ADJ'),
#  ('decker', 'NOUN'),
#  ('carciofo', 'VERB'),
#  ('ricco', 'ADJ'),
#  ('qualità', 'NOUN'),
#  ('naturale', 'ADJ'),
#  ('cynar', 'ADJ'),
#  ('aperitivo', 'ADJ'),
#  ('base', 'NOUN'),
#  ('carciofo', 'VERB'),
#  ('dopo', 'ADP'),
#  ('pranzo', 'NOUN'),
#  ('cynar', 'ADJ'),
#  ('liscio', 'ADJ'),
#  ('bere', 'VERB'),
#  ('liscio', 'ADJ'),
#  ('cynar', 'ADJ'),
#  ('essere', 'AUX'),
#  ('ottimo', 'ADJ'),
#  ('amaro', 'ADJ'),
#  ('scelta', 'NOUN'),
#  ('naturale', 'ADJ'),
#  ('volere', 'VERB'),
#  ('raffreddore', 'NOUN'),
#  ('uninfluenza', 'NOUN'),
#  ('guardare', 'VERB'),
#  ('avere', 'VERB'),
#  ('qualcosa', 'PRON'),
#  ('te', 'PRON'),
#  ('cebiopirina', 'VERB'),
#  ('effervescente', 'ADV'),
#  ('vitamina', 'NOUN'),
#  ('raffreddore', 'ADJ'),
#  ('influenza', 'NOUN'),
#  ('male', 'ADV'),
#  ('testa', 'VERB'),
#  ('primo', 'ADJ'),
#  ('sintomo', 'NOUN'),
#  ('cebiopirina', 'ADJ'),
#  ('effervescente', 'ADV'),
#  ('vitamina', 'NOUN'),
#  ('cebiopirina', 'ADJ'),
#  ('effervescente', 'ADJ'),
#  ('cebiopirina', 'ADJ'),
#  ('effervescente', 'ADJ'),
#  ('essere', 'AUX'),
#  ('prodotto', 'VERB'),
#  ('bracco', 'ADJ'),
#  ('seguire', 'VERB'),
#  ('attentamente', 'ADV'),
#  ('avvertenza', 'ADJ'),
#  ('modalità', 'NOUN'),
#  ('duso', 'ADJ'),
#  ('linea', 'NOUN'),
#  ('graziella', 'ADJ'),
#  ('simpatia', 'NOUN'),
#  ('due', 'NUM'),
#  ('ruota', 'NOUN'),
#  ('buongiorno', 'ADJ'),
#  ('fabio', 'ADJ'),
#  ('ciao', 'NOUN'),
#  ('fabio', 'ADJ'),
#  ('linea', 'NOUN'),
#  ('graziella', 'ADJ'),
#  ('simpatia', 'NOUN'),
#  ('due', 'NUM'),
#  ('ruota', 'NOUN'),
#  ('buongiorno', 'ADJ'),
#  ('stefano', 'AUX'),
#  ('buongiorno', 'ADJ'),
#  ('signorinare', 'VERB'),
#  ('linea', 'NOUN'),
#  ('graziella', 'ADJ'),
#  ('simpatia', 'NOUN'),
#  ('due', 'NUM'),
#  ('ruota', 'NOUN'),
#  ('graziella', 'ADJ'),
#  ('essere', 'AUX'),
#  ('prodotto', 'VERB'),
#  ('carnielli', 'NOUN'),
#  ('prodotto', 'VERB'),
#  ('ligiene', 'ADJ'),
#  ('intimo', 'ADV'),
#  ('certo', 'ADV'),
#  ('parte', 'NOUN'),
#  ('potere', 'NOUN'),
#  ('fare', 'VERB'),
#  ('vedere', 'VERB'),
#  ('dare', 'VERB'),
#  ('risultato', 'NOUN'),
#  ('piacivolo', 'ADJ'),
#  ('potere', 'NOUN'),
#  ('fare', 'VERB'),
#  ('vedere', 'VERB'),
#  ('prodotto', 'NOUN'),
#  ('essere', 'AUX'),
#  ('chilly', 'VERB'),
#  ('soluzione', 'NOUN'),
#  ('salviettino', 'PROPN'),
#  ('ligiena', 'VERB'),
#  ('intimo', 'ADJ'),
#  ('provalo', 'AUX'),
#  ('vedere', 'VERB'),
#  ('citizen', 'NOUN'),
#  ('quartz', 'DET'),
#  ('citizen', 'ADJ'),
#  ('quartz', 'DET'),
#  ('citizen', 'ADJ'),
#  ('quartz', 'DET'),
#  ('orologi', 'NOUN'),
#  ('raffinato', 'ADJ'),
#  ('orologio', 'NOUN'),
#  ('pratico', 'ADJ'),
#  ('orologio', 'NOUN'),
#  ('elegante', 'ADJ'),
#  ('ogni', 'DET'),
#  ('situazione', 'NOUN'),
#  ('ogni', 'DET'),
#  ('età', 'NOUN'),
#  ('incredibilmente', 'ADV'),
#  ('sottile', 'ADJ'),
#  ('incredibilmente', 'ADV'),
#  ('perfetto', 'ADJ'),
#  ('citizen', 'NOUN'),
#  ('quartz', 'DET'),
#  ('citizen', 'ADJ'),
#  ('gioielli', 'PROPN'),
#  ('quarzo', 'ADV'),
#  ('adesso', 'ADV'),
#  ('sapere', 'VERB'),
#  ('cosè', 'VERB'),
#  ('dentifricio', 'NOUN'),
#  ('dentifricio', 'NOUN'),
#  ('speciale', 'ADJ'),
#  ('formula', 'VERB'),
#  ('scientificamente', 'ADV'),
#  ('avanzare', 'VERB'),
#  ('nuovo', 'ADJ'),
#  ('colgare', 'VERB'),
#  ('fluor', 'NOUN'),
#  ('mfp', 'X'),
#  ('fluoro', 'VERB'),
#  ('cosa', 'PRON'),
#  ('fare', 'VERB'),
#  ('immaginate', 'VERB'),
#  ('gessetto', 'NOUN'),
#  ('essere', 'AUX'),
#  ('dente', 'ADJ'),
#  ('fluor', 'NOUN'),
#  ('mfp', 'DET'),
#  ('vedere', 'VERB'),
#  ('fluor', 'NOUN'),
#  ('mfp', 'X'),
#  ('fissare', 'VERB'),
#  ('dente', 'ADV'),
#  ('rinforzare', 'VERB'),
#  ('colgata', 'ADJ'),
#  ('fluor', 'PROPN'),
#  ('mfp', 'AUX'),
#  ('unaccurato', 'VERB'),
#  ('pulizia', 'NOUN'),
#  ('dente', 'ADP'),
#  ('azione', 'NOUN'),
#  ('igienico', 'ADJ'),
#  ('aiutare', 'VERB'),
#  ('prevenire', 'VERB'),
#  ('lacquario', 'ADJ'),
#  ('dare', 'VERB'),
#  ('sempre', 'ADV'),
#  ('lalire', 'VERB'),
#  ('presto', 'ADV'),
#  ('nuovo', 'ADJ'),
#  ('colgare', 'VERB'),
#  ('fluor', 'NOUN'),
#  ('mfp', 'VERB'),
#  ('cosa', 'NOUN'),
#  ('dietro', 'ADV'),
#  ('famoso', 'ADJ'),
#  ('sorriso', 'NOUN'),
#  ('turbo', 'ADJ'),
#  ('essere', 'AUX'),
#  ('naturale', 'ADJ'),
#  ('sapore', 'NOUN'),
#  ('bocca', 'VERB'),
#  ('fresco', 'ADJ'),
#  ('dare', 'VERB'),
#  ('famiglia', 'NOUN'),
#  ('piacere', 'ADJ'),
#  ('lavare', 'VERB'),
#  ('bene', 'ADV'),
#  ('però', 'ADV'),
#  ('mica', 'ADV'),
#  ('male', 'ADV'),
#  ('casa', 'NOUN'),
#  ('piacere', 'NOUN'),
#  ('sapore', 'NOUN'),
#  ('boccare', 'VERB'),
#  ('fresco', 'ADJ'),
#  ('turbo', 'VERB'),
#  ('stare', 'VERB'),
#  ('meglio', 'ADV'),
#  ('quando', 'SCONJ'),
#  ('bocca', 'NOUN'),
#  ('fresco', 'ADJ'),
#  ('sapore', 'NOUN'),
#  ('menta', 'VERB'),
#  ('appena', 'ADV'),
#  ('colgere', 'VERB'),
#  ('casa', 'NOUN'),
#  ('piacere', 'NOUN'),
#  ('sapore', 'NOUN'),
#  ('boccare', 'VERB'),
#  ('fresco', 'ADJ'),
#  ('turbo', 'ADJ'),
#  ('fabbri', 'NOUN'),
#  ('75', 'NUM'),
#  ('anno', 'NOUN'),
#  ('bontà', 'ADJ'),
#  ('frutta', 'NOUN'),
#  ('fabbri', 'NOUN'),
#  ('liquore', 'NOUN'),
#  ('proposta', 'VERB'),
#  ('fabbri', 'NOUN'),
#  ('macedonia', 'PROPN'),
#  ('fabbri', 'NOUN'),
#  ('75', 'NUM'),
#  ('anno', 'NOUN'),
#  ('bontà', 'ADJ'),
#  ('fin', 'ADP'),
#  ('primo', 'ADJ'),
#  ('poppare', 'VERB'),
#  ('bimbo', 'NOUN'),
#  ('avere', 'VERB'),
#  ('bisogno', 'NOUN'),
#  ('protezione', 'NOUN'),
#  ('puoi', 'AUX'),
#  ('usare', 'VERB'),
#  ('casa', 'NOUN'),
#  ('protezione', 'NOUN'),
#  ('milton', 'ADJ'),
#  ('solo', 'ADV'),
#  ('sterilizzare', 'VERB'),
#  ('poppatoio', 'NOUN'),
#  ('tettarella', 'VERB'),
#  ('milton', 'X'),
#  ('proteggere', 'VERB'),
#  ('infezione', 'DET'),
#  ('sicurezza', 'NOUN'),
#  ('protegge', 'VERB'),
#  ('infezione', 'NOUN'),
#  ('delicatezza', 'ADJ'),
#  ('protezione', 'NOUN'),
#  ('piccolo', 'ADJ'),
#  ('grande', 'ADJ'),
#  ('potere', 'NOUN'),
#  ('usare', 'VERB'),
#  ('milton', 'ADJ'),
#  ('casa', 'NOUN'),
#  ('milton', 'ADJ'),
#  ('proteggere', 'VERB'),
#  ('infezione', 'NOUN'),
#  ('leggere', 'VERB'),
#  ('attentamente', 'ADV'),
#  ('advertenza', 'NOUN'),
#  ('avere', 'VERB'),
#  ('mangiare', 'VERB'),
#  ('confettura', 'NOUN'),
#  ('sapere', 'VERB'),
#  ('confetturare', 'VERB'),
#  ('santa', 'DET'),
#  ('rosa', 'ADJ'),
#  ('tanto', 'ADV'),
#  ('bello', 'ADJ'),
#  ('frutta', 'NOUN'),
#  ('fresco', 'ADJ'),
#  ('peccatone', 'NOUN'),
#  ('né', 'CCONJ'),
#  ('colorante', 'VERB'),
#  ('né', 'CCONJ'),
#  ('conservante', 'ADJ'),
#  ('santa', 'ADJ'),
#  ('rosa', 'ADJ'),
#  ('frutta', 'NOUN'),
#  ('fresco', 'ADJ'),
#  ('zucchero', 'NOUN'),
#  ('ragazzo', 'NOUN'),
#  ('nutrimolo', 'ADJ'),
#  ('intelligenza', 'VERB'),
#  ('negoziante', 'ADV'),
#  ('regalo', 'NOUN'),
#  ('ladesivo', 'ADJ'),
#  ('santa', 'PROPN'),
#  ('rosa', 'ADJ'),
#  ('potere', 'NOUN'),
#  ('vincere', 'VERB'),
#  ('super', 'ADJ'),
#  ('sacca', 'NOUN'),
#  ('santa', 'ADJ'),
#  ('rosa', 'ADJ'),
#  ('confettura', 'VERB'),
#  ('santa', 'PROPN'),
#  ('rosa', 'PROPN'),
#  ('paola', 'VERB'),
#  ('fare', 'VERB'),
#  ('tardi', 'DET'),
#  ('cinema', 'NOUN'),
#  ('stare', 'VERB'),
#  ('fare', 'VERB'),
#  ('bello', 'ADJ'),
#  ('vedere', 'VERB'),
#  ('molto', 'ADV'),
#  ('molto', 'ADV'),
#  ('bello', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('camay', 'PROPN'),
#  ('cosha', 'PROPN'),
#  ('nuovo', 'ADJ'),
#  ('avere', 'VERB'),
#  ('nuovo', 'ADJ'),
#  ('profumo', 'NOUN'),
#  ('delicato', 'ADJ'),
#  ('prezioso', 'ADJ'),
#  ('francese', 'ADJ'),
#  ('naturalmente', 'ADV'),
#  ('nuovo', 'ADJ'),
#  ('camay', 'NOUN'),
#  ('essere', 'AUX'),
#  ('carezza', 'NOUN'),
#  ('pelle', 'NOUN'),
#  ('carezza', 'NOUN'),
#  ('ehi', 'NOUN'),
#  ('fare', 'VERB'),
#  ('tardi', 'DET'),
#  ('cinema', 'NOUN'),
#  ('cinema', 'NOUN'),
#  ('nuovo', 'ADJ'),
#  ('camay', 'NOUN'),
#  ('pizzico', 'ADJ'),
#  ('fascino', 'NOUN'),
#  ('sai', 'VERB'),
#  ('essere', 'AUX'),
#  ('proprio', 'ADV'),
#  ('ottimo', 'ADJ'),
#  ('sughia', 'NOUN'),
#  ('ragù', 'VERB'),
#  ('qui', 'ADV'),
#  ('pomodorissimo', 'ADJ'),
#  ('squisito', 'NOUN'),
#  ('praticissimo', 'ADJ'),
#  ('pomodorissimo', 'ADV'),
#  ('tutta', 'DET'),
#  ('fragranza', 'NOUN'),
#  ('essere', 'AUX'),
#  ('sapore', 'NOUN'),
#  ('pomodoro', 'ADJ'),
#  ('crudo', 'NOUN'),
#  ('pomodorissimo', 'ADJ'),
#  ('essere', 'AUX'),
#  ('solo', 'ADV'),
#  ('santa', 'ADJ'),
#  ('rosa', 'ADJ'),
#  ('freschezza', 'NOUN'),
#  ('dellacqua', 'NOUN'),
#  ('profumo', 'NOUN'),
#  ('fiore', 'ADJ'),
#  ('nuovo', 'ADJ'),
#  ('deodorante', 'ADJ'),
#  ('obao', 'VERB'),
#  ('obao', 'ADJ'),
#  ('freschezza', 'NOUN'),
#  ('mattino', 'ADJ'),
#  ('corpo', 'NOUN'),
#  ('obao', 'ADJ'),
#  ('freschezza', 'NOUN'),
#  ('pelle', 'ADJ'),
#  ('giornata', 'VERB'),
#  ('nuovo', 'ADJ'),
#  ('deodorante', 'ADJ'),
#  ('obao', 'ADJ'),
#  ('freschezza', 'NOUN'),
#  ('mattino', 'ADJ'),
#  ('obao', 'ADV'),
#  ('fresco', 'ADJ'),
#  ('corpo', 'NOUN'),
#  ('vigorsol', 'ADJ'),
#  ('evvia', 'NOUN'),
#  ('grinta', 'NOUN'),
#  ('vigorsol', 'ADJ'),
#  ('chewing', 'NOUN'),
#  ('gum', 'ADP'),
#  ('confetto', 'NOUN'),
#  ('grinta', 'ADJ'),
#  ('chewing', 'NOUN'),
#  ('gum', 'ADP'),
#  ('confetto', 'NOUN'),
#  ('gusto', 'VERB'),
#  ('forte', 'ADJ'),
#  ('fortissimo', 'ADJ'),
#  ('oro', 'NOUN'),
#  ('china', 'VERB'),
#  ('martini', 'PROPN'),
#  ('oggi', 'ADV'),
#  ('essere', 'AUX'),
#  ('giornata', 'VERB'),
#  ('vivere', 'VERB'),
#  ('oggi', 'ADV'),
#  ('lavoro', 'NOUN'),
#  ('impegno', 'ADJ'),
#  ('finalmente', 'ADV'),
#  ('borotalco', 'NOUN'),
#  ('volere', 'VERB'),
#  ('bene', 'ADV'),
#  ('tanto', 'ADV'),
#  ('agonismo', 'NOUN'),
#  ('impegno', 'ADJ'),
#  ('intenso', 'ADJ'),
#  ('poi', 'ADV'),
#  ('borotalco', 'ADJ'),
#  ('volere', 'VERB'),
#  ('bene', 'ADV'),
#  ('borotalco', 'ADJ'),
#  ('essere', 'AUX'),
#  ('tenero', 'ADJ'),
#  ('delicato', 'ADJ'),
#  ('te', 'PRON'),
#  ('stesso', 'ADJ'),
#  ('borotalco', 'NOUN'),
#  ('volere', 'VERB'),
#  ('bene', 'ADV'),
#  ('tanto', 'ADV'),
#  ('barbo', 'ADJ'),
#  ('eccolo', 'VERB'),
#  ('qui', 'ADV'),
#  ('lamarasoio', 'NOUN'),
#  ('bic', 'VERB'),
#  ('dovere', 'NOUN'),
#  ('usare', 'VERB'),
#  ('quando', 'SCONJ'),
#  ('svegliare', 'VERB'),
#  ('mattino', 'NOUN'),
#  ('avere', 'VERB'),
#  ('anno', 'NOUN'),
#  ('rassaturare', 'VERB'),
#  ('dolce', 'ADJ'),
#  ('perfetto', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('piacere', 'NOUN'),
#  ('lamarasoio', 'NOUN'),
#  ('qualità', 'NOUN'),
#  ('qualità', 'NOUN'),
#  ('bello', 'ADJ'),
#  ('radere', 'VERB'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bello', 'ADJ'),
#  ('radere', 'VERB'),
#  ('bravo', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('perfetto', 'ADJ'),
#  ('perfetto', 'ADJ'),
#  ('perfetto', 'ADJ'),
#  ('bravo', 'ADJ'),
#  ('bic', 'ADJ'),
#  ('lamarasoio', 'NOUN'),
#  ('bic', 'NOUN'),
#  ('pizzette', 'ADJ'),
#  ('pizzettino', 'NOUN'),
#  ('catarì', 'ADJ'),
#  ('essere', 'AUX'),
#  ('segreto', 'ADJ'),
#  ('avere', 'VERB'),
#  ('fame', 'NOUN'),
#  ('fare', 'VERB'),
#  ('passare', 'VERB'),
#  ('avere', 'VERB'),
#  ('fame', 'NOUN'),
#  ('fare', 'VERB'),
#  ('venire', 'VERB'),
#  ('pizzette', 'NOUN'),
#  ('catarì', 'VERB'),
#  ('alre', 'NOUN'),
#  ('fame', 'PROPN'),
#  ('stuzzicano', 'VERB'),
#  ('lappetito', 'NOUN'),
#  ('pizzette', 'ADJ'),
#  ('catarì', 'VERB'),
#  ('ora', 'ADV'),
#  ('vho', 'VERB'),
#  ('capire', 'VERB'),
#  ('essere', 'AUX'),
#  ('forma', 'VERB'),
#  ('lalimentazione', 'NOUN'),
#  ('essere', 'AUX'),
#  ('importante', 'ADJ'),
#  ('tanto', 'ADV'),
#  ('scelgono', 'VERB'),
#  ('certosa', 'PROPN'),
#  ('galbani', 'NOUN'),
#  ('formaggio', 'ADV'),
#  ('leggero', 'ADJ'),
#  ('nutriente', 'ADJ'),
#  ('certosa', 'PROPN'),
#  ('galbani', 'ADJ'),
#  ('essere', 'AUX'),
#  ('conveniente', 'ADJ'),
#  ('potere', 'NOUN'),
#  ('fare', 'VERB'),
#  ('tanto', 'DET'),
#  ('porzione', 'NOUN'),
#  ('certosa', 'ADJ'),
#  ('galbani', 'ADJ'),
#  ('essere', 'AUX'),
#  ('comodo', 'ADJ'),
#  ('contorno', 'ADV'),
#  ('diventare', 'VERB'),
#  ('unottimo', 'ADJ'),
#  ('cena', 'NOUN'),
#  ('certosa', 'ADJ'),
#  ('galbani', 'ADJ'),
#  ('prodotto', 'VERB'),
#  ('fiducia', 'NOUN'),
#  ('galbani', 'ADJ'),
#  ('volere', 'VERB'),
#  ('dire', 'VERB'),
#  ('fiducia', 'NOUN'),
#  ('succedere', 'ADJ'),
#  ('gengivo', 'ADJ'),
#  ('fare', 'VERB'),
#  ('male', 'ADV'),
#  ('attento', 'ADJ'),
#  ('gengiva', 'VERB'),
#  ('essere', 'AUX'),
#  ('importante', 'ADJ'),
#  ('guarda', 'VERB'),
#  ('essere', 'AUX'),
#  ('qui', 'ADV'),
#  ('dente', 'ADV'),
#  ('gengire', 'VERB'),
#  ('placca', 'NOUN'),
#  ('batterico', 'ADJ'),
#  ('formare', 'VERB'),
#  ('va', 'VERB'),
#  ('bene', 'ADV'),
#  ('potere', 'NOUN'),
#  ('fare', 'VERB'),
#  ('volere', 'VERB'),
#  ('comunque', 'ADV'),
#  ('lare', 'VERB'),
#  ('regolarmente', 'ADV'),
#  ('dente', 'ADP'),
#  ('dentificio', 'NOUN'),
#  ('disinfettante', 'NOUN'),
#  ('gengivo', 'ADJ'),
#  ('defend', 'NOUN'),
#  ('plus', 'NOUN'),
#  ('combattere', 'VERB'),
#  ('placca', 'NOUN'),
#  ('batterico', 'ADJ'),
#  ('avere', 'VERB'),
#  ('gengivo', 'NOUN'),
#  ('forte', 'ADJ'),
#  ('defend', 'NOUN'),
#  ('plus', 'NOUN'),
#  ('gengivo', 'ADJ'),
#  ('forte', 'ADJ'),
#  ('denne', 'VERB'),
#  ('prosciutto', 'NOUN'),
#  ('parma', 'PROPN'),
#  ('sapere', 'VERB'),
#  ('essere', 'AUX'),
#  ('diverso', 'ADJ'),
#  ('speciale', 'ADJ'),
#  ('prosciutto', 'NOUN'),
#  ('parma', 'PROPN'),
#  ('nascere', 'VERB'),
#  ('suine', 'ADJ'),
#  ('selezionato', 'VERB'),
#  ('lavorazione', 'NOUN'),
#  ('essere', 'AUX'),
#  ('fare', 'VERB'),
#  ('maniera', 'NOUN'),
#  ('tradizionale', 'ADJ'),
#  ('controllato', 'VERB'),
#  ('ogni', 'DET'),
#  ('fase', 'NOUN'),
#  ('fino', 'ADP'),
#  ('stagionatura', 'NOUN'),
#  ('ultimato', 'VERB'),
#  ('ecco', 'ADV'),
#  ('essere', 'AUX'),
#  ('dolce', 'ADJ'),
#  ('fragrante', 'ADV'),
#  ('inimitabile', 'ADJ'),
#  ('volere', 'VERB'),
#  ('prosciutto', 'NOUN'),
#  ('chiedetelo', 'VERB'),
#  ('nome', 'NOUN'),
#  ('dire', 'VERB'),
#  ('volere', 'VERB'),
#  ('parma', 'PROPN'),
#  ('dovere', 'PROPN'),
#  ('dare', 'VERB'),
#  ('prosciutto', 'ADJ'),
#  ('marchio', 'NOUN'),
#  ('consorzio', 'NOUN'),
#  ('prosciutto', 'ADJ'),
#  ('parma', 'PROPN'),
#  ('nutriente', 'ADV'),
#  ('completo', 'ADJ'),
#  ('appetitoso', 'ADJ'),
#  ('ciappi', 'ADJ'),
#  ('nutriente', 'ADV'),
#  ('completo', 'ADJ'),
#  ('appetitoso', 'ADJ'),
#  ('ciappi', 'PROPN'),
#  ('hopla', 'PROPN'),
#  ('nutriente', 'ADV'),
#  ('completo', 'ADJ'),
#  ('appetitoso', 'ADJ'),
#  ('ciappi', 'ADJ'),
#  ('essere', 'AUX'),
#  ('sparsa', 'VERB'),
#  ('voce', 'NOUN'),
#  ('ciappi', 'ADJ'),
#  ('essere', 'AUX'),
#  ('pasto', 'ADV'),
#  ('nutriente', 'ADV'),
#  ('completo', 'ADJ'),
#  ('appetitoso', 'ADJ'),
#  ('ciappi', 'ADJ'),
#  ('tanto', 'ADV'),
#  ('appetitoso', 'ADJ'),
#  ('varietà', 'NOUN'),
#  ('mantenere', 'VERB'),
#  ('forma', 'NOUN'),
#  ('mmmh', 'ADV'),
#  ('ciappi', 'ADJ'),
#  ('ciappi', 'ADJ'),
#  ('essere', 'AUX'),
#  ('sparsa', 'VERB'),
#  ('voce', 'NOUN'),
#  ('cosè', 'VERB'),
#  ('stasera', 'ADV'),
#  ('secondo', 'ADP'),
#  ('sorpresa', 'NOUN'),
#  ('secondo', 'ADP'),
#  ('sorpresa', 'NOUN'),
#  ('sofficini', 'NOUN'),
#  ('sofficini', 'NOUN'),
#  ('secondo', 'ADP'),
#  ('sofficini', 'NOUN'),
#  ('findus', 'PROPN'),
#  ('portare', 'VERB'),
#  ('tavola', 'NOUN'),
#  ('cambiare', 'VERB'),
#  ('sorpresa', 'NOUN'),
#  ('sofficissimo', 'ADJ'),
#  ('sorpreso', 'VERB'),
#  ('sorprendere', 'VERB'),
#  ('troppo', 'ADV'),
#  ('appessivo', 'ADJ'),
#  ('adorare', 'VERB'),
#  ('bontà', 'ADJ'),
#  ('sorpresa', 'NOUN'),
#  ('sofficissimo', 'ADJ'),
#  ('sorpreso', 'VERB'),
#  ('sorprendere', 'VERB'),
#  ('morbidissimo', 'ADV'),
#  ('ripieno', 'NOUN'),
#  ('bontàre', 'ADJ'),
#  ('sofficini', 'NOUN'),
#  ('findus', 'PROPN'),
#  ('buono', 'VERB'),
#  ('secondo', 'ADP'),
#  ('corro', 'NOUN'),
#  ('dietro', 'ADV'),
#  ('ogni', 'DET'),
#  ('volta', 'NOUN'),
#  ('sorpresa', 'VERB'),
#  ('mago', 'ADJ'),
#  ('g', 'CCONJ'),
#  ('mago', 'ADJ'),
#  ('g', 'CCONJ'),
#  ('chiudere', 'VERB'),
#  ('occhio', 'NOUN'),
#  ('aprire', 'VERB'),
#  ('bocca', 'NOUN'),
#  ('mago', 'ADJ'),
#  ('g', 'CCONJ'),
#  ('mago', 'ADJ'),
#  ('g', 'CCONJ'),
#  ('quasi', 'ADV'),
#  ('locchio', 'NOUN'),
#  ('lallico', 'ADJ'),
#  ('zalet', 'NOUN'),
#  ('galbusera', 'NOUN'),
#  ('frollini', 'ADJ'),
#  ('malto', 'VERB'),
#  ('miele', 'NOUN'),
#  ('buono', 'VERB'),
#  ('prendere', 'VERB'),
#  ('gurre', 'VERB'),
#  ('g', 'X'),
#  ('galbusera', 'NOUN'),
#  ('g', 'CCONJ'),
#  ('galbusera', 'NOUN'),
#  ('chiudere', 'VERB'),
#  ('occhio', 'NOUN'),
#  ('aprire', 'VERB'),
#  ('bocca', 'NOUN'),
#  ('mago', 'ADJ'),
#  ('g', 'CCONJ'),
#  ('mago', 'ADJ'),
#  ('g', 'CCONJ'),
#  ('zalet', 'NOUN'),
#  ('galbusera', 'NOUN'),
#  ('buono', 'ADJ'),
#  ('prendere', 'VERB'),
#  ('gurre', 'VERB'),
#  ('indesit', 'ADJ'),
#  ('indesit', 'DET'),
#  ('elettrodomestici', 'NOUN'),
#  ('indesit', 'ADP'),
#  ('elettrodomestici', 'NOUN'),
#  ('alto', 'ADJ'),
#  ('fedeltà', 'NOUN'),
#  ('indesit', 'ADJ'),
#  ('quando', 'SCONJ'),
#  ('cantare', 'VERB'),
#  ('gallo', 'NOUN'),
#  ('fare', 'VERB'),
#  ('primo', 'ADJ'),
#  ('colazione', 'NOUN'),
#  ('kellogg', 'PROPN'),
#  ('’', 'PROPN'),
#  ('s', 'X'),
#  ('corn', 'NOUN'),
#  ('flakes', 'VERB'),
#  ('12', 'NUM'),
#  ('pannocco', 'NOUN'),
#  ('ogni', 'DET'),
#  ('grande', 'ADJ'),
#  ('scatata', 'NOUN'),
#  ('kellogg', 'PROPN'),
#  ('’', 'PROPN'),
#  ('s', 'X'),
#  ('corn', 'NOUN'),
#  ('flakes', 'NOUN'),
#  ('fiocchi', 'NOUN'),
#  ('grano', 'VERB'),
#  ('turco', 'ADJ'),
#  ('latte', 'NOUN'),
#  ('buono', 'VERB'),
#  ('abitudine', 'NOUN'),
#  ('mattino', 'ADJ'),
#  ('kellogg', 'PROPN'),
#  ('’', 'PROPN'),
#  ('s', 'X'),
#  ('conosci', 'VERB'),
#  ('oil', 'ADV'),
#  ('of', 'ADP'),
#  ('olaz', 'NOUN'),
#  ('fluido', 'ADJ'),
#  ('aiutare', 'VERB'),
#  ('pelle', 'NOUN'),
#  ('mantenere', 'VERB'),
#  ('aspetto', 'NOUN'),
#  ('giovane', 'ADJ'),
#  ('oil', 'ADV'),
#  ('of', 'ADP'),
#  ('olaz', 'PROPN'),
#  ('compensare', 'VERB'),
#  ('perdita', 'NOUN'),
#  ('acqua', 'NOUN'),
#  ('pelle', 'NOUN'),
#  ('subire', 'VERB'),
#  ('venire', 'AUX'),
#  ('subito', 'ADV'),
#  ('assorbire', 'VERB'),
#  ('senza', 'ADP'),
#  ('lasciare', 'VERB'),
#  ('traccia', 'NOUN'),
#  ('oil', 'ADV'),
#  ('of', 'ADP'),
#  ('olaz', 'PROPN'),
#  ('potere', 'NOUN'),
#  ('aiutarto', 'ADJ'),
#  ('sembrare', 'VERB'),
#  ('giovane', 'ADJ'),
#  ('gelato', 'ADJ'),
#  ('caramello', 'ADJ'),
#  ('pralinato', 'VERB'),
#  ('gusto', 'ADJ'),
#  ('cioccolare', 'VERB'),
#  ('voglia', 'AUX'),
#  ('mattare', 'VERB'),
#  ('avventura', 'NOUN'),
#  ('avere', 'VERB'),
#  ('toseroni', 'NOUN'),
#  ('son', 'AUX'),
#  ('sicuro', 'ADJ'),
#  ('lho', 'NUM'),
#  ('toseroni', 'NOUN'),
#  ('gelato', 'ADJ'),
#  ('chiamare', 'VERB'),
#  ('blob', 'PROPN'),
#  ('blob', 'PROPN'),
#  ('provare', 'VERB'),
#  ('gusto', 'NOUN'),
#  ('blob', 'PROPN'),
#  ('provare', 'VERB'),
#  ('gusto', 'NOUN'),
#  ('blob', 'PROPN'),
#  ('provare', 'VERB'),
#  ('gurre', 'VERB'),
#  ('buon', 'ADJ'),
#  ('appetito', 'NOUN'),
#  ('fare', 'VERB'),
#  ('perfetto', 'ADJ'),
#  ('armonia', 'NOUN'),
#  ('dellaranciare', 'VERB'),
#  ('crodo', 'NOUN'),
#  ('base', 'NOUN'),
#  ('succo', 'ADJ'),
#  ('daranciare', 'VERB'),
#  ('aranciare', 'VERB'),
#  ('crodo', 'NOUN'),
#  ('garantire', 'VERB'),
#  ('grande', 'ADJ'),
#  ('casa', 'NOUN'),
#  ('aranciata', 'ADJ'),
#  ('crodo', 'NOUN'),
#  ('sporco', 'ADJ'),
#  ('impossibile', 'ADJ'),
#  ('unto', 'NOUN'),
#  ('cucina', 'NOUN'),
#  ('sporco', 'ADJ'),
#  ('federa', 'VERB'),
#  ('unto', 'ADV'),
#  ('pelle', 'NOUN'),
#  ('qui', 'ADV'),
#  ('camicia', 'VERB'),
#  ('lunto', 'ADJ'),
#  ('impossibile', 'ADJ'),
#  ('esistere', 'VERB'),
#  ('sporco', 'ADJ'),
#  ('impossibile', 'ADJ'),
#  ('bio', 'NOUN'),
#  ('presto', 'ADV'),
#  ('bucato', 'VERB'),
#  ('mano', 'NOUN'),
#  ('bio', 'ADJ'),
#  ('presto', 'ADV'),
#  ('bucato', 'VERB'),
#  ('mano', 'NOUN'),
#  ('liquidare', 'VERB'),
#  ('lunto', 'NOUN'),
#  ('bio', 'ADP'),
#  ('presto', 'ADV'),
#  ('sciogliere', 'VERB'),
#  ('sporco', 'ADJ'),
#  ('impossibile', 'ADJ'),
#  ('solito', 'NOUN'),
#  ('venire', 'VERB'),
#  ('via', 'ADV'),
#  ('vedere', 'VERB'),
#  ('pulire', 'VERB'),
#  ('bio', 'ADJ'),
#  ('presto', 'ADV'),
#  ('bucato', 'VERB'),
#  ('mano', 'NOUN'),
#  ('niente', 'PRON'),
#  ('sporco', 'ADJ'),
#  ('impossibile', 'ADJ'),
#  ('nessuno', 'PRON'),
#  ('asciugato', 'VERB'),
#  ('cucina', 'NOUN'),
#  ('nessuno', 'PRON'),
#  ('camicia', 'VERB'),
#  ('nessuno', 'PRON'),
#  ('federa', 'VERB'),
#  ('bio', 'ADJ'),
#  ('presto', 'ADV'),
#  ('bucato', 'VERB'),
#  ('mano', 'NOUN'),
#  ('liquidare', 'VERB'),
#  ('sporco', 'ADJ'),
#  ('impossibile', 'ADJ'),
#  ('bucato', 'VERB'),
#  ('happy', 'X'),
#  ('mentos', 'X'),
#  ('you', 'X'),
#  ('happy', 'X'),
#  ('mentos', 'X'),
#  ('today', 'X'),
#  ('happy', 'X'),
#  ('mentos', 'X'),
#  ('happy', 'X'),
#  ('mentos', 'X'),
#  ('happy', 'X'),
#  ('mentos', 'X'),
#  ('the', 'X'),
#  ('way', 'PROPN'),
#  ('mentos', 'NOUN'),
#  ('nuovo', 'ADJ'),
#  ('caramella', 'NOUN'),
#  ('dare', 'VERB'),
#  ('piacere', 'NOUN'),
#  ('masticare', 'VERB'),
#  ('freschezza', 'NOUN'),
#  ('menta', 'VERB'),
#  ('renault', 'NOUN'),
#  ('5', 'NUM'),
#  ('essere', 'AUX'),
#  ('proprio', 'ADV'),
#  ('inconfondibile', 'ADJ'),
#  ('insuperabile', 'ADJ'),
#  ('incredibile', 'ADJ'),
#  ('inimitabile', 'ADJ'),
#  ('imbattibile', 'ADJ'),
#  ('ineguagliabile', 'ADJ'),
#  ('impareggabile', 'ADJ'),
#  ('ecco', 'ADV'),
#  ('favoloso', 'ADJ'),
#  ('proposta', 'VERB'),
#  ('sposi', 'VERB'),
#  ('’', 'ADP'),
#  ('82', 'NUM'),
#  ('cucina', 'NOUN'),
#  ('laminato', 'VERB'),
#  ('plastico', 'ADJ'),
#  ('lira', 'VERB'),
#  ('1200000', 'NUM'),
#  ('camera', 'NOUN'),
#  ('letto', 'VERB'),
#  ('palissandro', 'NOUN'),
#  ('lira', 'NOUN'),
#  ('850000', 'NUM'),
#  ('aiazzone', 'NOUN'),
#  ...]

# %%
#Print the top 10 words of every lustrum

vocabularies = dict()
for key in dictionary:
    vocabularies[key] = set(spots_words[key])

frequencies = dict()
for key in dictionary:
    frequencies[key] = Counter(spots_words[key])

top = 10
previous_key = None

for key in sorted(dictionary):
    if key != previous_key and previous_key is not None:
        print()
    previous_key = key
    words_top = sorted(frequencies[key].items(), key=lambda x: x[1], reverse=True)[:10]
    for word, frequency in words_top:
        print(key, word, frequency, sep='\t')
# Out:
# 1980_1984	('essere', 'AUX')	813
# 1980_1984	('fare', 'VERB')	190
# 1980_1984	('avere', 'VERB')	151
# 1980_1984	('nuovo', 'ADJ')	149
# 1980_1984	('bello', 'ADJ')	99
# 1980_1984	('volere', 'VERB')	82
# 1980_1984	('grande', 'ADJ')	82
# 1980_1984	('potere', 'NOUN')	81
# 1980_1984	('quando', 'SCONJ')	77
# 1980_1984	('sempre', 'ADV')	71
#
# 1985_1989	('essere', 'AUX')	2376
# 1985_1989	('nuovo', 'ADJ')	527
# 1985_1989	('fare', 'VERB')	524
# 1985_1989	('avere', 'VERB')	515
# 1985_1989	('grande', 'ADJ')	307
# 1985_1989	('oggi', 'ADV')	293
# 1985_1989	('solo', 'ADV')	291
# 1985_1989	('potere', 'NOUN')	278
# 1985_1989	('volere', 'VERB')	247
# 1985_1989	('bello', 'ADJ')	225
#
# 1990_1994	('essere', 'AUX')	2123
# 1990_1994	('nuovo', 'ADJ')	604
# 1990_1994	('fare', 'VERB')	552
# 1990_1994	('avere', 'VERB')	543
# 1990_1994	('oggi', 'ADV')	297
# 1990_1994	('solo', 'ADV')	282
# 1990_1994	('grande', 'ADJ')	272
# 1990_1994	('potere', 'NOUN')	242
# 1990_1994	('avere', 'AUX')	235
# 1990_1994	('ogni', 'DET')	232
#
# 1995_1999	('essere', 'AUX')	815
# 1995_1999	('avere', 'VERB')	217
# 1995_1999	('fare', 'VERB')	178
# 1995_1999	('nuovo', 'ADJ')	162
# 1995_1999	('solo', 'ADV')	102
# 1995_1999	('potere', 'NOUN')	99
# 1995_1999	('avere', 'AUX')	92
# 1995_1999	('volere', 'VERB')	90
# 1995_1999	('oggi', 'ADV')	77
# 1995_1999	('bello', 'ADJ')	73
#
# 2000_2004	('essere', 'AUX')	918
# 2000_2004	('nuovo', 'ADJ')	327
# 2000_2004	('avere', 'VERB')	236
# 2000_2004	('fare', 'VERB')	222
# 2000_2004	('potere', 'NOUN')	146
# 2000_2004	('solo', 'ADV')	138
# 2000_2004	('danone', 'NOUN')	124
# 2000_2004	('oggi', 'ADV')	114
# 2000_2004	('avere', 'AUX')	109
# 2000_2004	('yogurt', 'X')	109
#
# 2005_2009	('essere', 'AUX')	1261
# 2005_2009	('nuovo', 'ADJ')	363
# 2005_2009	('avere', 'VERB')	352
# 2005_2009	('fare', 'VERB')	341
# 2005_2009	('solo', 'ADV')	249
# 2005_2009	('euro', 'NOUN')	244
# 2005_2009	('potere', 'NOUN')	230
# 2005_2009	('oggi', 'ADV')	152
# 2005_2009	('grande', 'ADJ')	146
# 2005_2009	('ogni', 'DET')	133
#
# 2010_2014	('essere', 'AUX')	578
# 2010_2014	('nuovo', 'ADJ')	96
# 2010_2014	('avere', 'VERB')	88
# 2010_2014	('potere', 'NOUN')	88
# 2010_2014	('fare', 'VERB')	84
# 2010_2014	('solo', 'ADV')	56
# 2010_2014	('sempre', 'ADV')	43
# 2010_2014	('laqua', 'NOUN')	43
# 2010_2014	('euro', 'NOUN')	43
# 2010_2014	('ogni', 'DET')	38
#
# 2015_2019	('essere', 'AUX')	346
# 2015_2019	('avere', 'VERB')	95
# 2015_2019	('potere', 'NOUN')	92
# 2015_2019	('nuovo', 'ADJ')	82
# 2015_2019	('fare', 'VERB')	74
# 2015_2019	('solo', 'ADV')	54
# 2015_2019	('quando', 'SCONJ')	49
# 2015_2019	('ogni', 'DET')	41
# 2015_2019	('grande', 'ADJ')	41
# 2015_2019	('sempre', 'ADV')	39
#
# 2020_2024	('essere', 'AUX')	510
# 2020_2024	('avere', 'VERB')	115
# 2020_2024	('fare', 'VERB')	111
# 2020_2024	('nuovo', 'ADJ')	105
# 2020_2024	('potere', 'NOUN')	97
# 2020_2024	('solo', 'ADV')	68
# 2020_2024	('sempre', 'ADV')	67
# 2020_2024	('ogni', 'DET')	62
# 2020_2024	('quando', 'SCONJ')	61
# 2020_2024	('te', 'PRON')	57

# %%
#Print the top 10 ADJECTIVES of every lustrum
spots_words = dict()
spots_adj=dict()
for key in dictionary:
     spots_words[key] = pos_tag_italian(dictionary[key])
for key in spots_words:
    if key not in spots_adj:
        spots_adj[key] = []
    for values in spots_words[key]:
        if 'ADJ' in values:  
            spots_adj[key].append(values)

# %%
vocabularies = dict()
for key in dictionary:
    vocabularies[key] = set(spots_adj[key])

frequencies = dict()
for key in dictionary:
    frequencies[key] = Counter(spots_adj[key])

top = 10
previous_key = None

for key in sorted(dictionary):
    if key != previous_key and previous_key is not None:
        print()
    previous_key = key
    words_top = sorted(frequencies[key].items(), key=lambda x: x[1], reverse=True)[:10]
    for word, frequency in words_top:
        print(key, word, frequency, sep='\t')
# Out:
# 1980_1984	('nuovo', 'ADJ')	149
# 1980_1984	('bello', 'ADJ')	99
# 1980_1984	('grande', 'ADJ')	82
# 1980_1984	('difficile', 'ADJ')	61
# 1980_1984	('fresco', 'ADJ')	53
# 1980_1984	('buono', 'ADJ')	42
# 1980_1984	('bianco', 'ADJ')	38
# 1980_1984	('primo', 'ADJ')	31
# 1980_1984	('piccolo', 'ADJ')	28
# 1980_1984	('delicato', 'ADJ')	28
#
# 1985_1989	('nuovo', 'ADJ')	527
# 1985_1989	('grande', 'ADJ')	307
# 1985_1989	('bello', 'ADJ')	225
# 1985_1989	('primo', 'ADJ')	190
# 1985_1989	('vero', 'ADJ')	146
# 1985_1989	('buono', 'ADJ')	132
# 1985_1989	('bianco', 'ADJ')	129
# 1985_1989	('fresco', 'ADJ')	110
# 1985_1989	('naturale', 'ADJ')	100
# 1985_1989	('dolce', 'ADJ')	100
#
# 1990_1994	('nuovo', 'ADJ')	604
# 1990_1994	('grande', 'ADJ')	272
# 1990_1994	('bello', 'ADJ')	190
# 1990_1994	('bianco', 'ADJ')	173
# 1990_1994	('primo', 'ADJ')	165
# 1990_1994	('fresco', 'ADJ')	136
# 1990_1994	('buono', 'ADJ')	127
# 1990_1994	('naturale', 'ADJ')	123
# 1990_1994	('vero', 'ADJ')	102
# 1990_1994	('dolce', 'ADJ')	79
#
# 1995_1999	('nuovo', 'ADJ')	162
# 1995_1999	('bello', 'ADJ')	73
# 1995_1999	('grande', 'ADJ')	70
# 1995_1999	('primo', 'ADJ')	53
# 1995_1999	('buono', 'ADJ')	51
# 1995_1999	('bianco', 'ADJ')	47
# 1995_1999	('fresco', 'ADJ')	42
# 1995_1999	('vero', 'ADJ')	34
# 1995_1999	('pronto', 'ADJ')	29
# 1995_1999	('sano', 'ADJ')	28
#
# 2000_2004	('nuovo', 'ADJ')	327
# 2000_2004	('grande', 'ADJ')	80
# 2000_2004	('primo', 'ADJ')	71
# 2000_2004	('bianco', 'ADJ')	68
# 2000_2004	('bello', 'ADJ')	59
# 2000_2004	('naturale', 'ADJ')	49
# 2000_2004	('vero', 'ADJ')	44
# 2000_2004	('fresco', 'ADJ')	43
# 2000_2004	('pronto', 'ADJ')	43
# 2000_2004	('nuova', 'ADJ')	42
#
# 2005_2009	('nuovo', 'ADJ')	363
# 2005_2009	('grande', 'ADJ')	146
# 2005_2009	('primo', 'ADJ')	113
# 2005_2009	('bello', 'ADJ')	89
# 2005_2009	('bianco', 'ADJ')	69
# 2005_2009	('vero', 'ADJ')	61
# 2005_2009	('nuova', 'ADJ')	55
# 2005_2009	('naturale', 'ADJ')	53
# 2005_2009	('fresco', 'ADJ')	49
# 2005_2009	('grissin', 'ADJ')	49
#
# 2010_2014	('nuovo', 'ADJ')	96
# 2010_2014	('vero', 'ADJ')	29
# 2010_2014	('corri', 'ADJ')	28
# 2010_2014	('nuova', 'ADJ')	27
# 2010_2014	('grande', 'ADJ')	26
# 2010_2014	('medicinale', 'ADJ')	24
# 2010_2014	('primo', 'ADJ')	23
# 2010_2014	('bello', 'ADJ')	21
# 2010_2014	('buonissime', 'ADJ')	18
# 2010_2014	('pittarosso', 'ADJ')	17
#
# 2015_2019	('nuovo', 'ADJ')	82
# 2015_2019	('grande', 'ADJ')	41
# 2015_2019	('primo', 'ADJ')	32
# 2015_2019	('italiano', 'ADJ')	24
# 2015_2019	('dolce', 'ADJ')	23
# 2015_2019	('bello', 'ADJ')	20
# 2015_2019	('naturale', 'ADJ')	18
# 2015_2019	('migliore', 'ADJ')	18
# 2015_2019	('natale', 'ADJ')	18
# 2015_2019	('nuova', 'ADJ')	16
#
# 2020_2024	('nuovo', 'ADJ')	105
# 2020_2024	('italiano', 'ADJ')	42
# 2020_2024	('bello', 'ADJ')	33
# 2020_2024	('grande', 'ADJ')	33
# 2020_2024	('primo', 'ADJ')	30
# 2020_2024	('unico', 'ADJ')	23
# 2020_2024	('stesso', 'ADJ')	22
# 2020_2024	('sporco', 'ADJ')	21
# 2020_2024	('vero', 'ADJ')	20
# 2020_2024	('buono', 'ADJ')	20

# %%
#Print the top 10 NOUNS of every lustrum
spots_words = dict()
spots_noun=dict()
for key in dictionary:
     spots_words[key] = pos_tag_italian(dictionary[key])
for key in spots_words:
    if key not in spots_noun:
        spots_noun[key] = []
    for values in spots_words[key]:
        if 'NOUN' in values:  
            spots_noun[key].append(values)

# %%
vocabularies = dict()
for key in dictionary:
    vocabularies[key] = set(spots_noun[key])

frequencies = dict()
for key in dictionary:
    frequencies[key] = Counter(spots_noun[key])

top = 20
previous_key = None

for key in sorted(dictionary):
    if key != previous_key and previous_key is not None:
        print()
    previous_key = key
    words_top = sorted(frequencies[key].items(), key=lambda x: x[1], reverse=True)[:20]
    for word, frequency in words_top:
              print(key, word, frequency, sep='\t')
# Out:
# 1980_1984	('potere', 'NOUN')	81
# 1980_1984	('piacere', 'NOUN')	62
# 1980_1984	('sapore', 'NOUN')	49
# 1980_1984	('casa', 'NOUN')	46
# 1980_1984	('giorno', 'NOUN')	38
# 1980_1984	('caffè', 'NOUN')	37
# 1980_1984	('oro', 'NOUN')	35
# 1980_1984	('shampoo', 'NOUN')	35
# 1980_1984	('bambino', 'NOUN')	34
# 1980_1984	('colore', 'NOUN')	33
# 1980_1984	('cosa', 'NOUN')	31
# 1980_1984	('pelle', 'NOUN')	30
# 1980_1984	('qualità', 'NOUN')	29
# 1980_1984	('mondo', 'NOUN')	28
# 1980_1984	('piatto', 'NOUN')	26
# 1980_1984	('computer', 'NOUN')	26
# 1980_1984	('latte', 'NOUN')	25
# 1980_1984	('dovere', 'NOUN')	24
# 1980_1984	('birra', 'NOUN')	24
# 1980_1984	('cuore', 'NOUN')	24
#
# 1985_1989	('potere', 'NOUN')	278
# 1985_1989	('giorno', 'NOUN')	187
# 1985_1989	('piacere', 'NOUN')	168
# 1985_1989	('casa', 'NOUN')	151
# 1985_1989	('cosa', 'NOUN')	137
# 1985_1989	('caffè', 'NOUN')	124
# 1985_1989	('vita', 'NOUN')	112
# 1985_1989	('sapore', 'NOUN')	109
# 1985_1989	('colore', 'NOUN')	108
# 1985_1989	('cuore', 'NOUN')	94
# 1985_1989	('pelle', 'NOUN')	94
# 1985_1989	('forza', 'NOUN')	86
# 1985_1989	('mano', 'NOUN')	81
# 1985_1989	('mamma', 'NOUN')	80
# 1985_1989	('tempo', 'NOUN')	73
# 1985_1989	('profumo', 'NOUN')	71
# 1985_1989	('pipe', 'NOUN')	71
# 1985_1989	('latte', 'NOUN')	70
# 1985_1989	('acqua', 'NOUN')	69
# 1985_1989	('mondo', 'NOUN')	68
#
# 1990_1994	('potere', 'NOUN')	242
# 1990_1994	('giorno', 'NOUN')	179
# 1990_1994	('piacere', 'NOUN')	172
# 1990_1994	('casa', 'NOUN')	147
# 1990_1994	('cosa', 'NOUN')	113
# 1990_1994	('pelle', 'NOUN')	103
# 1990_1994	('vita', 'NOUN')	102
# 1990_1994	('mamma', 'NOUN')	98
# 1990_1994	('shampoo', 'NOUN')	96
# 1990_1994	('caffè', 'NOUN')	93
# 1990_1994	('sapore', 'NOUN')	90
# 1990_1994	('colore', 'NOUN')	87
# 1990_1994	('natura', 'NOUN')	86
# 1990_1994	('tempo', 'NOUN')	85
# 1990_1994	('latte', 'NOUN')	84
# 1990_1994	('mondo', 'NOUN')	79
# 1990_1994	('regalo', 'NOUN')	75
# 1990_1994	('anno', 'NOUN')	70
# 1990_1994	('mulino', 'NOUN')	69
# 1990_1994	('lira', 'NOUN')	68
#
# 1995_1999	('potere', 'NOUN')	99
# 1995_1999	('giorno', 'NOUN')	56
# 1995_1999	('casa', 'NOUN')	49
# 1995_1999	('piacere', 'NOUN')	49
# 1995_1999	('kinder', 'NOUN')	46
# 1995_1999	('latte', 'NOUN')	45
# 1995_1999	('mondo', 'NOUN')	36
# 1995_1999	('cosa', 'NOUN')	36
# 1995_1999	('mamma', 'NOUN')	34
# 1995_1999	('forza', 'NOUN')	33
# 1995_1999	('colore', 'NOUN')	32
# 1995_1999	('pelle', 'NOUN')	31
# 1995_1999	('vita', 'NOUN')	30
# 1995_1999	('freschezza', 'NOUN')	30
# 1995_1999	('lira', 'NOUN')	29
# 1995_1999	('novità', 'NOUN')	27
# 1995_1999	('qualità', 'NOUN')	25
# 1995_1999	('gel', 'NOUN')	22
# 1995_1999	('minuto', 'NOUN')	22
# 1995_1999	('anno', 'NOUN')	21
#
# 2000_2004	('potere', 'NOUN')	146
# 2000_2004	('danone', 'NOUN')	124
# 2000_2004	('giorno', 'NOUN')	82
# 2000_2004	('pelle', 'NOUN')	57
# 2000_2004	('piacere', 'NOUN')	56
# 2000_2004	('colore', 'NOUN')	52
# 2000_2004	('cosa', 'NOUN')	52
# 2000_2004	('latte', 'NOUN')	46
# 2000_2004	('tempo', 'NOUN')	44
# 2000_2004	('lira', 'NOUN')	44
# 2000_2004	('euro', 'NOUN')	43
# 2000_2004	('casa', 'NOUN')	42
# 2000_2004	('qualità', 'NOUN')	41
# 2000_2004	('numero', 'NOUN')	41
# 2000_2004	('anno', 'NOUN')	41
# 2000_2004	('sapore', 'NOUN')	40
# 2000_2004	('volta', 'NOUN')	40
# 2000_2004	('vita', 'NOUN')	40
# 2000_2004	('mondo', 'NOUN')	38
# 2000_2004	('gel', 'NOUN')	34
#
# 2005_2009	('euro', 'NOUN')	244
# 2005_2009	('potere', 'NOUN')	230
# 2005_2009	('giorno', 'NOUN')	126
# 2005_2009	('casa', 'NOUN')	80
# 2005_2009	('piacere', 'NOUN')	79
# 2005_2009	('vita', 'NOUN')	66
# 2005_2009	('anno', 'NOUN')	65
# 2005_2009	('mondo', 'NOUN')	64
# 2005_2009	('cosa', 'NOUN')	64
# 2005_2009	('volta', 'NOUN')	62
# 2005_2009	('latte', 'NOUN')	54
# 2005_2009	('pelle', 'NOUN')	50
# 2005_2009	('qualità', 'NOUN')	46
# 2005_2009	('numero', 'NOUN')	46
# 2005_2009	('tv', 'NOUN')	43
# 2005_2009	('comunità', 'NOUN')	41
# 2005_2009	('gioco', 'NOUN')	40
# 2005_2009	('mese', 'NOUN')	36
# 2005_2009	('prezzo', 'NOUN')	35
# 2005_2009	('dovere', 'NOUN')	34
#
# 2010_2014	('potere', 'NOUN')	88
# 2010_2014	('laqua', 'NOUN')	43
# 2010_2014	('euro', 'NOUN')	43
# 2010_2014	('piacere', 'NOUN')	28
# 2010_2014	('buco', 'NOUN')	27
# 2010_2014	('comunità', 'NOUN')	25
# 2010_2014	('effetto', 'NOUN')	25
# 2010_2014	('sottotitoli', 'NOUN')	24
# 2010_2014	('giorno', 'NOUN')	21
# 2010_2014	('casa', 'NOUN')	21
# 2010_2014	('volta', 'NOUN')	20
# 2010_2014	('vita', 'NOUN')	20
# 2010_2014	('mese', 'NOUN')	18
# 2010_2014	('cosa', 'NOUN')	18
# 2010_2014	('mondo', 'NOUN')	18
# 2010_2014	('scaloppina', 'NOUN')	18
# 2010_2014	('momento', 'NOUN')	17
# 2010_2014	('calcio', 'NOUN')	16
# 2010_2014	('qualità', 'NOUN')	16
# 2010_2014	('foglio', 'NOUN')	16
#
# 2015_2019	('potere', 'NOUN')	92
# 2015_2019	('euro', 'NOUN')	37
# 2015_2019	('giorno', 'NOUN')	26
# 2015_2019	('cosa', 'NOUN')	24
# 2015_2019	('casa', 'NOUN')	21
# 2015_2019	('dolore', 'NOUN')	20
# 2015_2019	('volta', 'NOUN')	18
# 2015_2019	('effetto', 'NOUN')	17
# 2015_2019	('mondo', 'NOUN')	16
# 2015_2019	('piacere', 'NOUN')	15
# 2015_2019	('minuto', 'NOUN')	15
# 2015_2019	('colore', 'NOUN')	15
# 2015_2019	('dovere', 'NOUN')	14
# 2015_2019	('vita', 'NOUN')	14
# 2015_2019	('pelle', 'NOUN')	14
# 2015_2019	('momento', 'NOUN')	13
# 2015_2019	('sintomo', 'NOUN')	13
# 2015_2019	('gioco', 'NOUN')	12
# 2015_2019	('olio', 'NOUN')	11
# 2015_2019	('sapore', 'NOUN')	11
#
# 2020_2024	('potere', 'NOUN')	97
# 2020_2024	('cosa', 'NOUN')	31
# 2020_2024	('mondo', 'NOUN')	30
# 2020_2024	('euro', 'NOUN')	27
# 2020_2024	('casa', 'NOUN')	25
# 2020_2024	('volta', 'NOUN')	24
# 2020_2024	('giorno', 'NOUN')	23
# 2020_2024	('gioco', 'NOUN')	23
# 2020_2024	('vita', 'NOUN')	23
# 2020_2024	('colore', 'NOUN')	21
# 2020_2024	('pelle', 'NOUN')	20
# 2020_2024	('anno', 'NOUN')	19
# 2020_2024	('momento', 'NOUN')	17
# 2020_2024	('piacere', 'NOUN')	17
# 2020_2024	('tv', 'NOUN')	16
# 2020_2024	('tempo', 'NOUN')	15
# 2020_2024	('modo', 'NOUN')	15
# 2020_2024	('ciclo', 'NOUN')	15
# 2020_2024	('dovere', 'NOUN')	14
# 2020_2024	('irritazione', 'NOUN')	14
